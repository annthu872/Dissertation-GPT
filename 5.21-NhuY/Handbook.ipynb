# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
SYSTEM_PROMPT_8="""
I want you to act as a software tester.
Your task is to read the test scenario's name and the corresponding use case specification to base on those information for generateing test steps for test cases and their following expected result.
Return the test cases in json format.
The JSON format should follow the following structure:
{
  "Test Case 1":[
    "testCaseName": "Clear name of the test case so tester know what to test when they first read",
    "objective": "Verify who doing what action or function in the test case and the summary of the final result of the test case",
    "testSteps": [
      "Step 1: Describe the step.",
      "Step 2: Describe the step.",
      "Step 3: Describe the step."
    ],
    "expectedResult": "You inform the tester what should they see after doing all the steps",
    "explanation": "Why do you create this test case? How does this test case related to the test scenario inputed?",
  ],
}
If there are more than one test case for this scenario, continue writing other test case in this form.

Rules for generating test steps:
- Describe the test step clearly to make sure each test case is independent, tester do not need to read other information (example: other test case, use case specification) to know how to do that step.
- Avoid references to other test cases or instructions like "do as mentioned."
- If the test case need to be repeated to test with different order, data or case, seperate them to be distinct test cases.
- If the scenario is about testing the displation and there is no flow directly cover that scenario, use only the basic (or main) flow to test it.
- If there are use cases mentioned in extended or included use case, create test case combine use cases, Try to find the connection point of use cases for combination. 
- For test scenarios mentioning navigation in the name, only produce test cases related to the specified navigation method. 
(Example: "Scenario: User navigates to a page by navbar", only produce a test case of user navigates to that page by navbar even though the use case description has many way to navigate to that page)
- For test scenarios not mentioning navigation in the name, do not include any navigation test cases.
- Generate test cases that directly match the scenario name. Choose only one flow to cover the scenario.
- Ensure all actions and objectives match the scenario name.
"""

# %%
prompt="""
Scenario: Successful Display of Vocabulary List

use case id: 
use case name: handbook
objective: This use case allows to see the vocabulary that learner has learned and setup the vocabulary review test.
actor: learner 
Preconditions:
Learner must be logged into the application.

basic flow:
Step 1: Learner selects the "Handbook" tab on the navigation bar.
Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
Step 3:Learners can scroll the scroll bar to see more vocabulary.

Alternative Flows:
Alternative flow 1: Learner search vocabulary in Handbook.
At step 3 of the basic flow: Learner presses the search bar.
Step 4: Learner enters the word to search.
Step 5: The system filters vocabulary containing characters entered by learners in the search bar.

Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
At step 3 of the basic flow: Learner presses the search bar.
Step 4: Learner enters a meaningless word to search.
Step 5: The system notifies that there are no suitable search results.

Alternative flow 3: Learner set up 1 word to not be review in the review daily test
At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
Step 4: the system mark that vocabulary will not appear in the daily test review.

Alternative flow 4: Learner set up 1 word to be review in the review daily test
At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
Step 4: the system mark that vocabulary will appear in the daily test review.

Postcondition: 
None
"""

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT_8},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Verify Display of Vocabulary List",
#     "objective": "Verify that the vocabulary list is successfully displayed with all required details when the learner selects the 'Handbook' tab.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar."
#     ],
#     "expectedResult": "The system displays the learner's vocabulary list in vertical rows, each word in a horizontal row showing the word name, word type, word meaning, memorization level, and a checkbox for review test inclusion.",
#     "explanation": "This test case ensures that the basic flow of displaying the vocabulary list as described in the use case is functioning correctly."
#   },
#   "Test Case 2": {
#     "testCaseName": "Verify Vocabulary Search Functionality",
#     "objective": "Verify that the learner can search for a specific vocabulary in the Handbook and the system filters the vocabulary list accordingly.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Press the search bar.",
#       "Step 4: Enter a specific word to search."
#     ],
#     "expectedResult": "The system filters vocabulary containing characters entered by the learner in the search bar and displays the relevant vocabulary.",
#     "explanation": "This test case checks the functionality of searching for a specific vocabulary within the Handbook, as described in the alternative flow 1."
#   },
#   "Test Case 3": {
#     "testCaseName": "Verify Search for Meaningless Vocabulary",
#     "objective": "Verify that searching for a meaningless word in the Handbook results in a notification of no suitable search results.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Press the search bar.",
#       "Step 4: Enter a meaningless word to search."
#     ],
#     "expectedResult": "The system notifies that there are no suitable search results for the entered meaningless word.",
#     "explanation": "This test case validates the system's response when a learner searches for a word that does not exist in the vocabulary list, as described in alternative flow 2."
#   },
#   "Test Case 4": {
#     "testCaseName": "Verify Setting a Word for Review Exclusion",
#     "objective": "Verify that the learner can exclude a word from appearing in the daily review test by unticking its checkbox.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Scroll to find a specific vocabulary word.",
#       "Step 4: Untick the checkbox of the vocabulary word."
#     ],
#     "expectedResult": "The system marks that the selected vocabulary will not appear in the daily test review.",
#     "explanation": "This test case ensures that learners can customize their review tests by excluding specific vocabulary words, as described in alternative flow 3."
#   },
#   "Test Case 5": {
#     "testCaseName": "Verify Setting a Word for Review Inclusion",
#     "objective": "Verify that the learner can include a word in the daily review test by ticking its checkbox.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Scroll to find a specific vocabulary word.",
#       "Step 4: Tick the checkbox of the vocabulary word."
#     ],
#     "expectedResult": "The system marks that the selected vocabulary will appear in the daily test review.",
#     "explanation": "This test case checks that learners can customize their review tests by including specific vocabulary words, as described in alternative flow 4."
#   }
# }

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT_8},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Verify Display of Vocabulary List",
#     "objective": "Verify that the vocabulary list is successfully displayed with all details as per the basic flow.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Observe the displayed list of vocabulary."
#     ],
#     "expectedResult": "The system should display the learner's vocabulary list in vertical rows, with each word in a horizontal row showing the word name, word type, word meaning, memorization level, and a checkbox for review test inclusion.",
#     "explanation": "This test case ensures that the basic flow of displaying the vocabulary list as described in the use case is functioning correctly."
#   },
#   "Test Case 2": {
#     "testCaseName": "Verify Vocabulary Search Functionality",
#     "objective": "Verify that the search functionality filters the vocabulary list based on the entered characters.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Press the search bar.",
#       "Step 4: Enter a known word into the search bar.",
#       "Step 5: Observe the filtered vocabulary list."
#     ],
#     "expectedResult": "The system should display only the vocabulary containing characters entered by the learner, filtering out the rest.",
#     "explanation": "This test case checks if the search functionality within the handbook use case works as expected, allowing learners to filter their vocabulary list."
#   },
#   "Test Case 3": {
#     "testCaseName": "Verify No Results for Meaningless Vocabulary Search",
#     "objective": "Ensure the system notifies the user when no suitable search results are found for a meaningless word search.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Press the search bar.",
#       "Step 4: Enter a meaningless word into the search bar.",
#       "Step 5: Observe the system's response."
#     ],
#     "expectedResult": "The system should notify that there are no suitable search results for the entered meaningless word.",
#     "explanation": "This test case verifies the system's ability to handle searches for words that do not exist in the vocabulary list, ensuring user feedback is provided."
#   },
#   "Test Case 4": {
#     "testCaseName": "Verify Setting a Word for Review Exclusion",
#     "objective": "Verify that learners can exclude a word from appearing in the daily review test by unchecking its checkbox.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Scroll to a word and untick its checkbox.",
#       "Step 4: Observe the system's response."
#     ],
#     "expectedResult": "The system should mark the vocabulary as excluded from appearing in the daily review test.",
#     "explanation": "This test case ensures that learners can customize their review tests by excluding specific vocabulary words, as described in the use case."
#   },
#   "Test Case 5": {
#     "testCaseName": "Verify Setting a Word for Review Inclusion",
#     "objective": "Ensure that learners can include a word in the daily review test by checking its checkbox.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Scroll to a word and tick its checkbox.",
#       "Step 4: Observe the system's response."
#     ],
#     "expectedResult": "The system should mark the vocabulary as included in the daily review test.",
#     "explanation": "This test case checks if learners can actively manage their review tests by including specific vocabulary words, aligning with the use case description."
#   }
# }

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT_8},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Successful Display of Vocabulary List",
#     "objective": "Verify that the vocabulary list is successfully displayed with all required details when the learner selects the 'Handbook' tab.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Observe the displayed list of vocabulary."
#     ],
#     "expectedResult": "The system displays the learner's vocabulary list in vertical rows, with each word in a horizontal row showing the word name, word type, word meaning, memorization level, and a checkbox for review test inclusion.",
#     "explanation": "This test case ensures that the basic flow of displaying the vocabulary list as described in the use case is functioning correctly."
#   },
#   "Test Case 2": {
#     "testCaseName": "Search Vocabulary in Handbook",
#     "objective": "Verify that the learner can successfully search for a vocabulary word in the Handbook.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner and navigate to the 'Handbook' tab.",
#       "Step 2: Press the search bar.",
#       "Step 3: Enter a known word into the search bar.",
#       "Step 4: Observe the filtered vocabulary list."
#     ],
#     "expectedResult": "The system filters and displays vocabulary containing characters entered by the learner in the search bar.",
#     "explanation": "This test case verifies the functionality of searching for a specific vocabulary in the Handbook, as described in the alternative flow 1."
#   },
#   "Test Case 3": {
#     "testCaseName": "Search for a Meaningless Vocabulary in Handbook",
#     "objective": "Verify that searching for a meaningless word in the Handbook results in a 'no suitable search results' notification.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner and navigate to the 'Handbook' tab.",
#       "Step 2: Press the search bar.",
#       "Step 3: Enter a meaningless word into the search bar.",
#       "Step 4: Observe the response from the system."
#     ],
#     "expectedResult": "The system notifies that there are no suitable search results for the meaningless word entered.",
#     "explanation": "This test case checks the system's response when a learner searches for a word that does not exist in the vocabulary list, as described in alternative flow 2."
#   },
#   "Test Case 4": {
#     "testCaseName": "Exclude a Word from Review Test",
#     "objective": "Verify that a learner can exclude a word from appearing in the daily review test by unticking its checkbox.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner and navigate to the 'Handbook' tab.",
#       "Step 2: Scroll to find a word to exclude from the review test.",
#       "Step 3: Untick the checkbox next to the chosen word.",
#       "Step 4: Observe the system's response."
#     ],
#     "expectedResult": "The system marks the vocabulary as excluded, indicating it will not appear in the daily review test.",
#     "explanation": "This test case ensures that learners can customize their review tests by excluding specific vocabulary words, as described in alternative flow 3."
#   },
#   "Test Case 5": {
#     "testCaseName": "Include a Word in Review Test",
#     "objective": "Verify that a learner can include a word in the daily review test by ticking its checkbox.",
#     "testSteps": [
#       "Step 1: Log into the application as a learner and navigate to the 'Handbook' tab.",
#       "Step 2: Scroll to find a word to include in the review test.",
#       "Step 3: Tick the checkbox next to the chosen word.",
#       "Step 4: Observe the system's response."
#     ],
#     "expectedResult": "The system marks the vocabulary as included, indicating it will appear in the daily review test.",
#     "explanation": "This test case verifies that learners can customize their review tests by including specific vocabulary words, as described in alternative flow 4."
#   }
# }

# %%
prompt="""
Scenario: Scroll Through Vocabulary List

use case id: 
use case name: handbook
objective: This use case allows to see the vocabulary that learner has learned and setup the vocabulary review test.
actor: learner 
Preconditions:
Learner must be logged into the application.

basic flow:
Step 1: Learner selects the "Handbook" tab on the navigation bar.
Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
Step 3:Learners can scroll the scroll bar to see more vocabulary.

Alternative Flows:
Alternative flow 1: Learner search vocabulary in Handbook.
At step 3 of the basic flow: Learner presses the search bar.
Step 4: Learner enters the word to search.
Step 5: The system filters vocabulary containing characters entered by learners in the search bar.

Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
At step 3 of the basic flow: Learner presses the search bar.
Step 4: Learner enters a meaningless word to search.
Step 5: The system notifies that there are no suitable search results.

Alternative flow 3: Learner set up 1 word to not be review in the review daily test
At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
Step 4: the system mark that vocabulary will not appear in the daily test review.

Alternative flow 4: Learner set up 1 word to be review in the review daily test
At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
Step 4: the system mark that vocabulary will appear in the daily test review.

Postcondition: 
None
"""

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT_8},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Scroll Through Vocabulary List",
#     "objective": "Verify that the learner can scroll through the vocabulary list in the Handbook tab.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Observe the displayed list of vocabulary.",
#       "Step 4: Use the scroll bar to scroll through the list of vocabulary."
#     ],
#     "expectedResult": "The learner should be able to scroll through the entire list of vocabulary, viewing more vocabulary items that were not initially visible on the screen.",
#     "explanation": "This test case ensures that learners can scroll through their vocabulary list in the Handbook tab, which is a basic functionality for users to review their learned vocabulary."
#   },
#   "Test Case 2": {
#     "testCaseName": "Scroll Through Vocabulary List After Search",
#     "objective": "Verify that the learner can scroll through the filtered vocabulary list after performing a search in the Handbook tab.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Press the search bar and enter a word to search.",
#       "Step 4: Observe the filtered list of vocabulary.",
#       "Step 5: Use the scroll bar to scroll through the filtered list of vocabulary."
#     ],
#     "expectedResult": "The learner should be able to scroll through the filtered list of vocabulary, viewing more vocabulary items that match the search criteria and were not initially visible on the screen.",
#     "explanation": "This test case verifies that learners can still scroll through their vocabulary list after applying a search filter, which is important for efficiently navigating through search results."
#   }
# }

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT_8},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Scroll Through Vocabulary List",
#     "objective": "Verify that the learner can scroll through the vocabulary list in the Handbook tab.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Observe the displayed list of vocabulary.",
#       "Step 4: Use the scroll bar to scroll through the list of vocabulary."
#     ],
#     "expectedResult": "The learner should be able to scroll through the entire list of vocabulary, viewing more vocabulary items that were not initially visible.",
#     "explanation": "This test case ensures that learners can effectively scroll through their vocabulary list in the Handbook, allowing them to review all words they have learned."
#   }
# }

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT_8},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Scroll Through Vocabulary List",
#     "objective": "Verify that the learner can scroll through the vocabulary list in the Handbook tab.",
#     "testSteps": [
#       "Step 1: Log into the application with a learner account.",
#       "Step 2: Select the 'Handbook' tab on the navigation bar.",
#       "Step 3: Observe the list of vocabulary displayed.",
#       "Step 4: Scroll down the scroll bar to see more vocabulary."
#     ],
#     "expectedResult": "The learner should be able to scroll through the list and see more vocabulary beyond what is initially displayed on the screen.",
#     "explanation": "This test case ensures that learners can scroll through their vocabulary list in the Handbook tab, which is a basic functionality for reviewing learned vocabulary."
#   }
# }
