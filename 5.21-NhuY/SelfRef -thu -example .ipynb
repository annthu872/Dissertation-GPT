# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
SYSTEM_PROMPT="""
Given a test scenario and test cases to test that given test scenario.
Mark if test case can test the given test scenario or not through test steps, expected output, objective (although if it test other use case path or flow, if it is not used to test the given test scenario.)
And give explanation why you think the resulted test case reflect the given test scenario or not. 
Your response should keep the format of the inserted test cases.
The JSON format should follow the following structure:
{
  "Test Case 1":[
    "testCaseName": "Clear name of the test case so tester know what to test when they first read",
    "objective": "Verify who doing what action or function in the test case and the summary of the final result of the test case",
    "testSteps": [
      "Step 1: Describe the step.",
      "Step 2: Describe the step.",
      "Step 3: Describe the step."
    ],
    "expectedResult": "You inform the tester what should they see after doing all the steps",
    "reflect": "yes/no",
    "explanation": "explain why you think this test case reflect the given test scenario or not",
  ],
}
"""

# %%
prompt = """
Scenario: Navigation Away Through Menu Selection Before Submission
{
  "Test Case 1": {
    "testCaseName": "Navigation Away Through Menu Selection Before Submission - Cancel Operation",
    "objective": "Verify that navigating away through menu selection before submission cancels the operation and does not save data",
    "testSteps": [
      "Step 1: Navigate to the author list page.",
      "Step 2: Click the 'Create new' button to start adding a new author.",
      "Step 3: Start entering the author's details into the form fields without submitting.",
      "Step 4: Select the menu item 'Books' before pressing the 'Submit' button."
    ],
    "expectedResult": "The data is not saved to the database, and the Books page is displayed with updated data."
  },
  "Test Case 2": {
    "testCaseName": "Navigation Away Through Menu Selection Before Submission - Cancel Operation to Genres",
    "objective": "Verify that navigating away to 'Genres' through menu selection before submission cancels the operation and does not save data",
    "testSteps": [
      "Step 1: Navigate to the author list page.",
      "Step 2: Click the 'Create new' button to start adding a new author.",
      "Step 3: Start entering the author's details into the form fields without submitting.",
      "Step 4: Select the menu item 'Genres' before pressing the 'Submit' button."
    ],
    "expectedResult": "The data is not saved to the database, and the Genres page is displayed with updated data."
  },
  "Test Case 3": {
    "testCaseName": "Navigation Away Through Menu Selection Before Submission - Cancel Operation to Authors",
    "objective": "Verify that navigating away to 'Authors' through menu selection before submission cancels the operation and does not save data",
    "testSteps": [
      "Step 1: Navigate to the author list page.",
      "Step 2: Click the 'Create new' button to start adding a new author.",
      "Step 3: Start entering the author's details into the form fields without submitting.",
      "Step 4: Select the menu item 'Authors' before pressing the 'Submit' button."
    ],
    "expectedResult": "The data is not saved to the database, and the Authors page is displayed with updated data."
  },
  "Test Case 4": {
    "testCaseName": "Navigation Away Through Menu Selection Before Submission - Cancel Operation to Home",
    "objective": "Verify that navigating away to 'Home' through menu selection before submission cancels the operation and does not save data",
    "testSteps": [
      "Step 1: Navigate to the author list page.",
      "Step 2: Click the 'Create new' button to start adding a new author.",
      "Step 3: Start entering the author's details into the form fields without submitting.",
      "Step 4: Select the menu item 'Home' before pressing the 'Submit' button."
    ],
    "expectedResult": "The data is not saved to the database, and the Home page is displayed with updated data."
  },
  "Test Case 5": {
    "testCaseName": "Navigation Away Through Menu Selection Before Submission - Cancel Operation to API",
    "objective": "Verify that navigating away to 'API' through menu selection before submission cancels the operation and does not save data",
    "testSteps": [
      "Step 1: Navigate to the author list page.",
      "Step 2: Click the 'Create new' button to start adding a new author.",
      "Step 3: Start entering the author's details into the form fields without submitting.",
      "Step 4: Select the menu item 'API' before pressing the 'Submit' button."
    ],
    "expectedResult": "The data is not saved to the database, and the API page is displayed with updated data."
  }
}
"""

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Navigation Away Through Menu Selection Before Submission - Cancel Operation",
#     "objective": "Verify that navigating away through menu selection before submission cancels the operation and does not save data",
#     "testSteps": [
#       "Step 1: Navigate to the author list page.",
#       "Step 2: Click the 'Create new' button to start adding a new author.",
#       "Step 3: Start entering the author's details into the form fields without submitting.",
#       "Step 4: Select the menu item 'Books' before pressing the 'Submit' button."
#     ],
#     "expectedResult": "The data is not saved to the database, and the Books page is displayed with updated data.",
#     "reflect": "yes",
#     "explanation": "This test case directly reflects the given test scenario by verifying that navigating away through menu selection before submission cancels the operation and does not save data."
#   },
#   "Test Case 2": {
# ...

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Navigation Away Through Menu Selection Before Submission - Cancel Operation",
#     "objective": "Verify that navigating away through menu selection before submission cancels the operation and does not save data",
#     "testSteps": [
#       "Step 1: Navigate to the author list page.",
#       "Step 2: Click the 'Create new' button to start adding a new author.",
#       "Step 3: Start entering the author's details into the form fields without submitting.",
#       "Step 4: Select the menu item 'Books' before pressing the 'Submit' button."
#     ],
#     "expectedResult": "The data is not saved to the database, and the Books page is displayed with updated data.",
#     "reflect": "yes",
#     "explanation": "This test case directly tests the scenario by attempting to navigate away before submission and checks if the data is not saved, which is the core of the given scenario."
#   },
#   "Test Case 2": {
# ...

# %%
promptTestCase = [
    { "role": "system", "content": SYSTEM_PROMPT},
    { "role": "user", "content": prompt}
  ]
gpt_response = ask(promptTestCase, client, model)
print(gpt_response)
# Out:
# {
#   "Test Case 1": {
#     "testCaseName": "Navigation Away Through Menu Selection Before Submission - Cancel Operation",
#     "objective": "Verify that navigating away through menu selection before submission cancels the operation and does not save data",
#     "testSteps": [
#       "Step 1: Navigate to the author list page.",
#       "Step 2: Click the 'Create new' button to start adding a new author.",
#       "Step 3: Start entering the author's details into the form fields without submitting.",
#       "Step 4: Select the menu item 'Books' before pressing the 'Submit' button."
#     ],
#     "expectedResult": "The data is not saved to the database, and the Books page is displayed with updated data.",
#     "reflect": "yes",
#     "explanation": "This test case directly reflects the given test scenario by verifying that navigating away through menu selection before submission cancels the operation and does not save data."
#   },
#   "Test Case 2": {
# ...
