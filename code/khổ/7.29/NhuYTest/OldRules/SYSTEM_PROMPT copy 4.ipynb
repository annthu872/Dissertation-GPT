# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
    )

    return response.choices[0].message.content

def askJSON(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
import chardet

def read_file_content(file_path):
    # Detect the encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        return content
    except FileNotFoundError:
        return f"Error: The file at path {file_path} was not found."
    except UnicodeDecodeError:
        return f"Error: The file at path {file_path} cannot be decoded with the {encoding} encoding."
    except IOError:
        return f"Error: An I/O error occurred while reading the file at path {file_path}."

# %%
def write_string_to_file(filename, content):
    try:
        with open(filename, 'w') as file:
            file.write(content)
        print(f"String has been written to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# %%
SYSTEM_PROMPT = """
Based on the provided use case specification, please generate a set of test scenarios to thoroughly test the functionality described in the use case.
Your task is to generate suitable test scenarios that cover all the flows and test the boundaries of conditions, if possible. Each scenario should clearly and specifically describe the situation to be tested.
Please ensure that your test scenarios cover both the main flow and any alternate flows mentioned in the use case specification. Also, consider potential exception flows to address errors, failures, or unexpected events that could occur during the execution of the use case and encompass negative test scenarios (including edge cases and invalid inputs), and unexpected user behaviors.
Keep in mind the agile nature of the application and prioritize scenarios that align closely with the given use case specification and the application's requirements.
Return the list of test scenarios name to test the use case

Rules to predict scenarios:
- Stay close to the details described in the flow.
- Focus on important and likely scenarios, important scenario is the scenario that users are more likely to encounter it. 
- Minimize the appearance of rare scenarios. 
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- Do not generate scenarios with user analysis. (Example: User accidentally do A and user intentionally do A is the same scenario, so do not consider about "accidentally" or "intentionally" in scenario)
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- Do not arbitrarily create additional test scenarios to test cases that not mention in the use case flow.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

# %%
usecase_path = r"C:\Users\congc\Desktop\GPT\Dissertation-GPT\dataset\SpecificationData\Book(Github)"
# save_path = r"D:\Dissertation-GPT\evaluate\prove\Matcha\ts"

# %%
usecase_name_list = []
project_name = os.path.basename(usecase_path)

# %%
for filename in os.listdir(usecase_path):
    usecase_name_list.append (filename.split(".txt")[0])
print(usecase_name_list)
# usecase_name_list=["AddQuestion "]
# Out:
# ['Add a new author', 'Add a new book', 'Add a new genre', 'Display author details', 'Display book details', 'Display genre details', 'Display the list of authors', 'Display the list of books', 'Display the list of genres', 'Edit the author', 'Edit the book', 'Edit the genre', 'Remove the author', 'Remove the book', 'Remove the genre']

# %%
for usecase_name in usecase_name_list:
    print(usecase_name)
    usecase_directlink = os.path.join(usecase_path,usecase_name+".txt")
    prompt_all = read_file_content(usecase_directlink)
    promptSYSTEM_PROMPT = [
        { "role": "system", "content": SYSTEM_PROMPT},
        { "role": "user", "content": prompt_all}
    ]
    gpt_response = ask(promptSYSTEM_PROMPT, client, model)    
    print("gpt_response \n" +gpt_response)
    # write_string_to_file(os.path.join(save_path,f"{usecase_name}.txt"), gpt_response)
# Out:
# Add a new author
# gpt_response
# 1. Successful author creation
# 2. Incorrect data entry
# 3. Database error during author creation
# 4. Cancel author creation before data submission
# 5. Navigation away from author creation form before submission
# Add a new book
# gpt_response
# 1. Successful book creation
# 2. Book creation with incorrect data
# 3. Book creation with database error
# 4. Cancel book creation before submitting
# 5. Navigate away from book creation form before submitting
# Add a new genre
# gpt_response
# 1. Successful Genre Creation
# 2. Genre Creation with Incorrect Data
# 3. Genre Creation with Database Error
# 4. Cancel Genre Creation Before Submitting
# 5. Navigate Away Before Submitting Genre Data
# Display author details
# gpt_response
# 1. DisplayAuthorDetails_SuccessScenario
# Display book details
# gpt_response
# 1. Display Book Details - Successful Display
# Display genre details
# gpt_response
# 1. Display Genre Details - Successful Display
# Display the list of authors
# gpt_response
# 1. Display first page of authors list
# 2. Navigate to the next page of authors list
# 3. Navigate to a specific page of authors list through pagination
# 4. Display authors list with exactly 10 authors
# 5. Display authors list with less than 10 authors on the last page
# 6. Display empty authors list
# Display the list of books
# gpt_response
# 1. Display initial list of books
# 2. Navigate to next page of books
# 3. Navigate to a specific page of books
# 4. Filter books by date range
# 5. Display books with no records matching date filter
# 6. Navigate through pages after applying date filter
# Display the list of genres
# gpt_response
# 1. Display initial list of genres
# 2. Navigate to next page of genres
# 3. Navigate to a specific page of genres
# 4. Display genres list with less than 10 items on the last page
# Edit the author
# gpt_response
# 1. Successful Author Record Update
# 2. Update Author Record with Incorrect Data
# 3. Update Author Record with Error Occurring
# 4. Cancel Update Operation Before Submitting
# 5. Navigate Away Using Menu Before Submitting Update
# Edit the book
# gpt_response
# 1. Successful book record update
# 2. Update book record with incorrect data
# 3. Update book record with error during save
# 4. Cancel book update operation via Cancel button
# 5. Cancel book update operation via navigation menu
# Edit the genre
# gpt_response
# 1. Successful Genre Update
# 2. Update Genre With Incorrect Data
# 3. Update Genre Operation Cancelled
# 4. Update Genre With Navigation Away Through Menu Selection
# Remove the author
# gpt_response
# 1. Successful Author Deletion
# 2. Cancel Author Deletion
# 3. Navigate Away Without Deletion via Menu Selection
# Remove the book
# gpt_response
# 1. Successful Book Deletion
# 2. Cancel Book Deletion
# 3. Navigate Away Without Deletion Through Menu Selection
# Remove the genre
# gpt_response
# 1. Successful Genre Deletion
# 2. Cancel Genre Deletion
# 3. Navigate Away Without Deletion Through Menu Selection

# %%
for usecase_name in usecase_name_list:
    print(usecase_name)
    usecase_directlink = os.path.join(usecase_path,usecase_name+".txt")
    prompt_all = read_file_content(usecase_directlink)
    promptSYSTEM_PROMPT = [
        { "role": "system", "content": SYSTEM_PROMPT},
        { "role": "user", "content": prompt_all}
    ]
    gpt_response = ask(promptSYSTEM_PROMPT, client, model)    
    print("gpt_response \n" +gpt_response)
    # write_string_to_file(os.path.join(save_path,f"{usecase_name}.txt"), gpt_response)
# Out:
# Add a new author
# gpt_response
# 1. Successful author creation
# 2. Incorrect data entry
# 3. Database error during author creation
# 4. Cancel author creation before submitting
# 5. Navigate away before submitting author data
# Add a new book
# gpt_response
# 1. Successful book creation
# 2. Book creation with incorrect data
# 3. Book creation with database error
# 4. Cancel book creation before submitting
# 5. Navigate away from book creation form before submitting
# Add a new genre
# gpt_response
# 1. Successful Genre Creation
# 2. Genre Creation with Incorrect Data
# 3. Genre Creation with Database Error
# 4. Cancel Genre Creation Before Submit
# 5. Navigate Away Before Submit Without Saving
# Display author details
# gpt_response
# 1. DisplayAuthorDetails_SuccessScenario
# Display book details
# gpt_response
# 1. Display Book Details - Successful Display
# Display genre details
# gpt_response
# 1. DisplayGenreDetails_SuccessScenario
# Display the list of authors
# gpt_response
# 1. Display first page of authors list
# 2. Navigate to next page of authors list
# 3. Navigate to a specific page of authors list using page number
# 4. Display authors list with less than 10 items on the last page
# 5. Display empty authors list when no authors are available
# Display the list of books
# gpt_response
# 1. Display initial list of books
# 2. Navigate to next page of books
# 3. Navigate to a specific page of books
# 4. Filter books by date range
# 5. Display books with no records matching date filter
# 6. Navigate through filtered book results
# Display the list of genres
# gpt_response
# 1. Display initial list of genres
# 2. Navigate to next page of genres
# 3. Navigate to a specific page of genres
# 4. Display with no genres available
# Edit the author
# gpt_response
# 1. Successful Author Update
# 2. Update Author with Incorrect Data
# 3. Update Author Operation Canceled
# 4. Update Author and Navigate Away Using Menu
# Edit the book
# gpt_response
# 1. Successful book record update
# 2. Update book record with incorrect data
# 3. Update book record with error during save
# 4. Cancel book record update before submission
# 5. Navigate away from edit page before submitting changes
# Edit the genre
# gpt_response
# 1. Successful Genre Update
# 2. Update Genre with Incorrect Data
# 3. Update Genre Operation Canceled
# 4. Update Genre and Navigate Away Using Menu
# Remove the author
# gpt_response
# 1. Successful author deletion
# 2. Cancel author deletion operation
# 3. Navigate away without deletion via menu selection
# Remove the book
# gpt_response
# 1. Successful Book Deletion
# 2. Cancel Book Deletion
# 3. Navigate Away Without Deletion Through Menu Selection
# Remove the genre
# gpt_response
# 1. Successful genre deletion
# 2. Cancel genre deletion
# 3. Navigate away without deletion via menu selection
