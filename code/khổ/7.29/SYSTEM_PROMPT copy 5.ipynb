# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
    )

    return response.choices[0].message.content

def askJSON(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
import chardet

def read_file_content(file_path):
    # Detect the encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        return content
    except FileNotFoundError:
        return f"Error: The file at path {file_path} was not found."
    except UnicodeDecodeError:
        return f"Error: The file at path {file_path} cannot be decoded with the {encoding} encoding."
    except IOError:
        return f"Error: An I/O error occurred while reading the file at path {file_path}."

# %%
def write_string_to_file(filename, content):
    try:
        with open(filename, 'w') as file:
            file.write(content)
        print(f"String has been written to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# %%
SYSTEM_PROMPT = """
Based on the provided use case specification, please generate a set of test scenarios to thoroughly test the functionality described in the use case.
Your task is to generate suitable test scenarios that cover all the flows and test the boundaries of conditions, if possible. Each scenario should clearly and specifically describe the situation to be tested.
Please ensure that your test scenarios cover both the main flow and any alternate flows mentioned in the use case specification. Also, consider potential exception flows to address errors, failures, or unexpected events that could occur during the execution of the use case and encompass negative test scenarios (including edge cases and invalid inputs), and unexpected user behaviors.
Keep in mind the agile nature of the application and prioritize scenarios that align closely with the given use case specification and the application's requirements.
Return the list of test scenarios name to test the use case
Rules to predict scenarios:
- Stay close to the details described in the flow.
- Focus on important and likely scenarios, important scenario is the scenario that users are more likely to encounter it. 
- Minimize the appearance of rare scenarios. 
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- Do not generate scenarios with user analysis. (Example: User accidentally do A and user intentionally do A is the same scenario, so do not consider about "accidentally" or "intentionally" in scenario)
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- Do not arbitrarily create additional test scenarios to test cases that not mention in the use case flow.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

# %%
usecase_path = r"D:\Dissertation-GPT\dataset\SpecificationData\MatchaEnglishWebsite"
# save_path = r"D:\Dissertation-GPT\evaluate\prove\Matcha\ts"

# %%
usecase_name_list = []
project_name = os.path.basename(usecase_path)

# %%
for filename in os.listdir(usecase_path):
    usecase_name_list.append (filename.split(".txt")[0])
print(usecase_name_list)
# usecase_name_list=["Handbook"]
# Out:
# ['Add new topic', 'AddLesson', 'AddQuestion ', 'EditTest', 'Flashcard', 'Handbook', 'Learning days history', 'ListenToPronunciation', 'Login', 'Registry', 'Review test', 'WordSortingTest']

# %%
for usecase_name in usecase_name_list:
    print(usecase_name)
    usecase_directlink = os.path.join(usecase_path,usecase_name+".txt")
    prompt_all = read_file_content(usecase_directlink)
    promptSYSTEM_PROMPT = [
        { "role": "system", "content": SYSTEM_PROMPT},
        { "role": "user", "content": prompt_all}
    ]
    gpt_response = ask(promptSYSTEM_PROMPT, client, model)    
    print("gpt_response \n" +gpt_response)

    prompt_all = read_file_content(usecase_directlink)
    promptSYSTEM_PROMPT = [
        { "role": "system", "content": SYSTEM_PROMPT},
        { "role": "user", "content": prompt_all}
    ]
    gpt_response = ask(promptSYSTEM_PROMPT, client, model)    
    print("gpt_response \n" +gpt_response)

    prompt_all = read_file_content(usecase_directlink)
    promptSYSTEM_PROMPT = [
        { "role": "system", "content": SYSTEM_PROMPT},
        { "role": "user", "content": prompt_all}
    ]
    gpt_response = ask(promptSYSTEM_PROMPT, client, model)    
    print("gpt_response \n" +gpt_response)
    # write_string_to_file(os.path.join(save_path,f"{usecase_name}.txt"), gpt_response)
# Out:
# Add new topic
# gpt_response
# 1. Successful Topic Addition
# 2. Adding Topic with Already Used Name
# 3. Cancel Topic Addition
# gpt_response
# 1. Successful topic addition
# 2. Adding topic with already used name and then correcting it
# 3. Canceling topic addition
# gpt_response
# 1. Successful topic addition
# 2. Adding topic with already used name
# 3. Cancel topic addition
# AddLesson
# gpt_response
# 1. Successful New Lesson Addition
# 2. Adding Lesson with Already Used Name
# 3. Cancel Adding New Lesson
# 4. Navigate to Add New Lesson Page Directly from Navbar
# gpt_response
# 1. Successful new lesson addition
# 2. Adding a lesson with an already used name
# 3. Canceling lesson addition
# 4. Navigating to Add new lesson page via navbar option
# gpt_response
# 1. Successfully adding a new lesson
# 2. Adding a lesson with an already used name
# 3. Cancel adding a new lesson
# 4. Navigate to Add new lesson page via navbar option
# AddQuestion
# gpt_response
# 1. Create a question for the selection test with valid inputs
# 2. Access Lesson Management page from Homepage
# 3. Skip compulsory field "sentence" and attempt to save
# 4. Skip compulsory field "correct answer" and attempt to save
# 5. Skip compulsory field "other option 1" and attempt to save
# 6. Skip compulsory field "other option 2" and attempt to save
# 7. Skip compulsory field "other option 3" and attempt to save
# 8. Cancel question creation and choose to stay
# 9. Enter invalid sentence and attempt to save
# 10. Leave page without saving by using browser back button
# 11. Cancel question creation and confirm to cancel
# gpt_response
# 1. Create question with all valid inputs
# 2. Access Lesson Management from Homepage
# 3. Skip compulsory field "sentence" and attempt to save
# 4. Skip compulsory field "correct answer" and attempt to save
# 5. Skip compulsory field "other option 1" and attempt to save
# 6. Skip compulsory field "other option 2" and attempt to save
# 7. Skip compulsory field "other option 3" and attempt to save
# 8. Cancel question creation and choose to stay
# 9. Enter invalid sentence and attempt to save
# 10. Leave by browser back button without saving
# 11. Cancel question creation and confirm to cancel
# gpt_response
# 1. Create question with valid inputs
# 2. Access Lesson Management from Homepage
# 3. Skip compulsory field "sentence"
# 4. Skip compulsory field "correct answer"
# 5. Skip compulsory field "other option 1"
# 6. Skip compulsory field "other option 2"
# 7. Skip compulsory field "other option 3"
# 8. Cancel question creation and choose to stay
# 9. Enter invalid sentence
# 10. Leave page without saving question
# 11. Cancel question creation and confirm cancellation
# EditTest
# gpt_response
# 1. Successful Test Editing and Saving
# 2. Exiting Edit Mode and Saving Changes
# 3. Exiting Edit Mode and Discarding Changes
# gpt_response
# 1. Successful Test Editing and Saving
# 2. Exit Editing Mode and Save Changes
# 3. Exit Editing Mode and Discard Changes
# gpt_response
# 1. Successful Test Editing and Saving
# 2. Exiting and Saving Changes via Pop-Up
# 3. Exiting and Discarding Changes via Pop-Up
# Flashcard
# gpt_response
# 1. Successful navigation through flashcards and completion of a topic
# 2. Navigation to previous flashcard when on the first card
# 3. Pressing 'back' button and choosing to stay during flashcard study
# 4. Pressing 'back' button and choosing to exit during flashcard study
# 5. Continuing study from the 'completion notification' page
# 6. Continuing study from an incomplete topic displayed on the home page
# gpt_response
# 1. Successful navigation and study of flashcards
# 2. Navigation using 'Next' and 'Previous' buttons through flashcards
# 3. Completion of flashcard study and returning to lesson page
# 4. Continuing study after pressing 'continue studying'
# 5. Handling of 'back' button press with 'stay' selection during flashcard study
# 6. Handling of 'back' button press with 'exit' selection during flashcard study
# 7. Attempt to click 'Previous' button on the first flashcard
# gpt_response
# 1. Successful navigation and study of flashcards
# 2. Navigation using 'Next' and 'Previous' buttons through flashcards
# 3. Completion of flashcard study and redirection to congratulatory message
# 4. Returning to the lesson page after completing flashcard study
# 5. Continuing study after pressing 'back' button and selecting 'stay'
# 6. Continuing study of next topic after selecting 'continue studying'
# 7. Resuming study from an incomplete topic displayed on the home page
# 8. Attempt to click 'Previous' button on the first flashcard
# 9. Exiting flashcard study by pressing 'back' button and selecting 'exit'
# Handbook
# gpt_response
# 1. View Vocabulary List in Handbook
# 2. Search Vocabulary in Handbook
# 3. Search Meaningless Vocabulary in Handbook
# 4. Exclude Vocabulary from Daily Review Test
# 5. Include Vocabulary in Daily Review Test
# gpt_response
# 1. View Vocabulary List
# 2. Scroll Vocabulary List
# 3. Search Vocabulary Successfully
# 4. Search Meaningless Vocabulary
# 5. Exclude Vocabulary from Review Test
# 6. Include Vocabulary in Review Test
# gpt_response
# 1. View Vocabulary List in Handbook
# 2. Search Vocabulary in Handbook
# 3. Search Meaningless Vocabulary in Handbook
# 4. Exclude Vocabulary from Daily Review Test
# 5. Include Vocabulary in Daily Review Test
# Learning days history
# gpt_response
# 1. View Continuous Learning Days History
# 2. View Learning Days History After Chain Break
# gpt_response
# 1. View Continuous Learning Days History
# 2. View Learning Days History After Break in Learning Chain
# gpt_response
# 1. View Continuous Learning Days History
# 2. View Learning Days History After Break in Learning Chain
# ListenToPronunciation
# gpt_response
# 1. Successful Pronunciation Test Completion
# 2. Incorrect Answer Selection
# gpt_response
# 1. Successful pronunciation test attempt
# 2. Unsuccessful pronunciation test attempt
# gpt_response
# 1. Successful Pronunciation Test Completion
# 2. Incorrect Answer Selection
# Login
# gpt_response
# 1. Successful login with username
# 2. Successful login with email
# 3. Login with wrong password
# 4. Login with unregistered username
# 5. Login with blank username field
# 6. Login with blank password field
# gpt_response
# 1. Successful login with username
# 2. Successful login with email
# 3. Login with wrong password
# 4. Login with unregistered username
# 5. Login with blank username field
# 6. Login with blank password field
# gpt_response
# 1. Successful login with username
# 2. Successful login with email
# 3. Login with wrong password
# 4. Login with unregistered username
# 5. Login with blank username field
# 6. Login with blank password field
# Registry
# gpt_response
# 1. Successful registration with valid username and password
# 2. Successful registration with email
# 3. Registration with invalid username
# 4. Registration with invalid password
# 5. Registration with password same as username
# 6. Registration with an existed username
# 7. Registration with invalid email
# gpt_response
# 1. Successful registration with valid username and password
# 2. Successful registration with email
# 3. Registration with invalid username
# 4. Registration with invalid password
# 5. Registration with password same as username
# 6. Registration with an existed username
# 7. Registration with invalid email
# 8. Registration with username below minimum length
# 9. Registration with username above maximum length
# 10. Registration with password below minimum length
# 11. Registration with password above maximum length
# 12. Registration with password missing a normal character
# 13. Registration with password missing a capitalized character
# 14. Registration with password missing a number
# 15. Registration with password missing a special character
# gpt_response
# 1. Successful registration with valid username and password
# 2. Successful registration with email
# 3. Registration with invalid username
# 4. Registration with invalid password
# 5. Registration with an existed username
# 6. Registration with invalid email
# Review test
# gpt_response
# 1. Complete Review Successfully
# 2. Choose Wrong Answer During Review
# 3. Finish Review and Return to Home Page
# 4. Press Exit and Choose to Stay
# 5. Press Exit and Confirm to Exit
# gpt_response
# 1. Successful review completion with correct answers
# 2. Review completion with incorrect answers
# 3. Review completion and return to Home page after the last word
# 4. Exiting review and choosing to stay
# 5. Exiting review and choosing to confirm exit
# gpt_response
# 1. Successful Review Completion with Correct Answers
# 2. Review Completion with Incorrect Answers
# 3. Review Process Exit and Return to Home Without Saving
# 4. Review Process Interruption with Exit and Stay Decision
# 5. Completion of Review and Automatic Return to Home Page with Save
# WordSortingTest
# gpt_response
# 1. Successful Word Sorting Test with Correct Answer
# 2. Word Sorting Test with Incorrect Answer
# gpt_response
# 1. Successful Word Sorting Test with Correct Answer
# 2. Word Sorting Test with Incorrect Answer
# gpt_response
# 1. Successful Word Sorting Test with Correct Answer
# 2. Word Sorting Test with Incorrect Answer
