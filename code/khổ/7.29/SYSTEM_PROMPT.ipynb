# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
    )

    return response.choices[0].message.content

def askJSON(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
import chardet

def read_file_content(file_path):
    # Detect the encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        return content
    except FileNotFoundError:
        return f"Error: The file at path {file_path} was not found."
    except UnicodeDecodeError:
        return f"Error: The file at path {file_path} cannot be decoded with the {encoding} encoding."
    except IOError:
        return f"Error: An I/O error occurred while reading the file at path {file_path}."

# %%
def write_string_to_file(filename, content):
    try:
        with open(filename, 'w') as file:
            file.write(content)
        print(f"String has been written to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# %%
SYSTEM_PROMPT = """
Based on the provided use case specification, please generate a set of test scenarios to thoroughly test the functionality described in the use case.
Your task is to generate suitable test scenarios that cover all the flows and test the boundaries of conditions, if possible. Each scenario should clearly and specifically describe the situation to be tested.
Example for condition: "a valid username must be over 8 characters and below 30 characters." When you meets something like this, make sure to treat each condition as a negative scenario seperately. That means you will have two negative scenario: invalid username with lower than 8 characters and invalid username with higher than 30 characters. 
Return the list of test scenarios name to test the use case
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

# Please ensure that your test scenarios cover both the main flow and any alternate flows mentioned in the use case specification. Also, consider potential exception flows to address errors, failures, or unexpected events that could occur during the execution of the use case and encompass negative test scenarios (including edge cases and invalid inputs), and unexpected user behaviors.
# Keep in mind the agile nature of the application and prioritize scenarios that align closely with the given use case specification and the application's requirements.

# %%
usecase_path = r"D:\Dissertation-GPT\dataset\SpecificationData\Shopping System"
save_path = r"D:\Dissertation-GPT\evaluate\prove\Shopping System\ts"

# %%
usecase_name_list = []
project_name = os.path.basename(usecase_path)

# %%
for filename in os.listdir(usecase_path):
    usecase_name_list.append (filename.split(".txt")[0])
print(usecase_name_list)
# Out:
# ['add to cart', 'checkout', 'product information display', 'purchase', 'search']

# %%
for usecase_name in usecase_name_list:
    print(usecase_name)
    usecase_directlink = os.path.join(usecase_path,usecase_name+".txt")
    prompt_all = read_file_content(usecase_directlink)
    promptSYSTEM_PROMPT = [
        { "role": "system", "content": SYSTEM_PROMPT},
        { "role": "user", "content": prompt_all}
    ]
    gpt_response = ask(promptSYSTEM_PROMPT, client, model)    
    print("gpt_response \n" +gpt_response)
    # write_string_to_file(os.path.join(save_path,f"{usecase_name}.txt"), gpt_response)
# Out:
# add to cart
# gpt_response
# 1. Add Single Item Without Options to Cart
# 2. Add Single Item With One Option Selected to Cart
# 3. Add Single Item With Quantity Adjustment to Cart
# 4. Add Multiple Items to Cart
# 5. Add Item With Maximum Quantity to Cart
# 6. Attempt to Add Item Without Selecting Option
# 7. Attempt to Add Item With Quantity Exceeding Stock
# 8. Attempt to Add Item With Quantity Below Minimum
# 9. Attempt to Add Out of Stock Item to Cart
# 10. Add Item to Cart and Verify Cart Icon Update
# 11. Add Item to Cart and View Cart Contents
# 12. Add Item With Multiple Options and Select One Option
# 13. Add Item With Multiple Options and Adjust Quantity
# 14. Attempt to Add Item With Unavailable Option
# 15. Attempt to Add Multiple Items With Mixed Availability to Cart
# String has been written to D:\Dissertation-GPT\evaluate\prove\Shopping System\ts\add to cart.txt
# checkout
# gpt_response
# 1. Successful Checkout with Default Options
# 2. Successful Checkout with Changed Shipping Address
# 3. Successful Checkout with New Shipping Address
# 4. Successful Checkout with Changed Payment Method
# 5. Successful Checkout with Application Voucher Applied
# 6. Successful Checkout with Shop Voucher Applied
# 7. Successful Checkout with Changed Shipping Option
# 8. Successful Checkout with Note for Shop Added
# 9. Checkout with No Default Shipping Address
# 10. Checkout with Changed Shipping Address from Saved List
# 11. Checkout with Invalid Full Name for New Shipping Address
# 12. Checkout with Invalid Phone Number Format for New Shipping Address
# 13. Checkout with Invalid Location's Address for New Shipping Address
# 14. Checkout with Disabled Voucher Code
# 15. Checkout with Incorrect Voucher Code
# 16. Checkout with Unavailable Location's Address
# 17. Checkout Error Due to Payment Issue
# 18. Checkout Error Due to Shipping Address Issue
# 19. Checkout with Full Name Less Than 2 Letters for New Shipping Address
# 20. Checkout with Phone Number Not Following Required Format
# 21. Checkout with Address Type Selected as Own House
# 22. Checkout with Address Type Selected as Working Place
# String has been written to D:\Dissertation-GPT\evaluate\prove\Shopping System\ts\checkout.txt
# product information display
# gpt_response
# 1. Display Product Information from Homepage
# 2. Display Product Information from Search Page
# 3. Display Product Information from Cart Page
# 4. Display Title and Description Correctly
# 5. Display High-Quality Images from Multiple Angles
# 6. Display Product Videos
# 7. Display Detailed Product Specifications
# 8. Display Current Price and Discounts
# 9. Display Real-Time Stock Availability
# 10. Display Shipping Methods and Estimated Delivery Times
# 11. Display Shipping Fees
# 12. Display Seller Profile with Ratings and Reviews
# 13. Display Seller Contact Option
# 14. Display Link to Seller's Store Page
# 15. Display Average Rating in Customer Reviews and Ratings
# 16. Display 3 Latest Detailed Customer Reviews with Images
# 17. Display List of Related Product Cards
# 18. Expand Customer Reviews to View More
# 19. Expand Customer Questions to View More
# 20. Scroll to View More Related Products
# 21. Contact Seller Directly Through Messaging System
# 22. View Other Products from Seller via Store Link
# 23. Display Product Information with No Available Stock
# 24. Display Product Information with No Customer Reviews
# 25. Display Product Information with No Related Products
# 26. Display Product Information with No Discount or Special Pricing
# 27. Display Product Information with No Videos
# String has been written to D:\Dissertation-GPT\evaluate\prove\Shopping System\ts\product information display.txt
# purchase
# gpt_response
# 1. Purchase with single item selected from shopping cart
# 2. Purchase with multiple items selected from shopping cart
# 3. Purchase with all items from one store selected in shopping cart
# 4. Purchase single product from product detail page without options
# 5. Purchase single product from product detail page with options selected
# 6. Adjust quantity before adding product to cart from product detail page
# 7. Purchase product with quantity adjusted to more than stock from product detail page
# 8. Purchase product with quantity adjusted to less than one from product detail page
# 9. Attempt to select out of stock product in shopping cart
# 10. Attempt to purchase without selecting any product option when required
# 11. Attempt to purchase product with no stock from product detail page
# 12. Attempt to purchase out of stock option of a product with multiple options
# 13. Checkout button disabled when selected product is invalid
# 14. System separates products into different orders based on store
# 15. System combines products from the same store into one order
# 16. Summary costs display correctly for selected items
# 17. Redirect to new order(s) page after checkout from shopping cart
# 18. Redirect to new order page after checkout from product detail page
# String has been written to D:\Dissertation-GPT\evaluate\prove\Shopping System\ts\purchase.txt
# search
# gpt_response
# 1. Search_With_Valid_Keyword_Show_Relevant_Products
# 2. Search_With_Shop_Name_Show_Shop_And_Related_Products
# 3. Search_With_Brand_Name_Show_Brand_Related_Shops_And_Products
# 4. Search_With_Unmatched_Keyword_Show_Related_Products_Only
# 5. Search_With_No_Results_Show_Random_Products
# 6. Search_Result_Pagination_Functionality
# 7. Search_Result_Maximum_60_Products_Per_Page
# 8. Filter_Search_Result_By_Most_Related
# 9. Filter_Search_Result_By_Newest_Products
# 10. Filter_Search_Result_By_Best_Seller
# 11. Filter_Search_Result_By_Price_Lowest_To_Highest
# 12. Filter_Search_Result_By_Price_Highest_To_Lowest
# 13. Search_With_Empty_Keyword
# 14. Search_Functionality_With_Special_Characters
# 15. Search_Functionality_With_Numeric_Keyword
# 16. Search_Result_Shop_Information_Display
# 17. Search_Result_Brand_Related_Shop_Information_Display
# 18. Search_Result_Product_Cards_Information_Accuracy
# 19. Search_Result_Shop_Cards_Information_Accuracy
# 20. Search_Result_Pagination_Navigation
# 21. Search_Result_Pagination_With_Last_Page_Selection
# 22. Search_Result_Pagination_With_First_Page_Selection
# 23. Search_Result_Sort_Functionality_Accuracy
# 24. Search_With_Keyword_Matching_Multiple_Shops
# 25. Search_With_Keyword_Matching_Multiple_Brands
# String has been written to D:\Dissertation-GPT\evaluate\prove\Shopping System\ts\search.txt
