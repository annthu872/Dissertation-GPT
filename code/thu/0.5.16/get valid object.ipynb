# %%
import pandas as pd

# Load the Excel file
file_path = r"D:\Matcha.xlsx"  # Update this with your actual file path
# df = pd.read_excel(file_path, sheet_name='Trang tinh1')
df = pd.read_excel(file_path,header=None)

# Iterate through the DataFrame to keep only the valid scenarios
def filter_scenarios(df):
    valid_scenarios = []
    use_case = None
    
    for index, row in df.iterrows():
        if pd.isna(row[0]):
            use_case = None
        elif row[0].endswith('.txt'):
            use_case = row[0]
        elif row[1] == 'x' and pd.isna(row[3]):
            valid_scenarios.append([use_case, row[0]])
    
    return valid_scenarios

filtered_scenarios = filter_scenarios(df)

# Create a new DataFrame with the filtered scenarios
filtered_df = pd.DataFrame(filtered_scenarios, columns=['Use Case', 'Scenario'])

# Save the filtered DataFrame to a new Excel file
filtered_file_path = 'Matcha.xlsx'
filtered_df.to_excel(filtered_file_path, index=False)

print(f"Filtered scenarios saved to {filtered_file_path}")
# Out:
# Filtered scenarios saved to Matcha.xlsx

# %%
import pandas as pd

# Load the Excel file
file_path = r"D:\Matcha.xlsx"  # Update this with your actual file path
df = pd.read_excel(file_path,header=None)

# Create a new DataFrame to store the filtered results
filtered_df = pd.DataFrame(columns=df.columns)

use_case = None
for index, row in df.iterrows():
    if pd.isna(row[0]):
        # Add a blank row to separate use cases
        filtered_df = filtered_df.append(row)
    elif row[0].endswith('.txt'):
        use_case = row[0]
        filtered_df = filtered_df.append(row)
    elif row[1] == 'x' and pd.isna(row[3]):
        filtered_df = filtered_df.append(row)

# Save the filtered DataFrame to a new Excel file
filtered_file_path = 'Matcha.xlsx'
filtered_df.to_excel(filtered_file_path, index=False)

print(f"Filtered scenarios saved to {filtered_file_path}")
# Out:
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# Filtered scenarios saved to Matcha.xlsx
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)

# %%
import pandas as pd
import json
# Load the Excel file
file_path = r"D:\Book.xlsx"  # Update this with your actual file path
df = pd.read_excel(file_path,header=None)

# Create a new DataFrame to store the filtered results
# filtered_df = pd.DataFrame(columns=df.columns)

use_case_scenarios = {}
current_use_case = None
# current_scenarios = []

# Iterate through the DataFrame
for index, row in df.iterrows():
    test_scenario = row[0]
    valid = row[1]
    dup = row[3]
    
    if pd.isna(test_scenario):
        continue
    elif test_scenario.endswith('.txt'):
        current_use_case = test_scenario.replace('.txt','')
        use_case_scenarios[current_use_case] = []
    elif valid == 'x' and pd.isna(dup):
        use_case_scenarios[current_use_case].append(test_scenario)

file_list = []
print(use_case_scenarios)
use_case_scenarios_json = json.dumps(use_case_scenarios, indent=4)

# Print the JSON string
print(use_case_scenarios_json)
for key, value in use_case_scenarios.items():
    for scenario in value:

        file_list.append(key+'-'+scenario+'.txt')

for i in file_list: 
    print(i)
# Out:
# {'Add a new author': ['1. Successful Author Creation', '2. Author Creation with Missing Name', '3. Author Creation with Missing Bio', '4. Author Creation with Invalid Data', '5. Author Creation with Duplicate Name', '8. Navigation Away During Author Creation (To Books)', '9. Navigation Away During Author Creation (To Genres)', '10. Navigation Away During Author Creation (To Authors)', '11. Navigation Away During Author Creation (To Home)', '12. Navigation Away During Author Creation (To API)'], 'Add a new book': ['1. Successful Book Creation', '2. Book Creation with Missing Title', '3. Book Creation with Missing Author', '4. Book Creation with Missing Genre', '5. Book Creation with Missing Description', '6. Book Creation with Missing Publication Date', '7. Book Creation with Invalid Publication Date Format', '8. Book Creation with Duplicate Title and Author', '10. Cancel Book Creation Before Submitting', '11. Navigate Away Using Menu Before Submitting'], 'Add a new genre': ['1. Successful Genre Creation', '2. Genre Creation with Missing Name', '3. Genre Creation with Missing Description', '4. Genre Creation with Duplicate Name', '8. Cancel Genre Creation Before Submitting', '10. Navigation Away During Genre Creation Without Saving', '12. Genre Creation with Script Injection in Name', '13. Genre Creation with Script Injection in Description', '14. Genre Creation with HTML Tags in Name', '15. Genre Creation with HTML Tags in Description'], 'Display author details': ['1. Display Author Details - Valid Author Selection', '2. Display Author Details - Author With No Biography', '3. Display Author Details - Author With Extensive Biography', '4. Display Author Details - Nonexistent Author Selection', '5. Display Author Details - Author With Special Characters in Name', '8. Display Author Details - Access Through Direct URL', '10. Display Author Details - Navigation Back to Author List'], 'Display book details': ['1. DisplayBookDetails_ValidBookSelection', '3. DisplayBookDetails_BookWithNoAuthor', '4. DisplayBookDetails_BookWithNoGenre', '5. DisplayBookDetails_BookWithNoDescription', '6. DisplayBookDetails_BookWithFuturePublicationDate', '7. DisplayBookDetails_BookWithPastPublicationDate', '9. DisplayBookDetails_BookWithLongDescription', '10. DisplayBookDetails_BookWithSpecialCharactersInTitle', '11. DisplayBookDetails_BookWithSpecialCharactersInAuthorName', '12. DisplayBookDetails_BookWithLargeID'], 'Display genre details': ['1. DisplayGenreDetails_Successful', '6. DisplayGenreDetails_SpecialCharactersInGenreName', '7. DisplayGenreDetails_LongTextInDescription', '9. DisplayGenreDetails_NumericValuesInGenreName', '10. DisplayGenreDetails_GenreWithHTMLTagsInDescription'], 'Display the list of authors': ['1. DisplayFirstPageOfAuthors', '2. DisplaySecondPageOfAuthorsUsingNextButton', '3. DisplaySpecificPageOfAuthorsUsingPageNumber', '4. DisplayLastPageOfAuthors', '5. DisplayEmptyAuthorsList', '6. DisplayAuthorsListWithMaximumRecordsPerPage', '7. DisplayAuthorsListWithSingleAuthor', '8. DisplayAuthorsListWithAuthorsHavingLongBios', '9. DisplayAuthorsListWithSpecialCharactersInNameOrBio', '10. NavigateBackToPreviousPageOfAuthorsFromSubsequentPage'], 'Display the list of books': ['1. DisplayInitialBooksList - Verify that the initial list of books is displayed correctly upon selecting the "Books" item.', '2. PaginationNextButtonFunctionality - Verify that clicking the "Next" button displays the next 10 records of books.', '3. PaginationPageNumberFunctionality - Verify that clicking a specific page number displays the corresponding 10 records of books.', '5. DisplayBooksListWithinDateRange - Verify that the list of books is correctly filtered and displayed when a valid date range is provided and the refresh button is clicked.', "6. DisplayBooksListOutsideDateRange - Verify the behavior when the provided date range does not match any book's publication date.", '7. DisplayBooksListWithInvalidDateRange - Verify the behavior when an invalid date r ...
# {
#     "Add a new author": [
#         "1. Successful Author Creation",
#         "2. Author Creation with Missing Name",
#         "3. Author Creation with Missing Bio",
#         "4. Author Creation with Invalid Data",
#         "5. Author Creation with Duplicate Name",
#         "8. Navigation Away During Author Creation (To Books)",
#         "9. Navigation Away During Author Creation (To Genres)",
#         "10. Navigation Away During Author Creation (To Authors)",
#         "11. Navigation Away During Author Creation (To Home)",
#         "12. Navigation Away During Author Creation (To API)"
#     ],
#     "Add a new book": [
#         "1. Successful Book Creation",
#         "2. Book Creation with Missing Title",
#         "3. Book Creation with Missing Author",
#         "4. Book Creation with Missing Genre",
#         "5. Book Creation with Missing Description",
#         "6. Book Creation with Missing Publication Date",
#         "7. Book Creation with Invalid Publication Date Format",
#         "8. Book Creation with Duplicate Title and Author",
#         "10. Cancel Book Creation Before Submitting",
#         "11. Navigate Away Using Menu Before Submitting"
#     ],
#     "Add a new genre": [
#         "1. Successful Genre Creation",
#         "2. Genre Creation with Missing Name",
#         "3. Genre Creation with Missing Description",
#         "4. Genre Creation with Duplicate Name",
#         "8. Cancel Genre Creation Before Submitting",
#         "10. Navigation Away During Genre Creation Without Saving",
#         "12. Genre Creation with Script Injection in Name",
#         "13. Genre Creation with Script Injection in Description",
#         "14. Genre Creation with HTML Tags in Name",
#         "15. Genre Creation with HTML Tags in Description"
#     ],
#     "Display author details": [
#         "1. Display Author Details - Valid Author Selection",
#         "2. Display Author Details - Author With No Biography",
#         "3. Display Author Details - Author With Extensive Biography",
#         "4. Display Author Details - Nonexistent Author Selection",
#         "5. Display Author Details - Author With Special Characters in Name",
#         "8. Display Author Details - Access Through Direct URL",
#         "10. Display Author Details - Navigation Back to Author List"
#     ],
#     "Display book details": [
#         "1. DisplayBookDetails_ValidBookSelection",
#         "3. DisplayBookDetails_BookWithNoAuthor",
#         "4. DisplayBookDetails_BookWithNoGenre",
#         "5. DisplayBookDetails_BookWithNoDescription",
#         "6. DisplayBookDetails_BookWithFuturePublicationDate",
#         "7. DisplayBookDetails_BookWithPastPublicationDate",
#         "9. DisplayBookDetails_BookWithLongDescription",
#         "10. DisplayBookDetails_BookWithSpecialCharactersInTitle",
#         "11. DisplayBookDetails_BookWithSpecialCharactersInAuthorName",
#         "12. DisplayBookDetails_BookWithLargeID"
#     ],
#     "Display genre details": [
#         "1. DisplayGenreDetails_Successful",
#         "6. DisplayGenreDetails_SpecialCharactersInGenreName",
#         "7. DisplayGenreDetails_LongTextInDescription",
#         "9. DisplayGenreDetails_NumericValuesInGenreName",
#         "10. DisplayGenreDetails_GenreWithHTMLTagsInDescription"
#     ],
#     "Display the list of authors": [
#         "1. DisplayFirstPageOfAuthors",
#         "2. DisplaySecondPageOfAuthorsUsingNextButton",
#         "3. DisplaySpecificPageOfAuthorsUsingPageNumber",
#         "4. DisplayLastPageOfAuthors",
#         "5. DisplayEmptyAuthorsList",
#         "6. DisplayAuthorsListWithMaximumRecordsPerPage",
#         "7. DisplayAuthorsListWithSingleAuthor",
#         "8. DisplayAuthorsListWithAuthorsHavingLongBios",
#         "9. DisplayAuthorsListWithSpecialCharactersInNameOrBio",
#         "10. NavigateBackToPreviousPageOfAuthorsFromSubsequentPage"
#     ],
#     "Display the list of books": [
#         "1. DisplayInitialBooksList - Verify that the initial list of books is displayed correctly upon selecting the \"Books\" item.",
#         "2. PaginationNextButtonFunctionality - Verify that clicking the \"Next\" button displays the next 10 records of books.",
#         "3. PaginationPageNumberFunctionality - Verify that clicking a specific page number displays the corresponding 10 records of books.",
#         "5. DisplayBooksListWithinDateRange - Verify that the list of books is correctly filtered and displayed when a valid date range is provided and the refresh button is clicked.",
#         "6. DisplayBooksListOutsideDateRange - Verify the behavior when the provided date range does not match any book's publication date.",
#         "7. DisplayBooksListWithInvalidDateRange - Verify the behavior when an invalid date range is provided (e.g., end date is before start date) and the refresh button is clicked.",
#         "8. DisplayBooksListWithBoundaryDateRange - Verify the behavior when the date range is at the boundary conditions of the available data (e.g., the earliest or latest publication date).",
#         "9. DisplayBooksListWithSingleDate - Verify the behavior when the start and end dates are the same in the date range filter.",
#         "10. DisplayBooksListWithFutureDateRange - Verify the behavior when the date range is in the future, beyond any book's publication date.",
#         "11. DisplayBooksListWithPastDateRange - Verify the behavior when the date range is entirely in the past, before any book's publication date.",
#         "12. PaginationFunctionalityAfterFiltering - Verify that pagination works correctly after filtering the books list by a date range."
#     ],
#     "Display the list of genres": [
#         "1. DisplayInitialGenresList - Verify that the initial list of genres is displayed correctly upon selecting the \"Genres\" item.",
#         "2. DisplayGenresListWithMultiplePages - Verify that genres are paginated correctly when more than 10 items are available.",
#         "3. NavigateToNextPage - Verify that clicking the \"Next\" button displays the next 10 genres.",
#         "4. NavigateToPreviousPage - Verify that after moving forward, clicking a \"Previous\" button (if applicable) displays the previous 10 genres.",
#         "5. NavigateToSpecificPage - Verify that clicking a specific page number navigates to that page and displays the correct genres.",
#         "7. DisplayEmptyGenresList - Verify the behavior when there are no genres in the database.",
#         "9. RefreshGenresList - Verify that the list updates correctly after a new genre is added or an existing one is modified or deleted."
#     ],
#     "Edit the author": [
#         "1. Successful Author Update",
#         "2. Update Author with Incorrect Data",
#         "3. Update Author with Empty Mandatory Fields",
#         "4. Update Author with Exceedingly Long Data",
#         "5. Update Author with SQL Injection or XSS Attack Vectors",
#         "6. Update Author and Cancel Operation",
#         "7. Update Author and Navigate Away Using Menu Before Submitting",
#         "8. Update Author with Special Characters in Name",
#         "9. Update Author with HTML Tags in Bio",
#         "10. Update Author with Duplicate Name",
#         "13. Update Author with External Links in Bio",
#         "14. Update Author with Script Tags in Bio (Testing for Script Injection)"
#     ],
#     "Edit the book": [
#         "1. Update Book with Valid Data",
#         "2. Update Book with Invalid Title",
#         "3. Update Book with Invalid Author",
#         "4. Update Book with Invalid Genre",
#         "5. Update Book with Invalid Description",
#         "6. Update Book with Invalid Publication Date",
#         "7. Update Book with Empty Mandatory Fields",
#         "8. Update Book and Press Cancel",
#         "9. Update Book and Navigate Away Using Menu Before Submitting",
#         "10. Update Book with Special Characters in Fields",
#         "11. Update Book with SQL Injection Attack Vectors",
#         "12. Update Book with XSS Attack Vectors in Fields",
#         "13. Update Book with Extremely Long Data in Each Field",
#         "14. Update Book with Past Publication Date",
#         "15. Update Book with Future Publication Date Beyond Reasonable Future",
#         "16. Update Book with Non-Existent Author",
#         "17. Update Book with Non-Existent Genre",
#         "18. Update Book with Duplicate Title and Author"
#     ],
#     "Edit the genre": [
#         "1. Successful Genre Update",
#         "2. Update Genre with Invalid Data",
#         "3. Update Genre with Empty Fields",
#         "4. Update Genre with Duplicate Name",
#         "7. Navigate Away Using Menu Before Submitting",
#         "8. Navigate Away Using Menu After Data Entry",
#         "9. Update Genre with Special Characters in Name",
#         "10. Update Genre with Excessively Long Name",
#         "11. Update Genre with HTML Tags in Description",
#         "12. Update Genre with Script Injection in Description",
#         "14. Update Genre with SQL Injection in Name",
#         "15. Update Genre with JavaScript Code in Name"
#     ],
#     "Remove the author": [
#         "1. Successful Author Deletion",
#         "2. Cancel Author Deletion via Cancel Button",
#         "3. Cancel Author Deletion via Navigation to \"Books\"",
#         "4. Cancel Author Deletion via Navigation to \"Genres\"",
#         "5. Cancel Author Deletion via Navigation to \"Authors\"",
#         "6. Cancel Author Deletion via Navigation to \"Home\"",
#         "7. Cancel Author Deletion via Navigation to \"API\"",
#         "9. Delete Author with Associated Books (Constraint Check)"
#     ],
#     "Remove the book": [
#         "1. Successful Book Deletion",
#         "2. Cancel Book Deletion via Cancel Button",
#         "3. Cancel Book Deletion via Navigation to \"Books\"",
#         "4. Cancel Book Deletion via Navigation to \"Genres\"",
#         "5. Cancel Book Deletion via Navigation to \"Authors\"",
#         "6. Cancel Book Deletion via Navigation to \"Home\"",
#         "7. Cancel Book Deletion via Navigation to \"API\"",
#         "8. Attempt to Delete Non-Existent Book"
#     ],
#     "Remove the genre": [
#         "1. Successful Genre Deletion",
#         "2. Cancel Genre Deletion via Cancel Button",
#         "3. Cancel Genre Deletion via Navigation to Books",
#         "4. Cancel Genre Deletion via Navigation to Genres",
#         "5. Cancel Genre Deletion via Navigation to Authors",
#         "6. Cancel Genre Deletion via Navigation to Home",
#         "7. Cancel Genre Deletion via Navigation to API"
#     ]
# }
# Add a new author-1. Successful Author Creation.txt
# Add a new author-2. Author Creation with Missing Name.txt
# Add a new author-3. Author Creation with Missing Bio.txt
# Add a new author-4. Author Creation with Invalid Data.txt
# Add a new author-5. Author Creation with Duplicate Name.txt
# Add a new author-8. Navigation Away During Author Creation (To Books).txt
# Add a new author-9. Navigation Away During Author Creation (To Genres).txt
# Add a new author-10. Navigation Away During Author Creation (To Authors).txt
# Add a new author-11. Navigation Away During Author Creation (To Home).txt
# Add a new author-12. Navigation Away During Author Creation (To API).txt
# Add a new book-1. Successful Book Creation.txt
# Add a new book-2. Book Creation with Missing Title.txt
# Add a new book-3. Book Creation with Missing Author.txt
# Add a new book-4. Book Creation with Missing Genre.txt
# Add a new book-5. Book Creation with Missing Description.txt
# Add a new book-6. Book Creation with Missing Publication Date.txt
# Add a new book-7. Book Creation with Invalid Publication Date Format.txt
# Add a new book-8. Book Creation with Duplicate Title and Author.txt
# Add a new book-10. Cancel Book Creation Before Submitting.txt
# Add a new book-11. Navigate Away Using Menu Before Submitting.txt
# Add a new genre-1. Successful Genre Creation.txt
# Add a new genre-2. Genre Creation with Missing Name.txt
# Add a new genre-3. Genre Creation with Missing Description.txt
# Add a new genre-4. Genre Creation with Duplicate Name.txt
# Add a new genre-8. Cancel Genre Creation Before Submitting.txt
# Add a new genre-10. Navigation Away During Genre Creation Without Saving.txt
# Add a new genre-12. Genre Creation with Script Injection in Name.txt
# Add a new genre-13. Genre Creation with Script Injection in Description.txt
# Add a new genre-14. Genre Creation with HTML Tags in Name.txt
# Add a new genre-15. Genre Creation with HTML Tags in Description.txt
# Display author details-1. Display Author Details - Valid Author Selection.txt
# Display author details-2. Display Author Details - Author With No Biography.txt
# Display author details-3. Display Author Details - Author With Extensive Biography.txt
# Display author details-4. Display Author Details - Nonexistent Author Selection.txt
# Display author details-5. Display Author Details - Author With Special Characters in Name.txt
# Display author details-8. Display Author Details - Access Through Direct URL.txt
# Display author details-10. Display Author Details - Navigation Back to Author List.txt
# Display book details-1. DisplayBookDetails_ValidBookSelection.txt
# Display book details-3. DisplayBookDetails_BookWithNoAuthor.txt
# Display book details-4. DisplayBookDetails_BookWithNoGenre.txt
# Display book details-5. DisplayBookDetails_BookWithNoDescription.txt
# Display book details-6. DisplayBookDetails_BookWithFuturePublicationDate.txt
# Display book details-7. DisplayBookDetails_BookWithPastPublicationDate.txt
# Display book details-9. DisplayBookDetails_BookWithLongDescription.txt
# Display book details-10. DisplayBookDetails_BookWithSpecialCharactersInTitle.txt
# Display book details-11. DisplayBookDetails_BookWithSpecialCharactersInAuthorName.txt
# Display book details-12. DisplayBookDetails_BookWithLargeID.txt
# Display genre details-1. DisplayGenreDetails_Successful.txt
# Display genre details-6. DisplayGenreDetails_SpecialCharactersInGenreName.txt
# Display genre details-7. DisplayGenreDetails_LongTextInDescription.txt
# Display genre details-9. DisplayGenreDetails_NumericValuesInGenreName.txt
# Display genre details-10. DisplayGenreDetails_GenreWithHTMLTagsInDescription.txt
# Display the list of authors-1. DisplayFirstPageOfAuthors.txt
# Display the list of authors-2. DisplaySecondPageOfAuthorsUsingNextButton.txt
# Display the list of authors-3. DisplaySpecificPageOfAuthorsUsingPageNumber.txt
# Display the list of authors-4. DisplayLastPageOfAuthors.txt
# Display the list of authors-5. DisplayEmptyAuthorsList.txt
# Display the list of authors-6. DisplayAuthorsListWithMaximumRecordsPerPage.txt
# Display the list of authors-7. DisplayAuthorsListWithSingleAuthor.txt
# Display the list of authors-8. DisplayAuthorsListWithAuthorsHavingLongBios.txt
# Display the list of authors-9. DisplayAuthorsListWithSpecialCharactersInNameOrBio.txt
# Display the list of authors-10. NavigateBackToPreviousPageOfAuthorsFromSubsequentPage.txt
# Display the list of books-1. DisplayInitialBooksList - Verify that the initial list of books is displayed correctly upon selecting the "Books" item..txt
# Display the list of books-2. PaginationNextButtonFunctionality - Verify that clicking the "Next" button displays the next 10 records of books..txt
# Display the list of books-3. PaginationPageNumberFunctionality - Verify that clicking a specific page number displays the corresponding 10 records of books..txt
# Display the list of books-5. DisplayBooksListWithinDateRange - Verify that the list of books is correctly filtered and displayed when a valid date range is provided and the refresh button is clicked..txt
# Display the list of books-6. DisplayBooksListOutsideDateRange - Verify the behavior when the provided date range does not match any book's publication date..txt
# Display the list of books-7. DisplayBooksListWithInvalidDateRange - Verify the behavior when an invalid date range is provided (e.g., end date is before start date) and the refresh button is clicked..txt
# Display the list of books-8. DisplayBooksListWithBoundaryDateRange - Verify the behavior when the date range is at the boundary conditions of the available data (e.g., the earliest or latest publication date)..txt
# Display the list of books-9. DisplayBooksListWithSingleDate - Verify the behavior when the start and end dates are the same in the date range filter..txt
# Display the list of books-10. DisplayBooksListWithFutureDateRange - Verify the behavior when the date range is in the future, beyond any book's publication date..txt
# Display the list of books-11. DisplayBooksListWithPastDateRange - Verify the behavior when the date range is entirely in the past, before any book's publication date..txt
# Display the list of books-12. PaginationFunctionalityAfterFiltering - Verify that pagination works correctly after filtering the books list by a date range..txt
# Display the list of genres-1. DisplayInitialGenresList - Verify that the initial list of genres is displayed correctly upon selecting the "Genres" item..txt
# Display the list of genres-2. DisplayGenresListWithMultiplePages - Verify that genres are paginated correctly when more than 10 items are available..txt
# Display the list of genres-3. NavigateToNextPage - Verify that clicking the "Next" button displays the next 10 genres..txt
# Display the list of genres-4. NavigateToPreviousPage - Verify that after moving forward, clicking a "Previous" button (if applicable) displays the previous 10 genres..txt
# Display the list of genres-5. NavigateToSpecificPage - Verify that clicking a specific page number navigates to that page and displays the correct genres..txt
# Display the list of genres-7. DisplayEmptyGenresList - Verify the behavior when there are no genres in the database..txt
# Display the list of genres-9. RefreshGenresList - Verify that the list updates correctly after a new genre is added or an existing one is modified or deleted..txt
# Edit the author-1. Successful Author Update.txt
# Edit the author-2. Update Author with Incorrect Data.txt
# Edit the author-3. Update Author with Empty Mandatory Fields.txt
# Edit the author-4. Update Author with Exceedingly Long Data.txt
# Edit the author-5. Update Author with SQL Injection or XSS Attack Vectors.txt
# Edit the author-6. Update Author and Cancel Operation.txt
# Edit the author-7. Update Author and Navigate Away Using Menu Before Submitting.txt
# Edit the author-8. Update Author with Special Characters in Name.txt
# Edit the author-9. Update Author with HTML Tags in Bio.txt
# Edit the author-10. Update Author with Duplicate Name.txt
# Edit the author-13. Update Author with External Links in Bio.txt
# Edit the author-14. Update Author with Script Tags in Bio (Testing for Script Injection).txt
# Edit the book-1. Update Book with Valid Data.txt
# Edit the book-2. Update Book with Invalid Title.txt
# Edit the book-3. Update Book with Invalid Author.txt
# Edit the book-4. Update Book with Invalid Genre.txt
# Edit the book-5. Update Book with Invalid Description.txt
# Edit the book-6. Update Book with Invalid Publication Date.txt
# Edit the book-7. Update Book with Empty Mandatory Fields.txt
# Edit the book-8. Update Book and Press Cancel.txt
# Edit the book-9. Update Book and Navigate Away Using Menu Before Submitting.txt
# Edit the book-10. Update Book with Special Characters in Fields.txt
# Edit the book-11. Update Book with SQL Injection Attack Vectors.txt
# Edit the book-12. Update Book with XSS Attack Vectors in Fields.txt
# Edit the book-13. Update Book with Extremely Long Data in Each Field.txt
# Edit the book-14. Update Book with Past Publication Date.txt
# Edit the book-15. Update Book with Future Publication Date Beyond Reasonable Future.txt
# Edit the book-16. Update Book with Non-Existent Author.txt
# Edit the book-17. Update Book with Non-Existent Genre.txt
# Edit the book-18. Update Book with Duplicate Title and Author.txt
# Edit the genre-1. Successful Genre Update.txt
# Edit the genre-2. Update Genre with Invalid Data.txt
# Edit the genre-3. Update Genre with Empty Fields.txt
# Edit the genre-4. Update Genre with Duplicate Name.txt
# Edit the genre-7. Navigate Away Using Menu Before Submitting.txt
# Edit the genre-8. Navigate Away Using Menu After Data Entry.txt
# Edit the genre-9. Update Genre with Special Characters in Name.txt
# Edit the genre-10. Update Genre with Excessively Long Name.txt
# Edit the genre-11. Update Genre with HTML Tags in Description.txt
# Edit the genre-12. Update Genre with Script Injection in Description.txt
# Edit the genre-14. Update Genre with SQL Injection in Name.txt
# Edit the genre-15. Update Genre with JavaScript Code in Name.txt
# Remove the author-1. Successful Author Deletion.txt
# Remove the author-2. Cancel Author Deletion via Cancel Button.txt
# Remove the author-3. Cancel Author Deletion via Navigation to "Books".txt
# Remove the author-4. Cancel Author Deletion via Navigation to "Genres".txt
# Remove the author-5. Cancel Author Deletion via Navigation to "Authors".txt
# Remove the author-6. Cancel Author Deletion via Navigation to "Home".txt
# Remove the author-7. Cancel Author Deletion via Navigation to "API".txt
# Remove the author-9. Delete Author with Associated Books (Constraint Check).txt
# Remove the book-1. Successful Book Deletion.txt
# Remove the book-2. Cancel Book Deletion via Cancel Button.txt
# Remove the book-3. Cancel Book Deletion via Navigation to "Books".txt
# Remove the book-4. Cancel Book Deletion via Navigation to "Genres".txt
# Remove the book-5. Cancel Book Deletion via Navigation to "Authors".txt
# Remove the book-6. Cancel Book Deletion via Navigation to "Home".txt
# Remove the book-7. Cancel Book Deletion via Navigation to "API".txt
# Remove the book-8. Attempt to Delete Non-Existent Book.txt
# Remove the genre-1. Successful Genre Deletion.txt
# Remove the genre-2. Cancel Genre Deletion via Cancel Button.txt
# Remove the genre-3. Cancel Genre Deletion via Navigation to Books.txt
# Remove the genre-4. Cancel Genre Deletion via Navigation to Genres.txt
# Remove the genre-5. Cancel Genre Deletion via Navigation to Authors.txt
# Remove the genre-6. Cancel Genre Deletion via Navigation to Home.txt
# Remove the genre-7. Cancel Genre Deletion via Navigation to API.txt
