# %%
import re
import pandas as pd
import os
import chardet

def read_file_content(file_path):
    # Detect the encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        return content
    except FileNotFoundError:
        return f"Error: The file at path {file_path} was not found."
    except UnicodeDecodeError:
        return f"Error: The file at path {file_path} cannot be decoded with the {encoding} encoding."
    except IOError:
        return f"Error: An I/O error occurred while reading the file at path {file_path}."

def split_before_and_after_hyphen(file_name):
    parts = file_name.split('-', 1)
    if len(parts) == 2:
        before_hyphen, after_hyphen = parts
    else:
        before_hyphen, after_hyphen = file_name, ""
    return before_hyphen.strip(), after_hyphen.strip()

# Function to parse the test cases from the text file


def parse_test_cases(file_name,use_case_name):
    # with open(file_name, 'r') as file:
    #     content = file.read()
    content = read_file_content(file_name)
    base_name = os.path.basename(file_name)

    base_nam = os.path.splitext(base_name)[0]

    # Extract use case and test scenario names from the file name
    # use_case_name, test_scenario_name = split_before_and_after_hyphen(base_nam)
    test_scenario_name = base_nam
    # Regular expression to extract test cases
    test_case_pattern = re.compile(
        r"Test Case: (.*?)\ntestCaseName: (.*?)\nobjective: (.*?)\ntestSteps:\n(.*?)\nexpectedResult: (.*?)\n",
        re.DOTALL
    )
    
    matches = test_case_pattern.findall(content)
    
    test_cases = []
    for match in matches:
        test_case_name = match[1].strip()
        objective = match[2].strip()
        test_steps = match[3].strip().replace('\n', ' ')
        expected_result = match[4].strip()
        
        test_cases.append({
            'Use Case Name': use_case_name,
            'Test Scenario Name': test_scenario_name,
            'Test Case Name': test_case_name,
            'Objective': objective,
            'Test Steps': test_steps,
            'Expected Result': expected_result
        })
    
    return test_cases

# Function to write the parsed test cases to an Excel file
def write_to_excel(test_cases, output_file):
    df = pd.DataFrame(test_cases)
    df.to_excel(output_file, index=False)


def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(1)) if match else float('inf')

# Function to sort filenames naturally by the extracted number
def natural_sort_key(filename):
    # Split the filename into parts: prefix and number
    parts = re.split(r'(\d+)', filename)
    # Convert numerical parts to integers for proper numeric sorting
    parts[1::2] = map(int, parts[1::2])
    return parts

# Sort filenames using the natural sort key

def parse_use_cases(file_name):
    base_name = os.path.basename(file_name)
    usecase_name = os.path.splitext(base_name)[0]
    usecase_specification  = read_file_content(file_name)
    result = {
                'usecase_name': usecase_name,
                'usecase_specification': usecase_specification
            }
    return result

# %%
import openpyxl

def create_new_sheet(file_path, sheet_name):
    # Load the existing workbook
    workbook = openpyxl.load_workbook(file_path)

    # Create a new sheet with the specified name
    workbook.create_sheet(title=sheet_name)

    # Save the workbook
    workbook.save(file_path)

def add_data_to_sheet(file_path, sheet_name, data):
    # Load the existing workbook
    workbook = openpyxl.load_workbook(file_path)

    # Check if the sheet exists, if not create it
    if sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
    else:
        sheet = workbook.create_sheet(title=sheet_name)

    # Add data to the sheet
    for row in data:
        sheet.append(row)

    # Save the workbook
    workbook.save(file_path)

def write_to_excel(test_cases, output_file, sheet_name='Sheet1'):
    # Convert the list of JSON objects to a DataFrame
    df = pd.DataFrame(test_cases)

    # Try to open the existing workbook
    try:
        with pd.ExcelWriter(output_file, engine='openpyxl', mode='a') as writer:
            # Check if the sheet already exists
            writer.book = openpyxl.load_workbook(output_file)
            if sheet_name in writer.book.sheetnames:
                # If the sheet exists, remove it
                writer.book.remove(writer.book[sheet_name])
            # Write the DataFrame to the specified sheet
            df.to_excel(writer, index=False, sheet_name=sheet_name)
    except FileNotFoundError:
        # If the file does not exist, create a new workbook and add the sheet
        with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
            df.to_excel(writer, index=False, sheet_name=sheet_name)

# %%
def list_directories(directory_path):
    directories = []
    # Check if the directory exists
    if os.path.exists(directory_path):
        # Iterate over all items in the directory
        for item in os.listdir(directory_path):
            # Join the directory path with the item name
            item_path = os.path.join(directory_path, item)
            # Check if the item is a directory and add it to the list
            if os.path.isdir(item_path):
                directories.append(item)
    else:
        print("Directory does not exist.")
    return directories

# Example usage:

# %%
# def remove_elements_with_raw(input_list):
#     # Use list comprehension to filter out elements containing "raw"
#     filtered_list = [element for element in input_list if "raw" not in element]
#     return filtered_list

# # Example usage:
# input_list = ["apple", "rawhide", "banana", "strawberry", "orange"]
# filtered_list = remove_elements_with_raw(input_list)
# print(filtered_list)

# %%
import os
directory_testcase_folder = r"D:\Dissertation-GPT\5.25-NhuY"
application = "Matcha"


directory_testcase_folder_path =os.path.join(directory_testcase_folder,application)
directory_name = list_directories(directory_testcase_folder_path)
testcase_file_list = []
for directory in directory_name:
    testcase_path = os.listdir(os.path.join(directory_testcase_folder_path,directory))
    filter_testcase_without_raw = [path for path in testcase_path if "Raw" not in path]
    for i in filter_testcase_without_raw:
        temp = os.path.join(os.path.join(directory_testcase_folder_path,directory),i)
        testcase_file_list.append(temp)
print(testcase_file_list)
# Out:
# ['D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson After Entering Description1.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson After Entering Description2.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson After Entering Description3.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson After Entering Name1.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson After Entering Name2.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson After Entering Name3.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson Before Entering Name1.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson Before Entering Name2.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Cancel Adding New Lesson Before Entering Name3.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Duplicate Name1.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Duplicate Name2.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Duplicate Name3.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Missing Description1.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Missing Description2.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Missing Description3.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Missing Name1.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Missing Name2.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Lesson Creation with Missing Name3.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Navigate to Add New Lesson Page via Navbar Option1.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Navigate to Add New Lesson Page via Navbar Option2.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Navigate to Add New Lesson Page via Navbar Option3.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Successful Lesson Creation1.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Successful Lesson Creation2.txt', 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLesson\\Successful Lesson Creation3.txt', "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field containing special characters1.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field containing special characters2.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field containing special characters3.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field more than 250 characters1.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field more than 250 characters2.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field more than 250 characters3.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field not containing '...'1.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field not containing '...'2.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection test with 'sentence' field not containing '...'3.txt", "D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\AddLessonIdeal\\admin can not Add new question for selection te ...

# %%
output_file = 'test_cases.xlsx'

# testcase_folder_path = r'D:\Dissertation-GPT\evaluate\ResultSet\6.24\shopee - best\tc'
# usecase_folder_path = r"D:\Dissertation-GPT\dataset\SpecificationData\Shopee(new)"
# testcase_file_list = os.listdir(testcase_folder_path)
# testcase_sorted_files = sorted(testcase_file_list, key=natural_sort_key)
# usecase_file_list = os.listdir(usecase_folder_path)

# %%
    
all_test_cases = []
all_use_case = []
for file_path in testcase_file_list:
    print(file_path)
    if os.path.isfile(file_path):
        directory_path = os.path.dirname(file_path)
    # Get the name of the last directory
        last_directory = os.path.basename(directory_path)
        test_cases = parse_test_cases(file_path, last_directory)
        print(test_cases)
        # test_cases = parse_test_cases(file_path)
        all_test_cases.extend(test_cases)


# create_new_sheet(output_file, "Use case Description")
# create_new_sheet(output_file,"Test scenarios and Corresponding Test Case")
# create_new_sheet(output_file,"Test Case Detail")

# headings = ['Use case name', "Use case specification"]
# add_headings_to_sheet(output_file, "Use case Description",headings)
# headings = ['Use case name', "Use case specification"]
# add_headings_to_sheet(output_file,"Test scenarios and Corresponding Test Case",headings)
# add_headings_to_sheet(output_file,"Test Case Detail",headings)

# write_to_excel(all_use_case, output_file,"Use case Description")
# write_to_excel(all_test_cases,output_file,"Test Case Detail")
write_to_excel(all_test_cases, output_file,"Test scenarios and Corresponding Test Case")
# Out:
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson After Entering Description1.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson After Entering Description1', 'Test Case Name': 'Cancel Adding New Lesson After Entering Description', 'Objective': "Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's description.", 'Test Steps': "- Step 1: Log in to the application as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Cancel' to stop adding the new lesson.", 'Expected Result': 'The system should cancel the process of adding a new lesson and redirect the administrator to the previous page without creating a new lesson.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson After Entering Description2.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson After Entering Description2', 'Test Case Name': 'Cancel Adding New Lesson After Entering Description', 'Objective': "Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's description.", 'Test Steps': "- Step 1: Log in to the application as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Cancel' to stop adding the new lesson.", 'Expected Result': "The process of adding a new lesson is cancelled, and the administrator is redirected away from the 'Add new Lesson' page without creating a new lesson."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson After Entering Description3.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson After Entering Description3', 'Test Case Name': 'Cancel Adding New Lesson After Entering Description', 'Objective': 'Verify that the administrator can cancel the process of adding a new lesson after entering the description but before saving.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Cancel' to stop adding the new lesson.", 'Expected Result': 'The system should cancel the process of adding a new lesson and redirect the administrator back to the previous page or a main/admin dashboard without creating a new lesson.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson After Entering Name1.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson After Entering Name1', 'Test Case Name': 'Cancel Adding New Lesson After Entering Name', 'Objective': 'Verify that the administrator can cancel adding a new lesson after entering the lesson name but before saving.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: On the 'Add new Lesson' page, enter a unique name for the lesson in the name field.   - Step 5: Press 'Cancel' to stop adding the new lesson.", 'Expected Result': 'The system should cancel the lesson creation process and redirect the administrator to the previous page or a main dashboard without creating a new lesson.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson After Entering Name2.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson After Entering Name2', 'Test Case Name': 'Cancel Adding New Lesson After Entering Name', 'Objective': "Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's name.", 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name in the name field.   - Step 5: Select 'Cancel' to stop adding a new lesson.", 'Expected Result': 'The system should cancel the process of adding a new lesson and redirect the administrator to the previous page without creating a new lesson.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson After Entering Name3.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson After Entering Name3', 'Test Case Name': 'Cancel Adding New Lesson After Entering Name', 'Objective': "Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's name.", 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name in the name field.   - Step 5: Select 'Cancel' to stop adding a new lesson.", 'Expected Result': 'The system should cancel the process of adding a new lesson and redirect the administrator to the previous page without creating a new lesson.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson Before Entering Name1.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson Before Entering Name1', 'Test Case Name': 'Cancel Adding New Lesson Before Entering Name', 'Objective': 'Verify that the administrator can cancel the process of adding a new lesson before entering the lesson name.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: On the 'Add new Lesson' page, do not enter any information in the name field.   - Step 5: Select 'Cancel' to stop adding a new lesson.", 'Expected Result': 'The system should cancel the process of adding a new lesson and redirect the administrator to the previous page without creating a new lesson.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson Before Entering Name2.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson Before Entering Name2', 'Test Case Name': 'Cancel Adding New Lesson Before Entering Name', 'Objective': 'Verify that the administrator can cancel the process of adding a new lesson before entering the lesson name.', 'Test Steps': "- Step 1: Log in to the application as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: On the 'Add new Lesson' page, directly select 'Cancel' without entering any information in the name field.", 'Expected Result': 'The system should cancel the process of adding a new lesson and redirect the administrator to the previous page or a relevant page without creating a new lesson.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Cancel Adding New Lesson Before Entering Name3.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Cancel Adding New Lesson Before Entering Name3', 'Test Case Name': 'Cancel Adding New Lesson Before Entering Name', 'Objective': 'Verify that the administrator can cancel the process of adding a new lesson before entering the lesson name.', 'Test Steps': "- Step 1: Log in to the application as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: On the 'Add new Lesson' page, do not enter any information in the name field.   - Step 5: Select 'Cancel' to stop adding a new lesson.", 'Expected Result': 'The system should cancel the process of adding a new lesson and redirect the administrator to the previous page without creating a new lesson.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Duplicate Name1.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Duplicate Name1', 'Test Case Name': 'Lesson Creation with Duplicate Name', 'Objective': 'Verify that the system prevents the creation of a new lesson with a name that is already used and prompts for a new name.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Enter a name that is already used by an existing lesson in the name field on the 'Add new Lesson' page.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Save' to attempt to create the new lesson.", 'Expected Result': 'The system should display a notification that the name is already used, prompting the Administrator to add another name.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Duplicate Name2.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Duplicate Name2', 'Test Case Name': 'Lesson Creation with Duplicate Name', 'Objective': 'Verify that the system prevents the creation of a new lesson with a name that already exists.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Enter a name that is already used by an existing lesson in the name field.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Save' to attempt to create the new lesson.", 'Expected Result': 'The system should display a notification that the name is already used, prompting the Administrator to add another name.'}, {'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Duplicate Name2', 'Test Case Name': 'Lesson Creation with Duplicate Name and Correction', 'Objective': 'Verify that the administrator can successfully add a new lesson after initially attempting to use a duplicate name.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Enter a name that is already used by an existing lesson in the name field.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Save' to attempt to create the new lesson.   - Step 7: After receiving the notification that the name is already used, enter a new, unique name in the name field.   - Step 8: Select 'Save' again to create the lesson.", 'Expected Result': 'The system should create the new lesson with the new, unique name and redirect the administrator to the adding topic to new lesson section. The new lesson should appear in the lesson list.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Duplicate Name3.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Duplicate Name3', 'Test Case Name': 'Verify Lesson Creation with Duplicate Name', 'Objective': 'Ensure that the system prevents the creation of a new lesson with a name that is already in use.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Enter a name that is already used by an existing lesson in the name field on the 'Add new Lesson' page.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Save' to attempt to create the new lesson.", 'Expected Result': 'The system should display a notification that the name is already used, prompting the Administrator to add another name.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Missing Description1.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Missing Description1', 'Test Case Name': 'Lesson Creation with Missing Description', 'Objective': 'Verify that the system prevents the creation of a new lesson without a description.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.   - Step 5: Leave the description field empty.   - Step 6: Select 'Save' to attempt creating a new lesson.", 'Expected Result': 'The system should display an error message indicating that the description field is required and prevent the lesson from being created.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Missing Description2.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Missing Description2', 'Test Case Name': 'Lesson Creation with Missing Description', 'Objective': 'Verify that the system prevents the creation of a new lesson without a description.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name in the name field.   - Step 5: Leave the description field empty.   - Step 6: Select 'Save' to attempt creating a new lesson.", 'Expected Result': 'The system should display an error message indicating that the description field cannot be empty and the lesson is not created.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Missing Description3.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Missing Description3', 'Test Case Name': 'Lesson Creation with Missing Description', 'Objective': 'Verify that the system prevents the creation of a new lesson without a description', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Enter a unique name for the lesson in the name field.   - Step 5: Leave the description field empty.   - Step 6: Select 'Save' to attempt creating a new lesson.", 'Expected Result': 'The system should display an error message indicating that the description field cannot be empty and the lesson is not created.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Missing Name1.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Missing Name1', 'Test Case Name': 'Lesson Creation with Missing Name', 'Objective': 'Verify that the system prevents the creation of a new lesson without a lesson name', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Redirected to the 'Add new Lesson' page, leave the name field empty.   - Step 5: Fill in the description of the lesson in the description field.   - Step 6: Select 'Save' to attempt creating a new lesson.", 'Expected Result': 'The system should display an error message indicating that the lesson name is required and prevent the lesson from being created.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Missing Name2.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Missing Name2', 'Test Case Name': 'Lesson Creation with Missing Name', 'Objective': 'Verify that the system prevents the creation of a new lesson without a lesson name', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Leave the name field empty.   - Step 5: Add a description for the lesson in the description field.   - Step 6: Select 'Save' to attempt creating a new lesson.", 'Expected Result': 'The system should display an error message indicating that the lesson name is required and prevent the lesson from being created.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Lesson Creation with Missing Name3.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Lesson Creation with Missing Name3', 'Test Case Name': 'Lesson Creation with Missing Name', 'Objective': 'Verify that the system prevents the creation of a new lesson without a lesson name and prompts for a lesson name', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Leave the name field empty.   - Step 5: Add a description of the lesson in the description field.   - Step 6: Select 'Save' to attempt creating a new lesson.", 'Expected Result': 'The system should display a notification or message indicating that the lesson name is required and prevent the lesson from being created.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Navigate to Add New Lesson Page via Navbar Option1.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Navigate to Add New Lesson Page via Navbar Option1', 'Test Case Name': 'Navigate to Add New Lesson Page via Navbar', 'Objective': "Verify that the administrator can navigate to the 'Add New Lesson' page using the navbar option.", 'Test Steps': "- Step 1: Log in to the application as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: From the dropdown menu, select 'Add new Lesson'.", 'Expected Result': "The system should redirect the administrator to the 'Add new Lesson' page."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Navigate to Add New Lesson Page via Navbar Option2.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Navigate to Add New Lesson Page via Navbar Option2', 'Test Case Name': 'Navigate to Add New Lesson Page via Navbar', 'Objective': "Verify that the administrator can navigate to the 'Add New Lesson' page using the navbar option.", 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.", 'Expected Result': "The system should redirect the administrator to the 'Add New Lesson' page."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Navigate to Add New Lesson Page via Navbar Option3.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Navigate to Add New Lesson Page via Navbar Option3', 'Test Case Name': 'Navigate to Add New Lesson Page via Navbar', 'Objective': "Verify that the administrator can navigate to the 'Add New Lesson' page using the navbar option.", 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.", 'Expected Result': "The system should redirect the administrator to the 'Add new Lesson' page."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Successful Lesson Creation1.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Successful Lesson Creation1', 'Test Case Name': 'Successful New Lesson Creation', 'Objective': 'Verify that the administrator can successfully add a new English learning lesson.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: Enter a unique name for the lesson in the name field.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Save' to create the new lesson.", 'Expected Result': 'The system should redirect the administrator to the adding topic to new lesson section, and the new lesson should appear in the lesson list.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Successful Lesson Creation2.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Successful Lesson Creation2', 'Test Case Name': 'Successful New Lesson Creation', 'Objective': 'Verify that an administrator can successfully add a new English learning lesson.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'Add new Lesson' from the dropdown menu.   - Step 4: On the 'Add new Lesson' page, enter a unique name in the name field.   - Step 5: Enter a description for the lesson in the description field.   - Step 6: Select 'Save' to create the new lesson.", 'Expected Result': 'The system should redirect the administrator to the adding topic to new lesson section, and the new lesson should appear in the lesson list.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson\Successful Lesson Creation3.txt
# [{'Use Case Name': 'AddLesson', 'Test Scenario Name': 'Successful Lesson Creation3', 'Test Case Name': 'Successful Lesson Creation via Lesson Management', 'Objective': 'Verify that an administrator can successfully add a new English learning lesson through the Lesson Management page.', 'Test Steps': "- Step 1: Log in as an administrator.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select 'View list of Lesson' from the dropdown menu.   - Step 4: On the Lesson Management page, select the button 'Add new Lesson'.   - Step 5: On the 'Add new Lesson' page, enter a unique name for the lesson in the name field.   - Step 6: Add a description for the lesson in the description field.   - Step 7: Select 'Save' to create the new lesson.", 'Expected Result': 'The system should redirect the administrator to the adding topic to new lesson section, and the new lesson should appear in the lesson list.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field containing special characters1.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field containing special characters1", 'Test Case Name': "Verify admin cannot add new question with special characters in 'sentence' field", 'Objective': "Ensure that the system prevents the admin from adding a new question for the selection test if the 'sentence' field contains special characters", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option to add 'Create questions for the selection test'.   - Step 8: Fill the 'sentence' field with a sentence that includes special characters (e.g., '@#$%^&*').   - Step 9: Fill the 'correct answer' field with a valid word.   - Step 10: Fill the 'other option 1', 'other option 2', 'other option 3' fields with three different wrong answer words.   - Step 11: Press the 'Save' button.", 'Expected Result': "The system should display a notification that 'Sentence is invalid', preventing the admin from saving the question."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field containing special characters2.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field containing special characters2", 'Test Case Name': "Verify admin cannot add new question with special characters in 'sentence' field", 'Objective': "Ensure that the system prevents the admin from adding a new question for the selection test if the 'sentence' field contains special characters.", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a lesson from the lesson list.   - Step 4: Select a topic from the topic list of the selected lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option to add 'Create questions for the selection test'.   - Step 8: Fill in the 'sentence' field with a sentence that includes special characters (e.g., '@#$%').   - Step 9: Fill in the 'correct answer' and the three 'other option' fields with valid data.   - Step 10: Press the 'Save' button.", 'Expected Result': "The system displays a notification that 'Sentence is invalid', preventing the admin from saving the question."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field containing special characters3.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field containing special characters3", 'Test Case Name': "Verify admin cannot add new question with special characters in 'sentence' field", 'Objective': "Ensure that the system prevents the admin from adding a new question for the selection test if the 'sentence' field contains special characters.", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: In the 'sentence' field, input a valid sentence that includes special characters (e.g., 'This is a test sentence with special characters @#$%^&*').   - Step 9: Fill the 'correct answer' field with the correct word form of the blank in the sentence.   - Step 10: Fill 'other option 1', 'other option 2', 'other option 3' fields with 3 different wrong answer words.   - Step 11: Press the 'Save' button.", 'Expected Result': "The system should display a notification that 'Sentence is invalid', preventing the admin from saving the question."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field more than 250 characters1.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field more than 250 characters1", 'Test Case Name': "Verify admin cannot add a new question with 'sentence' field exceeding 250 characters", 'Objective': "Ensure the system prevents the admin from adding a new question for the selection test if the 'sentence' field contains more than 250 characters.", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a lesson from the lesson list.   - Step 4: Select a topic from the topic list of the selected lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: In the 'sentence' field, input a sentence that is more than 250 characters long, including a symbol '...'.   - Step 9: Fill in the 'correct answer' field with a valid word, and fill in 'other option 1', 'other option 2', 'other option 3' fields with different wrong answer words.   - Step 10: Press the 'Save' button.", 'Expected Result': "The system should display a notification or error message indicating that the 'sentence' field cannot exceed 250 characters and prevent the question from being saved."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field more than 250 characters2.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field more than 250 characters2", 'Test Case Name': "Verify admin cannot add a new question with 'sentence' field exceeding 250 characters", 'Objective': "Ensure the system prevents the addition of a new question for the selection test when the 'sentence' field contains more than 250 characters", 'Test Steps': "- Step 1: Log in as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: In the 'sentence' field, input a sentence that is more than 250 characters long, ensuring it includes the symbol '...'.   - Step 9: Fill in the 'correct answer' and the three 'other options' fields with valid data.   - Step 10: Press the 'Save' button.", 'Expected Result': "The system should display a notification or error message indicating that the 'sentence' field cannot exceed 250 characters and prevent the question from being saved."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field more than 250 characters3.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field more than 250 characters3", 'Test Case Name': "Verify admin cannot add a new question with 'sentence' field over 250 characters", 'Objective': "Ensure the system prevents the admin from adding a new question for the selection test if the 'sentence' field contains more than 250 characters.", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: In the 'sentence' field, input a sentence that is more than 250 characters long and includes the symbol '...'.   - Step 9: Fill in the 'correct answer' field with the correct word form of the blank in the sentence.   - Step 10: Fill in 'other option 1', 'other option 2', 'other option 3' fields with 3 different wrong answer words.   - Step 11: Press the 'Save' button.", 'Expected Result': "The system should display a notification that the 'sentence' is invalid due to exceeding 250 characters and prevent the question from being saved."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field not containing '...'1.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field not containing '...'1", 'Test Case Name': "Verify admin cannot add new question for selection test without '...' in sentence field", 'Objective': "Ensure that the system prevents adding a new question for the selection test if the 'sentence' field does not contain '...'", 'Test Steps': "- Step 1: Log in as Admin.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the button 'Add new question'.   - Step 7: Press option add 'Create questions for the selection test'.   - Step 8: Fill the 'sentence' field with a valid sentence without the symbol '...'.   - Step 9: Fill the 'correct answer' field with the correct word form of the blank in the sentence.   - Step 10: Fill 'other option 1', 'other option 2', 'other option 3' fields with 3 different wrong answer words.   - Step 11: Press the button 'Save'.", 'Expected Result': "System shows notification that 'Sentence is invalid', prompting Admin to re-enter the 'sentence' field with '...'."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field not containing '...'2.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field not containing '...'2", 'Test Case Name': "Add new question for selection test with 'sentence' field not containing '...'", 'Objective': "Verify that the system prevents adding a new question for the selection test if the 'sentence' field does not contain '...'", 'Test Steps': "- Step 1: Log in as Admin.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the button 'Add new question'.   - Step 7: Press option add 'Create questions for the selection test'.   - Step 8: Fill the 'sentence' field with a valid sentence that does not contain '...'.   - Step 9: Fill the 'correct answer' field with the correct word form of the blank in the sentence.   - Step 10: Fill 'other option 1', 'other option 2', 'other option 3' fields with 3 different wrong answer words.   - Step 11: Press the button 'Save'.", 'Expected Result': "System shows notification that 'Sentence is invalid', prompting Admin to re-enter the 'sentence' field with '...'."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with 'sentence' field not containing '...'3.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with 'sentence' field not containing '...'3", 'Test Case Name': "Verify admin cannot add new question for selection test with 'sentence' field not containing '...'", 'Objective': "Ensure the system prevents adding a new question for the selection test if the 'sentence' field does not include '...'", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' page by pressing the tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: On the 'Lesson Information' page, select a Topic from the Topic list.   - Step 5: On the 'Topic Information' page, select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button on the 'Word Information' page.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: Fill in the 'sentence' field with a valid sentence that does not contain '...', fill in the 'correct answer' field with the correct word, and fill in 'other option 1', 'other option 2', 'other option 3' fields with different wrong answers.   - Step 9: Press the 'Save' button.", 'Expected Result': "The system shows a notification that 'Sentence is invalid', prompting Admin to re-enter the 'sentence' field with '...'."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'correct answer' field1.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with empty 'correct answer' field1", 'Test Case Name': "Verify admin cannot add new question for selection test with empty 'correct answer' field", 'Objective': "Ensure the system prevents adding a new question for the selection test when the 'correct answer' field is left empty by the admin", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the button 'Add new question'.   - Step 7: Press option 'Create questions for the selection test'.   - Step 8: Fill the 'sentence' field with a valid sentence that includes the symbol '...'.   - Step 9: Leave the 'correct answer' field empty.   - Step 10: Fill the 'other option 1', 'other option 2', 'other option 3' fields with different wrong answers.   - Step 11: Press the button 'Save'.", 'Expected Result': "The system shows a notification that 'Admin did not fill all the fields', prompting Admin to fill the missing 'correct answer' field."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'correct answer' field2.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with empty 'correct answer' field2", 'Test Case Name': "Verify admin cannot add new question for selection test with empty 'correct answer' field", 'Objective': "Ensure the system prevents adding a new question for the selection test when the 'correct answer' field is empty", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: Fill in the 'sentence' field with a valid sentence that includes the symbol '...'.   - Step 9: Leave the 'correct answer' field empty.   - Step 10: Fill in the 'other option 1', 'other option 2', and 'other option 3' fields with different wrong answers.   - Step 11: Press the 'Save' button.", 'Expected Result': "The system should display a notification that 'Admin did not fill all the fields', prompting the Admin to fill the missing 'correct answer' field."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'correct answer' field3.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with empty 'correct answer' field3", 'Test Case Name': "Verify admin cannot add new question for selection test with empty 'correct answer' field", 'Objective': "Ensure the system prevents adding a new question for the selection test when the 'correct answer' field is left empty by the admin", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option to 'Create questions for the selection test'.   - Step 8: Fill in the 'sentence' field with a valid sentence that includes the symbol '...'.   - Step 9: Leave the 'correct answer' field empty.   - Step 10: Fill in 'other option 1', 'other option 2', 'other option 3' fields with different wrong answers.   - Step 11: Press the 'Save' button.", 'Expected Result': "The system should display a notification that 'Admin did not fill all the fields', prompting Admin to fill the missing 'correct answer' field."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'other option 1' field1.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with empty 'other option 1' field1", 'Test Case Name': "Verify admin cannot add new question for selection test with empty 'other option 1' field", 'Objective': "Ensure the system prevents adding a new question for the selection test if the 'other option 1' field is left empty by the admin", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: Fill in the 'sentence' field with a valid sentence that includes the symbol '...'.   - Step 9: Fill in the 'correct answer' field with the correct word form of the blank in the sentence.   - Step 10: Leave the 'other option 1' field empty.   - Step 11: Fill in the 'other option 2' and 'other option 3' fields with different wrong answer words.   - Step 12: Press the 'Save' button.", 'Expected Result': "The system should display a notification that 'Admin did not fill all the fields', prompting the Admin to fill the missing 'other option 1' field."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'other option 1' field2.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with empty 'other option 1' field2", 'Test Case Name': "Verify admin cannot add new question for selection test with empty 'other option 1' field", 'Objective': "Ensure the system prevents adding a new question for the selection test if the 'other option 1' field is left empty by the admin", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Press the tab 'Lesson Management' on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Press a Topic from the Topic list of the selected Lesson.   - Step 5: Press a word from the vocabulary word list.   - Step 6: Press the button 'Add new question'.   - Step 7: Press option 'Create questions for the selection test'.   - Step 8: Fill the 'sentence' field with a valid sentence that includes the symbol '...'.   - Step 9: Fill the 'correct answer' field with the correct word form of the blank in the sentence.   - Step 10: Leave the 'other option 1' field empty.   - Step 11: Fill the 'other option 2' and 'other option 3' fields with different wrong answer words.   - Step 12: Press the button 'Save'.", 'Expected Result': "The system shows a notification that 'Admin did not fill all the fields', prompting Admin to fill the missing 'other option 1' field."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'other option 1' field3.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with empty 'other option 1' field3", 'Test Case Name': "Verify admin cannot add new question for selection test with empty 'other option 1' field", 'Objective': "Ensure the system prevents adding a new question for the selection test when the 'other option 1' field is left empty by the admin", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: Fill in the 'sentence' field with a valid sentence that includes the symbol '...'.   - Step 9: Fill in the 'correct answer' field with the correct word form of the blank in the sentence.   - Step 10: Leave the 'other option 1' field empty.   - Step 11: Fill in the 'other option 2' and 'other option 3' fields with different wrong answer words.   - Step 12: Press the 'Save' button.", 'Expected Result': "The system shows a notification that 'Admin did not fill all the fields', prompting the Admin to fill the missing 'other option 1' field."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'other option 2' field1.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with empty 'other option 2' field1", 'Test Case Name': "Verify admin cannot add new question for selection test with empty 'other option 2' field", 'Objective': "Ensure the system prompts an error when 'other option 2' field is left empty while adding a new question for the selection test", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' page by pressing the tab 'Lesson Management' on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: On the 'Lesson Information' page, select a Topic from the Topic list.   - Step 5: On the 'Topic Information' page, select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button on the 'Word Information' page.   - Step 7: Choose the option 'Create questions for the selection test' when prompted to select the type of question.   - Step 8: Fill in the 'sentence' field with a valid sentence that includes the symbol '...'.   - Step 9: Fill in the 'correct answer' field with the correct word form of the blank in the sentence.   - Step 10: Fill in the 'other option 1' field with a different wrong answer word.   - Step 11: Leave the 'other option 2' field empty.   - Step 12: Fill in the 'other option 3' field with another different wrong answer word.   - Step 13: Press the 'Save' button to attempt saving the question.", 'Expected Result': "The system shows a notification that 'Admin did not fill all the fields', prompting Admin to fill the missing 'other option 2' field."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'other option 2' field2.txt
# [{'Use Case Name': 'AddLessonIdeal', 'Test Scenario Name': "admin can not Add new question for selection test with empty 'other option 2' field2", 'Test Case Name': "Verify admin cannot add new question for selection test with empty 'other option 2' field", 'Objective': "Ensure the system prompts an error when 'other option 2' field is left empty while adding a new question for the selection test", 'Test Steps': "- Step 1: Log in to the system as an Admin.   - Step 2: Navigate to the 'Lesson Management' tab on the navbar.   - Step 3: Select a Lesson from the Lesson list.   - Step 4: Select a Topic from the Topic list of the selected Lesson.   - Step 5: Select a word from the vocabulary word list.   - Step 6: Press the 'Add new question' button.   - Step 7: Choose the option 'Create questions for the selection test'.   - Step 8: Fill in the 'sentence' field with a valid sentence that includes '...'.   - Step 9: Fill in the 'correct answer' field with the correct word form.   - Step 10: Fill in the 'other option 1' field with a different wrong answer word.   - Step 11: Leave the 'other option 2' field empty.   - Step 12: Fill in the 'other option 3' field with a different wrong answer word.   - Step 13: Press the 'Save' button.", 'Expected Result': "The system should display a notification that 'Admin did not fill all the fields', prompting Admin to fill the missing 'other option 2' field."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLessonIdeal\admin can not Add new question for selection test with empty 'other option 2' field3.txt
# ...
# D:\Dissertation-GPT\5.25-NhuY\Matcha\ReviewTest\Exit and Choose to Stay Scenario1.txt
# [{'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Exit and Choose to Stay Scenario1', 'Test Case Name': 'Verify Exit and Choose to Stay during Review', 'Objective': "Ensure that when learners press 'Exit' and then choose 'Stay', they can continue with their review without losing progress.", 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review's screen and start the review process.   - Step 4: At any point during the review (before finishing all words), press the 'Exit' button.   - Step 5: On the pop-up, choose the 'Stay' button.", 'Expected Result': "The system should return the learner to the same point in the review process where they pressed 'Exit', allowing them to continue their review without any loss of progress."}, {'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Exit and Choose to Stay Scenario1', 'Test Case Name': 'Verify Exit and Choose to Confirm during Review', 'Objective': "Ensure that when learners press 'Exit' and then choose 'Confirm', they are redirected to the Home page and the review progress is not saved.", 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review's screen and start the review process.   - Step 4: At any point during the review (before finishing all words), press the 'Exit' button.   - Step 5: On the pop-up, choose the 'Confirm' button.", 'Expected Result': 'The system should redirect the learner to the Home page without saving the review progress.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\ReviewTest\Learner decides to exit during review session before selecting an answer.1.txt
# [{'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Learner decides to exit during review session before selecting an answer.1', 'Test Case Name': 'Learner decides to exit during review session before selecting an answer and confirms to exit', 'Objective': 'Verify that the learner can exit the review session before selecting an answer and ensure the session is not saved', 'Test Steps': "- Step 1: Log in as a learner with an account that has words for review.   - Step 2: Select the review button on the Home page to start the review session.   - Step 3: Wait for the system to redirect to the review screen and display a question, sound, image, or meaning of one word from the daily review words list.   - Step 4: Before selecting any of the four answer options, press the 'Exit' button.   - Step 5: On the pop-up, choose the 'Confirm' button to exit the review session.", 'Expected Result': 'The learner is redirected to the Home page without the review session being saved.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\ReviewTest\Learners choose the wrong answer1.txt
# [{'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Learners choose the wrong answer1', 'Test Case Name': 'Learners choose the wrong answer during review', 'Objective': 'Verify that when learners choose the wrong answer, the system shows a red word, decreases the memory level of the word, and allows continuation to the next word', 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review's screen.   - Step 4: Engage with the review by waiting for the system to present a word with four selections of answers.   - Step 5: Intentionally choose the wrong answer from the four selections.   - Step 6: Observe the feedback provided by the system.   - Step 7: Press the 'Continue' button to proceed to the next word.", 'Expected Result': "After choosing the wrong answer, the system should display a red word indicating the mistake, decrease the memory level of the word, and allow the learner to press 'Continue' to move to the next word."}, {'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Learners choose the wrong answer1', 'Test Case Name': 'Learners choose the wrong answer and reach the last word in the review list', 'Objective': 'Verify that after choosing the wrong answer for the last word in the review list, the system shows a red word, decreases the memory level, and redirects learners back to the Home page.', 'Test Steps': "- Step 1: Log in as a learner with only one word left in the review words list for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review's screen.   - Step 4: Engage with the review by waiting for the system to present the last word with four selections of answers.   - Step 5: Intentionally choose the wrong answer from the four selections for the last word.   - Step 6: Observe the feedback provided by the system.   - Step 7: Press the 'Continue' button.", 'Expected Result': 'After choosing the wrong answer for the last word, the system should display a red word indicating the mistake, decrease the memory level of the word, and then redirect the learner back to the Home page as the review session is completed.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\ReviewTest\Review with Meaning Method1.txt
# [{'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Review with Meaning Method1', 'Test Case Name': 'Review with Meaning Method - Correct Answer Selection', 'Objective': 'Verify that the system correctly increases the memory level of a word when the learner selects the right answer using the meaning method.', 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review screen.   - Step 4: Ensure the system randomly selects the meaning method for a word.   - Step 5: Choose the correct meaning by clicking on one of the four selections.   - Step 6: Click the right answer.   - Step 7: Press the 'Continue' button to proceed to the next word.", 'Expected Result': "After selecting the right answer, a green word should be displayed, indicating the word's memory level has been increased."}, {'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Review with Meaning Method1', 'Test Case Name': 'Review with Meaning Method - Incorrect Answer Selection', 'Objective': 'Verify that the system correctly decreases the memory level of a word when the learner selects the wrong answer using the meaning method.', 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review screen.   - Step 4: Ensure the system randomly selects the meaning method for a word.   - Step 5: Choose the wrong meaning by clicking on one of the four selections.   - Step 6: Click the wrong answer.   - Step 7: Press the 'Continue' button to proceed to the next word.", 'Expected Result': "After selecting the wrong answer, a red word should be displayed, indicating the word's memory level has been decreased."}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\ReviewTest\Review with Question Method1.txt
# [{'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Review with Question Method1', 'Test Case Name': 'Review with Question Method - Correct Answer Flow', 'Objective': 'Verify that the system correctly increases the memory level of a word when the learner selects the right answer during a review session.', 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review screen.   - Step 4: Answer a question correctly by clicking on the right one of the four selections provided.   - Step 5: Click the 'Continue' button to proceed to the next word.", 'Expected Result': 'After selecting the right answer, the system should display a green word indicating the correct choice and increase the memory level of the word.'}, {'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Review with Question Method1', 'Test Case Name': 'Review with Question Method - Incorrect Answer Flow', 'Objective': 'Verify that the system correctly decreases the memory level of a word when the learner selects the wrong answer during a review session.', 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review screen.   - Step 4: Answer a question incorrectly by clicking on the wrong one of the four selections provided.   - Step 5: Click the 'Continue' button to proceed to the next word.", 'Expected Result': 'After selecting the wrong answer, the system should display a red word indicating the incorrect choice and decrease the memory level of the word.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\ReviewTest\Review with Sound Method1.txt
# [{'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Review with Sound Method1', 'Test Case Name': 'Review with Sound Method - Correct Answer', 'Objective': 'Verify that the system correctly increases the memory level of a word when the learner selects the correct answer in the sound method review.', 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review screen.   - Step 4: Ensure the system randomly selects the sound method for one of the words in the review list.   - Step 5: Listen to the sound and choose the correct answer among the four selections provided.   - Step 6: Click the right answer.   - Step 7: Press the 'Continue' button to proceed to the next word.", 'Expected Result': "After selecting the correct answer, a green word should be displayed, indicating the word's memory level has been increased."}, {'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Review with Sound Method1', 'Test Case Name': 'Review with Sound Method - Incorrect Answer', 'Objective': 'Verify that the system correctly decreases the memory level of a word when the learner selects the wrong answer in the sound method review.', 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review screen.   - Step 4: Ensure the system randomly selects the sound method for one of the words in the review list.   - Step 5: Listen to the sound and choose the wrong answer among the four selections provided.   - Step 6: Click the wrong answer.   - Step 7: Press the 'Continue' button to proceed to the next word.", 'Expected Result': "After selecting the wrong answer, a red word should be displayed, indicating the word's memory level has been decreased."}, {'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Review with Sound Method1', 'Test Case Name': 'Review with Sound Method - Completion', 'Objective': 'Verify that the system correctly navigates the learner back to the Home page and saves the review upon completing the last word in the review list.', 'Test Steps': "- Step 1: Log in as a learner with only one word left in the review words list for today.   - Step 2: Select the review button on the Home page.   - Step 3: Wait for the system to redirect to the review screen.   - Step 4: Ensure the system randomly selects the sound method for the word in the review list.   - Step 5: Choose the correct or wrong answer for the word.   - Step 6: Press the 'Continue' button after answering the last word.", 'Expected Result': 'The system should navigate the learner back to the Home page and save the review session.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\ReviewTest\Scenario Learner decides to exit during review session before selecting an answer..txt
# [{'Use Case Name': 'ReviewTest', 'Test Scenario Name': 'Scenario Learner decides to exit during review session before selecting an answer.', 'Test Case Name': 'Verify learner can exit review session before selecting an answer', 'Objective': "Ensure that learners can exit the review session by pressing the 'Exit' button before selecting any answer and confirm to exit, and the review progress is not saved.", 'Test Steps': "- Step 1: Log in as a learner with a review words list available for today.   - Step 2: On the Home page, select the review button.   - Step 3: Wait for the system to redirect to the review's screen.   - Step 4: Observe a question, sound, image, or meaning displayed with four selections of answer at the bottom of the screen.   - Step 5: Press the 'Exit' button before selecting any of the four answer options.   - Step 6: On the pop-up, choose the 'Confirm' button to exit the review session.", 'Expected Result': 'The learner is redirected to the Home page without the review progress being saved.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\WordSorting\Correct Answer Submission Scenario1.txt
# [{'Use Case Name': 'WordSorting', 'Test Scenario Name': 'Correct Answer Submission Scenario1', 'Test Case Name': 'Correct Answer Submission', 'Objective': 'Verify that the system correctly identifies and accepts a correct answer submission from the learner.', 'Test Steps': '- Step 1: Log into the application with a learner account.   - Step 2: Navigate to the word sorting test.   - Step 3: Read the question or the meaning of the vocabulary or observe the image showing the word with its letters arranged randomly.   - Step 4: Arrange the letters in the correct order by clicking on the letter buttons and press enter after finishing.', 'Expected Result': 'A green pop-up screen should appear, indicating that the answer is correct.'}]
# D:\Dissertation-GPT\5.25-NhuY\Matcha\WordSorting\Incorrect Answer Submission Scenario1.txt
# [{'Use Case Name': 'WordSorting', 'Test Scenario Name': 'Incorrect Answer Submission Scenario1', 'Test Case Name': 'Incorrect Answer Submission for Word Sorting Test', 'Objective': 'Verify that the system correctly identifies and responds to an incorrect answer submission by displaying a red pop-up screen.', 'Test Steps': '- Step 1: Log into the application as a learner.   - Step 2: Navigate to the word sorting test.   - Step 3: The screen displays a question with letters of a vocabulary arranged randomly.   - Step 4: Incorrectly arrange the letters by clicking on the letter buttons in the wrong order.   - Step 5: Press enter after finishing arranging the letters.', 'Expected Result': 'A red pop-up screen should appear, indicating that the answer is wrong.'}]
# e:\ProgramData\anaconda3\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
