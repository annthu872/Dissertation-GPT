# %%
import os
import pandas as pd

def read_files_in_folder(folder_path):
    all_content = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                # Add file name
                all_content.append(filename)
                # Add file contents line by line
                lines = file.readlines()
                all_content.extend(lines)
                # Add a blank line to separate files
                all_content.append('')
    return all_content

def write_content_to_excel(content, excel_file_path):
    df = pd.DataFrame(content, columns=["Test Scenario"])
    df.to_excel(excel_file_path, index=False, engine='openpyxl')

def main():
    folder_path = r'D:\Dissertation-GPT\evaluate\baseline 2\matcha\ts'  # Change this to your folder path
    excel_file_path = 'output.xlsx'

    content = read_files_in_folder(folder_path)
    write_content_to_excel(content, excel_file_path)
    print(f"All file contents have been written to {excel_file_path}")

if __name__ == "__main__":
    main()
# Out:
# All file contents have been written to output.xlsx

# %%
import re
import pandas as pd
import os
import chardet

def read_file_content(file_path):
    # Detect the encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        return content
    except FileNotFoundError:
        return f"Error: The file at path {file_path} was not found."
    except UnicodeDecodeError:
        return f"Error: The file at path {file_path} cannot be decoded with the {encoding} encoding."
    except IOError:
        return f"Error: An I/O error occurred while reading the file at path {file_path}."

def split_before_and_after_hyphen(file_name):
    parts = file_name.split('-', 1)
    if len(parts) == 2:
        before_hyphen, after_hyphen = parts
    else:
        before_hyphen, after_hyphen = file_name, ""
    return before_hyphen.strip(), after_hyphen.strip()

# Function to parse the test cases from the text file
def parse_test_cases(file_name):
    # with open(file_name, 'r') as file:
    #     content = file.read()
    content = read_file_content(file_name)
    base_name = os.path.basename(file_name)

    base_nam = os.path.splitext(base_name)[0]

    # Extract use case and test scenario names from the file name
    use_case_name, test_scenario_name = split_before_and_after_hyphen(base_nam)
    
    # Regular expression to extract test cases
    test_case_pattern = re.compile(
        r"Test Case: (.*?)\ntestCaseName: (.*?)\nobjective: (.*?)\ntestSteps:\n(.*?)\nexpectedResult: (.*?)\n",
        re.DOTALL
    )
    
    matches = test_case_pattern.findall(content)
    
    test_cases = []
    for match in matches:
        test_case_name = match[1].strip()
        objective = match[2].strip()
        test_steps = match[3].strip().replace('\n', ' ')
        expected_result = match[4].strip()
        
        test_cases.append({
            'Use Case Name': use_case_name,
            'Test Scenario Name': test_scenario_name,
            'Test Case Name': test_case_name,
            'Objective': objective,
            'Test Steps': test_steps,
            'Expected Result': expected_result
        })
    
    return test_cases

# Function to write the parsed test cases to an Excel file
def write_to_excel(test_cases, output_file):
    df = pd.DataFrame(test_cases)
    df.to_excel(output_file, index=False)
all_test_cases = []

# File names
# input_file = 'use_case-test_scenario.txt'
output_file = 'test_cases.xlsx'
folder_path = r'D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw'
# Parse the test cases and write to Excel
file_list = os.listdir(folder_path)

def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(1)) if match else float('inf')

# Function to sort filenames naturally by the extracted number
def natural_sort_key(filename):
    # Split the filename into parts: prefix and number
    parts = re.split(r'(\d+)', filename)
    # Convert numerical parts to integers for proper numeric sorting
    parts[1::2] = map(int, parts[1::2])
    return parts

# Sort filenames using the natural sort key
sorted_files = sorted(file_list, key=natural_sort_key)

for i in sorted_files: 
    print(i)
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    print(file_path)
    if os.path.isfile(file_path):
        test_cases = parse_test_cases(file_path)
        print(test_cases)
        test_cases = parse_test_cases(file_path)
        all_test_cases.extend(test_cases)
write_to_excel(all_test_cases, output_file)
# Out:
# Add a new author-CreateNewAuthor_WithoutBio.txt
# Add a new author-CreateNewAuthor_WithoutName.txt
# Add a new author-Incorrect Data Submission.txt
# Add a new author-Successful Author Record Creation.txt
# Add a new author-User navigates to API before submitting data.txt
# Add a new author-User navigates to Authors before submitting data.txt
# Add a new author-User navigates to Books before submitting data.txt
# Add a new author-User navigates to Genres before submitting data.txt
# Add a new author-User navigates to Home before submitting data.txt
# Add a new author-User starts entering data and decides to cancel.txt
# Add a new book-Add a new book with empty Author.txt
# Add a new book-Add a new book with empty Description.txt
# Add a new book-Add a new book with empty Publication date.txt
# Add a new book-Add a new book with empty Title.txt
# Add a new book-Book Creation with Incorrect Data.txt
# Add a new book-Cancel Operation After Partial Data Entry.txt
# Add a new book-Cancel Operation Before Data Submission.txt
# Add a new book-Navigation to API Before Submission.txt
# Add a new book-Navigation to Authors Before Submission.txt
# Add a new book-Navigation to Books Before Submission.txt
# Add a new book-Navigation to Genres Before Submission.txt
# Add a new book-Navigation to Home Before Submission.txt
# Add a new book-Successful Book Creation.txt
# Add a new genre-CreateGenre_WithoutDescription.txt
# Add a new genre-CreateGenre_WithoutName.txt
# Add a new genre-Genre Creation with Incorrect Data.txt
# Add a new genre-Successful Genre Creation.txt
# Add a new genre-User Cancels While Entering Data.txt
# Add a new genre-User Navigates Away by Selecting API.txt
# Add a new genre-User Navigates Away by Selecting Authors.txt
# Add a new genre-User Navigates Away by Selecting Books.txt
# Add a new genre-User Navigates Away by Selecting Genres.txt
# Add a new genre-User Navigates Away by Selecting Home.txt
# Display author details-Display Author Details Successfully.txt
# Display book details-Successful Display of Book Details.txt
# Display genre details-1. Successful Genre Details Display.txt
# Display the list of authors-1. Display First Page of Authors.txt
# Display the list of authors-2. Navigate to Next Page of Authors.txt
# Display the list of authors-3. Navigate to a Specific Page of Authors.txt
# Display the list of authors-4. Last Page of Authors Displayed.txt
# Display the list of books-1. Scenario Date Range Not Specified.txt
# Display the list of books-2. Scenario Date Range Format Incorrect.txt
# Display the list of books-3. Successful display of the first page of books.txt
# Display the list of books-4. Navigation to the next page of books.txt
# Display the list of books-5. Navigation to a specific page of books.txt
# Display the list of books-6. Last page of books display.txt
# Display the list of books-7. Attempt to navigate beyond the last page of books.txt
# Display the list of genres-1. Viewing the First Page of Genres.txt
# Display the list of genres-2. Navigating to the Next Page of Genres.txt
# Display the list of genres-3. Navigating to a Specific Page of Genres.txt
# Display the list of genres-4. Viewing the Last Page of Genres.txt
# Display the list of genres-5. Attempting to Navigate Beyond the Last Page of Genres.txt
# Edit the author-Author Update with Incorrect Data.txt
# Edit the author-Cancel Operation by Pressing Cancel Button.txt
# Edit the author-Cancel Operation by Selecting API Menu Item.txt
# Edit the author-Cancel Operation by Selecting Authors Menu Item.txt
# Edit the author-Cancel Operation by Selecting Books Menu Item.txt
# Edit the author-Cancel Operation by Selecting Genres Menu Item.txt
# Edit the author-Cancel Operation by Selecting Home Menu Item.txt
# Edit the author-Successful Author Update.txt
# Edit the author-UpdateAuthor_WithEmptyBio.txt
# Edit the author-UpdateAuthor_WithEmptyName.txt
# Edit the book-Book Update with Incorrect Data.txt
# Edit the book-Successful Book Update.txt
# Edit the book-UpdateBook_InvalidAuthor.txt
# Edit the book-UpdateBook_InvalidDescription.txt
# Edit the book-UpdateBook_InvalidGenre.txt
# Edit the book-UpdateBook_InvalidPublicationDate.txt
# Edit the book-UpdateBook_InvalidTitle.txt
# Edit the book-User navigates to API menu item before submitting updated book data.txt
# Edit the book-User navigates to Authors menu item before submitting updated book data.txt
# Edit the book-User navigates to Books menu item before submitting updated book data.txt
# Edit the book-User navigates to Genres menu item before submitting updated book data.txt
# Edit the book-User navigates to Home menu item before submitting updated book data.txt
# Edit the book-User presses Cancel button before submitting updated book data.txt
# Edit the genre-1. Scenario Update Genre with Incorrectly Entered Genre Name.txt
# Edit the genre-2. Scenario Update Genre with Incorrectly Entered Genre Description.txt
# Edit the genre-3. Successful Genre Update.txt
# Edit the genre-4. Genre Update Failure with Error Message.txt
# Edit the genre-5. Cancel operation before data submission.txt
# Edit the genre-6. Navigation to Books before data submission.txt
# Edit the genre-7. Navigation to Genres before data submission.txt
# Edit the genre-8. Navigation to Authors before data submission.txt
# Edit the genre-9. Navigation to Home before data submission.txt
# Edit the genre-10. Navigation to API before data submission.txt
# Remove the author-1. Successful Deletion Scenario.txt
# Remove the author-2. Deletion Cancellation Scenario.txt
# Remove the author-4. User Navigates Away Using Menu Before Confirming Deletion.txt
# Remove the book-Successful Book Deletion.txt
# Remove the book-User Cancels Deletion by Selecting API Menu Item.txt
# Remove the book-User Cancels Deletion by Selecting Authors Menu Item.txt
# Remove the book-User Cancels Deletion by Selecting Books Menu Item.txt
# Remove the book-User Cancels Deletion by Selecting Genres Menu Item.txt
# Remove the book-User Cancels Deletion by Selecting Home Menu Item.txt
# Remove the book-User Cancels Deletion via Cancel Button.txt
# Remove the genre-Successful Genre Deletion.txt
# Remove the genre-User Cancels Deletion.txt
# Remove the genre-User Navigates Away Using Menu Before Confirming Deletion.txt
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-CreateNewAuthor_WithoutBio.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'CreateNewAuthor_WithoutBio', 'Test Case Name': 'Create New Author Without Entering Bio', 'Objective': 'Verify that a new author can be added without entering the biography and the record is successfully added to the database.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Enter the author's name in the 'Name' field.   - Step 4: Leave the 'Bio' field empty.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'A new author record without the biography is successfully added to the database, and the list of authors with the newly added record is displayed.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'CreateNewAuthor_WithoutBio', 'Test Case Name': 'Create New Author With Bio and Then Without Bio', 'Objective': 'Verify that the system allows creating new author records first with entering the biography and then without entering the biography.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Enter the author's name in the 'Name' field for the first author.   - Step 4: Enter a biography in the 'Bio' field for the first author.   - Step 5: Press the 'Submit' button for the first author.   - Step 6: Repeat steps 2 to 5 for the second author, but leave the 'Bio' field empty for the second author.", 'Expected Result': 'Two new author records are successfully added to the database, one with a biography and one without. The list of authors with these newly added records is displayed.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'CreateNewAuthor_WithoutBio', 'Test Case Name': 'Attempt to Create New Author Without Name', 'Objective': 'Verify that the system prevents adding a new author without entering the name, displaying an error message.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Leave the 'Name' field empty.   - Step 4: Enter a biography in the 'Bio' field.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'An error message is displayed indicating that the name field is required and the new author record is not added to the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-CreateNewAuthor_WithoutName.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'CreateNewAuthor_WithoutName', 'Test Case Name': 'Create New Author Without Entering Name', 'Objective': 'Verify that the system prevents the creation of a new author record without a name and displays the appropriate error message.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering author data.   - Step 3: Leave the 'Name' field empty.   - Step 4: Enter a valid biography in the 'Bio' field.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'An error message is displayed indicating that the name field is required and the record should not be added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'CreateNewAuthor_WithoutName', 'Test Case Name': 'Cancel Creating New Author Without Entering Name', 'Objective': "Verify that the system does not save the new author record when the 'Cancel' button is pressed, even if the name has not been entered.", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering author data.   - Step 3: Leave the 'Name' field empty.   - Step 4: Enter any data in the 'Bio' field.   - Step 5: Press the 'Cancel' button.", 'Expected Result': 'The system does not save the new author record and redirects the user to the list of authors, showing that no new record has been added.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-Incorrect Data Submission.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'Incorrect Data Submission', 'Test Case Name': 'Incorrect Name Data Submission for New Author', 'Objective': 'Verify that the system displays an incorrect data message when submitting a form with an incorrect name for a new author', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Enter an incorrect name format in the 'Name' field (e.g., using numbers or special characters).   - Step 4: Fill in the 'Bio' field with valid author's biography.   - Step 5: Press the 'Submit' button.", 'Expected Result': "An incorrect data message is displayed next to the 'Name' field indicating the error in the name format."}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'Incorrect Data Submission', 'Test Case Name': 'Incorrect Bio Data Submission for New Author', 'Objective': 'Verify that the system displays an incorrect data message when submitting a form with an incorrect bio for a new author', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Enter a valid name in the 'Name' field.   - Step 4: Enter incorrect data in the 'Bio' field (e.g., leaving it blank or using inappropriate language).   - Step 5: Press the 'Submit' button.", 'Expected Result': "An incorrect data message is displayed next to the 'Bio' field indicating the error in the biography format."}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'Incorrect Data Submission', 'Test Case Name': 'Cancel Operation During Incorrect Data Submission for New Author', 'Objective': "Verify that the data is not saved and the user is redirected to the list of authors upon pressing the 'Cancel' button during an incorrect data submission", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Enter incorrect data in both the 'Name' and 'Bio' fields.   - Step 4: Press the 'Cancel' button before pressing the 'Submit' button.", 'Expected Result': 'The user is redirected to the list of authors without the new author being added, indicating that the data was not saved.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-Successful Author Record Creation.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'Successful Author Record Creation', 'Test Case Name': 'Successful New Author Record Creation', 'Objective': 'Verify that a new author record can be successfully added to the database with valid data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author data entry form.   - Step 3: Enter valid data into the form fields including the author's name and biography.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'A new author record is successfully added to the database, and the list of authors with the newly added record is displayed.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'Successful Author Record Creation', 'Test Case Name': 'Display Error Message for Incorrect Author Data Submission', 'Objective': 'Verify that an error message is displayed when incorrect data is submitted for a new author record', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author data entry form.   - Step 3: Enter invalid data into one or more of the form fields (e.g., leave the author's name blank).   - Step 4: Press the 'Submit' button.", 'Expected Result': 'An error message is displayed indicating the incorrect data, and the new author record is not added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'Successful Author Record Creation', 'Test Case Name': 'Cancel New Author Record Creation', 'Objective': 'Verify that the new author record creation process can be canceled without saving data to the database', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author data entry form.   - Step 3: Start entering data into the form fields but do not complete the form.   - Step 4: Press the 'Cancel' button.", 'Expected Result': 'Data is not saved to the database, and the list of author records is displayed without the new record.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'Successful Author Record Creation', 'Test Case Name': 'Navigate Away from New Author Creation Form Without Saving', 'Objective': 'Verify that navigating away from the new author creation form without saving does not add a new record to the database', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author data entry form.   - Step 3: Start entering data into the form fields.   - Step 4: Without pressing 'Submit', select another menu item such as 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'Data is not saved to the database, and the user is redirected to the selected page without adding a new author record.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-User navigates to API before submitting data.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'User navigates to API before submitting data', 'Test Case Name': 'Navigate to API before submitting new author data', 'Objective': 'Verify that navigating to API before submitting new author data does not save the data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields of the form.   - Step 4: Before pressing the 'Submit' button, select the menu item 'API'.", 'Expected Result': 'The application navigates to the API page without saving the entered author data, and no new author record is added to the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-User navigates to Authors before submitting data.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'User navigates to Authors before submitting data', 'Test Case Name': 'Navigate to Authors Page Before Submitting New Author Data', 'Objective': 'Verify that the user can navigate to the Authors page before submitting new author data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button to start adding a new author.   - Step 3: Begin entering the author's details (Name, Bio) into the form.   - Step 4: Before pressing the 'Submit' button, navigate to the 'Authors' page by selecting the 'Authors' menu item.", 'Expected Result': 'The user is redirected to the Authors page, and the data entered is not saved in the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'User navigates to Authors before submitting data', 'Test Case Name': 'Cancel Operation While Adding New Author', 'Objective': 'Verify that the user can cancel the operation of adding a new author and navigate to the Authors page without saving data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button to start adding a new author.   - Step 3: Begin entering the author's details (Name, Bio) into the form.   - Step 4: Press the 'Cancel' button before submitting the form.", 'Expected Result': "The user is redirected to the Authors page without the new author's data being saved in the database."}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-User navigates to Books before submitting data.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'User navigates to Books before submitting data', 'Test Case Name': 'Navigate to Books before submitting new author data', 'Objective': "Verify that navigating to 'Books' before submitting new author data does not save the data", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to start adding a new author.   - Step 3: Application displays form to enter author data. Start entering the author's Name and Bio.   - Step 4: Before pressing 'Submit', navigate to the 'Books' page by selecting the menu item 'Books'.", 'Expected Result': 'The application does not save the entered author data and displays the Books page with updated data.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-User navigates to Genres before submitting data.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'User navigates to Genres before submitting data', 'Test Case Name': 'Navigate to Genres before submitting new author data', 'Objective': 'Verify that navigating to Genres from the author creation form before submitting data does not save the new author data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields of the form.   - Step 4: Before pressing the 'Submit' button, select the 'Genres' menu item to navigate away from the author creation form.", 'Expected Result': 'The application should navigate to the Genres page without saving the entered author data, and no new author record should be added to the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-User navigates to Home before submitting data.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'User navigates to Home before submitting data', 'Test Case Name': 'Navigate to Home Before Submitting New Author Data', 'Objective': 'Verify that navigating to Home before submitting new author data does not save the data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for entering new author data.   - Step 3: Start entering the author's name and biography in the respective fields.   - Step 4: Before pressing the 'Submit' button, select the 'Home' menu item to navigate away from the page.", 'Expected Result': 'The application does not save the entered author data and displays the Home page.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new author-User starts entering data and decides to cancel.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': 'User starts entering data and decides to cancel', 'Test Case Name': 'Cancel new author creation before submission', 'Objective': 'Verify that the author creation process can be cancelled before submitting the form and ensure no data is saved', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to start adding a new author.   - Step 3: Begin entering data into the form fields for the new author.   - Step 4: Press the 'Cancel' button before submitting the form.", 'Expected Result': 'The application should not save the entered data and should display the list of authors records.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': 'User starts entering data and decides to cancel', 'Test Case Name': 'Navigate away from author creation form before submission', 'Objective': 'Verify that navigating away from the author creation form without submitting it cancels the operation and no data is saved', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the form for adding a new author.   - Step 3: Start entering author's details into the form fields.   - Step 4: Without submitting the form, select the menu item 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The application should not save the entered data and should display the corresponding form or page selected from the menu.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Add a new book with empty Author.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Add a new book with empty Author', 'Test Case Name': 'Add a new book with empty Author field', 'Objective': 'Verify that the system prevents adding a new book record when the Author field is left empty and displays an appropriate error message.', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Enter valid data in the 'Title', 'Genre', 'Description', and 'Publication date' fields.   - Step 4: Leave the 'Author' field empty.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'An error message is displayed indicating that the Author field cannot be empty and the book record is not added to the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Add a new book with empty Description.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Add a new book with empty Description', 'Test Case Name': 'Add a new book with empty Description', 'Objective': 'Verify that the system allows adding a new book with all required fields filled except for the Description field', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click on the 'Create new' button to open the book creation form.   - Step 3: Enter valid data into the Title, Author, and Genre fields.   - Step 4: Leave the Description field empty.   - Step 5: Enter a valid date into the Publication date field.   - Step 6: Press the 'Submit' button.", 'Expected Result': 'The system should add the new book record to the database and display the list of books including the newly added record, even though the Description was left empty.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Add a new book with empty Publication date.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Add a new book with empty Publication date', 'Test Case Name': 'Add a new book with empty Publication date', 'Objective': 'Verify that the system allows adding a new book with the Publication date field left empty', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Enter valid data into the Title, Author, Genre, and Description fields.   - Step 4: Leave the Publication date field empty.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'The new book record is successfully added to the database without a Publication date, and the list of books with the newly added record is displayed.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Add a new book with empty Publication date', 'Test Case Name': 'Add a new book with all fields filled except Publication date', 'Objective': 'Verify that the system can add a new book record with all fields filled except for the Publication date', 'Test Steps': "- Step 1: Go to the book list page.   - Step 2: Click on 'Create new' to access the book creation form.   - Step 3: Fill in the Title, Author, Genre, and Description fields with valid information.   - Step 4: Ensure the Publication date field remains empty.   - Step 5: Click the 'Submit' button to attempt to add the new book.", 'Expected Result': 'The system successfully adds the new book record without a Publication date, and displays the updated list of books including the new addition.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Add a new book with empty Title.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Add a new book with empty Title', 'Test Case Name': 'Add a new book with empty Title field', 'Objective': 'Verify that the system prevents adding a new book with an empty Title field and displays an appropriate error message.', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Leave the 'Title' field empty.   - Step 4: Enter valid data into the 'Author', 'Genre', 'Description', and 'Publication date' fields.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'The system should display an error message indicating that the Title field is required and cannot be left empty. The book record should not be added to the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Book Creation with Incorrect Data.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Book Creation with Incorrect Data', 'Test Case Name': 'Book Creation with Missing Mandatory Fields', 'Objective': 'Verify that the system displays correct error messages for missing mandatory fields during book creation', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Leave the 'Title', 'Author', and 'Genre' fields empty.   - Step 4: Fill in the 'Description' and 'Publication date' fields with valid data.   - Step 5: Press the 'Submit' button.", 'Expected Result': "Error messages for missing 'Title', 'Author', and 'Genre' fields are displayed."}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Book Creation with Incorrect Data', 'Test Case Name': 'Book Creation with Incorrect Data Format', 'Objective': "Verify that the system displays an error message for incorrect data format in the 'Publication date' field", 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Fill in the 'Title', 'Author', and 'Genre' fields with valid data.   - Step 4: Enter an incorrect format data into the 'Publication date' field (e.g., 'abcd').   - Step 5: Press the 'Submit' button.", 'Expected Result': "An error message indicating the incorrect format for the 'Publication date' field is displayed."}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Book Creation with Incorrect Data', 'Test Case Name': 'Book Creation with Exceedingly Long Data', 'Objective': 'Verify that the system displays an error message for data that exceeds maximum length limits', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Enter a very long string (exceeding the field's maximum length) into the 'Title' field.   - Step 4: Fill in the remaining fields ('Author', 'Genre', 'Description', 'Publication date') with valid data.   - Step 5: Press the 'Submit' button.", 'Expected Result': "An error message indicating that the 'Title' field exceeds the maximum length is displayed."}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Cancel Operation After Partial Data Entry.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Cancel Operation After Partial Data Entry', 'Test Case Name': 'Cancel New Book Creation After Partial Data Entry by Cancel Button', 'Objective': "Verify that the book creation process can be canceled after partial data entry by using the 'Cancel' button and ensure that no data is saved in the database.", 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to start adding a new book.   - Step 3: On the book creation form, enter partial data for the new book (e.g., Title and Author).   - Step 4: Press the 'Cancel' button before completing all fields and submitting.   - Step 5: Confirm any prompt (if any) to ensure cancellation of the book creation process.", 'Expected Result': 'The application should navigate back to the list of books without adding the partially entered book data to the database.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Cancel Operation After Partial Data Entry', 'Test Case Name': 'Cancel New Book Creation After Partial Data Entry by Navigation', 'Objective': 'Verify that navigating away from the book creation page after partial data entry by selecting a different menu item cancels the book creation and does not save data.', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to start the process of adding a new book.   - Step 3: On the book creation form, enter partial data for the new book (e.g., Genre and Description).   - Step 4: Without submitting the form, select a different menu item (e.g., 'Authors').", 'Expected Result': "The application should navigate to the selected menu item's page without saving the partially entered book data, ensuring no new book record is added to the database."}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Cancel Operation Before Data Submission.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Cancel Operation Before Data Submission', 'Test Case Name': 'Cancel New Book Creation Before Data Submission', 'Objective': 'Verify that the book creation process can be canceled before data submission and ensure no data is saved to the database.', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to start adding a new book.   - Step 3: Enter book details in the form fields (Title, Author, Genre, Description, Publication Date).   - Step 4: Before pressing 'Submit', click the 'Cancel' button.", 'Expected Result': 'The application should not save the entered book data and should redirect the user to the list of book records.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Cancel Operation Before Data Submission', 'Test Case Name': 'Cancel New Book Creation by Navigation Before Data Submission', 'Objective': 'Verify that navigating away from the book creation page before submitting the form cancels the creation process without saving any data.', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to start the process of adding a new book.   - Step 3: Start entering book details in the form (Title, Author, Genre, Description, Publication Date).   - Step 4: Before pressing 'Submit', select a different menu item (e.g., 'Genres', 'Authors', 'Home', or 'API').", 'Expected Result': 'The application should not save the partially entered book data and should display the selected page without adding a new book record.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Navigation to API Before Submission.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to API Before Submission', 'Test Case Name': 'Navigate to API Before Submission', 'Objective': 'Verify that navigating to the API page before submitting a new book record does not save the entered data', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the form for entering new book data.   - Step 3: Enter data into the form fields for Title, Author, Genre, Description, and Publication Date.   - Step 4: Before pressing the 'Submit' button, select the 'API' menu item to navigate away from the creation page.", 'Expected Result': 'The application navigates to the API page without saving the entered book data, and no new book record is added to the database.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to API Before Submission', 'Test Case Name': 'Verify Data Not Saved on Cancel Before API Navigation', 'Objective': "Ensure that data is not saved when the 'Cancel' button is pressed before navigating to the API page", 'Test Steps': "- Step 1: Go to the book list page and click the 'Create new' button.   - Step 2: Fill in the form with Title, Author, Genre, Description, and Publication Date.   - Step 3: Press the 'Cancel' button to discard the entered data.   - Step 4: After canceling, navigate to the 'API' page by selecting the 'API' menu item.", 'Expected Result': 'Navigation to the API page is successful without saving any data, and no new book record is created in the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Navigation to Authors Before Submission.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Authors Before Submission', 'Test Case Name': 'Verify Navigation to Authors Before Submission', 'Objective': 'Verify that the user can navigate to the Authors page before submitting a new book record', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to start adding a new book.   - Step 3: Start entering the book data into the form fields but do not press the 'Submit' button.   - Step 4: Before submitting the new book data, select the 'Authors' menu item.", 'Expected Result': 'The Authors page is displayed, and the data entered for the new book is not saved in the database.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Authors Before Submission', 'Test Case Name': 'Verify Cancel Operation Navigates to Authors', 'Objective': "Verify that pressing the 'Cancel' button while adding a new book allows the user to navigate to the Authors page without saving the data", 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the form for entering new book data.   - Step 3: Enter some data into the form fields.   - Step 4: Press the 'Cancel' button.   - Step 5: After the list of books is displayed, select the 'Authors' menu item.", 'Expected Result': 'The Authors page is displayed without the new book data being saved in the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Navigation to Books Before Submission.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Books Before Submission', 'Test Case Name': 'Navigate to Create New Book Page via Navbar', 'Objective': "Verify that the user can navigate to the 'Create new' book page using the navbar from the book list page.", 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Locate the 'Create new' button on the navbar.   - Step 3: Click the 'Create new' button.", 'Expected Result': 'The application displays the form to enter book data.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Books Before Submission', 'Test Case Name': 'Navigate to Create New Book Page and Cancel', 'Objective': "Verify that the user can navigate to the 'Create new' book page and return to the book list page by pressing the 'Cancel' button.", 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button on the navbar to navigate to the create new book page.   - Step 3: Start entering book data into the form fields.   - Step 4: Press the 'Cancel' button before submitting the form.", 'Expected Result': 'Data is not saved in the database, and the application navigates back to the list of book records.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Books Before Submission', 'Test Case Name': 'Navigate to Create New Book Page and Use Menu Navigation', 'Objective': "Verify that navigating away from the 'Create new' book page using the menu items does not save data.", 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button on the navbar to navigate to the create new book page.   - Step 3: Start entering book data into the form fields.   - Step 4: Select a menu item (e.g., 'Genres') without submitting the book data.", 'Expected Result': "Data is not saved in the database, and the application navigates to the selected menu item's page."}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Navigation to Genres Before Submission.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Genres Before Submission', 'Test Case Name': 'Navigate to Genres from Book Creation Page Before Submission', 'Objective': 'Verify that the user can navigate to the Genres page from the book creation page before submitting the new book data.', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click on the 'Create new' button to open the book creation form.   - Step 3: Start entering data for the new book but do not press the 'Submit' button.   - Step 4: Select the 'Genres' menu item.", 'Expected Result': 'The Genres page is displayed, and the data entered in the book creation form is not saved to the database.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Genres Before Submission', 'Test Case Name': 'Cancel Book Creation and Navigate to Genres', 'Objective': 'Verify that the user can cancel the book creation process and navigate to the Genres page without saving any data.', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click on the 'Create new' button to open the book creation form.   - Step 3: Partially fill out the form with book details.   - Step 4: Press the 'Cancel' button.   - Step 5: After cancellation, select the 'Genres' menu item.", 'Expected Result': 'The user is redirected to the Genres page without the book data being saved in the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Navigation to Home Before Submission.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Home Before Submission', 'Test Case Name': 'Navigation to Home Before Submission via Cancel Button', 'Objective': 'Verify that navigating to Home using the Cancel button before submitting a new book does not save the book data', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to start adding a new book.   - Step 3: Enter book data into the form fields (Title, Author, Genre, Description, Publication Date).   - Step 4: Before pressing 'Submit', click the 'Cancel' button.   - Step 5: Confirm the action to cancel if prompted.   - Step 6: Navigate to the Home page by selecting the 'Home' menu item.", 'Expected Result': 'The user is redirected to the Home page without the new book data being saved in the database.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Navigation to Home Before Submission', 'Test Case Name': 'Navigation to Home Before Submission via Menu Selection', 'Objective': 'Verify that navigating to Home using the menu selection before submitting a new book does not save the book data', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to start adding a new book.   - Step 3: Start entering book data into the form fields but do not press 'Submit'.   - Step 4: Select the 'Home' menu item to navigate away from the book creation page.", 'Expected Result': 'The user is redirected to the Home page without the new book data being saved in the database.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new book-Successful Book Creation.txt
# [{'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Successful Book Creation', 'Test Case Name': 'Successful Book Record Creation', 'Objective': 'Verify that a new book record can be successfully added to the database with valid data', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Enter valid data into the book data form fields: Title, Author, Genre, Description, and Publication date.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'A new book record is successfully added to the database, and the user is redirected to the list of books with the newly added record visible.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Successful Book Creation', 'Test Case Name': 'Display Error on Incorrect Book Data Submission', 'Objective': 'Verify that the application displays error messages for incorrectly entered book data', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Enter invalid data into one or more of the book data form fields: Title, Author, Genre, Description, and Publication date. For example, leave the 'Title' field empty.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'The application displays messages indicating which data was entered incorrectly.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Successful Book Creation', 'Test Case Name': 'Cancel Book Creation Operation', 'Objective': 'Verify that the book creation process can be canceled without saving data to the database', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Start entering data into the book data form fields but do not complete the form.   - Step 4: Press the 'Cancel' button.", 'Expected Result': 'The book creation form is closed, no data is saved to the database, and the user is redirected to the list of book records without the addition of a new record.'}, {'Use Case Name': 'Add a new book', 'Test Scenario Name': 'Successful Book Creation', 'Test Case Name': 'Navigation Away from Book Creation Cancels Operation', 'Objective': 'Verify that navigating away from the book creation form cancels the operation without saving data', 'Test Steps': "- Step 1: Navigate to the book list page.   - Step 2: Click the 'Create new' button to open the book creation form.   - Step 3: Start entering data into the book data form fields.   - Step 4: Without pressing 'Submit', select another menu item such as 'Genres' or 'Home'.", 'Expected Result': 'The book creation form is closed, no data is saved to the database, and the user is redirected to the selected page without the addition of a new book record.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new genre-CreateGenre_WithoutDescription.txt
# [{'Use Case Name': 'Add a new genre', 'Test Scenario Name': 'CreateGenre_WithoutDescription', 'Test Case Name': 'Create Genre Without Entering Description', 'Objective': 'Verify that a new genre can be created without entering a description and the record is successfully added to the database.', 'Test Steps': "- Step 1: Navigate to the genre list page.   - Step 2: Click the 'Create new' button to open the genre creation form.   - Step 3: Enter a unique name for the genre in the 'Name' field.   - Step 4: Leave the 'Description' field empty.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'A new genre record with the entered name and without a description is successfully added to the database, and the user is redirected to the list of genres with the newly added record visible.'}, {'Use Case Name': 'Add a new genre', 'Test Scenario Name': 'CreateGenre_WithoutDescription', 'Test Case Name': 'Create Genre With Description Then Cancel', 'Objective': 'Verify that when a user cancels the creation of a new genre after entering data, the record is not added to the database.', 'Test Steps': "- Step 1: Navigate to the genre list page.   - Step 2: Click the 'Create new' button to open the genre creation form.   - Step 3: Enter a name in the 'Name' field.   - Step 4: Enter some text in the 'Description' field.   - Step 5: Press the 'Cancel' button.", 'Expected Result': 'The user is redirected to the list of genre records without the new genre being added to the database, indicating the cancellation was successful.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new genre-CreateGenre_WithoutName.txt
# [{'Use Case Name': 'Add a new genre', 'Test Scenario Name': 'CreateGenre_WithoutName', 'Test Case Name': 'Create Genre Without Entering Name', 'Objective': 'Verify that the system prevents the creation of a new genre without a name and displays an appropriate error message.', 'Test Steps': "- Step 1: Navigate to the genre list page.   - Step 2: Click the 'Create new' button to open the form for entering genre data.   - Step 3: Leave the 'Name' field empty.   - Step 4: Enter a valid description in the 'Description' field.   - Step 5: Press the 'Submit' button.", 'Expected Result': "An error message is displayed indicating that the 'Name' field is required."}, {'Use Case Name': 'Add a new genre', 'Test Scenario Name': 'CreateGenre_WithoutName', 'Test Case Name': 'Cancel Genre Creation Without Entering Name', 'Objective': "Verify that the system does not create a new genre record and returns to the genre list when the 'Cancel' button is pressed, even if the 'Name' field is left empty.", 'Test Steps': "- Step 1: Navigate to the genre list page.   - Step 2: Click the 'Create new' button to open the form for entering genre data.   - Step 3: Leave the 'Name' field empty.   - Step 4: Optionally enter a description in the 'Description' field.   - Step 5: Press the 'Cancel' button.", 'Expected Result': 'The system does not save the new genre and returns to the list of genres without displaying an error message.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Add a new genre-Genre Creation with Incorrect Data.txt
# ...
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Remove the book-User Cancels Deletion by Selecting Genres Menu Item.txt
# [{'Use Case Name': 'Remove the book', 'Test Scenario Name': 'User Cancels Deletion by Selecting Genres Menu Item', 'Test Case Name': 'Cancel Deletion and Select Genres Menu', 'Objective': 'Verify that the deletion process is canceled and the user is able to navigate to the Genres menu without deleting the book', 'Test Steps': "- Step 1: Navigate to the book list/details page.   - Step 2: Click the 'Delete' button next to the book intended for deletion.   - Step 3: On the confirmation dialog, press the 'Cancel' button.   - Step 4: After cancellation, select the 'Genres' menu item.", 'Expected Result': 'The book is not deleted from the database, and the user is redirected to the Genres page with the data updated.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Remove the book-User Cancels Deletion by Selecting Home Menu Item.txt
# [{'Use Case Name': 'Remove the book', 'Test Scenario Name': 'User Cancels Deletion by Selecting Home Menu Item', 'Test Case Name': 'Cancel Deletion and Select Home Menu', 'Objective': "Verify that the deletion process is canceled and the user is navigated to the Home page without deleting the data when selecting the Home menu item after pressing the 'Cancel' button in the deletion confirmation dialog.", 'Test Steps': "- Step 1: Navigate to the book list/details page.   - Step 2: Click the 'Delete' button next to the book intended for deletion.   - Step 3: On the confirmation dialog, press the 'Cancel' button.   - Step 4: Select the 'Home' menu item from the navigation bar.", 'Expected Result': 'The user is navigated to the Home page without any data being deleted, and the book list should still include the book that was selected for deletion.'}, {'Use Case Name': 'Remove the book', 'Test Scenario Name': 'User Cancels Deletion by Selecting Home Menu Item', 'Test Case Name': 'Cancel Deletion and Select Books Menu', 'Objective': "Verify that the deletion process is canceled and the user is navigated to the Books page without deleting the data when selecting the Books menu item after pressing the 'Cancel' button in the deletion confirmation dialog.", 'Test Steps': "- Step 1: Navigate to the book list/details page.   - Step 2: Click the 'Delete' button next to the book intended for deletion.   - Step 3: On the confirmation dialog, press the 'Cancel' button.   - Step 4: Select the 'Books' menu item from the navigation bar.", 'Expected Result': 'The user is navigated to the Books page without any data being deleted, and the book list should still include the book that was selected for deletion.'}, {'Use Case Name': 'Remove the book', 'Test Scenario Name': 'User Cancels Deletion by Selecting Home Menu Item', 'Test Case Name': 'Cancel Deletion and Select Genres Menu', 'Objective': "Verify that the deletion process is canceled and the user is navigated to the Genres page without deleting the data when selecting the Genres menu item after pressing the 'Cancel' button in the deletion confirmation dialog.", 'Test Steps': "- Step 1: Navigate to the book list/details page.   - Step 2: Click the 'Delete' button next to the book intended for deletion.   - Step 3: On the confirmation dialog, press the 'Cancel' button.   - Step 4: Select the 'Genres' menu item from the navigation bar.", 'Expected Result': 'The user is navigated to the Genres page without any data being deleted, ensuring the cancellation process is respected across different navigation paths.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Remove the book-User Cancels Deletion via Cancel Button.txt
# [{'Use Case Name': 'Remove the book', 'Test Scenario Name': 'User Cancels Deletion via Cancel Button', 'Test Case Name': 'Verify cancellation of book deletion via Cancel button', 'Objective': "Ensure that pressing the 'Cancel' button during the deletion confirmation dialog cancels the deletion process and retains the book record in the database", 'Test Steps': "- Step 1: Navigate to the book list/details page.   - Step 2: Click the 'Delete' button next to the book intended for deletion.   - Step 3: On the confirmation dialog, press the 'Cancel' button.", 'Expected Result': 'The book record should not be deleted from the database, and the user should be redirected back to the list of book records, with the previously selected book still present.'}, {'Use Case Name': 'Remove the book', 'Test Scenario Name': 'User Cancels Deletion via Cancel Button', 'Test Case Name': 'Verify navigation after cancelling book deletion', 'Objective': "To confirm that after cancelling a book deletion, navigating to other sections like 'Books', 'Genres', 'Authors', 'Home', or 'API' displays updated data without deleting the book", 'Test Steps': "- Step 1: Navigate to the book list/details page.   - Step 2: Click the 'Delete' button next to the book intended for deletion.   - Step 3: On the confirmation dialog, press the 'Cancel' button.   - Step 4: Navigate to one of the menu items: 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The application should display the corresponding form with updated data, and the book that was subject to deletion should still be present in the database and visible to the user.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Remove the genre-Successful Genre Deletion.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'Successful Genre Deletion', 'Test Case Name': 'Successful Genre Deletion', 'Objective': 'Verify that a user can successfully delete a genre and the record is removed from the database', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Locate the genre you wish to delete and click the 'Delete' button next to it.   - Step 3: On the confirmation dialog, click the 'Confirm' button.", 'Expected Result': 'The genre should be successfully deleted from the database, and the list of genres should no longer include the deleted genre.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'Successful Genre Deletion', 'Test Case Name': 'Cancel Genre Deletion Operation', 'Objective': 'Verify that a user can cancel the deletion of a genre and ensure the record remains in the database', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Locate the genre you wish to delete and click the 'Delete' button next to it.   - Step 3: On the confirmation dialog, click the 'Cancel' button.", 'Expected Result': 'The genre should not be deleted from the database, and the list of genres should still include the genre.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'Successful Genre Deletion', 'Test Case Name': 'Navigate Away During Genre Deletion Operation', 'Objective': 'Verify that navigating away from the deletion confirmation dialog cancels the deletion operation', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Locate the genre you wish to delete and click the 'Delete' button next to it.   - Step 3: On the confirmation dialog, instead of clicking 'Confirm' or 'Cancel', navigate to another page by selecting 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The genre should not be deleted from the database, and the list of genres should still include the genre. The user is taken to the selected page with updated data.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Remove the genre-User Cancels Deletion.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'User Cancels Deletion', 'Test Case Name': 'Verify cancellation of genre deletion via Cancel button', 'Objective': 'Ensure that when a user cancels the deletion of a genre, the genre is not deleted from the database and the user is redirected back to the list of genres.', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, press the 'Cancel' button.", 'Expected Result': 'The genre should not be deleted from the database, and the user should be redirected back to the list of genres with all records intact.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'User Cancels Deletion', 'Test Case Name': 'Verify navigation after cancelling genre deletion', 'Objective': "To confirm that after cancelling the deletion of a genre, navigating to any other page like 'Books', 'Genres', 'Authors', 'Home', or 'API' displays the correct data without deleting the genre.", 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, press the 'Cancel' button.   - Step 4: Select any menu item such as 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The system should not delete the genre from the database, and the selected page should display updated data correctly without any deletions.'}]
# D:\Dissertation-GPT\evaluate\bestScenario\bestTCs\Book(Github)_raw\Remove the genre-User Navigates Away Using Menu Before Confirming Deletion.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'User Navigates Away Using Menu Before Confirming Deletion', 'Test Case Name': "Navigate Away Using Menu Before Confirming Deletion to 'Books'", 'Objective': "Verify that navigating away to 'Books' from the deletion confirmation dialog cancels the deletion process and displays the 'Books' page.", 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the deletion confirmation dialog, instead of clicking 'Confirm', select the 'Books' menu item.", 'Expected Result': "The application cancels the deletion process, does not delete the genre, and navigates to the 'Books' page displaying updated data."}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'User Navigates Away Using Menu Before Confirming Deletion', 'Test Case Name': "Navigate Away Using Menu Before Confirming Deletion to 'Genres'", 'Objective': "Verify that navigating away to 'Genres' from the deletion confirmation dialog cancels the deletion process and displays the 'Genres' page.", 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the deletion confirmation dialog, instead of clicking 'Confirm', select the 'Genres' menu item.", 'Expected Result': "The application cancels the deletion process, does not delete the genre, and navigates to the 'Genres' page displaying updated data."}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'User Navigates Away Using Menu Before Confirming Deletion', 'Test Case Name': "Navigate Away Using Menu Before Confirming Deletion to 'Authors'", 'Objective': "Verify that navigating away to 'Authors' from the deletion confirmation dialog cancels the deletion process and displays the 'Authors' page.", 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the deletion confirmation dialog, instead of clicking 'Confirm', select the 'Authors' menu item.", 'Expected Result': "The application cancels the deletion process, does not delete the genre, and navigates to the 'Authors' page displaying updated data."}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'User Navigates Away Using Menu Before Confirming Deletion', 'Test Case Name': "Navigate Away Using Menu Before Confirming Deletion to 'Home'", 'Objective': "Verify that navigating away to 'Home' from the deletion confirmation dialog cancels the deletion process and displays the 'Home' page.", 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the deletion confirmation dialog, instead of clicking 'Confirm', select the 'Home' menu item.", 'Expected Result': "The application cancels the deletion process, does not delete the genre, and navigates to the 'Home' page displaying updated data."}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': 'User Navigates Away Using Menu Before Confirming Deletion', 'Test Case Name': "Navigate Away Using Menu Before Confirming Deletion to 'API'", 'Objective': "Verify that navigating away to 'API' from the deletion confirmation dialog cancels the deletion process and displays the 'API' page.", 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the deletion confirmation dialog, instead of clicking 'Confirm', select the 'API' menu item.", 'Expected Result': "The application cancels the deletion process, does not delete the genre, and navigates to the 'API' page displaying updated data."}]

# %%
import pandas as pd

# Load the Excel file
file_path = 'output_file.xlsx'  # Replace with your file path
df = pd.read_excel(file_path)

# Define the condition for keeping rows
condition = (df['Valid'].notna()) | (df['Test Scenario'].str.contains('txt', na=False))

# Apply the condition to filter the DataFrame
df_cleaned = df[condition]

# Save the cleaned data to a new Excel file
df_cleaned.to_excel('cleaned_file.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 # Load the Excel file
#       4 file_path = 'output_file.xlsx'  # Replace with your file path
# ----> 5 df = pd.read_excel(file_path)
#       7 # Define the condition for keeping rows
#       8 condition = (df['Valid'].notna()) | (df['Test Scenario'].str.contains('txt', na=False))
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:557, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     547 """
#     548 Reader using openpyxl engine.
#     549
#    (...)
#     554 {storage_options}
#     555 """
#     556 import_optional_dependency("openpyxl")
# --> 557 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:568, in OpenpyxlReader.load_workbook(self, filepath_or_buffer)
#     565 def load_workbook(self, filepath_or_buffer: FilePath | ReadBuffer[bytes]):
#     566     from openpyxl import load_workbook
# --> 568     return load_workbook(
#     569         filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     570     )
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:317, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     290 """Open the given filename and return the workbook
#     291
#     292 :param filename: the path to open or a file-like object
#    (...)
#     313
#     314 """
#     315 reader = ExcelReader(filename, read_only, keep_vba,
#     316                     data_only, keep_links)
# --> 317 reader.read()
#     318 return reader.wb
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:279, in ExcelReader.read(self)
#     277 self.read_strings()
#     278 self.read_workbook()
# --> 279 self.read_properties()
#     280 self.read_theme()
#     281 apply_stylesheet(self.archive, self.wb)
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:172, in ExcelReader.read_properties(self)
#     170 def read_properties(self):
#     171     if ARC_CORE in self.valid_files:
# --> 172         src = fromstring(self.archive.read(ARC_CORE))
#     173         self.wb.properties = DocumentProperties.from_tree(src)
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:1475, in ZipFile.read(self, name, pwd)
#    1473 def read(self, name, pwd=None):
#    1474     """Return file bytes for name."""
# -> 1475     with self.open(name, "r", pwd) as fp:
#    1476         return fp.read()
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:1530, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1526 zef_file = _SharedFile(self.fp, zinfo.header_offset,
#    1527                        self._fpclose, self._lock, lambda: self._writing)
#    1528 try:
#    1529     # Skip the file header:
# -> 1530     fheader = zef_file.read(sizeFileHeader)
#    1531     if len(fheader) != sizeFileHeader:
#    1532         raise BadZipFile("Truncated file header")
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:745, in _SharedFile.read(self, n)
#     741     raise ValueError("Can't read from the ZIP file while there "
#     742             "is an open writing handle on it. "
#     743             "Close the writing handle before trying to read.")
#     744 self._file.seek(self._pos)
# --> 745 data = self._file.read(n)
#     746 self._pos = self._file.tell()
#     747 return data
#
# KeyboardInterrupt:

# %%
import pandas as pd
import json

# Load the Excel file
file_path = 'cleaned_file.xlsx'
df = pd.read_excel(file_path, usecols=['Test Scenario'])

# Initialize variables
use_case_name = ''
scenarios = []
result = []

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    test_scenario = row['Test Scenario']
    if test_scenario.endswith('.txt'):
        # If we already have a use case name, save the previous use case and its scenarios
        if use_case_name:
            result.append({
                'use_case_name': use_case_name,
                'scenarios': scenarios
            })
        # Set the new use case name and reset the scenarios list
        use_case_name = test_scenario
        scenarios = []
    else:
        # Add the scenario to the current use case's scenarios list
        scenarios.append(test_scenario)

# Add the last use case and its scenarios
if use_case_name:
    result.append({
        'use_case_name': use_case_name,
        'scenarios': scenarios
    })

# Convert the result to a JSON string
result_json = json.dumps(result, indent=4)

# Print the result
print(result_json)

# # Optionally, save the result to a JSON file
# with open('result.json', 'w') as json_file:
#     json_file.write(result_json)
# Out:
# [
#     {
#         "use_case_name": "Add a new author.txt",
#         "scenarios": [
#             "3. VerifySubmitWithValidData",
#             "4. VerifyErrorMessageForInvalidData",
#             "6. VerifyErrorMessageOnDatabaseError",
#             "8. VerifyCancelOperationBeforeDataSubmission",
#             "10. VerifyNavigationAwayDoesNotSaveData",
#             "12. VerifyMaxLengthValidationForNameField",
#             "13. VerifyMaxLengthValidationForBioField",
#             "16. VerifyUniqueNameConstraint"
#         ]
#     },
#     {
#         "use_case_name": "Add a new book.txt",
#         "scenarios": [
#             "3. VerifySubmitWithValidData",
#             "4. VerifyErrorMessageForInvalidData",
#             "6. VerifyErrorMessageOnDatabaseError",
#             "9. VerifyDataNotSavedOnCancel",
#             "10. VerifyNavigationAwayDoesNotSaveData",
#             "16. VerifyFieldValidationsWithEmptyInputs",
#             "17. VerifyFieldValidationsWithBoundaryValues",
#             "18. VerifyFieldValidationsWithSpecialCharacters",
#             "22. VerifyUniqueConstraintForBookTitle"
#         ]
#     },
#     {
#         "use_case_name": "Add a new genre.txt",
#         "scenarios": [
#             "1. SuccessfulGenreCreation",
#             "3. IncorrectDataEntry",
#             "5. DisplaySuccessMessageOnSuccessfulAddition",
#             "6. CancelOperationWithDataEntered",
#             "7. CancelOperationWithoutDataEntered",
#             "11. ValidateInputFieldsForEmptyData",
#             "12. ValidateInputFieldsForInvalidData",
#             "13. ValidateMaxLengthForNameField",
#             "14. ValidateMaxLengthForDescriptionField",
#             "16. CheckDuplicateGenreNameHandling",
#             "19. CheckErrorResponseHandlingOnDatabaseError",
#             "20. ValidateGenreCreationWithSpecialCharactersInName",
#             "21. ValidateGenreCreationWithHTMLTagsInDescription",
#             "22. CheckLoadingIndicatorDuringDataSubmission",
#             "23. ValidateNavigationToBooksMenuWithoutSaving",
#             "24. ValidateNavigationToGenresMenuWithoutSaving",
#             "25. ValidateNavigationToAuthorsMenuWithoutSaving",
#             "26. ValidateNavigationToHomeMenuWithoutSaving",
#             "27. ValidateNavigationToAPIMenuWithoutSaving"
#         ]
#     },
#     {
#         "use_case_name": "Display author details.txt",
#         "scenarios": [
#             "10. Test Scenario: Verify Navigation from Author List to Author Details"
#         ]
#     },
#     {
#         "use_case_name": "Display book details.txt",
#         "scenarios": [
#             "1. Test Display of Book Details on Click"
#         ]
#     },
#     {
#         "use_case_name": "Display genre details.txt",
#         "scenarios": [
#             "1. Test_DisplayValidGenreDetails"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of authors.txt",
#         "scenarios": [
#             "1. DisplayInitialAuthorsList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation",
#             "11. LastPageAuthorsListDisplay",
#             "12. FirstPageNavigationFromMiddlePage",
#             "13. LastPageNavigationFromMiddlePage"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of books.txt",
#         "scenarios": [
#             "1. DisplayInitialBooksList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation",
#             "4. FilterBooksByDateRange",
#             "5. DisplayBooksListWithEmptyDateRange",
#             "6. DisplayBooksListWithInvalidDateRange",
#             "7. DisplayBooksListWithSingleDate",
#             "8. DisplayBooksListWithFutureDateRange",
#             "9. DisplayBooksListWithPastDateRange",
#             "10. DisplayBooksListWithNonexistentDates",
#             "11. DisplayBooksListWithBoundaryDateRange",
#             "19. DisplayBooksListWithSpecialCharactersInDateRange"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of genres.txt",
#         "scenarios": [
#             "1. DisplayInitialGenresList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation"
#         ]
#     },
#     {
#         "use_case_name": "Edit the author.txt",
#         "scenarios": [
#             "1. UpdateAuthor_SuccessfulUpdate",
#             "3. UpdateAuthor_DatabaseError",
#             "4. UpdateAuthor_CancelOperation",
#             "5. UpdateAuthor_NavigationAwayWithoutSaving",
#             "6. UpdateAuthor_EmptyNameField",
#             "7. UpdateAuthor_InvalidBioCharacters",
#             "8. UpdateAuthor_MaximumLengthExceeded_Name",
#             "9. UpdateAuthor_MaximumLengthExceeded_Bio",
#             "10. UpdateAuthor_MinimumLengthNotMet_Name",
#             "11. UpdateAuthor_MinimumLengthNotMet_Bio",
#             "12. UpdateAuthor_SpecialCharactersInName",
#             "13. UpdateAuthor_HTMLTagsInBio",
#             "14. UpdateAuthor_SQLInjection_NameField",
#             "15. UpdateAuthor_SQLInjection_BioField",
#             "16. UpdateAuthor_XSSAttack_NameField",
#             "17. UpdateAuthor_XSSAttack_BioField",
#             "18. UpdateAuthor_UpdateWithExistingAuthorName",
#             "19. UpdateAuthor_UpdateWithWhitespaceOnlyName",
#             "20. UpdateAuthor_UpdateWithWhitespaceOnlyBio"
#         ]
#     },
#     {
#         "use_case_name": "Edit the book.txt",
#         "scenarios": [
#             "1. UpdateBook_WithValidData",
#             "2. UpdateBook_WithInvalidTitle",
#             "3. UpdateBook_WithInvalidAuthor",
#             "4. UpdateBook_WithInvalidGenre",
#             "5. UpdateBook_WithInvalidDescription",
#             "6. UpdateBook_WithInvalidPublicationDate",
#             "7. UpdateBook_WithEmptyTitle",
#             "8. UpdateBook_WithEmptyAuthor",
#             "9. UpdateBook_WithEmptyGenre",
#             "10. UpdateBook_WithEmptyDescription",
#             "11. UpdateBook_WithEmptyPublicationDate",
#             "12. UpdateBook_DisplayErrorMessage_OnDatabaseError",
#             "15. CancelUpdateBook_BeforeSubmitting",
#             "16. CancelUpdateBook_AfterModifyingData",
#             "17. NavigateAwayFromUpdatePage_UsingMenuBeforeSubmitting",
#             "18. NavigateAwayFromUpdatePage_UsingMenuAfterModifyingData",
#             "19. UpdateBook_WithSpecialCharactersInTitle",
#             "20. UpdateBook_WithFuturePublicationDate",
#             "21. UpdateBook_WithPastPublicationDate",
#             "22. UpdateBook_WithNonexistentAuthor",
#             "23. UpdateBook_WithNonexistentGenre"
#         ]
#     },
#     {
#         "use_case_name": "Edit the genre.txt",
#         "scenarios": [
#             "1. UpdateGenre_SuccessfulUpdate",
#             "4. UpdateGenre_CancelOperationBeforeSubmit",
#             "5. UpdateGenre_NavigateAwayBeforeSubmit",
#             "6. UpdateGenre_RequiredFieldsMissing",
#             "7. UpdateGenre_InvalidCharactersInName",
#             "8. UpdateGenre_InvalidFormatInDescription",
#             "9. UpdateGenre_UniqueNameConstraint",
#             "11. UpdateGenre_CheckMaxLengthName",
#             "12. UpdateGenre_CheckMaxLengthDescription",
#             "13. UpdateGenre_SpecialCharactersInName",
#             "14. UpdateGenre_SpecialCharactersInDescription",
#             "15. UpdateGenre_WhitespaceInName",
#             "16. UpdateGenre_WhitespaceInDescription",
#             "17. UpdateGenre_UpdateWithSameData"
#         ]
#     },
#     {
#         "use_case_name": "Remove the author.txt",
#         "scenarios": [
#             "1. DeleteAuthor_SuccessfulDeletion",
#             "2. DeleteAuthor_CancelDeletion",
#             "6. DeleteAuthor_NavigateAwayUsingMenuBeforeDeletion",
#             "7. DeleteAuthor_NavigateAwayUsingBrowserBackBeforeDeletion",
#             "8. DeleteAuthor_MultipleDeletionsSequential"
#         ]
#     },
#     {
#         "use_case_name": "Remove the book.txt",
#         "scenarios": [
#             "1. DeleteBook_SuccessfulDeletion",
#             "2. DeleteBook_CancelDeletion"
#         ]
#     },
#     {
#         "use_case_name": "Remove the genre.txt",
#         "scenarios": [
#             "1. DeleteGenre_SuccessfulDeletion",
#             "2. DeleteGenre_CancelDeletion",
#             "4. DeleteGenre_NavigationAfterCancellation"
#         ]
#     }
# ]

# %%
import os
import csv

# Function to convert txt file content to csv
def convert_txt_to_csv(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            txt_file_path = os.path.join(folder_path, filename)
            csv_file_path = os.path.join(folder_path, f"{os.path.splitext(filename)[0]}.csv")
            
            # Read the content of the txt file
            with open(txt_file_path, 'r') as txt_file:
                content = txt_file.readlines()
            
            # Write the content to a csv file
            with open(csv_file_path, 'w', newline='') as csv_file:
                csv_writer = csv.writer(csv_file)
                
                # Write the name of the txt file in the first cell of column A
                csv_writer.writerow([filename])
                
                # Write an empty cell
                csv_writer.writerow([""])
                
                # Write the content of the txt file, each line in a new row
                for line in content:
                    csv_writer.writerow([line.strip()])

# Example usage:
folder_path =  r'D:\Dissertation-GPT\evaluate\ResultSet\5.23\0\MatchaEnglishWebsite' # Replace with your folder path
convert_txt_to_csv(folder_path)

# %%
import os
import pandas as pd
from openpyxl import Workbook

# Directory containing the txt files
directory = r'D:\Dissertation-GPT\code\thu\6.23'

# Initialize an empty dictionary to hold data for the main sheet
valid_invalid_data = []

# Initialize a dictionary to hold data for individual sheets
individual_sheets_data = {}

# Initialize a list for the Coverage sheet
coverage_data = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
        # Extract the function name
        function_name = filename.replace("-1", "").replace("-2", "").replace("-3", "").replace(".txt", "").strip()
        
        # Read the file content
        with open(os.path.join(directory, filename), 'r') as file:
            lines = file.readlines()
        
        # Prepare data for the "Valid/Invalid" sheet
        valid_invalid_data.append([function_name])
        valid_invalid_data.extend([[line.strip()] for line in lines])
        valid_invalid_data.append([''])  # Add a blank line after each file's content
        
        # Prepare data for the individual function sheet
        individual_sheets_data[function_name] = [[function_name], ['']]
        individual_sheets_data[function_name].extend([[line.strip()] for line in lines])
        
        # Prepare data for the Coverage sheet
        coverage_data.append([function_name, '', ''])

# Create a new workbook and add sheets
wb = Workbook()

# Create "Valid/Invalid" sheet
ws_valid_invalid = wb.active
ws_valid_invalid.title = "Valid Invalid"

# Write data to the "Valid/Invalid" sheet
ws_valid_invalid.append(['Test scenario'])
for row in valid_invalid_data:
    ws_valid_invalid.append(row)

# Write data to the individual function sheets
for function_name, content in individual_sheets_data.items():
    ws = wb.create_sheet(title=function_name)
    for row in content:
        ws.append(row)

# Create "Coverage" sheet
ws_coverage = wb.create_sheet(title="Coverage")
ws_coverage.append(['Use case', 'flow coverage', 'condition coverage'])
for row in coverage_data:
    ws_coverage.append(row)

# Save the workbook to an Excel file
wb.save('output_file.xlsx')
# Out:
# e:\ProgramData\anaconda3\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
import os

def print_file_names(folder_path):
    try:
        # List all files in the given directory
        for filename in os.listdir(folder_path):
            # Check if it is a file
            if os.path.isfile(os.path.join(folder_path, filename)):
                # Split the filename to remove the extension
                name, _ = os.path.splitext(filename)
                print(name)
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
folder_path = r"D:\Dissertation-GPT\dataset\SpecificationData\Hotel Management System"
print_file_names(folder_path)
# Out:
# Add Booking
# Add Employee
# Add Room
# Check in
# Check out
# Hotel Owner - Generate Reports
# Hotel Owner - Update Hotel Information
# login
# Request Service
# Update Booking
# Update Employee
# Update Room

# %%
import os

def create_summary_files(directory, path):
    # Define the names of the summary files
    directory_name = os.path.basename(directory)
    summary_file_raw = os.path.join(path, f"{directory_name}-Raw.txt")
    summary_file = os.path.join(path, f"{directory_name}.txt")

    # Initialize strings to store file contents
    raw_content = ""
    non_raw_content = ""

    # Iterate through the files in the directory
    for file_name in os.listdir(directory):
        file_path = os.path.join(directory, file_name)
        # Check if the current item is a file and not one of the summary files
        if os.path.isfile(file_path) and file_name not in [os.path.basename(summary_file_raw), os.path.basename(summary_file)]:
            # Read the file content
            with open(file_path, 'r') as file:
                content = file.read()
                # Categorize the files based on the presence of "-Raw" in the file name
                if "-Raw" in file_name:
                    raw_content += "Scenario: "+ file_name +"\n"
                    raw_content += content + "\n"
                else:
                    non_raw_content +="Scenario: "+ file_name +"\n"
                    non_raw_content += content + "\n"

    # Write the collected raw file contents to "Summary File Raw.txt"
    with open(summary_file_raw, 'w') as file:
        file.write(raw_content)

    # Write the collected non-raw file contents to "Summary File.txt"
    with open(summary_file, 'w') as file:
        file.write(non_raw_content)

# Example usage
directory_path =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"
create_summary_files(directory_path, path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 40
#      38 directory_path =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
#      39 path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"
# ---> 40 create_summary_files(directory_path, path)
#
# Cell In[15], line 30, in create_summary_files(directory, path)
#      27                 non_raw_content += content + "\n"
#      29 # Write the collected raw file contents to "Summary File Raw.txt"
# ---> 30 with open(summary_file_raw, 'w') as file:
#      31     file.write(raw_content)
#      33 # Write the collected non-raw file contents to "Summary File.txt"
#
# File e:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\summary test case\\AddLesson-Raw.txt'

# %%
def get_test_steps_and_expected_result(scenario, file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
        
        # Split content into individual scenarios
        scenarios = content.split("Scenario:")
        scenarios = content.strip().split('Scenario: ')
        scenarios = [s for s in scenarios if s.strip()]  # Remove empty strings if any
        for scenario_block in scenarios:
            if scenario in scenario_block:
                lines = scenario_block.strip().split("\n")
                test_steps = ""
                expected_result = ""
                for line in lines:
                    if line.startswith("testSteps:"):
                        test_steps = line.split("testSteps:")[1].strip()
                    elif line.startswith("expectedResult:"):
                        expected_result = line.split("expectedResult:")[1].strip()
                return test_steps, expected_result

        return None, None  # Scenario not found
    except FileNotFoundError:
        print("File not found.")
        return None, None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None, None

# Example usage:
scenario = "Cancel Adding New Lesson After Entering Name1"  # Replace with the actual scenario you are looking for
file_path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt"  # Replace with the actual file path
test_steps, expected_result = get_test_steps_and_expected_result(scenario, file_path)

if test_steps and expected_result:
    print("Test Steps:", test_steps)
    print("Expected Result:", expected_result)
else:
    print("Scenario not found or an error occurred.")
# Out:
# ['', " Cancel Adding New Lesson After Entering Description-Raw1.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's description.\ntestSteps:\n  - Step 1: Log in to the application as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The system should cancel the process of adding a new lesson and redirect the administrator to the previous page without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information into the description field, without the system saving any entered data. It directly tests the exception flow mentioned in the use case specification.\n\n\n", " Cancel Adding New Lesson After Entering Description-Raw2.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's description.\ntestSteps:\n  - Step 1: Log in to the application as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The process of adding a new lesson is cancelled, and the administrator is redirected away from the 'Add new Lesson' page without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information into the description field, which aligns with the exception flow of the use case specification.\n\n\n", " Cancel Adding New Lesson After Entering Description-Raw3.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the description but before saving.\ntestSteps:\n  - Step 1: Log in as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The system should cancel the process of adding a new lesson and redirect the administrator back to the previous page or a main/admin dashboard without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information but decided not to proceed with saving it. It directly relates to the exception flow where the administrator can select 'Cancel' to stop adding a new lesson at any time.\n\n\n", " Cancel Adding New Lesson After Entering Name-Raw1.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Name\nobjective: Verify that the administrator can cancel adding a new lesson after entering the lesson name but before saving.\ntestSteps:\n  - Step 1: Log in as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from  ...
# Scenario not found or an error occurred.

# %%
directory =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
file_path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt"  # Replace with the actual file path
directory_name = os.path.basename(directory)
path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"

# %%
import json

content = ""
with open(r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt", 'r') as file:
    content = file.read()
scenarios = content.strip().split('Scenario: ')
scenarios = [s for s in scenarios if s.strip()]  # Remove empty strings if any

# Function to parse each scenario into a dictionary
def parse_scenario(scenario_text):
    lines = scenario_text.strip().split('\n')
    scenario_name = lines[0].strip()
    test_case = {}
    for line in lines[1:]:
        if line.startswith('testSteps:'):
            test_case['testSteps'] = []
            continue
        if line.startswith('  - Step '):
            test_case['testSteps'].append(line.strip())
            continue
        if ':' in line:
            key, value = line.split(':', 1)
            test_case[key.strip()] = value.strip()
    return scenario_name, test_case

# Parse all scenarios
parsed_scenarios = {}
for scenario in scenarios:
    name, details = parse_scenario(scenario)
    parsed_scenarios[name] = details


filename = os.path.join(path,directory_name) + '.json'
with open(filename, 'w') as f:
    json.dump(parsed_scenarios, f, indent=4)

# print(parsed_scenarios)
print(parsed_scenarios["Lesson Creation with Duplicate Name-Raw1.txt"]["testSteps"])
# # Write each scenario to a separate JSON file
# for scenario_name, scenario_details in parsed_scenarios.items():
#     filename = scenario_name + '.json'
#     with open(filename, 'w') as f:
#         json.dump(scenario_details, f, indent=4)

# print("JSON files created successfully.")
# Out:
# ['- Step 1: Log in as an administrator.', "- Step 2: Press the tab 'Lesson Management' on the navbar.", "- Step 3: Select 'Add new Lesson' from the dropdown menu.", "- Step 4: Enter a name that is already used by an existing lesson in the name field on the 'Add new Lesson' page.", '- Step 5: Enter a description for the lesson in the description field.', "- Step 6: Select 'Save' to attempt to create the new lesson."]
