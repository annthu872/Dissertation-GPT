# %%
import os
import pandas as pd

def read_files_in_folder(folder_path):
    all_content = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                # Add file name
                all_content.append(filename)
                # Add file contents line by line
                lines = file.readlines()
                all_content.extend(lines)
                # Add a blank line to separate files
                all_content.append('')
    return all_content

def write_content_to_excel(content, excel_file_path):
    df = pd.DataFrame(content, columns=["Test Scenario"])
    df.to_excel(excel_file_path, index=False, engine='openpyxl')

def main():
    folder_path = r'D:\Dissertation-GPT\evaluate\oneAgent\Shopping System\ts'  # Change this to your folder path
    excel_file_path = 'output.xlsx'

    content = read_files_in_folder(folder_path)
    write_content_to_excel(content, excel_file_path)
    print(f"All file contents have been written to {excel_file_path}")

if __name__ == "__main__":
    main()
# Out:
# All file contents have been written to output.xlsx

# %%
import re
import pandas as pd
import os
import chardet

def read_file_content(file_path):
    # Detect the encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        return content
    except FileNotFoundError:
        return f"Error: The file at path {file_path} was not found."
    except UnicodeDecodeError:
        return f"Error: The file at path {file_path} cannot be decoded with the {encoding} encoding."
    except IOError:
        return f"Error: An I/O error occurred while reading the file at path {file_path}."

def split_before_and_after_hyphen(file_name):
    parts = file_name.split('-', 1)
    if len(parts) == 2:
        before_hyphen, after_hyphen = parts
    else:
        before_hyphen, after_hyphen = file_name, ""
    return before_hyphen.strip(), after_hyphen.strip()

# Function to parse the test cases from the text file
def parse_test_cases(file_name):
    # with open(file_name, 'r') as file:
    #     content = file.read()
    content = read_file_content(file_name)
    base_name = os.path.basename(file_name)

    base_nam = os.path.splitext(base_name)[0]

    # Extract use case and test scenario names from the file name
    use_case_name, test_scenario_name = split_before_and_after_hyphen(base_nam)
    
    # Regular expression to extract test cases
    test_case_pattern = re.compile(
        r"Test Case: (.*?)\ntestCaseName: (.*?)\nobjective: (.*?)\ntestSteps:\n(.*?)\nexpectedResult: (.*?)\n",
        re.DOTALL
    )
    
    matches = test_case_pattern.findall(content)
    
    test_cases = []
    for match in matches:
        test_case_name = match[1].strip()
        objective = match[2].strip()
        test_steps = match[3].strip().replace('\n', ' ')
        expected_result = match[4].strip()
        
        test_cases.append({
            'Use Case Name': use_case_name,
            'Test Scenario Name': test_scenario_name,
            'Test Case Name': test_case_name,
            'Objective': objective,
            'Test Steps': test_steps,
            'Expected Result': expected_result
        })
    
    return test_cases

# Function to write the parsed test cases to an Excel file
def write_to_excel(test_cases, output_file):
    df = pd.DataFrame(test_cases)
    df.to_excel(output_file, index=False)
all_test_cases = []

# File names
# input_file = 'use_case-test_scenario.txt'
output_file = 'test_cases.xlsx'
folder_path = r'D:\Dissertation-GPT\evaluate\baseline 2\book test case'
# Parse the test cases and write to Excel
file_list = os.listdir(folder_path)

def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(1)) if match else float('inf')

# Function to sort filenames naturally by the extracted number
def natural_sort_key(filename):
    # Split the filename into parts: prefix and number
    parts = re.split(r'(\d+)', filename)
    # Convert numerical parts to integers for proper numeric sorting
    parts[1::2] = map(int, parts[1::2])
    return parts

# Sort filenames using the natural sort key
sorted_files = sorted(file_list, key=natural_sort_key)

for i in sorted_files: 
    print(i)
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    print(file_path)
    if os.path.isfile(file_path):
        test_cases = parse_test_cases(file_path)
        print(test_cases)
        test_cases = parse_test_cases(file_path)
        all_test_cases.extend(test_cases)
write_to_excel(all_test_cases, output_file)
# Out:
# Add a new author-1. VerifyClickCreateNewButton.txt
# Add a new author-2. VerifyFormDisplayAfterClickingCreateNew.txt
# Add a new author-3. VerifySubmitWithValidData.txt
# Add a new author-4. VerifyErrorMessageForInvalidData.txt
# Add a new author-5. VerifyDatabaseEntryOnSuccessfulSubmission.txt
# Add a new author-6. VerifyErrorMessageOnDatabaseError.txt
# Add a new author-7. VerifyAuthorListUpdateAfterNewAuthorAdded.txt
# Add a new author-8. VerifyCancelOperationBeforeDataSubmission.txt
# Add a new author-9. VerifyNoDatabaseEntryOnCancel.txt
# Add a new author-10. VerifyNavigationAwayDoesNotSaveData.txt
# Add a new author-11. VerifyMandatoryFieldsValidation.txt
# Add a new author-12. VerifyMaxLengthValidationForNameField.txt
# Add a new author-13. VerifyMaxLengthValidationForBioField.txt
# Add a new author-14. VerifyInputTypeValidationForNameField.txt
# Add a new author-15. VerifyTextAreaInputForBioField.txt
# Add a new author-16. VerifyUniqueNameConstraint.txt
# Add a new author-17. VerifySuccessfulSubmissionMessage.txt
# Add a new author-18. VerifyFormResetAfterSubmission.txt
# Add a new author-19. VerifyFormResetAfterCancellation.txt
# Add a new author-20. VerifyNavigationToOtherSections.txt
# Add a new author-21. VerifyAuthorRecordDeletionFunctionality (If applicable).txt
# Add a new author-22. VerifyAuthorRecordEditFunctionality (If applicable).txt
# Add a new author-23. VerifyPaginationAfterMultipleAuthorsAdded.txt
# Add a new author-24. VerifySearchFunctionalityInAuthorList.txt
# Add a new author-25. VerifySortFunctionalityInAuthorList.txt
# Add a new book-1. VerifyClickCreateNewButton.txt
# Add a new book-2. VerifyFormDisplayAfterClickingCreateNew.txt
# Add a new book-3. VerifySubmitWithValidData.txt
# Add a new book-4. VerifyErrorMessageForInvalidData.txt
# Add a new book-5. VerifyDatabaseEntryOnSuccessfulSubmission.txt
# Add a new book-6. VerifyErrorMessageOnDatabaseError.txt
# Add a new book-7. VerifyDisplayOfBookListAfterSuccessfulAddition.txt
# Add a new book-8. VerifyCancelButtonFunctionality.txt
# Add a new book-9. VerifyDataNotSavedOnCancel.txt
# Add a new book-10. VerifyNavigationAwayDoesNotSaveData.txt
# Add a new book-11. VerifyTitleFieldValidation.txt
# Add a new book-12. VerifyAuthorFieldValidation.txt
# Add a new book-13. VerifyGenreFieldValidation.txt
# Add a new book-14. VerifyDescriptionFieldValidation.txt
# Add a new book-15. VerifyPublicationDateFieldValidation.txt
# Add a new book-16. VerifyFieldValidationsWithEmptyInputs.txt
# Add a new book-17. VerifyFieldValidationsWithBoundaryValues.txt
# Add a new book-18. VerifyFieldValidationsWithSpecialCharacters.txt
# Add a new book-19. VerifyFormPersistenceOnIncorrectDataEntry.txt
# Add a new book-20. VerifySuccessfulAdditionWithMinimumRequiredFields.txt
# Add a new book-21. VerifySuccessfulAdditionWithAllFieldsFilled.txt
# Add a new book-22. VerifyUniqueConstraintForBookTitle.txt
# Add a new book-23. VerifyLoadingPerformanceForCreateNewPage.txt
# Add a new book-24. VerifyAccessibilityOfCreateNewBookForm.txt
# Add a new book-25. VerifyResponsiveDesignOfCreateNewBookPage.txt
# Add a new genre-1. SuccessfulGenreCreation.txt
# Add a new genre-2. DisplayFormOnCreateNewButtonClick.txt
# Add a new genre-3. IncorrectDataEntry.txt
# Add a new genre-4. DisplayErrorMessageOnDataEntryError.txt
# Add a new genre-5. DisplaySuccessMessageOnSuccessfulAddition.txt
# Add a new genre-6. CancelOperationWithDataEntered.txt
# Add a new genre-7. CancelOperationWithoutDataEntered.txt
# Add a new genre-8. NavigationAwayFromFormWithoutSaving.txt
# Add a new genre-9. CheckDatabaseEntryOnSuccessfulAddition.txt
# Add a new genre-10. CheckNoDatabaseEntryOnCancel.txt
# Add a new genre-11. ValidateInputFieldsForEmptyData.txt
# Add a new genre-12. ValidateInputFieldsForInvalidData.txt
# Add a new genre-13. ValidateMaxLengthForNameField.txt
# Add a new genre-14. ValidateMaxLengthForDescriptionField.txt
# Add a new genre-15. CheckFormResetFunctionality.txt
# Add a new genre-16. CheckDuplicateGenreNameHandling.txt
# Add a new genre-17. CheckCaseSensitivityForGenreName.txt
# Add a new genre-18. CheckGenreListUpdateAfterNewGenreAdded.txt
# Add a new genre-19. CheckErrorResponseHandlingOnDatabaseError.txt
# Add a new genre-20. ValidateGenreCreationWithSpecialCharactersInName.txt
# Add a new genre-21. ValidateGenreCreationWithHTMLTagsInDescription.txt
# Add a new genre-22. CheckLoadingIndicatorDuringDataSubmission.txt
# Add a new genre-23. ValidateNavigationToBooksMenuWithoutSaving.txt
# Add a new genre-24. ValidateNavigationToGenresMenuWithoutSaving.txt
# Add a new genre-25. ValidateNavigationToAuthorsMenuWithoutSaving.txt
# Add a new genre-26. ValidateNavigationToHomeMenuWithoutSaving.txt
# Add a new genre-27. ValidateNavigationToAPIMenuWithoutSaving.txt
# Display author details-1. Test Scenario Verify Click Functionality on Author Title.txt
# Display author details-2. Test Scenario Validate Display of Author Details.txt
# Display author details-3. Test Scenario Check Author ID Visibility and Uniqueness.txt
# Display author details-4. Test Scenario Validate Author Name Display.txt
# Display author details-5. Test Scenario Check Author Bio Display.txt
# Display author details-6. Test Scenario Verify Error Handling for Invalid Author ID.txt
# Display author details-7. Test Scenario Test Page Layout for Author Details.txt
# Display author details-8. Test Scenario Validate Refresh Functionality on Author Details Page.txt
# Display author details-9. Test Scenario Check Responsiveness of Author Details Page.txt
# Display author details-10. Test Scenario Verify Navigation from Author List to Author Details.txt
# Display author details-11. Test Scenario Test Back Navigation to Author List Page.txt
# Display author details-12. Test Scenario Validate Loading Time for Author Details Page.txt
# Display author details-13. Test Scenario Check Accessibility Features for Author Details Page.txt
# Display author details-14. Test Scenario Verify Data Consistency for Author Details Across Sessions.txt
# Display author details-15. Test Scenario Test for SQL Injection Vulnerability in Author Details Page.txt
# Display book details-1. Test Display of Book Details on Click.txt
# Display book details-2. Test Correctness of Displayed Book ID.txt
# Display book details-3. Test Display of Correct Book Title.txt
# Display book details-4. Test Display of Correct Author Name.txt
# Display book details-5. Test Display of Correct Genre.txt
# Display book details-6. Test Display of Book Description.txt
# Display book details-7. Test Display of Correct Publication Date.txt
# Display book details-8. Test Display of Book Details for Multiple Books.txt
# Display book details-9. Test Display of Book Details with Special Characters in Title.txt
# Display book details-10. Test Display of Book Details with Long Description.txt
# Display book details-11. Test Display of Book Details with Future Publication Date.txt
# Display book details-12. Test Display of Book Details with Old Publication Date.txt
# Display book details-13. Test Display of Book Details with Non-English Characters.txt
# Display book details-14. Test Display of Book Details for a Book with Multiple Authors.txt
# Display book details-15. Test Display of Book Details for a Book without Genre.txt
# Display book details-16. Test Display of Book Details for a Book without Description.txt
# Display book details-17. Test Display of Book Details with Large Data Sets.txt
# Display book details-18. Test Display of Book Details Accessibility Features.txt
# Display book details-19. Test Display of Book Details Responsiveness on Different Devices.txt
# Display book details-20. Test Display of Book Details Performance under High Traffic.txt
# Display genre details-1. Test_DisplayValidGenreDetails.txt
# Display genre details-2. Test_DisplayGenreDetails_InvalidGenreId.txt
# Display genre details-3. Test_DisplayGenreDetails_EmptyGenreList.txt
# Display genre details-4. Test_DisplayGenreDetails_SpecialCharactersInGenreName.txt
# Display genre details-5. Test_DisplayGenreDetails_LongTextInDescription.txt
# Display genre details-6. Test_DisplayGenreDetails_MissingGenreId.txt
# Display genre details-7. Test_DisplayGenreDetails_MissingGenreName.txt
# Display genre details-8. Test_DisplayGenreDetails_MissingGenreDescription.txt
# Display genre details-9. Test_DisplayGenreDetails_GenreIdDataType.txt
# Display genre details-10. Test_DisplayGenreDetails_NavigationBackToGenreList.txt
# Display genre details-11. Test_DisplayGenreDetails_AccessibilityFeatures.txt
# Display genre details-12. Test_DisplayGenreDetails_RefreshPageStability.txt
# Display genre details-13. Test_DisplayGenreDetails_ConcurrentAccess.txt
# Display genre details-14. Test_DisplayGenreDetails_CrossBrowserCompatibility.txt
# Display genre details-15. Test_DisplayGenreDetails_ResponseTime.txt
# Display genre details-16. Test_DisplayGenreDetails_SecurityChecks.txt
# Display genre details-17. Test_DisplayGenreDetails_DirectURLAccessWithGenreId.txt
# Display genre details-18. Test_DisplayGenreDetails_UserPermissions.txt
# Display genre details-19. Test_DisplayGenreDetails_MobileResponsiveCheck.txt
# Display genre details-20. Test_DisplayGenreDetails_APIIntegrationCheck.txt
# Display the list of authors-1. DisplayInitialAuthorsList.txt
# Display the list of authors-2. PaginationNextButtonFunctionality.txt
# Display the list of authors-3. PaginationNumberedPageNavigation.txt
# Display the list of authors-4. DisplayAuthorIDColumn.txt
# Display the list of authors-5. DisplayAuthorNameColumn.txt
# Display the list of authors-6. DisplayAuthorBioColumn.txt
# Display the list of authors-7. EmptyAuthorsListHandling.txt
# Display the list of authors-8. DisplayMaximumTenAuthorsPerPage.txt
# Display the list of authors-9. PaginationWithOnlyOnePage.txt
# Display the list of authors-10. PaginationWithMultiplePages.txt
# Display the list of authors-11. LastPageAuthorsListDisplay.txt
# Display the list of authors-12. FirstPageNavigationFromMiddlePage.txt
# Display the list of authors-13. LastPageNavigationFromMiddlePage.txt
# Display the list of authors-14. RefreshPagePersistenceCheck.txt
# Display the list of authors-15. InvalidPageNumberHandling.txt
# Display the list of authors-16. ResponsiveDesignCheckForAuthorsList.txt
# Display the list of authors-17. AccessibilityCheckForAuthorsList.txt
# Display the list of authors-18. SearchFunctionalityIntegrationWithAuthorsList.txt
# Display the list of authors-19. SortingFunctionalityCheckForAuthorID.txt
# Display the list of authors-20. SortingFunctionalityCheckForAuthorName.txt
# Display the list of books-1. DisplayInitialBooksList.txt
# Display the list of books-2. PaginationNextButtonFunctionality.txt
# Display the list of books-3. PaginationNumberedPageNavigation.txt
# Display the list of books-4. FilterBooksByDateRange.txt
# Display the list of books-5. DisplayBooksListWithEmptyDateRange.txt
# Display the list of books-6. DisplayBooksListWithInvalidDateRange.txt
# Display the list of books-7. DisplayBooksListWithSingleDate.txt
# Display the list of books-8. DisplayBooksListWithFutureDateRange.txt
# Display the list of books-9. DisplayBooksListWithPastDateRange.txt
# Display the list of books-10. DisplayBooksListWithNonexistentDates.txt
# Display the list of books-11. DisplayBooksListWithBoundaryDateRange.txt
# Display the list of books-12. RefreshButtonFunctionalityAfterDateRangeInput.txt
# Display the list of books-13. DisplayBooksListColumnsVerification.txt
# Display the list of books-14. DisplayBooksListWithMaximumRecordsPerPage.txt
# Display the list of books-15. DisplayBooksListWithMoreThanMaximumRecords.txt
# Display the list of books-16. DisplayBooksListWithNoRecords.txt
# Display the list of books-17. DisplayBooksListWithExactMatchDateRange.txt
# Display the list of books-18. PaginationFunctionalityWithFilteredResults.txt
# Display the list of books-19. DisplayBooksListWithSpecialCharactersInDateRange.txt
# Display the list of books-20. DisplayBooksListWithLeapYearDateRange.txt
# Display the list of books-21. UserInterfaceResponsivenessOnDifferentDevices.txt
# Display the list of books-22. FilterFunctionalityWithConsecutiveDateRangeInputs.txt
# Display the list of books-23. DisplayBooksListSortingByPublicationDate.txt
# Display the list of books-24. DisplayBooksListWithConcurrentUsers.txt
# Display the list of books-25. ErrorHandlingForInvalidDateFormats.txt
# Display the list of genres-1. DisplayInitialGenresList.txt
# Display the list of genres-2. PaginationNextButtonFunctionality.txt
# Display the list of genres-3. PaginationNumberedPageNavigation.txt
# Display the list of genres-4. DisplayGenresListWithEmptyDatabase.txt
# Display the list of genres-5. DisplayGenresListWithMoreThan10Items.txt
# Display the list of genres-6. DisplayGenresListWithExactly10Items.txt
# Display the list of genres-7. DisplayGenresListColumnsVisibility.txt
# Display the list of genres-8. DisplayGenresListWithSpecialCharacters.txt
# Display the list of genres-9. DisplayGenresListOrderConsistency.txt
# Display the list of genres-10. DisplayGenresListWithDuplicateIds.txt
# Display the list of genres-11. DisplayGenresListWithLongTextDescription.txt
# Display the list of genres-12. DisplayGenresListWithHTMLTagsInData.txt
# Display the list of genres-13. DisplayGenresListAccessibilityFeatures.txt
# Display the list of genres-14. DisplayGenresListResponsiveDesign.txt
# Display the list of genres-15. DisplayGenresListPerformanceUnderLoad.txt
# Edit the author-1. UpdateAuthor_SuccessfulUpdate.txt
# Edit the author-2. UpdateAuthor_ValidationError.txt
# Edit the author-3. UpdateAuthor_DatabaseError.txt
# Edit the author-4. UpdateAuthor_CancelOperation.txt
# Edit the author-5. UpdateAuthor_NavigationAwayWithoutSaving.txt
# Edit the author-6. UpdateAuthor_EmptyNameField.txt
# Edit the author-7. UpdateAuthor_InvalidBioCharacters.txt
# Edit the author-8. UpdateAuthor_MaximumLengthExceeded_Name.txt
# Edit the author-9. UpdateAuthor_MaximumLengthExceeded_Bio.txt
# Edit the author-10. UpdateAuthor_MinimumLengthNotMet_Name.txt
# Edit the author-11. UpdateAuthor_MinimumLengthNotMet_Bio.txt
# Edit the author-12. UpdateAuthor_SpecialCharactersInName.txt
# Edit the author-13. UpdateAuthor_HTMLTagsInBio.txt
# Edit the author-14. UpdateAuthor_SQLInjection_NameField.txt
# Edit the author-15. UpdateAuthor_SQLInjection_BioField.txt
# Edit the author-16. UpdateAuthor_XSSAttack_NameField.txt
# Edit the author-17. UpdateAuthor_XSSAttack_BioField.txt
# Edit the author-18. UpdateAuthor_UpdateWithExistingAuthorName.txt
# Edit the author-19. UpdateAuthor_UpdateWithWhitespaceOnlyName.txt
# Edit the author-20. UpdateAuthor_UpdateWithWhitespaceOnlyBio.txt
# Edit the author-21. UpdateAuthor_RefreshPageDuringEdit.txt
# Edit the author-22. UpdateAuthor_BackButtonFunctionality.txt
# Edit the author-23. UpdateAuthor_UpdateButtonAccessibility.txt
# Edit the author-24. UpdateAuthor_SubmitButtonAccessibility.txt
# Edit the author-25. UpdateAuthor_CancelButtonAccessibility.txt
# Edit the book-1. UpdateBook_WithValidData.txt
# Edit the book-2. UpdateBook_WithInvalidTitle.txt
# Edit the book-3. UpdateBook_WithInvalidAuthor.txt
# Edit the book-4. UpdateBook_WithInvalidGenre.txt
# Edit the book-5. UpdateBook_WithInvalidDescription.txt
# Edit the book-6. UpdateBook_WithInvalidPublicationDate.txt
# Edit the book-7. UpdateBook_WithEmptyTitle.txt
# Edit the book-8. UpdateBook_WithEmptyAuthor.txt
# Edit the book-9. UpdateBook_WithEmptyGenre.txt
# Edit the book-10. UpdateBook_WithEmptyDescription.txt
# Edit the book-11. UpdateBook_WithEmptyPublicationDate.txt
# Edit the book-12. UpdateBook_DisplayErrorMessage_OnDatabaseError.txt
# Edit the book-13. UpdateBook_SuccessMessage_OnSuccessfulUpdate.txt
# Edit the book-14. UpdateBook_ValidateDataPersistence_OnSuccessfulUpdate.txt
# Edit the book-15. CancelUpdateBook_BeforeSubmitting.txt
# Edit the book-16. CancelUpdateBook_AfterModifyingData.txt
# Edit the book-17. NavigateAwayFromUpdatePage_UsingMenuBeforeSubmitting.txt
# Edit the book-18. NavigateAwayFromUpdatePage_UsingMenuAfterModifyingData.txt
# Edit the book-19. UpdateBook_WithSpecialCharactersInTitle.txt
# Edit the book-20. UpdateBook_WithFuturePublicationDate.txt
# Edit the book-21. UpdateBook_WithPastPublicationDate.txt
# Edit the book-22. UpdateBook_WithNonexistentAuthor.txt
# Edit the book-23. UpdateBook_WithNonexistentGenre.txt
# Edit the book-24. UpdateBook_RefreshPageBeforeSubmitting.txt
# Edit the book-25. UpdateBook_AccessibilityCheck_OnEditForm.txt
# Edit the genre-1. UpdateGenre_SuccessfulUpdate.txt
# Edit the genre-2. UpdateGenre_ValidationError.txt
# Edit the genre-3. UpdateGenre_DisplayErrorOnFailure.txt
# Edit the genre-4. UpdateGenre_CancelOperationBeforeSubmit.txt
# Edit the genre-5. UpdateGenre_NavigateAwayBeforeSubmit.txt
# Edit the genre-6. UpdateGenre_RequiredFieldsMissing.txt
# Edit the genre-7. UpdateGenre_InvalidCharactersInName.txt
# Edit the genre-8. UpdateGenre_InvalidFormatInDescription.txt
# Edit the genre-9. UpdateGenre_UniqueNameConstraint.txt
# Edit the genre-10. UpdateGenre_LoadExistingData.txt
# Edit the genre-11. UpdateGenre_CheckMaxLengthName.txt
# Edit the genre-12. UpdateGenre_CheckMaxLengthDescription.txt
# Edit the genre-13. UpdateGenre_SpecialCharactersInName.txt
# Edit the genre-14. UpdateGenre_SpecialCharactersInDescription.txt
# Edit the genre-15. UpdateGenre_WhitespaceInName.txt
# Edit the genre-16. UpdateGenre_WhitespaceInDescription.txt
# Edit the genre-17. UpdateGenre_UpdateWithSameData.txt
# Edit the genre-18. UpdateGenre_ConcurrencyCheckOnUpdate.txt
# Edit the genre-19. UpdateGenre_AccessibilityCheck.txt
# Edit the genre-20. UpdateGenre_SecurityPermissionsCheck.txt
# Remove the author-1. DeleteAuthor_SuccessfulDeletion.txt
# Remove the author-2. DeleteAuthor_CancelDeletion.txt
# Remove the author-3. DeleteAuthor_ConfirmationDialogDisplay.txt
# Remove the author-4. DeleteAuthor_AuthorDoesNotExist.txt
# Remove the author-5. DeleteAuthor_ValidateDataIntegrityPostDeletion.txt
# Remove the author-6. DeleteAuthor_NavigateAwayUsingMenuBeforeDeletion.txt
# Remove the author-7. DeleteAuthor_NavigateAwayUsingBrowserBackBeforeDeletion.txt
# Remove the author-8. DeleteAuthor_MultipleDeletionsSequential.txt
# Remove the author-9. DeleteAuthor_DatabaseConnectionErrorDuringDeletion.txt
# Remove the author-10. DeleteAuthor_PermissionsCheckBeforeDeletion.txt
# Remove the author-11. DeleteAuthor_RefreshPageDuringConfirmationDialog.txt
# Remove the author-12. DeleteAuthor_AccessibilityCheckOnDeletionDialog.txt
# Remove the author-13. DeleteAuthor_ResponseTimeForDeletionAction.txt
# Remove the author-14. DeleteAuthor_UndoDeleteActionAvailability.txt
# Remove the author-15. DeleteAuthor_DeleteButtonVisibilityAndAccessibility.txt
# Remove the book-1. DeleteBook_SuccessfulDeletion.txt
# Remove the book-2. DeleteBook_CancelDeletion.txt
# Remove the book-3. DeleteBook_ConfirmationDialogDisplay.txt
# Remove the book-4. DeleteBook_NavigateAwayWithoutDeletion_BooksMenu.txt
# Remove the book-5. DeleteBook_NavigateAwayWithoutDeletion_GenresMenu.txt
# Remove the book-6. DeleteBook_NavigateAwayWithoutDeletion_AuthorsMenu.txt
# Remove the book-7. DeleteBook_NavigateAwayWithoutDeletion_HomeMenu.txt
# Remove the book-8. DeleteBook_NavigateAwayWithoutDeletion_APIMenu.txt
# Remove the book-9. DeleteBook_DatabaseIntegrityAfterCancellation.txt
# Remove the book-10. DeleteBook_DatabaseIntegrityAfterDeletion.txt
# Remove the book-11. DeleteBook_UserInterfaceAfterSuccessfulDeletion.txt
# Remove the book-12. DeleteBook_UserInterfaceAfterCancellation.txt
# Remove the book-13. DeleteBook_AccessibilityOfDeleteButton.txt
# Remove the book-14. DeleteBook_ResponseTimeForDeletionConfirmation.txt
# Remove the book-15. DeleteBook_SecurityPermissions_CheckUserAuthorization.txt
# Remove the book-16. DeleteBook_ErrorHandling_InvalidBookID.txt
# Remove the book-17. DeleteBook_ErrorHandling_DatabaseUnavailable.txt
# Remove the book-18. DeleteBook_MultiUserConcurrentDeletionHandling.txt
# Remove the book-19. DeleteBook_AuditTrail_LogDeletionActivity.txt
# Remove the book-20. DeleteBook_UndoDeletionFeatureExistence (if applicable).txt
# Remove the genre-1. DeleteGenre_SuccessfulDeletion.txt
# Remove the genre-2. DeleteGenre_CancelDeletion.txt
# Remove the genre-3. DeleteGenre_ConfirmationDialogDisplay.txt
# Remove the genre-4. DeleteGenre_NavigationAfterCancellation.txt
# Remove the genre-5. DeleteGenre_DatabaseIntegrityAfterCancellation.txt
# Remove the genre-6. DeleteGenre_AccessibilityOfDeleteButton.txt
# Remove the genre-7. DeleteGenre_ResponseTimeForDeletion.txt
# Remove the genre-8. DeleteGenre_AuditLogEntryAfterDeletion.txt
# Remove the genre-9. DeleteGenre_PermissionDeniedForUnauthorizedUser.txt
# Remove the genre-10. DeleteGenre_ValidationForNonexistentGenre.txt
# Remove the genre-11. DeleteGenre_ConcurrencyHandlingWhenMultipleUsersDelete.txt
# Remove the genre-12. DeleteGenre_DataConsistencyAfterMultipleDeletions.txt
# Remove the genre-13. DeleteGenre_UndoDeleteOptionAvailability.txt
# Remove the genre-14. DeleteGenre_ImpactOnRelatedBooksOrAuthors.txt
# Remove the genre-15. DeleteGenre_NavigationToOtherPagesPreservesData.txt
# Remove the genre-16. DeleteGenre_RefreshPageAfterDeletionAttempt.txt
# Remove the genre-17. DeleteGenre_AccessViaDirectURLToDeletedGenre.txt
# Remove the genre-18. DeleteGenre_DeleteButtonVisibilityForDifferentUserRoles.txt
# Remove the genre-19. DeleteGenre_ErrorHandlingForDatabaseFailureDuringDeletion.txt
# Remove the genre-20. DeleteGenre_PerformanceUnderLoad.txt
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-1. VerifyClickCreateNewButton.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': '1. VerifyClickCreateNewButton', 'Test Case Name': 'Verify successful creation of a new author record', 'Objective': "To verify that a user can successfully create a new author record by entering valid data and clicking the 'Submit' button", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields.   - Step 4: Click the 'Submit' button.", 'Expected Result': 'A new author record is successfully added to the database, and the user is redirected to the list of authors with the newly added record visible.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '1. VerifyClickCreateNewButton', 'Test Case Name': 'Verify incorrect data handling in new author creation', 'Objective': 'To verify that the application displays error messages when incorrect data is entered in the author creation form', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button.   - Step 3: Enter invalid data into the 'Name' and/or 'Bio' fields.   - Step 4: Click the 'Submit' button.", 'Expected Result': 'The application displays error messages indicating the incorrect data, and the new author record is not added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '1. VerifyClickCreateNewButton', 'Test Case Name': 'Verify cancel operation during new author creation', 'Objective': "To verify that no new author record is created and data is not saved when the 'Cancel' button is clicked before submitting the form", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Click the 'Cancel' button before clicking 'Submit'.", 'Expected Result': 'The application does not save the entered data and redirects the user to the list of authors without adding a new record.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '1. VerifyClickCreateNewButton', 'Test Case Name': 'Verify navigation away from creation form discards data', 'Objective': 'To verify that navigating away from the author creation form by selecting another menu item discards any entered data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Without clicking 'Submit', select another menu item such as 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The application does not save the entered data and displays the selected page without adding a new author record.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-2. VerifyFormDisplayAfterClickingCreateNew.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': '2. VerifyFormDisplayAfterClickingCreateNew', 'Test Case Name': "Verify Form Display After Clicking 'Create New' for Author", 'Objective': "Ensure that the form to add a new author is displayed correctly after clicking the 'Create new' button.", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.", 'Expected Result': 'A form to enter author data including fields for Name and Bio should be displayed.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '2. VerifyFormDisplayAfterClickingCreateNew', 'Test Case Name': 'Verify Successful Author Creation', 'Objective': 'Verify that a new author record can be successfully added to the database with valid data.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter valid data into the Name and Bio fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'A new author record is added to the database, and the list of authors with the newly added record is displayed.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '2. VerifyFormDisplayAfterClickingCreateNew', 'Test Case Name': 'Verify Incorrect Data Handling', 'Objective': 'Ensure that entering incorrect data displays appropriate error messages.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter incorrect or invalid data into the Name and/or Bio fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'Messages indicating the incorrect data are displayed, and the record is not added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '2. VerifyFormDisplayAfterClickingCreateNew', 'Test Case Name': 'Verify Error Handling During Author Creation', 'Objective': 'Ensure that an error message is displayed if an error occurs while adding a new author record.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter valid data into the Name and Bio fields.   - Step 4: Simulate an error condition (e.g., database connection issue) and press the 'Submit' button.", 'Expected Result': 'An error message is displayed, and the new author record is not added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '2. VerifyFormDisplayAfterClickingCreateNew', 'Test Case Name': 'Verify Cancel Operation During Author Creation', 'Objective': "Ensure that pressing the 'Cancel' button while adding a new author discards the data and returns to the author list.", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Start entering data into the Name and Bio fields.   - Step 4: Press the 'Cancel' button.", 'Expected Result': 'Data is not saved in the database, and the list of author records is displayed.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '2. VerifyFormDisplayAfterClickingCreateNew', 'Test Case Name': 'Verify Navigation Away Discards Unsaved Author Data', 'Objective': 'Ensure that navigating away from the author creation form discards unsaved data.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Start entering data into the Name and Bio fields.   - Step 4: Without pressing 'Submit', navigate to another menu item like 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'Data is not saved to the database, and the corresponding form or page for the selected menu item is displayed with updated data.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-3. VerifySubmitWithValidData.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': '3. VerifySubmitWithValidData', 'Test Case Name': 'Verify Submit with Valid Author Data', 'Objective': 'Ensure that the system correctly adds a new author record to the database when valid data is entered and the submit button is pressed', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'A new author record is successfully added to the database, and the user is redirected to the list of authors with the newly added record visible.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '3. VerifySubmitWithValidData', 'Test Case Name': 'Verify Submit with Invalid Author Data', 'Objective': 'To verify that the system displays appropriate error messages when invalid data is entered in the author creation form', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button.   - Step 3: Enter invalid data into the 'Name' and/or 'Bio' fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'The system displays error messages indicating which fields contain incorrect data and does not add a new record to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '3. VerifySubmitWithValidData', 'Test Case Name': 'Verify Cancel Operation during Author Creation', 'Objective': "To ensure that no data is saved to the database and the user is redirected back to the list of authors when the 'Cancel' button is pressed", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Press the 'Cancel' button.", 'Expected Result': 'No new author record is added to the database, and the user is redirected to the list of authors without the data they entered being saved.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '3. VerifySubmitWithValidData', 'Test Case Name': 'Verify Navigation Away from Author Creation Does Not Save Data', 'Objective': 'To confirm that navigating away from the author creation form without submitting does not save any entered data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Without pressing 'Submit', select another menu item like 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The system does not save the partially entered author data and displays the selected page without adding a new author record to the database.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-4. VerifyErrorMessageForInvalidData.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': '4. VerifyErrorMessageForInvalidData', 'Test Case Name': 'Verify error message for invalid author name', 'Objective': 'To verify that the application displays an error message when the user enters an invalid author name while adding a new author', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Leave the 'Name' field empty or enter invalid characters.   - Step 4: Fill in the 'Bio' field with valid data.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'An error message should be displayed indicating that the name field is required or contains invalid characters.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '4. VerifyErrorMessageForInvalidData', 'Test Case Name': 'Verify error message for invalid author bio', 'Objective': 'To verify that the application displays an error message when the user enters an invalid author bio while adding a new author', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Fill in the 'Name' field with valid data.   - Step 4: Leave the 'Bio' field empty or enter invalid characters.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'An error message should be displayed indicating that the bio field is required or contains invalid characters.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '4. VerifyErrorMessageForInvalidData', 'Test Case Name': 'Verify successful author creation', 'Objective': 'To verify that the application successfully adds a new author record to the database when valid data is entered', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Fill in the 'Name' field with valid data.   - Step 4: Fill in the 'Bio' field with valid data.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'The new author record should be successfully added to the database, and the user should be redirected to the list of authors with the newly added record visible.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '4. VerifyErrorMessageForInvalidData', 'Test Case Name': 'Verify cancel operation during author creation', 'Objective': "To verify that no data is saved and the user is redirected back to the list of authors when the 'Cancel' button is pressed during the author creation process", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Start entering data into the form fields.   - Step 4: Press the 'Cancel' button before pressing 'Submit'.", 'Expected Result': 'The user should be redirected back to the list of authors without the new author being added to the database.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-5. VerifyDatabaseEntryOnSuccessfulSubmission.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': '5. VerifyDatabaseEntryOnSuccessfulSubmission', 'Test Case Name': 'Verify Successful Author Creation and Database Entry', 'Objective': 'To ensure that a new author record is successfully created and added to the database when valid data is submitted', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author creation form.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'A confirmation message is displayed, and the new author record is visible in the list of authors, indicating successful addition to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '5. VerifyDatabaseEntryOnSuccessfulSubmission', 'Test Case Name': 'Verify Incorrect Data Handling in Author Creation', 'Objective': 'To verify that the system correctly handles and displays messages for incorrectly entered data during author creation', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author creation form.   - Step 3: Enter invalid data into either the 'Name' or 'Bio' fields (e.g., leaving them blank).   - Step 4: Press the 'Submit' button.", 'Expected Result': 'The system displays messages indicating which fields are incorrectly filled out, preventing the creation of a new author record.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '5. VerifyDatabaseEntryOnSuccessfulSubmission', 'Test Case Name': 'Verify Error Handling on Author Creation Failure', 'Objective': 'To ensure that the system displays an appropriate error message if an error occurs during the author creation process', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author creation form.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields.   - Step 4: Simulate an error condition (e.g., database connection issue) and press the 'Submit' button.", 'Expected Result': 'An error message is displayed, indicating that the author record could not be added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '5. VerifyDatabaseEntryOnSuccessfulSubmission', 'Test Case Name': 'Verify Cancellation of Author Creation', 'Objective': 'To verify that no data is saved to the database and the user is redirected back to the list of authors upon cancellation', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author creation form.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Press the 'Cancel' button before submitting the form.", 'Expected Result': 'The user is redirected to the list of authors without the new author being added, indicating no data was saved to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '5. VerifyDatabaseEntryOnSuccessfulSubmission', 'Test Case Name': 'Verify Navigation Away from Author Creation Discards Data', 'Objective': 'To ensure that navigating away from the author creation form without submitting discards any entered data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to open the author creation form.   - Step 3: Enter data into the 'Name' and 'Bio' fields.   - Step 4: Without pressing 'Submit', navigate to another menu item like 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The navigation is successful, and the author creation form is closed without saving the entered data, as evidenced by the absence of the new author in the list.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-6. VerifyErrorMessageOnDatabaseError.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': '6. VerifyErrorMessageOnDatabaseError', 'Test Case Name': 'Verify successful author creation', 'Objective': 'To verify that a new author record is successfully added to the database when valid data is entered', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'A success message is displayed, and the new author record is visible in the list of authors.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '6. VerifyErrorMessageOnDatabaseError', 'Test Case Name': 'Verify error message on entering invalid data', 'Objective': 'To verify that an error message is displayed when invalid data is entered for a new author', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter invalid data into the 'Name' and/or 'Bio' fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'An error message related to the invalid data is displayed, and the record is not added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '6. VerifyErrorMessageOnDatabaseError', 'Test Case Name': 'Verify error message on database error', 'Objective': 'To verify that an error message is displayed when there is a database error during the author creation process', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields.   - Step 4: Simulate a database error or disconnect the database connection.   - Step 5: Press the 'Submit' button.", 'Expected Result': 'An error message indicating a database error is displayed, and the record is not added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '6. VerifyErrorMessageOnDatabaseError', 'Test Case Name': 'Verify cancellation of author creation', 'Objective': 'To verify that the author creation process can be cancelled without saving data to the database', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Press the 'Cancel' button.", 'Expected Result': 'The author creation form is closed, no data is saved to the database, and the list of author records is displayed.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '6. VerifyErrorMessageOnDatabaseError', 'Test Case Name': 'Verify navigation away from author creation does not save data', 'Objective': 'To verify that navigating away from the author creation form without submitting does not save data to the database', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Without pressing 'Submit', navigate to another menu item like 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The navigation is successful, no data is saved to the database, and the selected page is displayed with updated data.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-7. VerifyAuthorListUpdateAfterNewAuthorAdded.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': '7. VerifyAuthorListUpdateAfterNewAuthorAdded', 'Test Case Name': 'Verify successful addition of a new author', 'Objective': 'To verify that a new author can be successfully added and the author list is updated accordingly', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'A success message is displayed, and the new author appears in the author list.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '7. VerifyAuthorListUpdateAfterNewAuthorAdded', 'Test Case Name': 'Verify incorrect data handling when adding a new author', 'Objective': 'To verify that the application displays error messages for incorrect data when adding a new author', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter invalid data into the 'Name' and/or 'Bio' fields.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'Error messages related to incorrect data are displayed, and the author is not added to the database.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '7. VerifyAuthorListUpdateAfterNewAuthorAdded', 'Test Case Name': 'Verify error handling when adding a new author', 'Objective': 'To verify that the application displays an error message if an error occurs while adding a new author', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Enter valid data into the 'Name' and 'Bio' fields but simulate a database error.   - Step 4: Press the 'Submit' button.", 'Expected Result': 'An error message is displayed, and the new author is not added to the author list.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '7. VerifyAuthorListUpdateAfterNewAuthorAdded', 'Test Case Name': 'Verify cancel operation during new author addition', 'Objective': "To verify that no data is saved and the user is redirected back to the author list when the 'Cancel' button is pressed", 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Press the 'Cancel' button before submitting.", 'Expected Result': 'Data is not saved, and the user is redirected back to the author list page.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '7. VerifyAuthorListUpdateAfterNewAuthorAdded', 'Test Case Name': 'Verify navigation away from the create new author page', 'Objective': 'To verify that navigating away from the create new author page without submitting does not save data', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click on the 'Create new' button.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Navigate away from the page by selecting another menu item like 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'Data is not saved, and the user is redirected to the selected page without adding the new author.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-8. VerifyCancelOperationBeforeDataSubmission.txt
# [{'Use Case Name': 'Add a new author', 'Test Scenario Name': '8. VerifyCancelOperationBeforeDataSubmission', 'Test Case Name': 'Verify Cancel Operation Before Data Submission on New Author Creation', 'Objective': 'Ensure that the cancel operation before submitting new author data does not save data to the database and redirects the user to the author list page.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to add a new author.   - Step 3: Start entering data into the 'Name' and 'Bio' fields.   - Step 4: Before submitting, click the 'Cancel' button.", 'Expected Result': 'The application should not save the entered data and should redirect the user to the author list page, displaying the existing authors without the addition of the new author.'}, {'Use Case Name': 'Add a new author', 'Test Scenario Name': '8. VerifyCancelOperationBeforeDataSubmission', 'Test Case Name': 'Verify Navigation Away Cancels New Author Data Submission', 'Objective': 'To confirm that navigating away from the new author creation form without submitting cancels the operation and does not save the entered data.', 'Test Steps': "- Step 1: Navigate to the author list page.   - Step 2: Click the 'Create new' button to initiate the creation of a new author.   - Step 3: Enter data into the 'Name' and 'Bio' fields.   - Step 4: Without submitting, select another menu item such as 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': "The application should not save the entered data and should display the selected page. If 'Authors' is selected, the list of authors should be shown without the addition of the new author."}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Add a new author-9. VerifyNoDatabaseEntryOnCancel.txt
# ...
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Remove the genre-15. DeleteGenre_NavigationToOtherPagesPreservesData.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': '15. DeleteGenre_NavigationToOtherPagesPreservesData', 'Test Case Name': 'Verify deletion of genre and navigation preserves data', 'Objective': 'Ensure that a user can delete a genre and upon confirmation, the genre is deleted. Also, verify that navigating to other pages after initiating but canceling a delete operation preserves the data.', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre intended for deletion.   - Step 3: On the confirmation dialog, click the 'Confirm' button.   - Step 4: Observe the list to confirm deletion.   - Step 5: Navigate to other pages such as 'Books', 'Genres', 'Authors', 'Home', or 'API' and observe the data.", 'Expected Result': 'The selected genre should be deleted from the list after confirmation. Navigating to other pages should display updated data without the deleted genre.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '15. DeleteGenre_NavigationToOtherPagesPreservesData', 'Test Case Name': 'Verify canceling deletion of genre preserves data', 'Objective': 'To verify that canceling the deletion of a genre does not remove the genre from the database and that navigation to other pages still shows the genre.', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre intended for deletion.   - Step 3: On the confirmation dialog, click the 'Cancel' button.   - Step 4: Observe the list to confirm the genre is still present.   - Step 5: Navigate to 'Books', 'Genres', 'Authors', 'Home', or 'API' pages.   - Step 6: Verify that the previously attempted-to-delete genre is visible and data is preserved.", 'Expected Result': 'The genre should not be deleted from the database and should still be visible in the list. Navigating to other pages should also display the genre as part of the data.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Remove the genre-16. DeleteGenre_RefreshPageAfterDeletionAttempt.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': '16. DeleteGenre_RefreshPageAfterDeletionAttempt', 'Test Case Name': 'Verify genre deletion and refresh page after deletion', 'Objective': 'Ensure that the genre is deleted from the list after the user confirms the deletion and the page refreshes to reflect the changes', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, click the 'Confirm' button to proceed with deletion.", 'Expected Result': 'The genre should be deleted from the list, and the page should refresh to reflect that the genre has been removed.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '16. DeleteGenre_RefreshPageAfterDeletionAttempt', 'Test Case Name': 'Verify cancellation of genre deletion', 'Objective': 'Ensure that the genre is not deleted from the list when the user cancels the deletion process', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, click the 'Cancel' button to abort deletion.", 'Expected Result': 'The genre should not be deleted from the list, and the user should be redirected back to the list of genres without any changes.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '16. DeleteGenre_RefreshPageAfterDeletionAttempt', 'Test Case Name': 'Verify navigation after cancelling genre deletion', 'Objective': 'Ensure that navigation works correctly after cancelling the deletion of a genre and that no data is deleted', 'Test Steps': "- Step 1: Navigate to the genre list/details page and click the 'Delete' button next to the genre you wish to delete.   - Step 2: On the confirmation dialog, click the 'Cancel' button.   - Step 3: After cancellation, select any menu item such as 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': "The application should navigate to the selected menu item's page without deleting any data, and the data displayed should be up to date."}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Remove the genre-17. DeleteGenre_AccessViaDirectURLToDeletedGenre.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': '17. DeleteGenre_AccessViaDirectURLToDeletedGenre', 'Test Case Name': 'Verify Deletion of Genre with Confirmation', 'Objective': 'To ensure that the genre is successfully deleted from the list after the user confirms the deletion.', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, click the 'Confirm' button.", 'Expected Result': 'The genre should be successfully deleted from the list, and the list should be updated to reflect this change.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '17. DeleteGenre_AccessViaDirectURLToDeletedGenre', 'Test Case Name': 'Verify Cancellation of Genre Deletion', 'Objective': 'To verify that the genre is not deleted from the list when the user cancels the deletion process.', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, click the 'Cancel' button.", 'Expected Result': 'The genre should not be deleted from the list, and the user should be redirected back to the updated list of genres.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '17. DeleteGenre_AccessViaDirectURLToDeletedGenre', 'Test Case Name': 'Verify Navigation Away Cancels Deletion', 'Objective': 'To ensure that navigating away from the deletion confirmation dialog cancels the deletion process.', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, instead of clicking 'Confirm' or 'Cancel', navigate away by selecting another menu item such as 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The genre should not be deleted from the list, and the user should be redirected to the selected page with no changes made to the genre list.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Remove the genre-18. DeleteGenre_DeleteButtonVisibilityForDifferentUserRoles.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': '18. DeleteGenre_DeleteButtonVisibilityForDifferentUserRoles', 'Test Case Name': 'Verify Delete Button Visibility for Admin User', 'Objective': "Ensure that the 'Delete' button is visible to users with Admin role on the genre list/details page", 'Test Steps': '- Step 1: Log in as a user with Admin role.   - Step 2: Navigate to the genre list/details page.   - Step 3: Identify a genre you wish to delete.', 'Expected Result': "The 'Delete' button should be visible next to the genre details."}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '18. DeleteGenre_DeleteButtonVisibilityForDifferentUserRoles', 'Test Case Name': 'Verify Delete Button Visibility for Non-Admin User', 'Objective': "Ensure that the 'Delete' button is not visible to users without Admin role on the genre list/details page", 'Test Steps': '- Step 1: Log in as a user without Admin role.   - Step 2: Navigate to the genre list/details page.   - Step 3: Identify a genre.', 'Expected Result': "The 'Delete' button should not be visible next to the genre details."}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '18. DeleteGenre_DeleteButtonVisibilityForDifferentUserRoles', 'Test Case Name': 'Verify Genre Deletion Confirmation for Admin User', 'Objective': 'Ensure that an Admin user can delete a genre after confirming the deletion', 'Test Steps': "- Step 1: Log in as a user with Admin role.   - Step 2: Navigate to the genre list/details page and click the 'Delete' button next to a genre.   - Step 3: On the dialog page, confirm deletion by pressing the 'Confirm' button.", 'Expected Result': 'The genre should be deleted from the list, and the application should not display it anymore.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '18. DeleteGenre_DeleteButtonVisibilityForDifferentUserRoles', 'Test Case Name': 'Verify Genre Deletion Cancellation for Admin User', 'Objective': 'Ensure that an Admin user can cancel the deletion of a genre', 'Test Steps': "- Step 1: Log in as a user with Admin role.   - Step 2: Navigate to the genre list/details page and click the 'Delete' button next to a genre.   - Step 3: On the dialog page, press the 'Cancel' button.", 'Expected Result': 'The genre should not be deleted from the list, and the application should still display it.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '18. DeleteGenre_DeleteButtonVisibilityForDifferentUserRoles', 'Test Case Name': 'Verify Navigation After Cancelling Genre Deletion', 'Objective': 'Ensure that after cancelling the deletion of a genre, the user can navigate to other pages without deleting the genre', 'Test Steps': "- Step 1: Log in as a user with Admin role.   - Step 2: Navigate to the genre list/details page and click the 'Delete' button next to a genre.   - Step 3: On the dialog page, press the 'Cancel' button.   - Step 4: Select the menu item 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The application navigates to the selected page without deleting the genre, and the data is updated accordingly.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Remove the genre-19. DeleteGenre_ErrorHandlingForDatabaseFailureDuringDeletion.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': '19. DeleteGenre_ErrorHandlingForDatabaseFailureDuringDeletion', 'Test Case Name': 'Verify deletion confirmation dialog is displayed when deleting a genre', 'Objective': 'Ensure that the application prompts the user with a confirmation dialog when attempting to delete a genre', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.", 'Expected Result': 'A dialog page asking for confirmation to delete the selected genre should be displayed.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '19. DeleteGenre_ErrorHandlingForDatabaseFailureDuringDeletion', 'Test Case Name': 'Verify successful deletion of a genre', 'Objective': 'To confirm that a genre can be successfully deleted from the database upon user confirmation', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, click the 'Confirm' button.", 'Expected Result': 'The genre should be successfully deleted from the database, and the list of genres should be updated to reflect this change.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '19. DeleteGenre_ErrorHandlingForDatabaseFailureDuringDeletion', 'Test Case Name': 'Verify cancellation of genre deletion', 'Objective': 'To ensure that the deletion process can be cancelled and that no data is deleted from the database when the user cancels the operation', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, click the 'Cancel' button.", 'Expected Result': 'The deletion process should be cancelled, no data should be deleted from the database, and the user should be redirected back to the list of genres.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '19. DeleteGenre_ErrorHandlingForDatabaseFailureDuringDeletion', 'Test Case Name': 'Verify navigation away from deletion cancels the deletion process', 'Objective': 'To verify that navigating away from the deletion confirmation dialog by selecting another menu item cancels the deletion process and no data is deleted', 'Test Steps': "- Step 1: Navigate to the genre list/details page.   - Step 2: Click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, instead of clicking 'Confirm' or 'Cancel', select another menu item such as 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The deletion process should be cancelled, no data should be deleted from the database, and the user should be redirected to the selected page with updated data.'}]
# D:\Dissertation-GPT\evaluate\baseline 2\book test case\Remove the genre-20. DeleteGenre_PerformanceUnderLoad.txt
# [{'Use Case Name': 'Remove the genre', 'Test Scenario Name': '20. DeleteGenre_PerformanceUnderLoad', 'Test Case Name': 'Delete Genre - Confirm Deletion Under Load', 'Objective': 'Verify that the genre can be successfully deleted under load when the user confirms the deletion.', 'Test Steps': "- Step 1: Simulate load on the system by initiating multiple delete requests for different genres.   - Step 2: For one of the genres, click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, click the 'Confirm' button to proceed with the deletion.", 'Expected Result': 'The system should handle the load efficiently and delete the selected genre from the database. The user should be redirected to the updated genre list, not showing the deleted genre.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '20. DeleteGenre_PerformanceUnderLoad', 'Test Case Name': 'Delete Genre - Cancel Deletion Under Load', 'Objective': 'Verify that the genre is not deleted and remains in the database under load when the user cancels the deletion.', 'Test Steps': "- Step 1: Simulate load on the system by initiating multiple delete requests for different genres.   - Step 2: For one of the genres, click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, click the 'Cancel' button to abort the deletion process.", 'Expected Result': 'Despite the system being under load, the cancellation process should be successful, and the genre should remain in the database. The user should be redirected to the genre list, still showing the genre that was attempted to be deleted.'}, {'Use Case Name': 'Remove the genre', 'Test Scenario Name': '20. DeleteGenre_PerformanceUnderLoad', 'Test Case Name': 'Delete Genre - Navigate Away Under Load', 'Objective': 'Verify that the genre is not deleted from the database under load when the user navigates away from the deletion confirmation dialog without confirming deletion.', 'Test Steps': "- Step 1: Simulate load on the system by initiating multiple delete requests for different genres.   - Step 2: For one of the genres, click the 'Delete' button next to the genre you wish to delete.   - Step 3: On the confirmation dialog, instead of clicking 'Confirm' or 'Cancel', navigate away by selecting another menu item such as 'Books', 'Genres', 'Authors', 'Home', or 'API'.", 'Expected Result': 'The system should handle the load and user navigation efficiently, not deleting the genre from the database. The user should be redirected to the selected page with the data intact and the genre still present in the genre list.'}]

# %%
import pandas as pd

# Load the Excel file
file_path = 'output_file.xlsx'  # Replace with your file path
df = pd.read_excel(file_path)

# Define the condition for keeping rows
condition = (df['Valid'].notna()) | (df['Test Scenario'].str.contains('txt', na=False))

# Apply the condition to filter the DataFrame
df_cleaned = df[condition]

# Save the cleaned data to a new Excel file
df_cleaned.to_excel('cleaned_file.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 # Load the Excel file
#       4 file_path = 'output_file.xlsx'  # Replace with your file path
# ----> 5 df = pd.read_excel(file_path)
#       7 # Define the condition for keeping rows
#       8 condition = (df['Valid'].notna()) | (df['Test Scenario'].str.contains('txt', na=False))
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:557, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     547 """
#     548 Reader using openpyxl engine.
#     549
#    (...)
#     554 {storage_options}
#     555 """
#     556 import_optional_dependency("openpyxl")
# --> 557 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:568, in OpenpyxlReader.load_workbook(self, filepath_or_buffer)
#     565 def load_workbook(self, filepath_or_buffer: FilePath | ReadBuffer[bytes]):
#     566     from openpyxl import load_workbook
# --> 568     return load_workbook(
#     569         filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     570     )
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:317, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     290 """Open the given filename and return the workbook
#     291
#     292 :param filename: the path to open or a file-like object
#    (...)
#     313
#     314 """
#     315 reader = ExcelReader(filename, read_only, keep_vba,
#     316                     data_only, keep_links)
# --> 317 reader.read()
#     318 return reader.wb
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:279, in ExcelReader.read(self)
#     277 self.read_strings()
#     278 self.read_workbook()
# --> 279 self.read_properties()
#     280 self.read_theme()
#     281 apply_stylesheet(self.archive, self.wb)
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:172, in ExcelReader.read_properties(self)
#     170 def read_properties(self):
#     171     if ARC_CORE in self.valid_files:
# --> 172         src = fromstring(self.archive.read(ARC_CORE))
#     173         self.wb.properties = DocumentProperties.from_tree(src)
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:1475, in ZipFile.read(self, name, pwd)
#    1473 def read(self, name, pwd=None):
#    1474     """Return file bytes for name."""
# -> 1475     with self.open(name, "r", pwd) as fp:
#    1476         return fp.read()
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:1530, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1526 zef_file = _SharedFile(self.fp, zinfo.header_offset,
#    1527                        self._fpclose, self._lock, lambda: self._writing)
#    1528 try:
#    1529     # Skip the file header:
# -> 1530     fheader = zef_file.read(sizeFileHeader)
#    1531     if len(fheader) != sizeFileHeader:
#    1532         raise BadZipFile("Truncated file header")
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:745, in _SharedFile.read(self, n)
#     741     raise ValueError("Can't read from the ZIP file while there "
#     742             "is an open writing handle on it. "
#     743             "Close the writing handle before trying to read.")
#     744 self._file.seek(self._pos)
# --> 745 data = self._file.read(n)
#     746 self._pos = self._file.tell()
#     747 return data
#
# KeyboardInterrupt:

# %%
import pandas as pd
import json

# Load the Excel file
file_path = 'cleaned_file.xlsx'
df = pd.read_excel(file_path, usecols=['Test Scenario'])

# Initialize variables
use_case_name = ''
scenarios = []
result = []

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    test_scenario = row['Test Scenario']
    if test_scenario.endswith('.txt'):
        # If we already have a use case name, save the previous use case and its scenarios
        if use_case_name:
            result.append({
                'use_case_name': use_case_name,
                'scenarios': scenarios
            })
        # Set the new use case name and reset the scenarios list
        use_case_name = test_scenario
        scenarios = []
    else:
        # Add the scenario to the current use case's scenarios list
        scenarios.append(test_scenario)

# Add the last use case and its scenarios
if use_case_name:
    result.append({
        'use_case_name': use_case_name,
        'scenarios': scenarios
    })

# Convert the result to a JSON string
result_json = json.dumps(result, indent=4)

# Print the result
print(result_json)

# # Optionally, save the result to a JSON file
# with open('result.json', 'w') as json_file:
#     json_file.write(result_json)
# Out:
# [
#     {
#         "use_case_name": "Add a new author.txt",
#         "scenarios": [
#             "3. VerifySubmitWithValidData",
#             "4. VerifyErrorMessageForInvalidData",
#             "6. VerifyErrorMessageOnDatabaseError",
#             "8. VerifyCancelOperationBeforeDataSubmission",
#             "10. VerifyNavigationAwayDoesNotSaveData",
#             "12. VerifyMaxLengthValidationForNameField",
#             "13. VerifyMaxLengthValidationForBioField",
#             "16. VerifyUniqueNameConstraint"
#         ]
#     },
#     {
#         "use_case_name": "Add a new book.txt",
#         "scenarios": [
#             "3. VerifySubmitWithValidData",
#             "4. VerifyErrorMessageForInvalidData",
#             "6. VerifyErrorMessageOnDatabaseError",
#             "9. VerifyDataNotSavedOnCancel",
#             "10. VerifyNavigationAwayDoesNotSaveData",
#             "16. VerifyFieldValidationsWithEmptyInputs",
#             "17. VerifyFieldValidationsWithBoundaryValues",
#             "18. VerifyFieldValidationsWithSpecialCharacters",
#             "22. VerifyUniqueConstraintForBookTitle"
#         ]
#     },
#     {
#         "use_case_name": "Add a new genre.txt",
#         "scenarios": [
#             "1. SuccessfulGenreCreation",
#             "3. IncorrectDataEntry",
#             "5. DisplaySuccessMessageOnSuccessfulAddition",
#             "6. CancelOperationWithDataEntered",
#             "7. CancelOperationWithoutDataEntered",
#             "11. ValidateInputFieldsForEmptyData",
#             "12. ValidateInputFieldsForInvalidData",
#             "13. ValidateMaxLengthForNameField",
#             "14. ValidateMaxLengthForDescriptionField",
#             "16. CheckDuplicateGenreNameHandling",
#             "19. CheckErrorResponseHandlingOnDatabaseError",
#             "20. ValidateGenreCreationWithSpecialCharactersInName",
#             "21. ValidateGenreCreationWithHTMLTagsInDescription",
#             "22. CheckLoadingIndicatorDuringDataSubmission",
#             "23. ValidateNavigationToBooksMenuWithoutSaving",
#             "24. ValidateNavigationToGenresMenuWithoutSaving",
#             "25. ValidateNavigationToAuthorsMenuWithoutSaving",
#             "26. ValidateNavigationToHomeMenuWithoutSaving",
#             "27. ValidateNavigationToAPIMenuWithoutSaving"
#         ]
#     },
#     {
#         "use_case_name": "Display author details.txt",
#         "scenarios": [
#             "10. Test Scenario: Verify Navigation from Author List to Author Details"
#         ]
#     },
#     {
#         "use_case_name": "Display book details.txt",
#         "scenarios": [
#             "1. Test Display of Book Details on Click"
#         ]
#     },
#     {
#         "use_case_name": "Display genre details.txt",
#         "scenarios": [
#             "1. Test_DisplayValidGenreDetails"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of authors.txt",
#         "scenarios": [
#             "1. DisplayInitialAuthorsList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation",
#             "11. LastPageAuthorsListDisplay",
#             "12. FirstPageNavigationFromMiddlePage",
#             "13. LastPageNavigationFromMiddlePage"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of books.txt",
#         "scenarios": [
#             "1. DisplayInitialBooksList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation",
#             "4. FilterBooksByDateRange",
#             "5. DisplayBooksListWithEmptyDateRange",
#             "6. DisplayBooksListWithInvalidDateRange",
#             "7. DisplayBooksListWithSingleDate",
#             "8. DisplayBooksListWithFutureDateRange",
#             "9. DisplayBooksListWithPastDateRange",
#             "10. DisplayBooksListWithNonexistentDates",
#             "11. DisplayBooksListWithBoundaryDateRange",
#             "19. DisplayBooksListWithSpecialCharactersInDateRange"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of genres.txt",
#         "scenarios": [
#             "1. DisplayInitialGenresList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation"
#         ]
#     },
#     {
#         "use_case_name": "Edit the author.txt",
#         "scenarios": [
#             "1. UpdateAuthor_SuccessfulUpdate",
#             "3. UpdateAuthor_DatabaseError",
#             "4. UpdateAuthor_CancelOperation",
#             "5. UpdateAuthor_NavigationAwayWithoutSaving",
#             "6. UpdateAuthor_EmptyNameField",
#             "7. UpdateAuthor_InvalidBioCharacters",
#             "8. UpdateAuthor_MaximumLengthExceeded_Name",
#             "9. UpdateAuthor_MaximumLengthExceeded_Bio",
#             "10. UpdateAuthor_MinimumLengthNotMet_Name",
#             "11. UpdateAuthor_MinimumLengthNotMet_Bio",
#             "12. UpdateAuthor_SpecialCharactersInName",
#             "13. UpdateAuthor_HTMLTagsInBio",
#             "14. UpdateAuthor_SQLInjection_NameField",
#             "15. UpdateAuthor_SQLInjection_BioField",
#             "16. UpdateAuthor_XSSAttack_NameField",
#             "17. UpdateAuthor_XSSAttack_BioField",
#             "18. UpdateAuthor_UpdateWithExistingAuthorName",
#             "19. UpdateAuthor_UpdateWithWhitespaceOnlyName",
#             "20. UpdateAuthor_UpdateWithWhitespaceOnlyBio"
#         ]
#     },
#     {
#         "use_case_name": "Edit the book.txt",
#         "scenarios": [
#             "1. UpdateBook_WithValidData",
#             "2. UpdateBook_WithInvalidTitle",
#             "3. UpdateBook_WithInvalidAuthor",
#             "4. UpdateBook_WithInvalidGenre",
#             "5. UpdateBook_WithInvalidDescription",
#             "6. UpdateBook_WithInvalidPublicationDate",
#             "7. UpdateBook_WithEmptyTitle",
#             "8. UpdateBook_WithEmptyAuthor",
#             "9. UpdateBook_WithEmptyGenre",
#             "10. UpdateBook_WithEmptyDescription",
#             "11. UpdateBook_WithEmptyPublicationDate",
#             "12. UpdateBook_DisplayErrorMessage_OnDatabaseError",
#             "15. CancelUpdateBook_BeforeSubmitting",
#             "16. CancelUpdateBook_AfterModifyingData",
#             "17. NavigateAwayFromUpdatePage_UsingMenuBeforeSubmitting",
#             "18. NavigateAwayFromUpdatePage_UsingMenuAfterModifyingData",
#             "19. UpdateBook_WithSpecialCharactersInTitle",
#             "20. UpdateBook_WithFuturePublicationDate",
#             "21. UpdateBook_WithPastPublicationDate",
#             "22. UpdateBook_WithNonexistentAuthor",
#             "23. UpdateBook_WithNonexistentGenre"
#         ]
#     },
#     {
#         "use_case_name": "Edit the genre.txt",
#         "scenarios": [
#             "1. UpdateGenre_SuccessfulUpdate",
#             "4. UpdateGenre_CancelOperationBeforeSubmit",
#             "5. UpdateGenre_NavigateAwayBeforeSubmit",
#             "6. UpdateGenre_RequiredFieldsMissing",
#             "7. UpdateGenre_InvalidCharactersInName",
#             "8. UpdateGenre_InvalidFormatInDescription",
#             "9. UpdateGenre_UniqueNameConstraint",
#             "11. UpdateGenre_CheckMaxLengthName",
#             "12. UpdateGenre_CheckMaxLengthDescription",
#             "13. UpdateGenre_SpecialCharactersInName",
#             "14. UpdateGenre_SpecialCharactersInDescription",
#             "15. UpdateGenre_WhitespaceInName",
#             "16. UpdateGenre_WhitespaceInDescription",
#             "17. UpdateGenre_UpdateWithSameData"
#         ]
#     },
#     {
#         "use_case_name": "Remove the author.txt",
#         "scenarios": [
#             "1. DeleteAuthor_SuccessfulDeletion",
#             "2. DeleteAuthor_CancelDeletion",
#             "6. DeleteAuthor_NavigateAwayUsingMenuBeforeDeletion",
#             "7. DeleteAuthor_NavigateAwayUsingBrowserBackBeforeDeletion",
#             "8. DeleteAuthor_MultipleDeletionsSequential"
#         ]
#     },
#     {
#         "use_case_name": "Remove the book.txt",
#         "scenarios": [
#             "1. DeleteBook_SuccessfulDeletion",
#             "2. DeleteBook_CancelDeletion"
#         ]
#     },
#     {
#         "use_case_name": "Remove the genre.txt",
#         "scenarios": [
#             "1. DeleteGenre_SuccessfulDeletion",
#             "2. DeleteGenre_CancelDeletion",
#             "4. DeleteGenre_NavigationAfterCancellation"
#         ]
#     }
# ]

# %%
import os
import csv

# Function to convert txt file content to csv
def convert_txt_to_csv(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            txt_file_path = os.path.join(folder_path, filename)
            csv_file_path = os.path.join(folder_path, f"{os.path.splitext(filename)[0]}.csv")
            
            # Read the content of the txt file
            with open(txt_file_path, 'r') as txt_file:
                content = txt_file.readlines()
            
            # Write the content to a csv file
            with open(csv_file_path, 'w', newline='') as csv_file:
                csv_writer = csv.writer(csv_file)
                
                # Write the name of the txt file in the first cell of column A
                csv_writer.writerow([filename])
                
                # Write an empty cell
                csv_writer.writerow([""])
                
                # Write the content of the txt file, each line in a new row
                for line in content:
                    csv_writer.writerow([line.strip()])

# Example usage:
folder_path =  r'D:\Dissertation-GPT\evaluate\ResultSet\5.23\0\MatchaEnglishWebsite' # Replace with your folder path
convert_txt_to_csv(folder_path)

# %%
import os
import pandas as pd
from openpyxl import Workbook

# Directory containing the txt files
directory = r'D:\Dissertation-GPT\code\thu\6.23'

# Initialize an empty dictionary to hold data for the main sheet
valid_invalid_data = []

# Initialize a dictionary to hold data for individual sheets
individual_sheets_data = {}

# Initialize a list for the Coverage sheet
coverage_data = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
        # Extract the function name
        function_name = filename.replace("-1", "").replace("-2", "").replace("-3", "").replace(".txt", "").strip()
        
        # Read the file content
        with open(os.path.join(directory, filename), 'r') as file:
            lines = file.readlines()
        
        # Prepare data for the "Valid/Invalid" sheet
        valid_invalid_data.append([function_name])
        valid_invalid_data.extend([[line.strip()] for line in lines])
        valid_invalid_data.append([''])  # Add a blank line after each file's content
        
        # Prepare data for the individual function sheet
        individual_sheets_data[function_name] = [[function_name], ['']]
        individual_sheets_data[function_name].extend([[line.strip()] for line in lines])
        
        # Prepare data for the Coverage sheet
        coverage_data.append([function_name, '', ''])

# Create a new workbook and add sheets
wb = Workbook()

# Create "Valid/Invalid" sheet
ws_valid_invalid = wb.active
ws_valid_invalid.title = "Valid Invalid"

# Write data to the "Valid/Invalid" sheet
ws_valid_invalid.append(['Test scenario'])
for row in valid_invalid_data:
    ws_valid_invalid.append(row)

# Write data to the individual function sheets
for function_name, content in individual_sheets_data.items():
    ws = wb.create_sheet(title=function_name)
    for row in content:
        ws.append(row)

# Create "Coverage" sheet
ws_coverage = wb.create_sheet(title="Coverage")
ws_coverage.append(['Use case', 'flow coverage', 'condition coverage'])
for row in coverage_data:
    ws_coverage.append(row)

# Save the workbook to an Excel file
wb.save('output_file.xlsx')
# Out:
# e:\ProgramData\anaconda3\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
import os

def print_file_names(folder_path):
    try:
        # List all files in the given directory
        for filename in os.listdir(folder_path):
            # Check if it is a file
            if os.path.isfile(os.path.join(folder_path, filename)):
                # Split the filename to remove the extension
                name, _ = os.path.splitext(filename)
                print(name)
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
folder_path = r"D:\Dissertation-GPT\dataset\SpecificationData\Hotel Management System"
print_file_names(folder_path)
# Out:
# Add Booking
# Add Employee
# Add Room
# Check in
# Check out
# Hotel Owner - Generate Reports
# Hotel Owner - Update Hotel Information
# login
# Request Service
# Update Booking
# Update Employee
# Update Room

# %%
import os

def create_summary_files(directory, path):
    # Define the names of the summary files
    directory_name = os.path.basename(directory)
    summary_file_raw = os.path.join(path, f"{directory_name}-Raw.txt")
    summary_file = os.path.join(path, f"{directory_name}.txt")

    # Initialize strings to store file contents
    raw_content = ""
    non_raw_content = ""

    # Iterate through the files in the directory
    for file_name in os.listdir(directory):
        file_path = os.path.join(directory, file_name)
        # Check if the current item is a file and not one of the summary files
        if os.path.isfile(file_path) and file_name not in [os.path.basename(summary_file_raw), os.path.basename(summary_file)]:
            # Read the file content
            with open(file_path, 'r') as file:
                content = file.read()
                # Categorize the files based on the presence of "-Raw" in the file name
                if "-Raw" in file_name:
                    raw_content += "Scenario: "+ file_name +"\n"
                    raw_content += content + "\n"
                else:
                    non_raw_content +="Scenario: "+ file_name +"\n"
                    non_raw_content += content + "\n"

    # Write the collected raw file contents to "Summary File Raw.txt"
    with open(summary_file_raw, 'w') as file:
        file.write(raw_content)

    # Write the collected non-raw file contents to "Summary File.txt"
    with open(summary_file, 'w') as file:
        file.write(non_raw_content)

# Example usage
directory_path =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"
create_summary_files(directory_path, path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 40
#      38 directory_path =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
#      39 path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"
# ---> 40 create_summary_files(directory_path, path)
#
# Cell In[15], line 30, in create_summary_files(directory, path)
#      27                 non_raw_content += content + "\n"
#      29 # Write the collected raw file contents to "Summary File Raw.txt"
# ---> 30 with open(summary_file_raw, 'w') as file:
#      31     file.write(raw_content)
#      33 # Write the collected non-raw file contents to "Summary File.txt"
#
# File e:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\summary test case\\AddLesson-Raw.txt'

# %%
def get_test_steps_and_expected_result(scenario, file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
        
        # Split content into individual scenarios
        scenarios = content.split("Scenario:")
        scenarios = content.strip().split('Scenario: ')
        scenarios = [s for s in scenarios if s.strip()]  # Remove empty strings if any
        for scenario_block in scenarios:
            if scenario in scenario_block:
                lines = scenario_block.strip().split("\n")
                test_steps = ""
                expected_result = ""
                for line in lines:
                    if line.startswith("testSteps:"):
                        test_steps = line.split("testSteps:")[1].strip()
                    elif line.startswith("expectedResult:"):
                        expected_result = line.split("expectedResult:")[1].strip()
                return test_steps, expected_result

        return None, None  # Scenario not found
    except FileNotFoundError:
        print("File not found.")
        return None, None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None, None

# Example usage:
scenario = "Cancel Adding New Lesson After Entering Name1"  # Replace with the actual scenario you are looking for
file_path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt"  # Replace with the actual file path
test_steps, expected_result = get_test_steps_and_expected_result(scenario, file_path)

if test_steps and expected_result:
    print("Test Steps:", test_steps)
    print("Expected Result:", expected_result)
else:
    print("Scenario not found or an error occurred.")
# Out:
# ['', " Cancel Adding New Lesson After Entering Description-Raw1.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's description.\ntestSteps:\n  - Step 1: Log in to the application as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The system should cancel the process of adding a new lesson and redirect the administrator to the previous page without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information into the description field, without the system saving any entered data. It directly tests the exception flow mentioned in the use case specification.\n\n\n", " Cancel Adding New Lesson After Entering Description-Raw2.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's description.\ntestSteps:\n  - Step 1: Log in to the application as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The process of adding a new lesson is cancelled, and the administrator is redirected away from the 'Add new Lesson' page without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information into the description field, which aligns with the exception flow of the use case specification.\n\n\n", " Cancel Adding New Lesson After Entering Description-Raw3.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the description but before saving.\ntestSteps:\n  - Step 1: Log in as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The system should cancel the process of adding a new lesson and redirect the administrator back to the previous page or a main/admin dashboard without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information but decided not to proceed with saving it. It directly relates to the exception flow where the administrator can select 'Cancel' to stop adding a new lesson at any time.\n\n\n", " Cancel Adding New Lesson After Entering Name-Raw1.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Name\nobjective: Verify that the administrator can cancel adding a new lesson after entering the lesson name but before saving.\ntestSteps:\n  - Step 1: Log in as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from  ...
# Scenario not found or an error occurred.

# %%
directory =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
file_path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt"  # Replace with the actual file path
directory_name = os.path.basename(directory)
path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"

# %%
import json

content = ""
with open(r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt", 'r') as file:
    content = file.read()
scenarios = content.strip().split('Scenario: ')
scenarios = [s for s in scenarios if s.strip()]  # Remove empty strings if any

# Function to parse each scenario into a dictionary
def parse_scenario(scenario_text):
    lines = scenario_text.strip().split('\n')
    scenario_name = lines[0].strip()
    test_case = {}
    for line in lines[1:]:
        if line.startswith('testSteps:'):
            test_case['testSteps'] = []
            continue
        if line.startswith('  - Step '):
            test_case['testSteps'].append(line.strip())
            continue
        if ':' in line:
            key, value = line.split(':', 1)
            test_case[key.strip()] = value.strip()
    return scenario_name, test_case

# Parse all scenarios
parsed_scenarios = {}
for scenario in scenarios:
    name, details = parse_scenario(scenario)
    parsed_scenarios[name] = details


filename = os.path.join(path,directory_name) + '.json'
with open(filename, 'w') as f:
    json.dump(parsed_scenarios, f, indent=4)

# print(parsed_scenarios)
print(parsed_scenarios["Lesson Creation with Duplicate Name-Raw1.txt"]["testSteps"])
# # Write each scenario to a separate JSON file
# for scenario_name, scenario_details in parsed_scenarios.items():
#     filename = scenario_name + '.json'
#     with open(filename, 'w') as f:
#         json.dump(scenario_details, f, indent=4)

# print("JSON files created successfully.")
# Out:
# ['- Step 1: Log in as an administrator.', "- Step 2: Press the tab 'Lesson Management' on the navbar.", "- Step 3: Select 'Add new Lesson' from the dropdown menu.", "- Step 4: Enter a name that is already used by an existing lesson in the name field on the 'Add new Lesson' page.", '- Step 5: Enter a description for the lesson in the description field.', "- Step 6: Select 'Save' to attempt to create the new lesson."]
