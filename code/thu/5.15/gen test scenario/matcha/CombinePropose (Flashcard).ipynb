# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
    )

    return response.choices[0].message.content

def askJSON(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
def write_string_to_file(filename, content):
    try:
        with open(filename, 'w') as file:
            file.write(content)
        print(f"String has been written to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# %%
#Prompt
MAIN_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow of a use case.
Then you predict all scenarios that can happen in this flow.

Rules to predict scenarios:
- Stay close to the details described in the flow.
- Choose important cases to generate, important scenario is the scenario that users are more likely to encounter it.
- Limit the appearance of scenarios that are hard to happen. 
- A scenario encompasses a whole function, not just verifying individual steps.
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

SUB_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow and one alternative or exception flow of a use case.
Then you predict all scenarios that can lead user from the main flow to change to the alternative or exception flow mentioned for creating test cases.

Rules to predict scenarios:
- A scenario encompasses a whole function, not just verifying individual steps.
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- Do not generate scenarios with user analysis. (Example: User accidentally do A and user intentionally do A is the same scenario, so do not consider about "accidentally" or "intentionally" in scenario)
- Do not choose another option that is not chosen by the flow, eventhough it is mentioned (Example: A pop up with OK and Cancel, the flow only has step choose OK. Do not generate scenario that press Cancel)
- Do not generate scenario to test only the main flow.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

EXTRACT_CONDITION_SYSTEM_PROMPT="""
Given use case flows of a feature.
Your task is to identify all the interactive elements within the feature. 
For each interactive element:
Identify what type of that element (button,buttons, icon,scroll, text field,text area, tab, radio buttons, menu, combobox, sliders, switches, dialog, link, form,rating, filter).
Identify all the conditions mentioned in the use case of that element that would make the element valid and the conditions that would make the element invalid based on the description of the use case flow.
Do not arbitrarily create additional conditions that not mention in the use case flow.
Return the element extracted in json format.
The JSON format should follow the following structure:
{"Name of interactive element": {"condition": {valid:"conditions that make element valid", invalid: "conditions that make element invalid"}, "type": "element type"}}
Examples of output json format template: 
{"Username": {"condition": {"valid": "must be over 8 characters and below 30 characters, must be entered", racter, empty"}, "type": "text field"}}
{"Search button": {"condition": {"valid": "", "invalid": ""}, "type": "text field"}}
"""

GEN_SCENARIO_FOR_CONDITION_PROMPT="""
Given a list of interaction element for input value, their extracted conditions and use c"invalid": "below 8 characters, over 30 chaase specification.
For each given invalid condition:
- Generate a test scenario that test that condition.
Do not generate test scenario to test element/condition that not mention in the given element list.
Do not generate test scenario to test valid conditions.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""


FILTER_SYSTEM_PROMPT="""
Your task is to read all of this scenarios generation from many sources.
Then you remove all the same copies because there are many duplicate scenarios in meanings inside the input.
Make sure every scenarios in the response is unique.
Return scenario name only.
"""

# Identify what type of that element (button,buttons, icon,scroll, text field, radio buttons, menu, menu for navigation,menu for opening dialog or another menu, menu for filter, sliders, switches, dialog, link, form,rating, filter).

# %%
usecase_name = "Flashcard"
project_name = "MatchaEnglishWebsite"
main_flow_prompt = """
basic flow:
Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
Step 2:The system displays a list of available lessons.
Step 3:Learner selects a lesson from the list.
Step 4:The system displays the details of the selected lesson, including the topics associated with it.
Step 5:Learner chooses a topic to study.
Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
Step 11:Steps 8-11 are repeated for all flashcards in the topic.
Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
Step 13: learner clicks "return to the lesson page" 
Step 14: the system redirect to the lesson page.

"""
prompt_all = """
basic flow:
Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
Step 2:The system displays a list of available lessons.
Step 3:Learner selects a lesson from the list.
Step 4:The system displays the details of the selected lesson, including the topics associated with it.
Step 5:Learner chooses a topic to study.
Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
Step 11:Steps 8-11 are repeated for all flashcards in the topic.
Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
Step 13: learner clicks "return to the lesson page" 
Step 14: the system redirect to the lesson page.

Alternative Flows:
Alternative flow 1: Learner presses the 'back' button during flashcard study and presses 'stay'.
At step 7 of the basic flow: Learner presses the 'back button.
Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
Step 9: Learner clicks 'stay'.
Go back to step 7 in the basic flow and continue with the steps from step 7.

Alternative flow 2:Learner presses the 'continue studying'
At step 13 of the basic flow: learner clicks 'continue studying'
Step 14: Topic is marked as completed. Vocabulary words are marked as studied.Learner can review completed topics and studied vocabulary later.
Step 15: The system redirects the learner to the corresponding Flashcard page for the continuous topic.

Alternative flow 3: Continuing from Home Page with incomplete topic displayed on the home page
At step 1 of the basic flow: Learner clicks one incomplete topic.
Go back to step 6 in the basic flow and continue with the steps from step 6.

Alternative flow 4: learner tries to click 'Previous' button when on the first flashcard, the button is disabled.
At step 9 of the basic flow: Learner clicks 'Previous' button.
Step 10: the system display message 'there is no previous vocabulary to display'.
Go back to step 9 in the basic flow and continue with the steps from step 9.

Exception flow:
Exception flow 1: Learner presses the 'back' button during flashcard study and presses 'exit'.
At step 7 of the basic flow: Learner presses the 'back' button.
Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
Step 9: Learner clicks 'exit'.
Step 10: System returns learner to the topic page and the topic is marked as incomplete topic and be displayed on the home page.
"""
alt_prompt=[
"""Alternative Flows:
Alternative flow 1: Learner presses the 'back' button during flashcard study and presses 'stay'.
At step 7 of the basic flow: Learner presses the 'back button.
Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
Step 9: Learner clicks 'stay'.
Go back to step 7 in the basic flow and continue with the steps from step 7.""",
"""Alternative flow 2:Learner presses the 'continue studying'
At step 13 of the basic flow: learner clicks 'continue studying'
Step 14: Topic is marked as completed. Vocabulary words are marked as studied.Learner can review completed topics and studied vocabulary later.
Step 15: The system redirects the learner to the corresponding Flashcard page for the continuous topic.""",
"""Alternative flow 3: Continuing from Home Page with incomplete topic displayed on the home page
At step 1 of the basic flow: Learner clicks one incomplete topic.
Go back to step 6 in the basic flow and continue with the steps from step 6.
""",
"""Alternative flow 4: learner tries to click 'Previous' button when on the first flashcard, the button is disabled.
At step 9 of the basic flow: Learner clicks 'Previous' button.
Step 10: the system display message 'there is no previous vocabulary to display'.
Go back to step 9 in the basic flow and continue with the steps from step 9."""]
exc_prompt = ["""Exception flow:
Exception flow 1: Learner presses the 'back' button during flashcard study and presses 'exit'.
At step 7 of the basic flow: Learner presses the 'back' button.
Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
Step 9: Learner clicks 'exit'.
Step 10: System returns learner to the topic page and the topic is marked as incomplete topic and be displayed on the home page."""]

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-1.txt", filter_gpt_response)
# Out:
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding to complete the set.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Repeated Study of the Same Topic**: After completing the flashcards for a topic, the learner chooses to study the same topic again, repeating the process from selecting the topic to reviewing flashcards.
#
# These scenarios encompass the most likely user interactions based on the described flow, focusing on the selection of lessons and topics, the review process of flashcards, and the navigation between different parts of the application.
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner presses the 'back' button during flashcard study and presses 'stay'.
# At step 7 of the basic flow: Learner presses the 'back button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'stay'.
# Go back to step 7 in the basic flow and continue with the steps from step 7.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding to complete the set.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Repeated Study of the Same Topic**: After completing the flashcards for a topic, the learner chooses to study the same topic again, repeating the process from selecting the topic to reviewing flashcards.
#
# These scenarios encompass the most likely user interactions based on the described flow, focusing on the selection of lessons and topics, the review process of flashcards, and the navigation between different parts of the application.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner accidentally presses the 'back' button during flashcard study and chooses to 'stay'.
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 2:Learner presses the 'continue studying'
# At step 13 of the basic flow: learner clicks 'continue studying'
# Step 14: Topic is marked as completed. Vocabulary words are marked as studied.Learner can review completed topics and studied vocabulary later.
# Step 15: The system redirects the learner to the corresponding Flashcard page for the continuous topic.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding to complete the set.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Repeated Study of the Same Topic**: After completing the flashcards for a topic, the learner chooses to study the same topic again, repeating the process from selecting the topic to reviewing flashcards.
#
# These scenarios encompass the most likely user interactions based on the described flow, focusing on the selection of lessons and topics, the review process of flashcards, and the navigation between different parts of the application.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner accidentally presses the 'back' button during flashcard study and chooses to 'stay'.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 3: Continuing from Home Page with incomplete topic displayed on the home page
# At step 1 of the basic flow: Learner clicks one incomplete topic.
# Go back to step 6 in the basic flow and continue with the steps from step 6.
#
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding to complete the set.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Repeated Study of the Same Topic**: After completing the flashcards for a topic, the learner chooses to study the same topic again, repeating the process from selecting the topic to reviewing flashcards.
#
# These scenarios encompass the most likely user interactions based on the described flow, focusing on the selection of lessons and topics, the review process of flashcards, and the navigation between different parts of the application.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner accidentally presses the 'back' button during flashcard study and chooses to 'stay'.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# 1. Scenario: Learner continues studying an incomplete topic from the Home Page
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 4: learner tries to click 'Previous' button when on the first flashcard, the button is disabled.
# At step 9 of the basic flow: Learner clicks 'Previous' button.
# Step 10: the system display message 'there is no previous vocabulary to display'.
# Go back to step 9 in the basic flow and continue with the steps from step 9.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding to complete the set.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Repeated Study of the Same Topic**: After completing the flashcards for a topic, the learner chooses to study the same topic again, repeating the process from selecting the topic to reviewing flashcards.
#
# These scenarios encompass the most likely user interactions based on the described flow, focusing on the selection of lessons and topics, the review process of flashcards, and the navigation between different parts of the application.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner accidentally presses the 'back' button during flashcard study and chooses to 'stay'.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# 1. Scenario: Learner continues studying an incomplete topic from the Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on the First Flashcard
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Exception flow:
# Exception flow 1: Learner presses the 'back' button during flashcard study and presses 'exit'.
# At step 7 of the basic flow: Learner presses the 'back' button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'exit'.
# Step 10: System returns learner to the topic page and the topic is marked as incomplete topic and be displayed on the home page.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding to complete the set.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Repeated Study of the Same Topic**: After completing the flashcards for a topic, the learner chooses to study the same topic again, repeating the process from selecting the topic to reviewing flashcards.
#
# These scenarios encompass the most likely user interactions based on the described flow, focusing on the selection of lessons and topics, the review process of flashcards, and the navigation between different parts of the application.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner accidentally presses the 'back' button during flashcard study and chooses to 'stay'.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# 1. Scenario: Learner continues studying an incomplete topic from the Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on the First Flashcard
#
# 1. Learner Exits Flashcard Study via Back Button
# {}
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding to complete the set.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Repeated Study of the Same Topic**: After completing the flashcards for a topic, the learner chooses to study the same topic again, repeating the process from selecting the topic to reviewing flashcards.
#
# These scenarios encompass the most likely user interactions based on the described flow, focusing on the selection of lessons and topics, the review process of flashcards, and the navigation between different parts of the application.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner accidentally presses the 'back' button during flashcard study and chooses to 'stay'.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# 1. Scenario: Learner continues studying an incomplete topic from the Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on the First Flashcard
#
# 1. Learner Exits Flashcard Study via Back Button
# filter_gpt_response
# - Successful Lesson and Topic Selection with Complete Flashcard Review
# - Lesson Selection with Partial Flashcard Review
# - Navigation to a Different Lesson After Partial Review
# - Revisiting Previously Studied Flashcards
# - Direct Navigation to Completion Notification
# - Repeated Study of the Same Topic
# - Learner accidentally presses the 'back' button during flashcard study and chooses to 'stay'
# - Learner completes a topic and chooses to continue studying with the next topic
# - Learner continues studying an incomplete topic from the Home Page
# - Attempt to Navigate to Previous Flashcard on the First Flashcard
# - Learner Exits Flashcard Study via Back Button
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Flashcard-1.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-2.txt", filter_gpt_response)
# Out:
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review. This involves returning to the lesson list and selecting a new lesson.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding with the next ones.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Using the "Continue Studying" Option After Completion**: After completing the review of all flashcards and reaching the completion notification, the learner chooses to continue studying, which could lead them to select a new lesson or topic.
#
# Each of these scenarios represents a cohesive sequence of steps that a user might take while interacting with the application, from beginning a lesson to completing it or navigating through the application in various ways.
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner presses the 'back' button during flashcard study and presses 'stay'.
# At step 7 of the basic flow: Learner presses the 'back button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'stay'.
# Go back to step 7 in the basic flow and continue with the steps from step 7.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review. This involves returning to the lesson list and selecting a new lesson.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding with the next ones.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Using the "Continue Studying" Option After Completion**: After completing the review of all flashcards and reaching the completion notification, the learner chooses to continue studying, which could lead them to select a new lesson or topic.
#
# Each of these scenarios represents a cohesive sequence of steps that a user might take while interacting with the application, from beginning a lesson to completing it or navigating through the application in various ways.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner decides to exit during flashcard study but then chooses to stay
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 2:Learner presses the 'continue studying'
# At step 13 of the basic flow: learner clicks 'continue studying'
# Step 14: Topic is marked as completed. Vocabulary words are marked as studied.Learner can review completed topics and studied vocabulary later.
# Step 15: The system redirects the learner to the corresponding Flashcard page for the continuous topic.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review. This involves returning to the lesson list and selecting a new lesson.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding with the next ones.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Using the "Continue Studying" Option After Completion**: After completing the review of all flashcards and reaching the completion notification, the learner chooses to continue studying, which could lead them to select a new lesson or topic.
#
# Each of these scenarios represents a cohesive sequence of steps that a user might take while interacting with the application, from beginning a lesson to completing it or navigating through the application in various ways.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner decides to exit during flashcard study but then chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 3: Continuing from Home Page with incomplete topic displayed on the home page
# At step 1 of the basic flow: Learner clicks one incomplete topic.
# Go back to step 6 in the basic flow and continue with the steps from step 6.
#
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review. This involves returning to the lesson list and selecting a new lesson.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding with the next ones.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Using the "Continue Studying" Option After Completion**: After completing the review of all flashcards and reaching the completion notification, the learner chooses to continue studying, which could lead them to select a new lesson or topic.
#
# Each of these scenarios represents a cohesive sequence of steps that a user might take while interacting with the application, from beginning a lesson to completing it or navigating through the application in various ways.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner decides to exit during flashcard study but then chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# 1. Scenario: Learner continues studying an incomplete topic from the Home Page
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 4: learner tries to click 'Previous' button when on the first flashcard, the button is disabled.
# At step 9 of the basic flow: Learner clicks 'Previous' button.
# Step 10: the system display message 'there is no previous vocabulary to display'.
# Go back to step 9 in the basic flow and continue with the steps from step 9.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review. This involves returning to the lesson list and selecting a new lesson.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding with the next ones.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Using the "Continue Studying" Option After Completion**: After completing the review of all flashcards and reaching the completion notification, the learner chooses to continue studying, which could lead them to select a new lesson or topic.
#
# Each of these scenarios represents a cohesive sequence of steps that a user might take while interacting with the application, from beginning a lesson to completing it or navigating through the application in various ways.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner decides to exit during flashcard study but then chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# 1. Scenario: Learner continues studying an incomplete topic from the Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on First Flashcard
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Exception flow:
# Exception flow 1: Learner presses the 'back' button during flashcard study and presses 'exit'.
# At step 7 of the basic flow: Learner presses the 'back' button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'exit'.
# Step 10: System returns learner to the topic page and the topic is marked as incomplete topic and be displayed on the home page.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review. This involves returning to the lesson list and selecting a new lesson.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding with the next ones.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Using the "Continue Studying" Option After Completion**: After completing the review of all flashcards and reaching the completion notification, the learner chooses to continue studying, which could lead them to select a new lesson or topic.
#
# Each of these scenarios represents a cohesive sequence of steps that a user might take while interacting with the application, from beginning a lesson to completing it or navigating through the application in various ways.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner decides to exit during flashcard study but then chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# 1. Scenario: Learner continues studying an incomplete topic from the Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on First Flashcard
#
# 1. Learner Exits Flashcard Study via Back Button and Confirms Exit
# {}
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Complete Flashcard Review**: This scenario covers the entire flow from selecting a lesson and topic to reviewing all flashcards and returning to the lesson page after completion.
#
# 2. **Lesson Selection with Partial Flashcard Review**: In this scenario, the learner selects a lesson and a topic but does not complete the review of all flashcards. Instead, they might return to the lesson page before finishing.
#
# 3. **Navigation to a Different Lesson After Partial Review**: Here, the learner starts reviewing flashcards for a selected topic but decides to switch to a different lesson before completing the review. This involves returning to the lesson list and selecting a new lesson.
#
# 4. **Revisiting Previously Studied Flashcards**: This scenario focuses on the learner using the "Previous" button to review flashcards they have already seen before proceeding with the next ones.
#
# 5. **Direct Navigation to Completion Notification**: This scenario might occur if the learner quickly clicks through the flashcards without spending time on each, reaching the completion notification page rapidly.
#
# 6. **Using the "Continue Studying" Option After Completion**: After completing the review of all flashcards and reaching the completion notification, the learner chooses to continue studying, which could lead them to select a new lesson or topic.
#
# Each of these scenarios represents a cohesive sequence of steps that a user might take while interacting with the application, from beginning a lesson to completing it or navigating through the application in various ways.
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner decides to exit during flashcard study but then chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# 1. Scenario: Learner continues studying an incomplete topic from the Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on First Flashcard
#
# 1. Learner Exits Flashcard Study via Back Button and Confirms Exit
# filter_gpt_response
# - Successful Lesson and Topic Selection with Complete Flashcard Review
# - Lesson Selection with Partial Flashcard Review
# - Navigation to a Different Lesson After Partial Review
# - Revisiting Previously Studied Flashcards
# - Direct Navigation to Completion Notification
# - Using the "Continue Studying" Option After Completion
# - Learner decides to exit during flashcard study but then chooses to stay
# - Learner Completes a Topic and Chooses to Continue Studying
# - Learner continues studying an incomplete topic from the Home Page
# - Attempt to Navigate to Previous Flashcard on First Flashcard
# - Learner Exits Flashcard Study via Back Button and Confirms Exit
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Flashcard-2.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-3.txt", filter_gpt_response)
# Out:
# 1. Successful Lesson and Topic Selection with Flashcard Review Completion
# 2. Navigation to Flashcard Page with No Previous Flashcard Available
# 3. Navigation to Flashcard Page with No Next Flashcard Available
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner presses the 'back' button during flashcard study and presses 'stay'.
# At step 7 of the basic flow: Learner presses the 'back button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'stay'.
# Go back to step 7 in the basic flow and continue with the steps from step 7.
# 1. Successful Lesson and Topic Selection with Flashcard Review Completion
# 2. Navigation to Flashcard Page with No Previous Flashcard Available
# 3. Navigation to Flashcard Page with No Next Flashcard Available
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner presses the 'back' button during flashcard study and chooses to stay.
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 2:Learner presses the 'continue studying'
# At step 13 of the basic flow: learner clicks 'continue studying'
# Step 14: Topic is marked as completed. Vocabulary words are marked as studied.Learner can review completed topics and studied vocabulary later.
# Step 15: The system redirects the learner to the corresponding Flashcard page for the continuous topic.
# 1. Successful Lesson and Topic Selection with Flashcard Review Completion
# 2. Navigation to Flashcard Page with No Previous Flashcard Available
# 3. Navigation to Flashcard Page with No Next Flashcard Available
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner presses the 'back' button during flashcard study and chooses to stay.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 3: Continuing from Home Page with incomplete topic displayed on the home page
# At step 1 of the basic flow: Learner clicks one incomplete topic.
# Go back to step 6 in the basic flow and continue with the steps from step 6.
#
# 1. Successful Lesson and Topic Selection with Flashcard Review Completion
# 2. Navigation to Flashcard Page with No Previous Flashcard Available
# 3. Navigation to Flashcard Page with No Next Flashcard Available
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner presses the 'back' button during flashcard study and chooses to stay.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# Based on the provided information, here is the scenario that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# **Scenario Name:** Resuming an Incomplete Topic from Home Page
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 4: learner tries to click 'Previous' button when on the first flashcard, the button is disabled.
# At step 9 of the basic flow: Learner clicks 'Previous' button.
# Step 10: the system display message 'there is no previous vocabulary to display'.
# Go back to step 9 in the basic flow and continue with the steps from step 9.
# 1. Successful Lesson and Topic Selection with Flashcard Review Completion
# 2. Navigation to Flashcard Page with No Previous Flashcard Available
# 3. Navigation to Flashcard Page with No Next Flashcard Available
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner presses the 'back' button during flashcard study and chooses to stay.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# Based on the provided information, here is the scenario that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# **Scenario Name:** Resuming an Incomplete Topic from Home Page
#
# 1. AttemptToNavigatePreviousOnFirstFlashcard
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Exception flow:
# Exception flow 1: Learner presses the 'back' button during flashcard study and presses 'exit'.
# At step 7 of the basic flow: Learner presses the 'back' button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'exit'.
# Step 10: System returns learner to the topic page and the topic is marked as incomplete topic and be displayed on the home page.
# 1. Successful Lesson and Topic Selection with Flashcard Review Completion
# 2. Navigation to Flashcard Page with No Previous Flashcard Available
# 3. Navigation to Flashcard Page with No Next Flashcard Available
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner presses the 'back' button during flashcard study and chooses to stay.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# Based on the provided information, here is the scenario that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# **Scenario Name:** Resuming an Incomplete Topic from Home Page
#
# 1. AttemptToNavigatePreviousOnFirstFlashcard
#
# 1. Learner exits flashcard study via back button and exit confirmation
# {}
# 1. Successful Lesson and Topic Selection with Flashcard Review Completion
# 2. Navigation to Flashcard Page with No Previous Flashcard Available
# 3. Navigation to Flashcard Page with No Next Flashcard Available
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. Scenario: Learner presses the 'back' button during flashcard study and chooses to stay.
#
# 1. Scenario: Learner completes a topic and chooses to continue studying with the next topic.
#
# Based on the provided information, here is the scenario that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# **Scenario Name:** Resuming an Incomplete Topic from Home Page
#
# 1. AttemptToNavigatePreviousOnFirstFlashcard
#
# 1. Learner exits flashcard study via back button and exit confirmation
# filter_gpt_response
# 1. Successful Lesson and Topic Selection with Flashcard Review Completion
# 2. Navigation to Flashcard Page with No Previous Flashcard Available
# 3. Navigation to Flashcard Page with No Next Flashcard Available
# 4. Learner presses the 'back' button during flashcard study and chooses to stay
# 5. Learner completes a topic and chooses to continue studying with the next topic
# 6. Resuming an Incomplete Topic from Home Page
# 7. AttemptToNavigatePreviousOnFirstFlashcard
# 8. Learner exits flashcard study via back button and exit confirmation
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Flashcard-3.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-4.txt", filter_gpt_response)
# Out:
# 1. Successful Lesson and Topic Selection with Flashcard Review
# 2. Navigation to Previous Flashcard
# 3. Completion of Flashcard Set and Return to Lesson Page
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner presses the 'back' button during flashcard study and presses 'stay'.
# At step 7 of the basic flow: Learner presses the 'back button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'stay'.
# Go back to step 7 in the basic flow and continue with the steps from step 7.
# 1. Successful Lesson and Topic Selection with Flashcard Review
# 2. Navigation to Previous Flashcard
# 3. Completion of Flashcard Set and Return to Lesson Page
#
# 1. Learner presses 'back' button during flashcard study and chooses to stay
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 2:Learner presses the 'continue studying'
# At step 13 of the basic flow: learner clicks 'continue studying'
# Step 14: Topic is marked as completed. Vocabulary words are marked as studied.Learner can review completed topics and studied vocabulary later.
# Step 15: The system redirects the learner to the corresponding Flashcard page for the continuous topic.
# 1. Successful Lesson and Topic Selection with Flashcard Review
# 2. Navigation to Previous Flashcard
# 3. Completion of Flashcard Set and Return to Lesson Page
#
# 1. Learner presses 'back' button during flashcard study and chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 3: Continuing from Home Page with incomplete topic displayed on the home page
# At step 1 of the basic flow: Learner clicks one incomplete topic.
# Go back to step 6 in the basic flow and continue with the steps from step 6.
#
# 1. Successful Lesson and Topic Selection with Flashcard Review
# 2. Navigation to Previous Flashcard
# 3. Completion of Flashcard Set and Return to Lesson Page
#
# 1. Learner presses 'back' button during flashcard study and chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# Based on the provided information, here is the scenario that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# - Scenario: Learner Continues Incomplete Topic from Home Page
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 4: learner tries to click 'Previous' button when on the first flashcard, the button is disabled.
# At step 9 of the basic flow: Learner clicks 'Previous' button.
# Step 10: the system display message 'there is no previous vocabulary to display'.
# Go back to step 9 in the basic flow and continue with the steps from step 9.
# 1. Successful Lesson and Topic Selection with Flashcard Review
# 2. Navigation to Previous Flashcard
# 3. Completion of Flashcard Set and Return to Lesson Page
#
# 1. Learner presses 'back' button during flashcard study and chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# Based on the provided information, here is the scenario that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# - Scenario: Learner Continues Incomplete Topic from Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on First Flashcard
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Exception flow:
# Exception flow 1: Learner presses the 'back' button during flashcard study and presses 'exit'.
# At step 7 of the basic flow: Learner presses the 'back' button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'exit'.
# Step 10: System returns learner to the topic page and the topic is marked as incomplete topic and be displayed on the home page.
# 1. Successful Lesson and Topic Selection with Flashcard Review
# 2. Navigation to Previous Flashcard
# 3. Completion of Flashcard Set and Return to Lesson Page
#
# 1. Learner presses 'back' button during flashcard study and chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# Based on the provided information, here is the scenario that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# - Scenario: Learner Continues Incomplete Topic from Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on First Flashcard
#
# 1. Learner Exits Flashcard Study via Back Button
# {}
# 1. Successful Lesson and Topic Selection with Flashcard Review
# 2. Navigation to Previous Flashcard
# 3. Completion of Flashcard Set and Return to Lesson Page
#
# 1. Learner presses 'back' button during flashcard study and chooses to stay
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# Based on the provided information, here is the scenario that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# - Scenario: Learner Continues Incomplete Topic from Home Page
#
# 1. Attempt to Navigate to Previous Flashcard on First Flashcard
#
# 1. Learner Exits Flashcard Study via Back Button
# filter_gpt_response
# - Successful Lesson and Topic Selection with Flashcard Review
# - Navigation to Previous Flashcard
# - Completion of Flashcard Set and Return to Lesson Page
# - Learner presses 'back' button during flashcard study and chooses to stay
# - Learner Completes a Topic and Chooses to Continue Studying
# - Learner Continues Incomplete Topic from Home Page
# - Attempt to Navigate to Previous Flashcard on First Flashcard
# - Learner Exits Flashcard Study via Back Button
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Flashcard-4.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-5.txt", filter_gpt_response)
# Out:
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Flashcard Learning Completion**: This scenario covers the entire flow from selecting a lesson and topic, studying flashcards, and completing the study session by returning to the lesson page.
#
# 2. **Lesson Selection with Immediate Return to Lesson Page**: In this scenario, a learner selects a lesson but decides to return to the lesson page without choosing a topic or studying any flashcards.
#
# 3. **Topic Selection with No Flashcard Interaction**: Here, the learner selects a topic, is redirected to the flashcard page but does not interact with any flashcards (does not flip or navigate through them) before returning to the lesson page.
#
# 4. **Navigating Through Flashcards Without Flipping**: This scenario involves the learner navigating through the flashcards using the "Next" and "Previous" buttons without flipping any to see the back.
#
# 5. **Flipping Flashcards Without Navigating to Next or Previous**: The learner flips the flashcards to view the back but does not use the "Next" or "Previous" buttons to navigate through the flashcards.
#
# 6. **Completing Flashcards and Choosing to Continue Studying**: After completing all flashcards, the learner chooses the option to continue studying, which could potentially redirect them to either a new set of flashcards or allow them to repeat the same topic.
#
# Each of these scenarios represents a complete flow from the initial action to a concluding step, focusing on different aspects of user interaction with the system.
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner presses the 'back' button during flashcard study and presses 'stay'.
# At step 7 of the basic flow: Learner presses the 'back button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'stay'.
# Go back to step 7 in the basic flow and continue with the steps from step 7.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Flashcard Learning Completion**: This scenario covers the entire flow from selecting a lesson and topic, studying flashcards, and completing the study session by returning to the lesson page.
#
# 2. **Lesson Selection with Immediate Return to Lesson Page**: In this scenario, a learner selects a lesson but decides to return to the lesson page without choosing a topic or studying any flashcards.
#
# 3. **Topic Selection with No Flashcard Interaction**: Here, the learner selects a topic, is redirected to the flashcard page but does not interact with any flashcards (does not flip or navigate through them) before returning to the lesson page.
#
# 4. **Navigating Through Flashcards Without Flipping**: This scenario involves the learner navigating through the flashcards using the "Next" and "Previous" buttons without flipping any to see the back.
#
# 5. **Flipping Flashcards Without Navigating to Next or Previous**: The learner flips the flashcards to view the back but does not use the "Next" or "Previous" buttons to navigate through the flashcards.
#
# 6. **Completing Flashcards and Choosing to Continue Studying**: After completing all flashcards, the learner chooses the option to continue studying, which could potentially redirect them to either a new set of flashcards or allow them to repeat the same topic.
#
# Each of these scenarios represents a complete flow from the initial action to a concluding step, focusing on different aspects of user interaction with the system.
#
# 1. Learner Presses 'Back' Button and Chooses 'Stay' During Flashcard Study
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 2:Learner presses the 'continue studying'
# At step 13 of the basic flow: learner clicks 'continue studying'
# Step 14: Topic is marked as completed. Vocabulary words are marked as studied.Learner can review completed topics and studied vocabulary later.
# Step 15: The system redirects the learner to the corresponding Flashcard page for the continuous topic.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Flashcard Learning Completion**: This scenario covers the entire flow from selecting a lesson and topic, studying flashcards, and completing the study session by returning to the lesson page.
#
# 2. **Lesson Selection with Immediate Return to Lesson Page**: In this scenario, a learner selects a lesson but decides to return to the lesson page without choosing a topic or studying any flashcards.
#
# 3. **Topic Selection with No Flashcard Interaction**: Here, the learner selects a topic, is redirected to the flashcard page but does not interact with any flashcards (does not flip or navigate through them) before returning to the lesson page.
#
# 4. **Navigating Through Flashcards Without Flipping**: This scenario involves the learner navigating through the flashcards using the "Next" and "Previous" buttons without flipping any to see the back.
#
# 5. **Flipping Flashcards Without Navigating to Next or Previous**: The learner flips the flashcards to view the back but does not use the "Next" or "Previous" buttons to navigate through the flashcards.
#
# 6. **Completing Flashcards and Choosing to Continue Studying**: After completing all flashcards, the learner chooses the option to continue studying, which could potentially redirect them to either a new set of flashcards or allow them to repeat the same topic.
#
# Each of these scenarios represents a complete flow from the initial action to a concluding step, focusing on different aspects of user interaction with the system.
#
# 1. Learner Presses 'Back' Button and Chooses 'Stay' During Flashcard Study
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 3: Continuing from Home Page with incomplete topic displayed on the home page
# At step 1 of the basic flow: Learner clicks one incomplete topic.
# Go back to step 6 in the basic flow and continue with the steps from step 6.
#
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Flashcard Learning Completion**: This scenario covers the entire flow from selecting a lesson and topic, studying flashcards, and completing the study session by returning to the lesson page.
#
# 2. **Lesson Selection with Immediate Return to Lesson Page**: In this scenario, a learner selects a lesson but decides to return to the lesson page without choosing a topic or studying any flashcards.
#
# 3. **Topic Selection with No Flashcard Interaction**: Here, the learner selects a topic, is redirected to the flashcard page but does not interact with any flashcards (does not flip or navigate through them) before returning to the lesson page.
#
# 4. **Navigating Through Flashcards Without Flipping**: This scenario involves the learner navigating through the flashcards using the "Next" and "Previous" buttons without flipping any to see the back.
#
# 5. **Flipping Flashcards Without Navigating to Next or Previous**: The learner flips the flashcards to view the back but does not use the "Next" or "Previous" buttons to navigate through the flashcards.
#
# 6. **Completing Flashcards and Choosing to Continue Studying**: After completing all flashcards, the learner chooses the option to continue studying, which could potentially redirect them to either a new set of flashcards or allow them to repeat the same topic.
#
# Each of these scenarios represents a complete flow from the initial action to a concluding step, focusing on different aspects of user interaction with the system.
#
# 1. Learner Presses 'Back' Button and Chooses 'Stay' During Flashcard Study
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# - Scenario: Learner Continues Incomplete Topic from Home Page
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Alternative flow 4: learner tries to click 'Previous' button when on the first flashcard, the button is disabled.
# At step 9 of the basic flow: Learner clicks 'Previous' button.
# Step 10: the system display message 'there is no previous vocabulary to display'.
# Go back to step 9 in the basic flow and continue with the steps from step 9.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Flashcard Learning Completion**: This scenario covers the entire flow from selecting a lesson and topic, studying flashcards, and completing the study session by returning to the lesson page.
#
# 2. **Lesson Selection with Immediate Return to Lesson Page**: In this scenario, a learner selects a lesson but decides to return to the lesson page without choosing a topic or studying any flashcards.
#
# 3. **Topic Selection with No Flashcard Interaction**: Here, the learner selects a topic, is redirected to the flashcard page but does not interact with any flashcards (does not flip or navigate through them) before returning to the lesson page.
#
# 4. **Navigating Through Flashcards Without Flipping**: This scenario involves the learner navigating through the flashcards using the "Next" and "Previous" buttons without flipping any to see the back.
#
# 5. **Flipping Flashcards Without Navigating to Next or Previous**: The learner flips the flashcards to view the back but does not use the "Next" or "Previous" buttons to navigate through the flashcards.
#
# 6. **Completing Flashcards and Choosing to Continue Studying**: After completing all flashcards, the learner chooses the option to continue studying, which could potentially redirect them to either a new set of flashcards or allow them to repeat the same topic.
#
# Each of these scenarios represents a complete flow from the initial action to a concluding step, focusing on different aspects of user interaction with the system.
#
# 1. Learner Presses 'Back' Button and Chooses 'Stay' During Flashcard Study
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# - Scenario: Learner Continues Incomplete Topic from Home Page
#
# 1. Scenario: Learner attempts to navigate to a previous flashcard when viewing the first flashcard in the series
#
# basic flow:
# Step 1: Learner clicks the "Learn New Word" tab on the navigation bar.
# Step 2:The system displays a list of available lessons.
# Step 3:Learner selects a lesson from the list.
# Step 4:The system displays the details of the selected lesson, including the topics associated with it.
# Step 5:Learner chooses a topic to study.
# Step 6:The system redirects the learner to the corresponding Flashcard page for the selected topic.
# Step 7:The system displays the first flashcard of the vocabulary words for the selected topic. The front of the flashcard shows the vocabulary name, pronunciation, and Vietnamese meaning.
# Step 8:Learner click on the flashcard to flip it and view the back, which contains illustrations and examples of real-life usage.
# Step 9:Learner click the "Next" button to go to the flashcard of the next vocabulary word.
# Step 10:If there is a flashcard of the previous word, learner click the "Previous" button to go back to the previous flashcard.
# Step 11:Steps 8-11 are repeated for all flashcards in the topic.
# Step 12:Once all the flashcards have been studied, the 'Next' button on the last flashcard will redirect system to the 'completion notification' page with a congratulatory message and option buttons to 'continue studying' and 'return to the lesson page'.
# Step 13: learner clicks "return to the lesson page"
# Step 14: the system redirect to the lesson page.
#
#
#
# Exception flow:
# Exception flow 1: Learner presses the 'back' button during flashcard study and presses 'exit'.
# At step 7 of the basic flow: Learner presses the 'back' button.
# Step 8: Exit confirmation dialog box appears, asking "Are you sure you want to exit?"
# Step 9: Learner clicks 'exit'.
# Step 10: System returns learner to the topic page and the topic is marked as incomplete topic and be displayed on the home page.
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Flashcard Learning Completion**: This scenario covers the entire flow from selecting a lesson and topic, studying flashcards, and completing the study session by returning to the lesson page.
#
# 2. **Lesson Selection with Immediate Return to Lesson Page**: In this scenario, a learner selects a lesson but decides to return to the lesson page without choosing a topic or studying any flashcards.
#
# 3. **Topic Selection with No Flashcard Interaction**: Here, the learner selects a topic, is redirected to the flashcard page but does not interact with any flashcards (does not flip or navigate through them) before returning to the lesson page.
#
# 4. **Navigating Through Flashcards Without Flipping**: This scenario involves the learner navigating through the flashcards using the "Next" and "Previous" buttons without flipping any to see the back.
#
# 5. **Flipping Flashcards Without Navigating to Next or Previous**: The learner flips the flashcards to view the back but does not use the "Next" or "Previous" buttons to navigate through the flashcards.
#
# 6. **Completing Flashcards and Choosing to Continue Studying**: After completing all flashcards, the learner chooses the option to continue studying, which could potentially redirect them to either a new set of flashcards or allow them to repeat the same topic.
#
# Each of these scenarios represents a complete flow from the initial action to a concluding step, focusing on different aspects of user interaction with the system.
#
# 1. Learner Presses 'Back' Button and Chooses 'Stay' During Flashcard Study
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# - Scenario: Learner Continues Incomplete Topic from Home Page
#
# 1. Scenario: Learner attempts to navigate to a previous flashcard when viewing the first flashcard in the series
#
# 1. Learner Exits Flashcard Study via Back Button
# {}
# Based on the provided flow, here are the scenarios that can be predicted:
#
# 1. **Successful Lesson and Topic Selection with Flashcard Learning Completion**: This scenario covers the entire flow from selecting a lesson and topic, studying flashcards, and completing the study session by returning to the lesson page.
#
# 2. **Lesson Selection with Immediate Return to Lesson Page**: In this scenario, a learner selects a lesson but decides to return to the lesson page without choosing a topic or studying any flashcards.
#
# 3. **Topic Selection with No Flashcard Interaction**: Here, the learner selects a topic, is redirected to the flashcard page but does not interact with any flashcards (does not flip or navigate through them) before returning to the lesson page.
#
# 4. **Navigating Through Flashcards Without Flipping**: This scenario involves the learner navigating through the flashcards using the "Next" and "Previous" buttons without flipping any to see the back.
#
# 5. **Flipping Flashcards Without Navigating to Next or Previous**: The learner flips the flashcards to view the back but does not use the "Next" or "Previous" buttons to navigate through the flashcards.
#
# 6. **Completing Flashcards and Choosing to Continue Studying**: After completing all flashcards, the learner chooses the option to continue studying, which could potentially redirect them to either a new set of flashcards or allow them to repeat the same topic.
#
# Each of these scenarios represents a complete flow from the initial action to a concluding step, focusing on different aspects of user interaction with the system.
#
# 1. Learner Presses 'Back' Button and Chooses 'Stay' During Flashcard Study
#
# 1. Scenario: Learner Completes a Topic and Chooses to Continue Studying
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# - Scenario: Learner Continues Incomplete Topic from Home Page
#
# 1. Scenario: Learner attempts to navigate to a previous flashcard when viewing the first flashcard in the series
#
# 1. Learner Exits Flashcard Study via Back Button
# filter_gpt_response
# - Successful Lesson and Topic Selection with Flashcard Learning Completion
# - Lesson Selection with Immediate Return to Lesson Page
# - Topic Selection with No Flashcard Interaction
# - Navigating Through Flashcards Without Flipping
# - Flipping Flashcards Without Navigating to Next or Previous
# - Completing Flashcards and Choosing to Continue Studying
# - Learner Presses 'Back' Button and Chooses 'Stay' During Flashcard Study
# - Learner Continues Incomplete Topic from Home Page
# - Learner attempts to navigate to a previous flashcard when viewing the first flashcard in the series
# - Learner Exits Flashcard Study via Back Button
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Flashcard-5.txt
