# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
    )

    return response.choices[0].message.content

def askJSON(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
def write_string_to_file(filename, content):
    try:
        with open(filename, 'w') as file:
            file.write(content)
        print(f"String has been written to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# %%
#Prompt
MAIN_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow of a use case.
Then you predict all scenarios that can happen in this flow.

Rules to predict scenarios:
- Stay close to the details described in the flow.
- Choose important cases to generate, important scenario is the scenario that users are more likely to encounter it.
- Limit the appearance of scenarios that are hard to happen. 
- A scenario encompasses a whole function, not just verifying individual steps.
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

SUB_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow and one alternative or exception flow of a use case.
Then you predict all scenarios that can lead user from the main flow to change to the alternative or exception flow mentioned for creating test cases.

Rules to predict scenarios:
- A scenario encompasses a whole function, not just verifying individual steps.
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- Do not generate scenarios with user analysis. (Example: User accidentally do A and user intentionally do A is the same scenario, so do not consider about "accidentally" or "intentionally" in scenario)
- Do not choose another option that is not chosen by the flow, eventhough it is mentioned (Example: A pop up with OK and Cancel, the flow only has step choose OK. Do not generate scenario that press Cancel)
- Do not generate scenario to test only the main flow.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

EXTRACT_CONDITION_SYSTEM_PROMPT="""
Given use case flows of a feature.
Your task is to identify all the interactive elements within the feature. 
For each interactive element:
Identify what type of that element (button,buttons, icon,scroll, text field,text area, tab, radio buttons, menu, combobox, sliders, switches, dialog, link, form,rating, filter).
Identify all the conditions mentioned in the use case of that element that would make the element valid and the conditions that would make the element invalid based on the description of the use case flow.
Do not arbitrarily create additional conditions that not mention in the use case flow.
Return the element extracted in json format.
The JSON format should follow the following structure:
{"Name of interactive element": {"condition": {valid:"conditions that make element valid", invalid: "conditions that make element invalid"}, "type": "element type"}}
Examples of output json format template: 
{"Username": {"condition": {"valid": "must be over 8 characters and below 30 characters, must be entered", racter, empty"}, "type": "text field"}}
{"Search button": {"condition": {"valid": "", "invalid": ""}, "type": "text field"}}
"""

GEN_SCENARIO_FOR_CONDITION_PROMPT="""
Given a list of interaction element for input value, their extracted conditions and use c"invalid": "below 8 characters, over 30 chaase specification.
For each given invalid condition:
- Generate a test scenario that test that condition.
Do not generate test scenario to test element/condition that not mention in the given element list.
Do not generate test scenario to test valid conditions.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""


FILTER_SYSTEM_PROMPT="""
Your task is to read all of this scenarios generation from many sources.
Then you remove all the same copies because there are many duplicate scenarios in meanings inside the input.
Make sure every scenarios in the response is unique.
Return scenario name only.
"""

# Identify what type of that element (button,buttons, icon,scroll, text field, radio buttons, menu, menu for navigation,menu for opening dialog or another menu, menu for filter, sliders, switches, dialog, link, form,rating, filter).

# %%
usecase_name = "Handbook"
project_name = "MatchaEnglishWebsite"
main_flow_prompt = """
basic flow:
Step 1: Learner selects the "Handbook" tab on the navigation bar.
Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
Step 3:Learners can scroll the scroll bar to see more vocabulary.

"""
prompt_all = """
basic flow:
Step 1: Learner selects the "Handbook" tab on the navigation bar.
Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
Step 3:Learners can scroll the scroll bar to see more vocabulary.

Alternative Flows:
Alternative flow 1: Learner search vocabulary in Handbook.
At step 3 of the basic flow: Learner presses the search bar.
Step 4: Learner enters the word to search.
Step 5: The system filters vocabulary containing characters entered by learners in the search bar.

Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
At step 3 of the basic flow: Learner presses the search bar.
Step 4: Learner enters a meaningless word to search.
Step 5: The system notifies that there are no suitable search results.

Alternative flow 3: Learner set up 1 word to not be review in the review daily test
At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
Step 4: the system mark that vocabulary will not appear in the daily test review.

Alternative flow 4: Learner set up 1 word to be review in the review daily test
At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
Step 4: the system mark that vocabulary will appear in the daily test review.

"""
alt_prompt=[
"""Alternative Flows:
Alternative flow 1: Learner search vocabulary in Handbook.
At step 3 of the basic flow: Learner presses the search bar.
Step 4: Learner enters the word to search.
Step 5: The system filters vocabulary containing characters entered by learners in the search bar.""",
"""Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
At step 3 of the basic flow: Learner presses the search bar.
Step 4: Learner enters a meaningless word to search.
Step 5: The system notifies that there are no suitable search results.""",
"""Alternative flow 3: Learner set up 1 word to not be review in the review daily test
At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
Step 4: the system mark that vocabulary will not appear in the daily test review.""",
"""Alternative flow 4: Learner set up 1 word to be review in the review daily test
At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
Step 4: the system mark that vocabulary will appear in the daily test review.
"""]
exc_prompt = []

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-1.txt", filter_gpt_response)
# Out:
# Based on the provided flow, here are the predicted scenarios:
#
# 1. Display Vocabulary List Scenario: This scenario covers the entire flow from selecting the "Handbook" tab to the display of the vocabulary list with all specified details (word name, word type, word meaning, memorization level) and the functionality of the checkboxes.
#
# 2. Scroll Vocabulary List Scenario: This scenario involves the learner scrolling through the vocabulary list to view additional words beyond those initially visible on the screen.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner search vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters the word to search.
# Step 5: The system filters vocabulary containing characters entered by learners in the search bar.
# Based on the provided flow, here are the predicted scenarios:
#
# 1. Display Vocabulary List Scenario: This scenario covers the entire flow from selecting the "Handbook" tab to the display of the vocabulary list with all specified details (word name, word type, word meaning, memorization level) and the functionality of the checkboxes.
#
# 2. Scroll Vocabulary List Scenario: This scenario involves the learner scrolling through the vocabulary list to view additional words beyond those initially visible on the screen.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Searches for a Specific Vocabulary in the Handbook** - This scenario starts with the learner following the basic flow up to step 3 and then decides to use the search function to find a specific word, leading them into the alternative flow.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters a meaningless word to search.
# Step 5: The system notifies that there are no suitable search results.
# Based on the provided flow, here are the predicted scenarios:
#
# 1. Display Vocabulary List Scenario: This scenario covers the entire flow from selecting the "Handbook" tab to the display of the vocabulary list with all specified details (word name, word type, word meaning, memorization level) and the functionality of the checkboxes.
#
# 2. Scroll Vocabulary List Scenario: This scenario involves the learner scrolling through the vocabulary list to view additional words beyond those initially visible on the screen.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Searches for a Specific Vocabulary in the Handbook** - This scenario starts with the learner following the basic flow up to step 3 and then decides to use the search function to find a specific word, leading them into the alternative flow.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. Scenario: Search for a Meaningless Vocabulary in Handbook
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 3: Learner set up 1 word to not be review in the review daily test
# At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will not appear in the daily test review.
# Based on the provided flow, here are the predicted scenarios:
#
# 1. Display Vocabulary List Scenario: This scenario covers the entire flow from selecting the "Handbook" tab to the display of the vocabulary list with all specified details (word name, word type, word meaning, memorization level) and the functionality of the checkboxes.
#
# 2. Scroll Vocabulary List Scenario: This scenario involves the learner scrolling through the vocabulary list to view additional words beyond those initially visible on the screen.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Searches for a Specific Vocabulary in the Handbook** - This scenario starts with the learner following the basic flow up to step 3 and then decides to use the search function to find a specific word, leading them into the alternative flow.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. Scenario: Search for a Meaningless Vocabulary in Handbook
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes Vocabulary from Review Test** - This scenario starts with the learner following the basic flow steps: selecting the "Handbook" tab, viewing their vocabulary list, and then proceeds to the alternative flow where they untick a checkbox next to a vocabulary word to exclude it from the daily review test.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 4: Learner set up 1 word to be review in the review daily test
# At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will appear in the daily test review.
#
# Based on the provided flow, here are the predicted scenarios:
#
# 1. Display Vocabulary List Scenario: This scenario covers the entire flow from selecting the "Handbook" tab to the display of the vocabulary list with all specified details (word name, word type, word meaning, memorization level) and the functionality of the checkboxes.
#
# 2. Scroll Vocabulary List Scenario: This scenario involves the learner scrolling through the vocabulary list to view additional words beyond those initially visible on the screen.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Searches for a Specific Vocabulary in the Handbook** - This scenario starts with the learner following the basic flow up to step 3 and then decides to use the search function to find a specific word, leading them into the alternative flow.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. Scenario: Search for a Meaningless Vocabulary in Handbook
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes Vocabulary from Review Test** - This scenario starts with the learner following the basic flow steps: selecting the "Handbook" tab, viewing their vocabulary list, and then proceeds to the alternative flow where they untick a checkbox next to a vocabulary word to exclude it from the daily review test.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Marks Vocabulary for Review**: This scenario starts with the learner selecting the "Handbook" tab and ends with them ticking a checkbox next to a vocabulary word, indicating it should appear in the daily review test.
# {'Search bar': {'condition': {'valid': 'pressed by the learner', 'invalid': 'not pressed'}, 'type': 'text field'}}
# 1. Scenario: Search with Search Bar Not Pressed
# Based on the provided flow, here are the predicted scenarios:
#
# 1. Display Vocabulary List Scenario: This scenario covers the entire flow from selecting the "Handbook" tab to the display of the vocabulary list with all specified details (word name, word type, word meaning, memorization level) and the functionality of the checkboxes.
#
# 2. Scroll Vocabulary List Scenario: This scenario involves the learner scrolling through the vocabulary list to view additional words beyond those initially visible on the screen.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Searches for a Specific Vocabulary in the Handbook** - This scenario starts with the learner following the basic flow up to step 3 and then decides to use the search function to find a specific word, leading them into the alternative flow.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. Scenario: Search for a Meaningless Vocabulary in Handbook
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes Vocabulary from Review Test** - This scenario starts with the learner following the basic flow steps: selecting the "Handbook" tab, viewing their vocabulary list, and then proceeds to the alternative flow where they untick a checkbox next to a vocabulary word to exclude it from the daily review test.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Marks Vocabulary for Review**: This scenario starts with the learner selecting the "Handbook" tab and ends with them ticking a checkbox next to a vocabulary word, indicating it should appear in the daily review test.
# 1. Scenario: Search with Search Bar Not Pressed
# filter_gpt_response
# - Display Vocabulary List Scenario
# - Scroll Vocabulary List Scenario
# - Learner Searches for a Specific Vocabulary in the Handbook
# - Search for a Meaningless Vocabulary in Handbook
# - Learner Excludes Vocabulary from Review Test
# - Learner Marks Vocabulary for Review
# - Search with Search Bar Not Pressed
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Handbook-1.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-2.txt", filter_gpt_response)
# Out:
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner search vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters the word to search.
# Step 5: The system filters vocabulary containing characters entered by learners in the search bar.
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary Word**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters a meaningless word to search.
# Step 5: The system notifies that there are no suitable search results.
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary Word**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# 1. Learner Searches for a Meaningless Vocabulary
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 3: Learner set up 1 word to not be review in the review daily test
# At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will not appear in the daily test review.
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary Word**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# 1. Learner Searches for a Meaningless Vocabulary
#
# Based on the provided information, here is a scenario that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes a Vocabulary Word from Review Test**
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 4: Learner set up 1 word to be review in the review daily test
# At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will appear in the daily test review.
#
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary Word**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# 1. Learner Searches for a Meaningless Vocabulary
#
# Based on the provided information, here is a scenario that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes a Vocabulary Word from Review Test**
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Selects Vocabulary for Review**: This scenario starts with the learner following the basic flow of selecting the "Handbook" tab and viewing their vocabulary list. As they scroll through their vocabulary (as per the main flow), they decide to tick a checkbox next to a vocabulary word, thus triggering the alternative flow where the system marks that vocabulary to appear in the daily review test.
# {'Search bar': {'condition': {'valid': 'learner presses the search bar', 'invalid': ''}, 'type': 'text field'}}
# Based on the provided information, there are no invalid conditions specified for the interaction elements, hence no test scenarios for invalid conditions can be generated.
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary Word**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# 1. Learner Searches for a Meaningless Vocabulary
#
# Based on the provided information, here is a scenario that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes a Vocabulary Word from Review Test**
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Selects Vocabulary for Review**: This scenario starts with the learner following the basic flow of selecting the "Handbook" tab and viewing their vocabulary list. As they scroll through their vocabulary (as per the main flow), they decide to tick a checkbox next to a vocabulary word, thus triggering the alternative flow where the system marks that vocabulary to appear in the daily review test.
# Based on the provided information, there are no invalid conditions specified for the interaction elements, hence no test scenarios for invalid conditions can be generated.
# filter_gpt_response
# - Successful Display of Vocabulary List
# - Scroll Through Vocabulary List
# - Searching for a Specific Vocabulary Word
# - Learner Searches for a Meaningless Vocabulary
# - Learner Excludes a Vocabulary Word from Review Test
# - Learner Selects Vocabulary for Review
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Handbook-2.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-3.txt", filter_gpt_response)
# Out:
# 1. Display Vocabulary List Successfully
# 2. Scroll Through Vocabulary List
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner search vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters the word to search.
# Step 5: The system filters vocabulary containing characters entered by learners in the search bar.
# 1. Display Vocabulary List Successfully
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary in the Handbook**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters a meaningless word to search.
# Step 5: The system notifies that there are no suitable search results.
# 1. Display Vocabulary List Successfully
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary in the Handbook**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# 1. Learner Searches for a Nonexistent Vocabulary Word
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 3: Learner set up 1 word to not be review in the review daily test
# At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will not appear in the daily test review.
# 1. Display Vocabulary List Successfully
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary in the Handbook**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# 1. Learner Searches for a Nonexistent Vocabulary Word
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes a Vocabulary from Daily Review Test**
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 4: Learner set up 1 word to be review in the review daily test
# At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will appear in the daily test review.
#
# 1. Display Vocabulary List Successfully
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary in the Handbook**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# 1. Learner Searches for a Nonexistent Vocabulary Word
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes a Vocabulary from Daily Review Test**
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Marks a Vocabulary for Review**: This scenario starts with the learner selecting the "Handbook" tab and ends with the learner ticking a checkbox next to a vocabulary word, which triggers the system to mark that vocabulary for appearance in the daily review test.
# {'Search bar': {'condition': {'valid': 'presses the search bar', 'invalid': ''}, 'type': 'text field'}}
# Based on the provided information, there are no specific invalid conditions mentioned for the interaction elements, particularly for the "Search bar". The invalid conditions you've asked to generate test scenarios for are not specified in the given element list. Therefore, based on the instructions, I cannot generate test scenarios for invalid conditions that are not mentioned.
# 1. Display Vocabulary List Successfully
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Scenario: Searching for a Specific Vocabulary in the Handbook**
#    - This scenario starts with the learner following the basic flow up to step 3, where instead of continuing to scroll through the vocabulary list, the learner decides to use the search function to find a specific word. This action transitions the user from the main flow to the alternative flow.
#
# 1. Learner Searches for a Nonexistent Vocabulary Word
#
# Based on the provided information, here is the scenario that can lead the user from the main flow to the alternative or exception flow:
#
# 1. **Learner Excludes a Vocabulary from Daily Review Test**
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Marks a Vocabulary for Review**: This scenario starts with the learner selecting the "Handbook" tab and ends with the learner ticking a checkbox next to a vocabulary word, which triggers the system to mark that vocabulary for appearance in the daily review test.
# Based on the provided information, there are no specific invalid conditions mentioned for the interaction elements, particularly for the "Search bar". The invalid conditions you've asked to generate test scenarios for are not specified in the given element list. Therefore, based on the instructions, I cannot generate test scenarios for invalid conditions that are not mentioned.
# filter_gpt_response
# - Display Vocabulary List Successfully
# - Scroll Through Vocabulary List
# - Searching for a Specific Vocabulary in the Handbook
# - Learner Searches for a Nonexistent Vocabulary Word
# - Learner Excludes a Vocabulary from Daily Review Test
# - Learner Marks a Vocabulary for Review
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Handbook-3.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-4.txt", filter_gpt_response)
# Out:
# 1. Successful Display of Vocabulary List
# 2. Vocabulary List Scroll Functionality
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner search vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters the word to search.
# Step 5: The system filters vocabulary containing characters entered by learners in the search bar.
# 1. Successful Display of Vocabulary List
# 2. Vocabulary List Scroll Functionality
#
# 1. Learner Searches Vocabulary in Handbook
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters a meaningless word to search.
# Step 5: The system notifies that there are no suitable search results.
# 1. Successful Display of Vocabulary List
# 2. Vocabulary List Scroll Functionality
#
# 1. Learner Searches Vocabulary in Handbook
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for a Non-Existent Vocabulary Word** - This scenario starts with the learner following the basic flow up to step 3, where instead of just scrolling to see more vocabulary, the learner decides to use the search function to look for a specific word. The word entered does not exist in the vocabulary list, leading to the alternative flow where the system notifies the user of no suitable search results.
#
# 2. **Search for a Meaningless String** - Similar to the first scenario, but in this case, the learner enters a string of characters that does not form a meaningful word or is not recognized as a valid vocabulary word in the system's database, triggering the alternative flow.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 3: Learner set up 1 word to not be review in the review daily test
# At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will not appear in the daily test review.
# 1. Successful Display of Vocabulary List
# 2. Vocabulary List Scroll Functionality
#
# 1. Learner Searches Vocabulary in Handbook
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for a Non-Existent Vocabulary Word** - This scenario starts with the learner following the basic flow up to step 3, where instead of just scrolling to see more vocabulary, the learner decides to use the search function to look for a specific word. The word entered does not exist in the vocabulary list, leading to the alternative flow where the system notifies the user of no suitable search results.
#
# 2. **Search for a Meaningless String** - Similar to the first scenario, but in this case, the learner enters a string of characters that does not form a meaningful word or is not recognized as a valid vocabulary word in the system's database, triggering the alternative flow.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Unticks a Vocabulary Checkbox**: This scenario starts with the learner following the basic flow of selecting the "Handbook" tab and viewing their vocabulary list. During or after scrolling through their vocabulary, they decide to untick the checkbox for a specific vocabulary word, indicating they do not want it to appear in their daily review test.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 4: Learner set up 1 word to be review in the review daily test
# At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will appear in the daily test review.
#
# 1. Successful Display of Vocabulary List
# 2. Vocabulary List Scroll Functionality
#
# 1. Learner Searches Vocabulary in Handbook
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for a Non-Existent Vocabulary Word** - This scenario starts with the learner following the basic flow up to step 3, where instead of just scrolling to see more vocabulary, the learner decides to use the search function to look for a specific word. The word entered does not exist in the vocabulary list, leading to the alternative flow where the system notifies the user of no suitable search results.
#
# 2. **Search for a Meaningless String** - Similar to the first scenario, but in this case, the learner enters a string of characters that does not form a meaningful word or is not recognized as a valid vocabulary word in the system's database, triggering the alternative flow.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Unticks a Vocabulary Checkbox**: This scenario starts with the learner following the basic flow of selecting the "Handbook" tab and viewing their vocabulary list. During or after scrolling through their vocabulary, they decide to untick the checkbox for a specific vocabulary word, indicating they do not want it to appear in their daily review test.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Learner Selects Vocabulary for Review Test** - This scenario starts with the learner following the basic flow steps and then diverges at step 3, where instead of just scrolling to view more vocabulary, the learner ticks a checkbox next to a vocabulary word, triggering the alternative flow where the system marks that vocabulary to appear in the daily review test.
# {'Search bar': {'condition': {'valid': 'presses the search bar', 'invalid': ''}, 'type': 'text field'}}
# Based on the provided information, there are no specific invalid conditions mentioned for the interaction elements, particularly for the "Search bar". Since the invalid conditions for the "Search bar" are not specified and we are instructed not to generate test scenarios for conditions not mentioned or for valid conditions, no test scenario names can be generated according to the given instructions.
# 1. Successful Display of Vocabulary List
# 2. Vocabulary List Scroll Functionality
#
# 1. Learner Searches Vocabulary in Handbook
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for a Non-Existent Vocabulary Word** - This scenario starts with the learner following the basic flow up to step 3, where instead of just scrolling to see more vocabulary, the learner decides to use the search function to look for a specific word. The word entered does not exist in the vocabulary list, leading to the alternative flow where the system notifies the user of no suitable search results.
#
# 2. **Search for a Meaningless String** - Similar to the first scenario, but in this case, the learner enters a string of characters that does not form a meaningful word or is not recognized as a valid vocabulary word in the system's database, triggering the alternative flow.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Unticks a Vocabulary Checkbox**: This scenario starts with the learner following the basic flow of selecting the "Handbook" tab and viewing their vocabulary list. During or after scrolling through their vocabulary, they decide to untick the checkbox for a specific vocabulary word, indicating they do not want it to appear in their daily review test.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Learner Selects Vocabulary for Review Test** - This scenario starts with the learner following the basic flow steps and then diverges at step 3, where instead of just scrolling to view more vocabulary, the learner ticks a checkbox next to a vocabulary word, triggering the alternative flow where the system marks that vocabulary to appear in the daily review test.
# Based on the provided information, there are no specific invalid conditions mentioned for the interaction elements, particularly for the "Search bar". Since the invalid conditions for the "Search bar" are not specified and we are instructed not to generate test scenarios for conditions not mentioned or for valid conditions, no test scenario names can be generated according to the given instructions.
# filter_gpt_response
# - Successful Display of Vocabulary List
# - Vocabulary List Scroll Functionality
# - Learner Searches Vocabulary in Handbook
# - Search for a Non-Existent Vocabulary Word
# - Search for a Meaningless String
# - Learner Unticks a Vocabulary Checkbox
# - Learner Selects Vocabulary for Review Test
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Handbook-4.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-5.txt", filter_gpt_response)
# Out:
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative Flows:
# Alternative flow 1: Learner search vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters the word to search.
# Step 5: The system filters vocabulary containing characters entered by learners in the search bar.
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. **Learner Uses Search Functionality to Find Specific Vocabulary** - This scenario starts with the learner following the main flow but decides to use the search functionality to find a specific word in the handbook.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 2:Learner search a meaningless vocabulary in Handbook.
# At step 3 of the basic flow: Learner presses the search bar.
# Step 4: Learner enters a meaningless word to search.
# Step 5: The system notifies that there are no suitable search results.
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. **Learner Uses Search Functionality to Find Specific Vocabulary** - This scenario starts with the learner following the main flow but decides to use the search functionality to find a specific word in the handbook.
#
# 1. Search for a Meaningless Vocabulary
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 3: Learner set up 1 word to not be review in the review daily test
# At step 3 of the basic flow: Learner untick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will not appear in the daily test review.
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. **Learner Uses Search Functionality to Find Specific Vocabulary** - This scenario starts with the learner following the main flow but decides to use the search functionality to find a specific word in the handbook.
#
# 1. Search for a Meaningless Vocabulary
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Unticks a Vocabulary Checkbox**: This scenario starts with the learner following the basic flow and then deciding to exclude a specific vocabulary word from their daily review test by unticking its checkbox.
#
# basic flow:
# Step 1: Learner selects the "Handbook" tab on the navigation bar.
# Step 2:The system displays a list of leaner's vocabulary list. The list of vocabulary is displayed in vertical rows, each word is a horizontal row displaying the word name, word type, word meaning, memorization level and has a checkbox to mark the appearance of the vocabulary in the review test.
# Step 3:Learners can scroll the scroll bar to see more vocabulary.
#
#
#
# Alternative flow 4: Learner set up 1 word to be review in the review daily test
# At step 3 of the basic flow: Learner tick a checkbox of a vocabulary.
# Step 4: the system mark that vocabulary will appear in the daily test review.
#
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. **Learner Uses Search Functionality to Find Specific Vocabulary** - This scenario starts with the learner following the main flow but decides to use the search functionality to find a specific word in the handbook.
#
# 1. Search for a Meaningless Vocabulary
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Unticks a Vocabulary Checkbox**: This scenario starts with the learner following the basic flow and then deciding to exclude a specific vocabulary word from their daily review test by unticking its checkbox.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Scenario: Marking a Vocabulary for Review**
#    - Description: The learner navigates through their vocabulary list and decides to mark one or more words for review in the daily test by ticking the checkbox next to the vocabulary item(s). This action transitions the user from just viewing the vocabulary list to actively selecting items for review, engaging with the system's functionality to customize their learning experience.
# {'Search bar': {'condition': {'valid': 'pressed by the learner', 'invalid': 'not pressed'}, 'type': 'text field'}}
# 1. Scenario: Search with Search Bar Not Pressed
# 1. Successful Display of Vocabulary List
# 2. Scroll Through Vocabulary List
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. **Learner Uses Search Functionality to Find Specific Vocabulary** - This scenario starts with the learner following the main flow but decides to use the search functionality to find a specific word in the handbook.
#
# 1. Search for a Meaningless Vocabulary
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Learner Unticks a Vocabulary Checkbox**: This scenario starts with the learner following the basic flow and then deciding to exclude a specific vocabulary word from their daily review test by unticking its checkbox.
#
# Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Scenario: Marking a Vocabulary for Review**
#    - Description: The learner navigates through their vocabulary list and decides to mark one or more words for review in the daily test by ticking the checkbox next to the vocabulary item(s). This action transitions the user from just viewing the vocabulary list to actively selecting items for review, engaging with the system's functionality to customize their learning experience.
# 1. Scenario: Search with Search Bar Not Pressed
# filter_gpt_response
# - Successful Display of Vocabulary List
# - Scroll Through Vocabulary List
# - Learner Uses Search Functionality to Find Specific Vocabulary
# - Search for a Meaningless Vocabulary
# - Learner Unticks a Vocabulary Checkbox
# - Marking a Vocabulary for Review
# - Search with Search Bar Not Pressed
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Handbook-5.txt
