# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
    )

    return response.choices[0].message.content

def askJSON(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
def write_string_to_file(filename, content):
    try:
        with open(filename, 'w') as file:
            file.write(content)
        print(f"String has been written to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# %%
#Prompt
MAIN_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow of a use case.
Then you predict all scenarios that can happen in this flow.

Rules to predict scenarios:
- Stay close to the details described in the flow.
- Choose important cases to generate, important scenario is the scenario that users are more likely to encounter it.
- Limit the appearance of scenarios that are hard to happen. 
- A scenario encompasses a whole function, not just verifying individual steps.
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

SUB_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow and one alternative or exception flow of a use case.
Then you predict all scenarios that can lead user from the main flow to change to the alternative or exception flow mentioned for creating test cases.

Rules to predict scenarios:
- A scenario encompasses a whole function, not just verifying individual steps.
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- Do not generate scenarios with user analysis. (Example: User accidentally do A and user intentionally do A is the same scenario, so do not consider about "accidentally" or "intentionally" in scenario)
- Do not choose another option that is not chosen by the flow, eventhough it is mentioned (Example: A pop up with OK and Cancel, the flow only has step choose OK. Do not generate scenario that press Cancel)
- Do not generate scenario to test only the main flow.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

EXTRACT_CONDITION_SYSTEM_PROMPT="""
Given use case flows of a feature.
Your task is to identify all the interactive elements within the feature. 
For each interactive element:
Identify what type of that element (button,buttons, icon,scroll, text field,text area, tab, radio buttons, menu, combobox, sliders, switches, dialog, link, form,rating, filter).
Identify all the conditions mentioned in the use case of that element that would make the element valid and the conditions that would make the element invalid based on the description of the use case flow.
Do not arbitrarily create additional conditions that not mention in the use case flow.
Return the element extracted in json format.
The JSON format should follow the following structure:
{"Name of interactive element": {"condition": {valid:"conditions that make element valid", invalid: "conditions that make element invalid"}, "type": "element type"}}
Examples of output json format template: 
{"Username": {"condition": {"valid": "must be over 8 characters and below 30 characters, must be entered", racter, empty"}, "type": "text field"}}
{"Search button": {"condition": {"valid": "", "invalid": ""}, "type": "text field"}}
"""

GEN_SCENARIO_FOR_CONDITION_PROMPT="""
Given a list of interaction element for input value, their extracted conditions and use c"invalid": "below 8 characters, over 30 chaase specification.
For each given invalid condition:
- Generate a test scenario that test that condition.
Do not generate test scenario to test element/condition that not mention in the given element list.
Do not generate test scenario to test valid conditions.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""


FILTER_SYSTEM_PROMPT="""
Your task is to read all of this scenarios generation from many sources.
Then you remove all the same copies because there are many duplicate scenarios in meanings inside the input.
Make sure every scenarios in the response is unique.
Return scenario name only.
"""

# Identify what type of that element (button,buttons, icon,scroll, text field, radio buttons, menu, menu for navigation,menu for opening dialog or another menu, menu for filter, sliders, switches, dialog, link, form,rating, filter).

# %%
usecase_name = "Registry"
project_name = "MatchaEnglishWebsite"
main_flow_prompt = """
Main flow
Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
Step 3: Learner press "Registry" button
Step 4: System redirects learner to Home page

"""
prompt_all = """
Main flow
Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
Step 3: Learner press "Registry" button
Step 4: System redirects learner to Home page

Alternative flow 1: Learner register by email
At step 1 of the basic flow: Learner clicks on the Mail icon
Step 2: Learner fills in the email field by a valid email, a valid email must be an exist email with the right format
Go back to step 2 in the basic flow and continue with the steps from step 2.

Exception flow 1: Learner enters invalid username
At step 1 of the basic flow: Learner fills in the username field by an invalid username
Go back to step 2 in the basic flow and continue with the steps from step 2.
At step 4 of the basic flow: System shows a notification that the username is invalid

Exception flow 2: Learner enters invalid password
At step 2 of the basic flow: Learner fills in the password field by an invalid password
Go back to step 3 in the basic flow and take only step 3.
At step 4 of the basic flow: System shows a notification that the passowrd is invalid

Exception flow 3: Learner enters an existed username
At step 1 of the basic flow: Learner fills in the username field by an username that has been registered
Go back to step 2 in the basic flow and continue with the steps from step 2.
At step 4 of the basic flow: System shows a notification that this username has been registered and ask the learner to choose another username.

Exception flow 4: Learner enters invalid email
At step 2 of the alternative flow 1: Learner fills in the email field by an invalid email, an invalid email must be an inexist email or email with the wrong format
Go back to step 3 in the alternative flow 1 and continue with the steps from step 3.
At step 4 of the basic flow: System shows a notification that the mail is invalid
"""
alt_prompt=[
"""Alternative flow 1: Learner register by email
At step 1 of the basic flow: Learner clicks on the Mail icon
Step 2: Learner fills in the email field by a valid email, a valid email must be an exist email with the right format
Go back to step 2 in the basic flow and continue with the steps from step 2."""]
exc_prompt = ["""Exception flow 1: Learner enters invalid username
At step 1 of the basic flow: Learner fills in the username field by an invalid username
Go back to step 2 in the basic flow and continue with the steps from step 2.
At step 4 of the basic flow: System shows a notification that the username is invalid""",
"""Exception flow 2: Learner enters invalid password
At step 2 of the basic flow: Learner fills in the password field by an invalid password
Go back to step 3 in the basic flow and take only step 3.
At step 4 of the basic flow: System shows a notification that the passowrd is invalid""",
"""Exception flow 3: Learner enters an existed username
At step 1 of the basic flow: Learner fills in the username field by an username that has been registered
Go back to step 2 in the basic flow and continue with the steps from step 2.
At step 4 of the basic flow: System shows a notification that this username has been registered and ask the learner to choose another username.""",
"""Exception flow 4: Learner enters invalid email
At step 2 of the alternative flow 1: Learner fills in the email field by an invalid email, an invalid email must be an inexist email or email with the wrong format
Go back to step 3 in the alternative flow 1 and continue with the steps from step 3.
At step 4 of the basic flow: System shows a notification that the mail is invalid"""]

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-1.txt", filter_gpt_response)
# Out:
# Based on the provided main flow, here are the scenarios that can be predicted:
#
# 1. Successful Registration with Valid Username and Password
# 2. Registration Attempt with Username Below 8 Characters
# 3. Registration Attempt with Username Above 30 Characters
# 4. Registration Attempt with Password Below 8 Characters
# 5. Registration Attempt with Password Above 30 Characters
# 6. Registration Attempt with Password Missing a Normal Character
# 7. Registration Attempt with Password Missing a Capitalized Character
# 8. Registration Attempt with Password Missing a Number
# 9. Registration Attempt with Password Missing a Special Character
# 10. Registration Attempt with Password Matching Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Alternative flow 1: Learner register by email
# At step 1 of the basic flow: Learner clicks on the Mail icon
# Step 2: Learner fills in the email field by a valid email, a valid email must be an exist email with the right format
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# Based on the provided main flow, here are the scenarios that can be predicted:
#
# 1. Successful Registration with Valid Username and Password
# 2. Registration Attempt with Username Below 8 Characters
# 3. Registration Attempt with Username Above 30 Characters
# 4. Registration Attempt with Password Below 8 Characters
# 5. Registration Attempt with Password Above 30 Characters
# 6. Registration Attempt with Password Missing a Normal Character
# 7. Registration Attempt with Password Missing a Capitalized Character
# 8. Registration Attempt with Password Missing a Number
# 9. Registration Attempt with Password Missing a Special Character
# 10. Registration Attempt with Password Matching Username
#
# 1. Learner registers with a username that meets all validity criteria
# 2. Learner registers with an email that meets all validity criteria
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 1: Learner enters invalid username
# At step 1 of the basic flow: Learner fills in the username field by an invalid username
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that the username is invalid
# Based on the provided main flow, here are the scenarios that can be predicted:
#
# 1. Successful Registration with Valid Username and Password
# 2. Registration Attempt with Username Below 8 Characters
# 3. Registration Attempt with Username Above 30 Characters
# 4. Registration Attempt with Password Below 8 Characters
# 5. Registration Attempt with Password Above 30 Characters
# 6. Registration Attempt with Password Missing a Normal Character
# 7. Registration Attempt with Password Missing a Capitalized Character
# 8. Registration Attempt with Password Missing a Number
# 9. Registration Attempt with Password Missing a Special Character
# 10. Registration Attempt with Password Matching Username
#
# 1. Learner registers with a username that meets all validity criteria
# 2. Learner registers with an email that meets all validity criteria
#
# 1. Username Below Minimum Length
# 2. Username Exceeds Maximum Length
# 3. Password Below Minimum Length
# 4. Password Exceeds Maximum Length
# 5. Password Missing a Normal Character
# 6. Password Missing a Capitalized Character
# 7. Password Missing a Number
# 8. Password Missing a Special Character
# 9. Password Same as Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 2: Learner enters invalid password
# At step 2 of the basic flow: Learner fills in the password field by an invalid password
# Go back to step 3 in the basic flow and take only step 3.
# At step 4 of the basic flow: System shows a notification that the passowrd is invalid
# Based on the provided main flow, here are the scenarios that can be predicted:
#
# 1. Successful Registration with Valid Username and Password
# 2. Registration Attempt with Username Below 8 Characters
# 3. Registration Attempt with Username Above 30 Characters
# 4. Registration Attempt with Password Below 8 Characters
# 5. Registration Attempt with Password Above 30 Characters
# 6. Registration Attempt with Password Missing a Normal Character
# 7. Registration Attempt with Password Missing a Capitalized Character
# 8. Registration Attempt with Password Missing a Number
# 9. Registration Attempt with Password Missing a Special Character
# 10. Registration Attempt with Password Matching Username
#
# 1. Learner registers with a username that meets all validity criteria
# 2. Learner registers with an email that meets all validity criteria
#
# 1. Username Below Minimum Length
# 2. Username Exceeds Maximum Length
# 3. Password Below Minimum Length
# 4. Password Exceeds Maximum Length
# 5. Password Missing a Normal Character
# 6. Password Missing a Capitalized Character
# 7. Password Missing a Number
# 8. Password Missing a Special Character
# 9. Password Same as Username
#
# 1. Password shorter than 9 characters
# 2. Password longer than 29 characters
# 3. Password without a normal character
# 4. Password without a capitalized character
# 5. Password without a number
# 6. Password without a special character
# 7. Password identical to username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 3: Learner enters an existed username
# At step 1 of the basic flow: Learner fills in the username field by an username that has been registered
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that this username has been registered and ask the learner to choose another username.
# Based on the provided main flow, here are the scenarios that can be predicted:
#
# 1. Successful Registration with Valid Username and Password
# 2. Registration Attempt with Username Below 8 Characters
# 3. Registration Attempt with Username Above 30 Characters
# 4. Registration Attempt with Password Below 8 Characters
# 5. Registration Attempt with Password Above 30 Characters
# 6. Registration Attempt with Password Missing a Normal Character
# 7. Registration Attempt with Password Missing a Capitalized Character
# 8. Registration Attempt with Password Missing a Number
# 9. Registration Attempt with Password Missing a Special Character
# 10. Registration Attempt with Password Matching Username
#
# 1. Learner registers with a username that meets all validity criteria
# 2. Learner registers with an email that meets all validity criteria
#
# 1. Username Below Minimum Length
# 2. Username Exceeds Maximum Length
# 3. Password Below Minimum Length
# 4. Password Exceeds Maximum Length
# 5. Password Missing a Normal Character
# 6. Password Missing a Capitalized Character
# 7. Password Missing a Number
# 8. Password Missing a Special Character
# 9. Password Same as Username
#
# 1. Password shorter than 9 characters
# 2. Password longer than 29 characters
# 3. Password without a normal character
# 4. Password without a capitalized character
# 5. Password without a number
# 6. Password without a special character
# 7. Password identical to username
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Already Exists** - This scenario starts with the user entering a username that has already been registered in the system, which then triggers the exception flow where the system notifies the user that the username exists and prompts them to choose a different one.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 4: Learner enters invalid email
# At step 2 of the alternative flow 1: Learner fills in the email field by an invalid email, an invalid email must be an inexist email or email with the wrong format
# Go back to step 3 in the alternative flow 1 and continue with the steps from step 3.
# At step 4 of the basic flow: System shows a notification that the mail is invalid
# Based on the provided main flow, here are the scenarios that can be predicted:
#
# 1. Successful Registration with Valid Username and Password
# 2. Registration Attempt with Username Below 8 Characters
# 3. Registration Attempt with Username Above 30 Characters
# 4. Registration Attempt with Password Below 8 Characters
# 5. Registration Attempt with Password Above 30 Characters
# 6. Registration Attempt with Password Missing a Normal Character
# 7. Registration Attempt with Password Missing a Capitalized Character
# 8. Registration Attempt with Password Missing a Number
# 9. Registration Attempt with Password Missing a Special Character
# 10. Registration Attempt with Password Matching Username
#
# 1. Learner registers with a username that meets all validity criteria
# 2. Learner registers with an email that meets all validity criteria
#
# 1. Username Below Minimum Length
# 2. Username Exceeds Maximum Length
# 3. Password Below Minimum Length
# 4. Password Exceeds Maximum Length
# 5. Password Missing a Normal Character
# 6. Password Missing a Capitalized Character
# 7. Password Missing a Number
# 8. Password Missing a Special Character
# 9. Password Same as Username
#
# 1. Password shorter than 9 characters
# 2. Password longer than 29 characters
# 3. Password without a normal character
# 4. Password without a capitalized character
# 5. Password without a number
# 6. Password without a special character
# 7. Password identical to username
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Already Exists** - This scenario starts with the user entering a username that has already been registered in the system, which then triggers the exception flow where the system notifies the user that the username exists and prompts them to choose a different one.
#
# 1. Invalid Email Format Scenario
# 2. Inexistent Email Scenario
# {'Username': {'condition': {'valid': 'must be over 8 characters and below 30 characters, must be entered', 'invalid': 'below 8 characters or over 30 characters, has been registered'}, 'type': 'text field'}, 'Password': {'condition': {'valid': 'must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character, cannot be the same as the username', 'invalid': 'below 8 characters or over 30 characters, does not contain at least one of each kind: a normal character, a capitalize character, a number and a special character, is the same as the username'}, 'type': 'text field'}, 'Email': {'condition': {'valid': 'must be an exist email with the right format', 'invalid': 'an inexist email or email with the wrong format'}, 'type': 'text field'}}
# 1. Username below 8 characters
# 2. Username over 30 characters
# 3. Username has been registered
# 4. Password below 8 characters
# 5. Password over 30 characters
# 6. Password does not contain at least one normal character
# 7. Password does not contain at least one capitalize character
# 8. Password does not contain at least one number
# 9. Password does not contain at least one special character
# 10. Password is the same as the username
# 11. Email is an inexist email
# 12. Email with the wrong format
# Based on the provided main flow, here are the scenarios that can be predicted:
#
# 1. Successful Registration with Valid Username and Password
# 2. Registration Attempt with Username Below 8 Characters
# 3. Registration Attempt with Username Above 30 Characters
# 4. Registration Attempt with Password Below 8 Characters
# 5. Registration Attempt with Password Above 30 Characters
# 6. Registration Attempt with Password Missing a Normal Character
# 7. Registration Attempt with Password Missing a Capitalized Character
# 8. Registration Attempt with Password Missing a Number
# 9. Registration Attempt with Password Missing a Special Character
# 10. Registration Attempt with Password Matching Username
#
# 1. Learner registers with a username that meets all validity criteria
# 2. Learner registers with an email that meets all validity criteria
#
# 1. Username Below Minimum Length
# 2. Username Exceeds Maximum Length
# 3. Password Below Minimum Length
# 4. Password Exceeds Maximum Length
# 5. Password Missing a Normal Character
# 6. Password Missing a Capitalized Character
# 7. Password Missing a Number
# 8. Password Missing a Special Character
# 9. Password Same as Username
#
# 1. Password shorter than 9 characters
# 2. Password longer than 29 characters
# 3. Password without a normal character
# 4. Password without a capitalized character
# 5. Password without a number
# 6. Password without a special character
# 7. Password identical to username
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Already Exists** - This scenario starts with the user entering a username that has already been registered in the system, which then triggers the exception flow where the system notifies the user that the username exists and prompts them to choose a different one.
#
# 1. Invalid Email Format Scenario
# 2. Inexistent Email Scenario
# 1. Username below 8 characters
# 2. Username over 30 characters
# 3. Username has been registered
# 4. Password below 8 characters
# 5. Password over 30 characters
# 6. Password does not contain at least one normal character
# 7. Password does not contain at least one capitalize character
# 8. Password does not contain at least one number
# 9. Password does not contain at least one special character
# 10. Password is the same as the username
# 11. Email is an inexist email
# 12. Email with the wrong format
# filter_gpt_response
# - Successful Registration with Valid Username and Password
# - Registration Attempt with Username Below 8 Characters
# - Registration Attempt with Username Above 30 Characters
# - Registration Attempt with Password Below 8 Characters
# - Registration Attempt with Password Above 30 Characters
# - Registration Attempt with Password Missing a Normal Character
# - Registration Attempt with Password Missing a Capitalized Character
# - Registration Attempt with Password Missing a Number
# - Registration Attempt with Password Missing a Special Character
# - Registration Attempt with Password Matching Username
# - Username Already Exists
# - Invalid Email Format Scenario
# - Inexistent Email Scenario
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Registry-1.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-2.txt", filter_gpt_response)
# Out:
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Alternative flow 1: Learner register by email
# At step 1 of the basic flow: Learner clicks on the Mail icon
# Step 2: Learner fills in the email field by a valid email, a valid email must be an exist email with the right format
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 1: Learner enters invalid username
# At step 1 of the basic flow: Learner fills in the username field by an invalid username
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that the username is invalid
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length** - The username entered is either less than 8 characters or more than 30 characters.
# 2. **Invalid Password Length** - The password entered is either less than 8 characters or more than 30 characters, but the username is valid.
# 3. **Password Lacks Required Characters** - The password does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character, but the username is valid.
# 4. **Password Matches Username** - The password entered is the same as the username, but both are within the valid length.
# 5. **Valid Username and Password** - This scenario is to ensure that the system behaves as expected when both username and password are valid, leading to successful registration.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 2: Learner enters invalid password
# At step 2 of the basic flow: Learner fills in the password field by an invalid password
# Go back to step 3 in the basic flow and take only step 3.
# At step 4 of the basic flow: System shows a notification that the passowrd is invalid
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length** - The username entered is either less than 8 characters or more than 30 characters.
# 2. **Invalid Password Length** - The password entered is either less than 8 characters or more than 30 characters, but the username is valid.
# 3. **Password Lacks Required Characters** - The password does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character, but the username is valid.
# 4. **Password Matches Username** - The password entered is the same as the username, but both are within the valid length.
# 5. **Valid Username and Password** - This scenario is to ensure that the system behaves as expected when both username and password are valid, leading to successful registration.
#
# 1. Password Too Short
# 2. Password Too Long
# 3. Password Lacks Capital Letter
# 4. Password Lacks Number
# 5. Password Lacks Special Character
# 6. Password Lacks Normal Character
# 7. Password Same as Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 3: Learner enters an existed username
# At step 1 of the basic flow: Learner fills in the username field by an username that has been registered
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that this username has been registered and ask the learner to choose another username.
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length** - The username entered is either less than 8 characters or more than 30 characters.
# 2. **Invalid Password Length** - The password entered is either less than 8 characters or more than 30 characters, but the username is valid.
# 3. **Password Lacks Required Characters** - The password does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character, but the username is valid.
# 4. **Password Matches Username** - The password entered is the same as the username, but both are within the valid length.
# 5. **Valid Username and Password** - This scenario is to ensure that the system behaves as expected when both username and password are valid, leading to successful registration.
#
# 1. Password Too Short
# 2. Password Too Long
# 3. Password Lacks Capital Letter
# 4. Password Lacks Number
# 5. Password Lacks Special Character
# 6. Password Lacks Normal Character
# 7. Password Same as Username
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Username Already Exists Scenario**: The learner attempts to register with a username that already exists in the system.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 4: Learner enters invalid email
# At step 2 of the alternative flow 1: Learner fills in the email field by an invalid email, an invalid email must be an inexist email or email with the wrong format
# Go back to step 3 in the alternative flow 1 and continue with the steps from step 3.
# At step 4 of the basic flow: System shows a notification that the mail is invalid
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length** - The username entered is either less than 8 characters or more than 30 characters.
# 2. **Invalid Password Length** - The password entered is either less than 8 characters or more than 30 characters, but the username is valid.
# 3. **Password Lacks Required Characters** - The password does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character, but the username is valid.
# 4. **Password Matches Username** - The password entered is the same as the username, but both are within the valid length.
# 5. **Valid Username and Password** - This scenario is to ensure that the system behaves as expected when both username and password are valid, leading to successful registration.
#
# 1. Password Too Short
# 2. Password Too Long
# 3. Password Lacks Capital Letter
# 4. Password Lacks Number
# 5. Password Lacks Special Character
# 6. Password Lacks Normal Character
# 7. Password Same as Username
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Username Already Exists Scenario**: The learner attempts to register with a username that already exists in the system.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Invalid Email Format Scenario**: The learner enters an email with an incorrect format during the registration process.
# 2. **Inexistent Email Scenario**: The learner enters an email that does not exist or cannot be verified during the registration process.
# {'Username': {'condition': {'valid': 'must be over 8 characters and below 30 characters, must be entered', 'invalid': 'below 8 characters or over 30 characters, has been registered'}, 'type': 'text field'}, 'Password': {'condition': {'valid': 'must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character, cannot be the same as the username', 'invalid': 'below 8 characters or over 30 characters, does not contain at least one of each required kind, is the same as the username'}, 'type': 'text field'}, 'Email': {'condition': {'valid': 'must be an exist email with the right format', 'invalid': 'an inexist email or email with the wrong format'}, 'type': 'text field'}}
# 1. Username below 8 characters
# 2. Username over 30 characters
# 3. Username has been registered
# 4. Password below 8 characters
# 5. Password over 30 characters
# 6. Password does not contain at least one normal character
# 7. Password does not contain at least one capitalize character
# 8. Password does not contain at least one number
# 9. Password does not contain at least one special character
# 10. Password is the same as the username
# 11. Email is an inexist email
# 12. Email with the wrong format
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length** - The username entered is either less than 8 characters or more than 30 characters.
# 2. **Invalid Password Length** - The password entered is either less than 8 characters or more than 30 characters, but the username is valid.
# 3. **Password Lacks Required Characters** - The password does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character, but the username is valid.
# 4. **Password Matches Username** - The password entered is the same as the username, but both are within the valid length.
# 5. **Valid Username and Password** - This scenario is to ensure that the system behaves as expected when both username and password are valid, leading to successful registration.
#
# 1. Password Too Short
# 2. Password Too Long
# 3. Password Lacks Capital Letter
# 4. Password Lacks Number
# 5. Password Lacks Special Character
# 6. Password Lacks Normal Character
# 7. Password Same as Username
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Username Already Exists Scenario**: The learner attempts to register with a username that already exists in the system.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Invalid Email Format Scenario**: The learner enters an email with an incorrect format during the registration process.
# 2. **Inexistent Email Scenario**: The learner enters an email that does not exist or cannot be verified during the registration process.
# 1. Username below 8 characters
# 2. Username over 30 characters
# 3. Username has been registered
# 4. Password below 8 characters
# 5. Password over 30 characters
# 6. Password does not contain at least one normal character
# 7. Password does not contain at least one capitalize character
# 8. Password does not contain at least one number
# 9. Password does not contain at least one special character
# 10. Password is the same as the username
# 11. Email is an inexist email
# 12. Email with the wrong format
# filter_gpt_response
# - Successful Registration
# - Registration with Username Below Minimum Length
# - Registration with Username Above Maximum Length
# - Registration with Password Below Minimum Length
# - Registration with Password Above Maximum Length
# - Registration with Password Missing a Normal Character
# - Registration with Password Missing a Capitalized Character
# - Registration with Password Missing a Number
# - Registration with Password Missing a Special Character
# - Registration with Password Same as Username
# - Learner Registers with Email Instead of Username
# - Username Already Exists Scenario
# - Invalid Email Format Scenario
# - Inexistent Email Scenario
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Registry-2.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-3.txt", filter_gpt_response)
# Out:
# Based on the provided main flow and the rules for predicting scenarios, here are the important scenarios that can happen in this flow:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Alternative flow 1: Learner register by email
# At step 1 of the basic flow: Learner clicks on the Mail icon
# Step 2: Learner fills in the email field by a valid email, a valid email must be an exist email with the right format
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# Based on the provided main flow and the rules for predicting scenarios, here are the important scenarios that can happen in this flow:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 1: Learner enters invalid username
# At step 1 of the basic flow: Learner fills in the username field by an invalid username
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that the username is invalid
# Based on the provided main flow and the rules for predicting scenarios, here are the important scenarios that can happen in this flow:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Below Minimum Length** - The learner enters a username that is less than 8 characters long.
# 2. **Username Exceeds Maximum Length** - The learner enters a username that is more than 30 characters long.
# 3. **Username with Invalid Characters** - The learner enters a username that contains characters not allowed by the system's validation rules (assuming the system has specific character requirements not detailed in the main flow).
# 4. **Username as Password** - The learner enters a valid username but uses the same string for both the username and password fields, violating the rule that the password cannot be the same as the username.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 2: Learner enters invalid password
# At step 2 of the basic flow: Learner fills in the password field by an invalid password
# Go back to step 3 in the basic flow and take only step 3.
# At step 4 of the basic flow: System shows a notification that the passowrd is invalid
# Based on the provided main flow and the rules for predicting scenarios, here are the important scenarios that can happen in this flow:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Below Minimum Length** - The learner enters a username that is less than 8 characters long.
# 2. **Username Exceeds Maximum Length** - The learner enters a username that is more than 30 characters long.
# 3. **Username with Invalid Characters** - The learner enters a username that contains characters not allowed by the system's validation rules (assuming the system has specific character requirements not detailed in the main flow).
# 4. **Username as Password** - The learner enters a valid username but uses the same string for both the username and password fields, violating the rule that the password cannot be the same as the username.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Password Too Short** - The password entered is shorter than the minimum required length.
# 2. **Password Too Long** - The password entered exceeds the maximum allowed length.
# 3. **Password Lacks Number** - The password does not contain any numeric character.
# 4. **Password Lacks Special Character** - The password does not include any special character.
# 5. **Password Lacks Capital Letter** - The password is missing a capital letter.
# 6. **Password Lacks Normal Character** - The password does not have any lowercase letters.
# 7. **Password Matches Username** - The password entered is the same as the username.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 3: Learner enters an existed username
# At step 1 of the basic flow: Learner fills in the username field by an username that has been registered
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that this username has been registered and ask the learner to choose another username.
# Based on the provided main flow and the rules for predicting scenarios, here are the important scenarios that can happen in this flow:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Below Minimum Length** - The learner enters a username that is less than 8 characters long.
# 2. **Username Exceeds Maximum Length** - The learner enters a username that is more than 30 characters long.
# 3. **Username with Invalid Characters** - The learner enters a username that contains characters not allowed by the system's validation rules (assuming the system has specific character requirements not detailed in the main flow).
# 4. **Username as Password** - The learner enters a valid username but uses the same string for both the username and password fields, violating the rule that the password cannot be the same as the username.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Password Too Short** - The password entered is shorter than the minimum required length.
# 2. **Password Too Long** - The password entered exceeds the maximum allowed length.
# 3. **Password Lacks Number** - The password does not contain any numeric character.
# 4. **Password Lacks Special Character** - The password does not include any special character.
# 5. **Password Lacks Capital Letter** - The password is missing a capital letter.
# 6. **Password Lacks Normal Character** - The password does not have any lowercase letters.
# 7. **Password Matches Username** - The password entered is the same as the username.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Already Exists Scenario**: This scenario starts with the learner attempting to register with a username that has already been taken by another user. This directly leads to the exception flow where the system notifies the learner that the username exists and prompts for a different username.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 4: Learner enters invalid email
# At step 2 of the alternative flow 1: Learner fills in the email field by an invalid email, an invalid email must be an inexist email or email with the wrong format
# Go back to step 3 in the alternative flow 1 and continue with the steps from step 3.
# At step 4 of the basic flow: System shows a notification that the mail is invalid
# Based on the provided main flow and the rules for predicting scenarios, here are the important scenarios that can happen in this flow:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Below Minimum Length** - The learner enters a username that is less than 8 characters long.
# 2. **Username Exceeds Maximum Length** - The learner enters a username that is more than 30 characters long.
# 3. **Username with Invalid Characters** - The learner enters a username that contains characters not allowed by the system's validation rules (assuming the system has specific character requirements not detailed in the main flow).
# 4. **Username as Password** - The learner enters a valid username but uses the same string for both the username and password fields, violating the rule that the password cannot be the same as the username.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Password Too Short** - The password entered is shorter than the minimum required length.
# 2. **Password Too Long** - The password entered exceeds the maximum allowed length.
# 3. **Password Lacks Number** - The password does not contain any numeric character.
# 4. **Password Lacks Special Character** - The password does not include any special character.
# 5. **Password Lacks Capital Letter** - The password is missing a capital letter.
# 6. **Password Lacks Normal Character** - The password does not have any lowercase letters.
# 7. **Password Matches Username** - The password entered is the same as the username.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Already Exists Scenario**: This scenario starts with the learner attempting to register with a username that has already been taken by another user. This directly leads to the exception flow where the system notifies the learner that the username exists and prompts for a different username.
#
# 1. Invalid Email Format Scenario
# 2. Inexistent Email Scenario
# {'Username': {'condition': {'valid': 'must be over 8 characters and below 30 characters, must be entered', 'invalid': 'below 8 characters or over 30 characters, has been registered'}, 'type': 'text field'}, 'Password': {'condition': {'valid': 'must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character, cannot be the same as the username', 'invalid': 'below 8 characters or over 30 characters, does not contain at least one of each kind: a normal character, a capitalize character, a number and a special character, is the same as the username'}, 'type': 'text field'}, 'Email': {'condition': {'valid': 'must be an exist email with the right format', 'invalid': 'an inexist email or email with the wrong format'}, 'type': 'text field'}}
# 1. Username below 8 characters
# 2. Username over 30 characters
# 3. Username has been registered
# 4. Password below 8 characters
# 5. Password over 30 characters
# 6. Password does not contain a normal character
# 7. Password does not contain a capitalized character
# 8. Password does not contain a number
# 9. Password does not contain a special character
# 10. Password is the same as the username
# 11. Email is an inexist email
# 12. Email with the wrong format
# Based on the provided main flow and the rules for predicting scenarios, here are the important scenarios that can happen in this flow:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# 1. Learner Registers with Email Instead of Username
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Below Minimum Length** - The learner enters a username that is less than 8 characters long.
# 2. **Username Exceeds Maximum Length** - The learner enters a username that is more than 30 characters long.
# 3. **Username with Invalid Characters** - The learner enters a username that contains characters not allowed by the system's validation rules (assuming the system has specific character requirements not detailed in the main flow).
# 4. **Username as Password** - The learner enters a valid username but uses the same string for both the username and password fields, violating the rule that the password cannot be the same as the username.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Password Too Short** - The password entered is shorter than the minimum required length.
# 2. **Password Too Long** - The password entered exceeds the maximum allowed length.
# 3. **Password Lacks Number** - The password does not contain any numeric character.
# 4. **Password Lacks Special Character** - The password does not include any special character.
# 5. **Password Lacks Capital Letter** - The password is missing a capital letter.
# 6. **Password Lacks Normal Character** - The password does not have any lowercase letters.
# 7. **Password Matches Username** - The password entered is the same as the username.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Already Exists Scenario**: This scenario starts with the learner attempting to register with a username that has already been taken by another user. This directly leads to the exception flow where the system notifies the learner that the username exists and prompts for a different username.
#
# 1. Invalid Email Format Scenario
# 2. Inexistent Email Scenario
# 1. Username below 8 characters
# 2. Username over 30 characters
# 3. Username has been registered
# 4. Password below 8 characters
# 5. Password over 30 characters
# 6. Password does not contain a normal character
# 7. Password does not contain a capitalized character
# 8. Password does not contain a number
# 9. Password does not contain a special character
# 10. Password is the same as the username
# 11. Email is an inexist email
# 12. Email with the wrong format
# filter_gpt_response
# - Successful Registration
# - Registration with Username Below Minimum Length
# - Registration with Username Above Maximum Length
# - Registration with Password Below Minimum Length
# - Registration with Password Above Maximum Length
# - Registration with Password Missing a Normal Character
# - Registration with Password Missing a Capitalized Character
# - Registration with Password Missing a Number
# - Registration with Password Missing a Special Character
# - Registration with Password Same as Username
# - Learner Registers with Email Instead of Username
# - Username with Invalid Characters
# - Username Already Exists Scenario
# - Invalid Email Format Scenario
# - Inexistent Email Scenario
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Registry-3.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-4.txt", filter_gpt_response)
# Out:
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Alternative flow 1: Learner register by email
# At step 1 of the basic flow: Learner clicks on the Mail icon
# Step 2: Learner fills in the email field by a valid email, a valid email must be an exist email with the right format
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Register with Email Instead of Username** - This scenario starts with the user opting to register using an email address by clicking on the Mail icon instead of entering a username, following the steps outlined in the alternative flow.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 1: Learner enters invalid username
# At step 1 of the basic flow: Learner fills in the username field by an invalid username
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that the username is invalid
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Register with Email Instead of Username** - This scenario starts with the user opting to register using an email address by clicking on the Mail icon instead of entering a username, following the steps outlined in the alternative flow.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length Scenario**: Learner enters a username shorter than 8 characters or longer than 30 characters.
# 2. **Invalid Password as Username Scenario**: Learner enters a valid password that is the same as the username.
# 3. **Invalid Password Length Scenario**: Learner enters a password shorter than 8 characters or longer than 30 characters.
# 4. **Password Missing Character Type Scenario**: Learner enters a password that does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 2: Learner enters invalid password
# At step 2 of the basic flow: Learner fills in the password field by an invalid password
# Go back to step 3 in the basic flow and take only step 3.
# At step 4 of the basic flow: System shows a notification that the passowrd is invalid
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Register with Email Instead of Username** - This scenario starts with the user opting to register using an email address by clicking on the Mail icon instead of entering a username, following the steps outlined in the alternative flow.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length Scenario**: Learner enters a username shorter than 8 characters or longer than 30 characters.
# 2. **Invalid Password as Username Scenario**: Learner enters a valid password that is the same as the username.
# 3. **Invalid Password Length Scenario**: Learner enters a password shorter than 8 characters or longer than 30 characters.
# 4. **Password Missing Character Type Scenario**: Learner enters a password that does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Password Too Short
# 2. Password Too Long
# 3. Password Lacks a Normal Character
# 4. Password Lacks a Capitalized Character
# 5. Password Lacks a Number
# 6. Password Lacks a Special Character
# 7. Password Matches Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 3: Learner enters an existed username
# At step 1 of the basic flow: Learner fills in the username field by an username that has been registered
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that this username has been registered and ask the learner to choose another username.
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Register with Email Instead of Username** - This scenario starts with the user opting to register using an email address by clicking on the Mail icon instead of entering a username, following the steps outlined in the alternative flow.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length Scenario**: Learner enters a username shorter than 8 characters or longer than 30 characters.
# 2. **Invalid Password as Username Scenario**: Learner enters a valid password that is the same as the username.
# 3. **Invalid Password Length Scenario**: Learner enters a password shorter than 8 characters or longer than 30 characters.
# 4. **Password Missing Character Type Scenario**: Learner enters a password that does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Password Too Short
# 2. Password Too Long
# 3. Password Lacks a Normal Character
# 4. Password Lacks a Capitalized Character
# 5. Password Lacks a Number
# 6. Password Lacks a Special Character
# 7. Password Matches Username
#
# 1. UsernameAlreadyExistsScenario
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 4: Learner enters invalid email
# At step 2 of the alternative flow 1: Learner fills in the email field by an invalid email, an invalid email must be an inexist email or email with the wrong format
# Go back to step 3 in the alternative flow 1 and continue with the steps from step 3.
# At step 4 of the basic flow: System shows a notification that the mail is invalid
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Register with Email Instead of Username** - This scenario starts with the user opting to register using an email address by clicking on the Mail icon instead of entering a username, following the steps outlined in the alternative flow.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length Scenario**: Learner enters a username shorter than 8 characters or longer than 30 characters.
# 2. **Invalid Password as Username Scenario**: Learner enters a valid password that is the same as the username.
# 3. **Invalid Password Length Scenario**: Learner enters a password shorter than 8 characters or longer than 30 characters.
# 4. **Password Missing Character Type Scenario**: Learner enters a password that does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Password Too Short
# 2. Password Too Long
# 3. Password Lacks a Normal Character
# 4. Password Lacks a Capitalized Character
# 5. Password Lacks a Number
# 6. Password Lacks a Special Character
# 7. Password Matches Username
#
# 1. UsernameAlreadyExistsScenario
#
# 1. Invalid Email Format Scenario
# 2. Inexistent Email Scenario
# {'Username': {'condition': {'valid': 'must be over 8 characters and below 30 characters, must be entered', 'invalid': 'is below 8 characters or over 30 characters, is an existed username'}, 'type': 'text field'}, 'Password': {'condition': {'valid': 'must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character, cannot be the same as the username', 'invalid': 'is below 8 characters or over 30 characters, does not contain at least one of each kind: a normal character, a capitalize character, a number and a special character, is the same as the username'}, 'type': 'text field'}, 'Email': {'condition': {'valid': 'must be an exist email with the right format', 'invalid': 'must be an inexist email or email with the wrong format'}, 'type': 'text field'}}
# 1. Username below 8 characters
# 2. Username over 30 characters
# 3. Password below 8 characters
# 4. Password over 30 characters
# 5. Password without a normal character
# 6. Password without a capitalized character
# 7. Password without a number
# 8. Password without a special character
# 9. Password same as username
# 10. Email with wrong format
# 11. Email inexist
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Register with Email Instead of Username** - This scenario starts with the user opting to register using an email address by clicking on the Mail icon instead of entering a username, following the steps outlined in the alternative flow.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Invalid Username Length Scenario**: Learner enters a username shorter than 8 characters or longer than 30 characters.
# 2. **Invalid Password as Username Scenario**: Learner enters a valid password that is the same as the username.
# 3. **Invalid Password Length Scenario**: Learner enters a password shorter than 8 characters or longer than 30 characters.
# 4. **Password Missing Character Type Scenario**: Learner enters a password that does not contain at least one of each kind: a normal character, a capitalized character, a number, and a special character.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Password Too Short
# 2. Password Too Long
# 3. Password Lacks a Normal Character
# 4. Password Lacks a Capitalized Character
# 5. Password Lacks a Number
# 6. Password Lacks a Special Character
# 7. Password Matches Username
#
# 1. UsernameAlreadyExistsScenario
#
# 1. Invalid Email Format Scenario
# 2. Inexistent Email Scenario
# 1. Username below 8 characters
# 2. Username over 30 characters
# 3. Password below 8 characters
# 4. Password over 30 characters
# 5. Password without a normal character
# 6. Password without a capitalized character
# 7. Password without a number
# 8. Password without a special character
# 9. Password same as username
# 10. Email with wrong format
# 11. Email inexist
# filter_gpt_response
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
# 11. Register with Email Instead of Username
# 12. UsernameAlreadyExistsScenario
# 13. Invalid Email Format Scenario
# 14. Inexistent Email Scenario
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Registry-4.txt

# %%
promptMainScenario = [
    { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
    { "role": "user", "content": main_flow_prompt}
  ]
main_gpt_response = ask(promptMainScenario, client, model)
filtercontent = main_gpt_response
print(filtercontent)
for alt in alt_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
    ]
  print(main_flow_prompt +"\n\n"+alt)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)


for exc in exc_prompt:

  promptSubScenario = [
      { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
    ]
  print(main_flow_prompt +"\n\n"+exc)
  sub_gpt_response = ask(promptSubScenario, client, model)
  filtercontent+=  "\n\n" + sub_gpt_response
  print(filtercontent)



promptExtractCondition = [
    { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
    { "role": "user", "content": prompt_all}
  ]
gpt_response = askJSON(promptExtractCondition, client, model)
full_elements = json.loads(gpt_response)
condition_element = {key: value for key, value in full_elements.items() 
                              if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
print(condition_element)

if(len(condition_element)!= 0):
  promptScenarioForCondition = [
      { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
      { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
    ]
  condition_scenario_response = ask(promptScenarioForCondition, client, model)
  print(condition_scenario_response)
  filtercontent += "\n" + condition_scenario_response

print(filtercontent)

promptFilter = [
    { "role": "system", "content": FILTER_SYSTEM_PROMPT},
    { "role": "user", "content": filtercontent}
  ]
filter_gpt_response = ask(promptFilter, client, model)
print("filter_gpt_response \n" +filter_gpt_response)
write_string_to_file(f"D:\\GPT-testing\\ResultSet\\5.15\\{project_name}\\{usecase_name}-5.txt", filter_gpt_response)
# Out:
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Alternative flow 1: Learner register by email
# At step 1 of the basic flow: Learner clicks on the Mail icon
# Step 2: Learner fills in the email field by a valid email, a valid email must be an exist email with the right format
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. Scenario: Register with email instead of username
# 2. Scenario: Incorrect username format and switch to email registration
# 3. Scenario: Username already taken and switch to email registration
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 1: Learner enters invalid username
# At step 1 of the basic flow: Learner fills in the username field by an invalid username
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that the username is invalid
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. Scenario: Register with email instead of username
# 2. Scenario: Incorrect username format and switch to email registration
# 3. Scenario: Username already taken and switch to email registration
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Too Short** - The username entered is shorter than the minimum required length of 8 characters.
# 2. **Username Too Long** - The username entered exceeds the maximum allowed length of 30 characters.
# 3. **Username With Invalid Characters** - The username contains characters that are not allowed, assuming the system has specific rules about which characters are valid.
# 4. **Username Is Blank** - The username field is left empty and the user attempts to proceed by clicking the "Registry" button.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 2: Learner enters invalid password
# At step 2 of the basic flow: Learner fills in the password field by an invalid password
# Go back to step 3 in the basic flow and take only step 3.
# At step 4 of the basic flow: System shows a notification that the passowrd is invalid
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. Scenario: Register with email instead of username
# 2. Scenario: Incorrect username format and switch to email registration
# 3. Scenario: Username already taken and switch to email registration
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Too Short** - The username entered is shorter than the minimum required length of 8 characters.
# 2. **Username Too Long** - The username entered exceeds the maximum allowed length of 30 characters.
# 3. **Username With Invalid Characters** - The username contains characters that are not allowed, assuming the system has specific rules about which characters are valid.
# 4. **Username Is Blank** - The username field is left empty and the user attempts to proceed by clicking the "Registry" button.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Password Too Short** - The password entered is shorter than the minimum required length.
# 2. **Password Too Long** - The password entered exceeds the maximum allowed length.
# 3. **Password Lacks Number** - The password does not contain any numeric character.
# 4. **Password Lacks Special Character** - The password does not include any special character.
# 5. **Password Lacks Capital Letter** - The password is missing a capital letter.
# 6. **Password Lacks Normal Character** - The password does not have any lowercase letters.
# 7. **Password Matches Username** - The password entered is the same as the username, violating the rule that they cannot match.
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 3: Learner enters an existed username
# At step 1 of the basic flow: Learner fills in the username field by an username that has been registered
# Go back to step 2 in the basic flow and continue with the steps from step 2.
# At step 4 of the basic flow: System shows a notification that this username has been registered and ask the learner to choose another username.
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. Scenario: Register with email instead of username
# 2. Scenario: Incorrect username format and switch to email registration
# 3. Scenario: Username already taken and switch to email registration
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Too Short** - The username entered is shorter than the minimum required length of 8 characters.
# 2. **Username Too Long** - The username entered exceeds the maximum allowed length of 30 characters.
# 3. **Username With Invalid Characters** - The username contains characters that are not allowed, assuming the system has specific rules about which characters are valid.
# 4. **Username Is Blank** - The username field is left empty and the user attempts to proceed by clicking the "Registry" button.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Password Too Short** - The password entered is shorter than the minimum required length.
# 2. **Password Too Long** - The password entered exceeds the maximum allowed length.
# 3. **Password Lacks Number** - The password does not contain any numeric character.
# 4. **Password Lacks Special Character** - The password does not include any special character.
# 5. **Password Lacks Capital Letter** - The password is missing a capital letter.
# 6. **Password Lacks Normal Character** - The password does not have any lowercase letters.
# 7. **Password Matches Username** - The password entered is the same as the username, violating the rule that they cannot match.
#
# 1. Username Already Exists Scenario
#
# Main flow
# Step 1: Learner fills in the username field by a valid username, a valid username must be over 8 characters and below 30 characters.
# Step 2: Learner fills in the password field by a valid password, a valid password must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character. A valid password cannot be the same as the username.
# Step 3: Learner press "Registry" button
# Step 4: System redirects learner to Home page
#
#
#
# Exception flow 4: Learner enters invalid email
# At step 2 of the alternative flow 1: Learner fills in the email field by an invalid email, an invalid email must be an inexist email or email with the wrong format
# Go back to step 3 in the alternative flow 1 and continue with the steps from step 3.
# At step 4 of the basic flow: System shows a notification that the mail is invalid
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. Scenario: Register with email instead of username
# 2. Scenario: Incorrect username format and switch to email registration
# 3. Scenario: Username already taken and switch to email registration
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Too Short** - The username entered is shorter than the minimum required length of 8 characters.
# 2. **Username Too Long** - The username entered exceeds the maximum allowed length of 30 characters.
# 3. **Username With Invalid Characters** - The username contains characters that are not allowed, assuming the system has specific rules about which characters are valid.
# 4. **Username Is Blank** - The username field is left empty and the user attempts to proceed by clicking the "Registry" button.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Password Too Short** - The password entered is shorter than the minimum required length.
# 2. **Password Too Long** - The password entered exceeds the maximum allowed length.
# 3. **Password Lacks Number** - The password does not contain any numeric character.
# 4. **Password Lacks Special Character** - The password does not include any special character.
# 5. **Password Lacks Capital Letter** - The password is missing a capital letter.
# 6. **Password Lacks Normal Character** - The password does not have any lowercase letters.
# 7. **Password Matches Username** - The password entered is the same as the username, violating the rule that they cannot match.
#
# 1. Username Already Exists Scenario
#
# 1. Invalid Email Format Scenario
# 2. Inexistent Email Scenario
# {'Username': {'condition': {'valid': 'must be over 8 characters and below 30 characters, must be entered', 'invalid': 'below 8 characters or over 30 characters, has been registered'}, 'type': 'text field'}, 'Password': {'condition': {'valid': 'must be over 8 characters and below 30 characters, contains at least one of each kind: a normal character, a capitalize character, a number and a special character, cannot be the same as the username', 'invalid': 'below 8 characters or over 30 characters, does not contain at least one of each kind: a normal character, a capitalize character, a number and a special character, is the same as the username'}, 'type': 'text field'}, 'Email': {'condition': {'valid': 'must be an exist email with the right format', 'invalid': 'an inexist email or email with the wrong format'}, 'type': 'text field'}}
# 1. Scenario: Username Below 8 Characters
# 2. Scenario: Username Over 30 Characters
# 3. Scenario: Username Already Registered
# 4. Scenario: Password Below 8 Characters
# 5. Scenario: Password Over 30 Characters
# 6. Scenario: Password Lacks Normal Character
# 7. Scenario: Password Lacks Capitalize Character
# 8. Scenario: Password Lacks Number
# 9. Scenario: Password Lacks Special Character
# 10. Scenario: Password Same As Username
# 11. Scenario: Email Inexistent
# 12. Scenario: Email Wrong Format
# 1. Successful Registration
# 2. Registration with Username Below Minimum Length
# 3. Registration with Username Above Maximum Length
# 4. Registration with Password Below Minimum Length
# 5. Registration with Password Above Maximum Length
# 6. Registration with Password Missing a Normal Character
# 7. Registration with Password Missing a Capitalized Character
# 8. Registration with Password Missing a Number
# 9. Registration with Password Missing a Special Character
# 10. Registration with Password Same as Username
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. Scenario: Register with email instead of username
# 2. Scenario: Incorrect username format and switch to email registration
# 3. Scenario: Username already taken and switch to email registration
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Username Too Short** - The username entered is shorter than the minimum required length of 8 characters.
# 2. **Username Too Long** - The username entered exceeds the maximum allowed length of 30 characters.
# 3. **Username With Invalid Characters** - The username contains characters that are not allowed, assuming the system has specific rules about which characters are valid.
# 4. **Username Is Blank** - The username field is left empty and the user attempts to proceed by clicking the "Registry" button.
#
# Based on the provided main flow and the exception flow, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Password Too Short** - The password entered is shorter than the minimum required length.
# 2. **Password Too Long** - The password entered exceeds the maximum allowed length.
# 3. **Password Lacks Number** - The password does not contain any numeric character.
# 4. **Password Lacks Special Character** - The password does not include any special character.
# 5. **Password Lacks Capital Letter** - The password is missing a capital letter.
# 6. **Password Lacks Normal Character** - The password does not have any lowercase letters.
# 7. **Password Matches Username** - The password entered is the same as the username, violating the rule that they cannot match.
#
# 1. Username Already Exists Scenario
#
# 1. Invalid Email Format Scenario
# 2. Inexistent Email Scenario
# 1. Scenario: Username Below 8 Characters
# 2. Scenario: Username Over 30 Characters
# 3. Scenario: Username Already Registered
# 4. Scenario: Password Below 8 Characters
# 5. Scenario: Password Over 30 Characters
# 6. Scenario: Password Lacks Normal Character
# 7. Scenario: Password Lacks Capitalize Character
# 8. Scenario: Password Lacks Number
# 9. Scenario: Password Lacks Special Character
# 10. Scenario: Password Same As Username
# 11. Scenario: Email Inexistent
# 12. Scenario: Email Wrong Format
# filter_gpt_response
# - Successful Registration
# - Registration with Username Below Minimum Length
# - Registration with Username Above Maximum Length
# - Registration with Password Below Minimum Length
# - Registration with Password Above Maximum Length
# - Registration with Password Missing a Normal Character
# - Registration with Password Missing a Capitalized Character
# - Registration with Password Missing a Number
# - Registration with Password Missing a Special Character
# - Registration with Password Same as Username
# - Register with email instead of username
# - Incorrect username format and switch to email registration
# - Username already taken and switch to email registration
# - Username With Invalid Characters
# - Username Is Blank
# - Invalid Email Format Scenario
# - Inexistent Email Scenario
# String has been written to D:\GPT-testing\ResultSet\5.15\MatchaEnglishWebsite\Registry-5.txt
