# %%
# import pandas as pd

# # Read the Excel file
# file_path = 'test_cases.xlsx'  # Update this path to the actual path of your Excel file
# df = pd.read_excel(file_path, header=None)

# # Initialize variables
# use_case_scenarios = {}
# current_use_case = None

# # Iterate through the rows of the DataFrame
# for index, row in df.iterrows():
#     test_scenario = row[0]
#     if pd.isna(test_scenario):
#         continue
#     if test_scenario.endswith('.txt'):

#         current_use_case = test_scenario.replace('.txt','')
#         use_case_scenarios[current_use_case] = []
#     elif current_use_case:
#         use_case_scenarios[current_use_case].append(test_scenario)

# # Convert the dictionary to a 2D array
# result_array = [[use_case, scenarios] for use_case, scenarios in use_case_scenarios.items()]

# # Print the result
# for item in result_array:
#     print(item)

# %%
import pandas as pd

# Read the Excel file
file_path = r"D:\hotel-ts-baseline.xlsx" # Update this path to the actual path of your Excel file
df = pd.read_excel(file_path, header=None)

# Initialize variables
use_case_scenarios = {}
current_use_case = None

# Iterate through the rows of the DataFrame
for index, row in df.iterrows():
    test_scenario = row[0]
    valid = row[1]
    if pd.isna(test_scenario):
        continue
    if test_scenario.endswith('.txt'):
        current_use_case = test_scenario.replace('.txt','')
        use_case_scenarios[current_use_case] = []
    elif current_use_case and valid == 'x':
        use_case_scenarios[current_use_case].append(test_scenario)

# # Convert the dictionary to a 2D array
# result_array = [[use_case, scenarios] for use_case, scenarios in use_case_scenarios.items()]

# # Print the result
# for item in result_array:
#     print(item)
file_list = []
print(use_case_scenarios)
for key, value in use_case_scenarios.items():
    for scenario in value:

        file_list.append(key+'-'+scenario+'.txt')
print(file_list)
# Out:
# {'Add Booking': ['1. SuccessfulBookingAddition', '2. BookingWithoutLogin', '5. CalculateTotalAmount', '8. AddBookingWithoutFillingFields', '13. CalculateAmountWithoutFillingFields', '14. AddBookingWithoutCalculatingTotalAmount', '18. AddBookingWithPartialFieldsFilled', '19. LogoutAndTryToAddBooking'], 'Add Employee': ['1. Test Scenario: Successful Employee Addition', '2. Test Scenario: Manager Not Logged In', '3. Test Scenario: Mandatory Fields Left Blank', '4. Test Scenario: Invalid Field Entry', '7. Test Scenario: Refresh Page During Employee Addition'], 'Add Room': ['1. AddRoom_SuccessfulAddition', '2. AddRoom_InvalidFieldInput', '3. AddRoom_RoomAlreadyExists', '4. AddRoom_MissingMandatoryFields', '11. AddRoom_AccessControl_ManagerOnly'], 'Check in': ['1. Test Scenario: Verify successful check-in with valid booking ID', '2. Test Scenario: Verify system behavior with invalid booking ID', '3. Test Scenario: Verify system response when no booking ID is entered', '9. Test Scenario: Verify system behavior with already checked-in booking ID'], 'Check out': ['1. Test Scenario: Valid Checkout Process', '2. Test Scenario: Invalid Booking ID Entry', '3. Test Scenario: Booking ID Without Linked Room'], 'Hotel Owner - Generate Reports': ['- Successful Report Generation', '- Access Reports Page without Authentication', '- Access Reports Page with Non-Hotel Owner Role', '- Generate Report without Selecting Parameters', '- Display Error for Invalid Report Parameters', '- Reset Report Parameters after Error'], 'Hotel Owner - Update Hotel Information': ['1. UpdateHotelInformation_SuccessfulUpdate', '2. UpdateHotelInformation_InvalidFieldInput', '3. UpdateHotelInformation_EmptyRequiredFields', '4. UpdateHotelInformation_UnauthorizedAccess', '15. UpdateHotelInformation_AccessByNonOwnerUser'], 'login': ['1. ValidLogin_HotelOwner', '2. ValidLogin_Manager', '3. ValidLogin_Employee', '7. LoginWithEmptyUsername', '8. LoginWithEmptyPassword', '9. LoginWithEmptyUsernameAndPassword', '19. ErrorMessageDisplayForInvalidLogin'], 'Request Service': ['1. ValidRoomID_ServiceRequestSuccess', '2. InvalidRoomID_ShowErrorMessage', '4. ChooseMultipleServices_CalculateTotalCharges', '5. ChooseUnavailableService_ShowUnavailableMessage', '6. SubmitWithoutChoosingService_ShowChooseServiceMessage'], 'Update Booking': ['1. UpdateBooking_SuccessfulUpdate', '2. UpdateBooking_BookingNotFound', '3. UpdateBooking_InvalidFieldInput', '5. UpdateBooking_LoggedOutUser', '7. UpdateBooking_NoFieldsUpdated', '8. UpdateBooking_OnlyPartialFieldsUpdated', '9. UpdateBooking_AddNewService_ComputePayment', '10. UpdateBooking_ChangeRoomType_ComputePayment'], 'Update Employee': ['1. UpdateEmployee_SuccessfulUpdate', '3. UpdateEmployee_InvalidFieldInput', '4. UpdateEmployee_ManagerNotLoggedIn', '5. UpdateEmployee_EmployeeDoesNotExist', '6. UpdateEmployee_NoFieldsChanged', '7. UpdateEmployee_UpdateWithAllFields', '8. UpdateEmployee_UpdateWithMinimumFields'], 'Update Room': ['1. UpdateRoom_SuccessfulUpdate', '2. UpdateRoom_RoomNotFound', '3. UpdateRoom_InvalidFieldInput', '5. UpdateRoom_PreconditionsNotMet_NotLoggedIn', '6. UpdateRoom_PreconditionsNotMet_RoomDoesNotExist', '8. UpdateRoom_PartialFieldsUpdate', '9. UpdateRoom_ValidationCheck_MissingRequiredFields', '10. UpdateRoom_ValidationCheck_InvalidDataType']}
# ['Add Booking-1. SuccessfulBookingAddition.txt', 'Add Booking-2. BookingWithoutLogin.txt', 'Add Booking-5. CalculateTotalAmount.txt', 'Add Booking-8. AddBookingWithoutFillingFields.txt', 'Add Booking-13. CalculateAmountWithoutFillingFields.txt', 'Add Booking-14. AddBookingWithoutCalculatingTotalAmount.txt', 'Add Booking-18. AddBookingWithPartialFieldsFilled.txt', 'Add Booking-19. LogoutAndTryToAddBooking.txt', 'Add Employee-1. Test Scenario: Successful Employee Addition.txt', 'Add Employee-2. Test Scenario: Manager Not Logged In.txt', 'Add Employee-3. Test Scenario: Mandatory Fields Left Blank.txt', 'Add Employee-4. Test Scenario: Invalid Field Entry.txt', 'Add Employee-7. Test Scenario: Refresh Page During Employee Addition.txt', 'Add Room-1. AddRoom_SuccessfulAddition.txt', 'Add Room-2. AddRoom_InvalidFieldInput.txt', 'Add Room-3. AddRoom_RoomAlreadyExists.txt', 'Add Room-4. AddRoom_MissingMandatoryFields.txt', 'Add Room-11. AddRoom_AccessControl_ManagerOnly.txt', 'Check in-1. Test Scenario: Verify successful check-in with valid booking ID.txt', 'Check in-2. Test Scenario: Verify system behavior with invalid booking ID.txt', 'Check in-3. Test Scenario: Verify system response when no booking ID is entered.txt', 'Check in-9. Test Scenario: Verify system behavior with already checked-in booking ID.txt', 'Check out-1. Test Scenario: Valid Checkout Process.txt', 'Check out-2. Test Scenario: Invalid Booking ID Entry.txt', 'Check out-3. Test Scenario: Booking ID Without Linked Room.txt', 'Hotel Owner - Generate Reports-- Successful Report Generation.txt', 'Hotel Owner - Generate Reports-- Access Reports Page without Authentication.txt', 'Hotel Owner - Generate Reports-- Access Reports Page with Non-Hotel Owner Role.txt', 'Hotel Owner - Generate Reports-- Generate Report without Selecting Parameters.txt', 'Hotel Owner - Generate Reports-- Display Error for Invalid Report Parameters.txt', 'Hotel Owner - Generate Reports-- Reset Report Parameters after Error.txt', 'Hotel Owner - Update Hotel Information-1. UpdateHotelInformation_SuccessfulUpdate.txt', 'Hotel Owner - Update Hotel Information-2. UpdateHotelInformation_InvalidFieldInput.txt', 'Hotel Owner - Update Hotel Information-3. UpdateHotelInformation_EmptyRequiredFields.txt', 'Hotel Owner - Update Hotel Information-4. UpdateHotelInformation_UnauthorizedAccess.txt', 'Hotel Owner - Update Hotel Information-15. UpdateHotelInformation_AccessByNonOwnerUser.txt', 'login-1. ValidLogin_HotelOwner.txt', 'login-2. ValidLogin_Manager.txt', 'login-3. ValidLogin_Employee.txt', 'login-7. LoginWithEmptyUsername.txt', 'login-8. LoginWithEmptyPassword.txt', 'login-9. LoginWithEmptyUsernameAndPassword.txt', 'login-19. ErrorMessageDisplayForInvalidLogin.txt', 'Request Service-1. ValidRoomID_ServiceRequestSuccess.txt', 'Request Service-2. InvalidRoomID_ShowErrorMessage.txt', 'Request Service-4. ChooseMultipleServices_CalculateTotalCharges.txt', 'Request Service-5. ChooseUnavailableService_ShowUnavailableMessage.txt', 'Request Service-6. SubmitWithoutChoosingService_ShowChooseServiceMessage.txt', 'Update Booking-1. UpdateBooking_SuccessfulUpdate.txt', 'Update Booking-2. UpdateBooking_BookingNotFound.txt', 'Update Booking-3. UpdateBooking_InvalidFieldInput.txt', 'Update Booking-5. UpdateBooking_LoggedOutUser.txt', 'Update Booking-7. UpdateBooking_NoFieldsUpdated.txt', 'Update Booking-8. UpdateBooking_OnlyPartialFieldsUpdated.txt', 'Update Booking-9. UpdateBooking_AddNewService_ComputePayment.txt', 'Update Booking-10. UpdateBooking_ChangeRoomType_ComputePayment.txt', 'Update Employee-1. UpdateEmployee_SuccessfulUpdate.txt', 'Update Employee-3. UpdateEmployee_InvalidFieldInput.txt', 'Update Employee-4. UpdateEmployee_ManagerNotLoggedIn.txt', 'Update Employee-5. UpdateEmployee_EmployeeDoesNotExist.txt', 'Update Employee-6. UpdateEmployee_NoFieldsChanged.txt', 'Update Employee-7. UpdateEmployee_UpdateWithAllFields.txt', 'Update Employee-8. UpdateEmployee_UpdateWithMinimumFields.txt', 'Update Room-1. Update ...

# %%
import re
import pandas as pd
import os
import chardet

def read_file_content(file_path):
    # Detect the encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        return content
    except FileNotFoundError:
        return f"Error: The file at path {file_path} was not found."
    except UnicodeDecodeError:
        return f"Error: The file at path {file_path} cannot be decoded with the {encoding} encoding."
    except IOError:
        return f"Error: An I/O error occurred while reading the file at path {file_path}."

def split_before_and_after_hyphen(file_name):
    parts = file_name.split('-', 1)
    if len(parts) == 2:
        before_hyphen, after_hyphen = parts
    else:
        before_hyphen, after_hyphen = file_name, ""
    return before_hyphen.strip(), after_hyphen.strip()

# Function to parse the test cases from the text file
def parse_test_cases(file_name):
    # with open(file_name, 'r') as file:
    #     content = file.read()
    content = read_file_content(file_name)
    base_name = os.path.basename(file_name)

    base_nam = os.path.splitext(base_name)[0]

    # Extract use case and test scenario names from the file name
    use_case_name, test_scenario_name = split_before_and_after_hyphen(base_nam)
    
    # Regular expression to extract test cases
    test_case_pattern = re.compile(
        r"Test Case: (.*?)\ntestCaseName: (.*?)\nobjective: (.*?)\ntestSteps:\n(.*?)\nexpectedResult: (.*?)\n",
        re.DOTALL
    )
    
    matches = test_case_pattern.findall(content)
    
    test_cases = []
    for match in matches:
        test_case_name = match[1].strip()
        objective = match[2].strip()
        test_steps = match[3].strip().replace('\n', ' ')
        expected_result = match[4].strip()
        
        test_cases.append({
            'Use Case Name': use_case_name,
            'Test Scenario Name': test_scenario_name,
            'Test Case Name': test_case_name,
            'Objective': objective,
            'Test Steps': test_steps,
            'Expected Result': expected_result
        })
    
    return test_cases

# Function to write the parsed test cases to an Excel file
def write_to_excel(test_cases, output_file):
    df = pd.DataFrame(test_cases)
    df.to_excel(output_file, index=False)

all_test_cases = []

# File names
# input_file = 'use_case-test_scenario.txt'
output_file = 'test_cases.xlsx'
folder_path = r'D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc'
# Parse the test cases and write to Excel
# file_list = os.listdir(folder_path)


def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(1)) if match else float('inf')

# Function to sort filenames naturally by the extracted number
def natural_sort_key(filename):
    # Split the filename into parts: prefix and number
    parts = re.split(r'(\d+)', filename)
    # Convert numerical parts to integers for proper numeric sorting
    parts[1::2] = map(int, parts[1::2])
    return parts

# Sort filenames using the natural sort key
sorted_files = sorted(file_list, key=natural_sort_key)

for i in sorted_files: 
    print(i)
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    print(file_path)
    if os.path.isfile(file_path):
        test_cases = parse_test_cases(file_path)
        # print(test_cases)
        test_cases = parse_test_cases(file_path)
        all_test_cases.extend(test_cases)
write_to_excel(all_test_cases, output_file)
print(all_test_cases)
# Out:
# Add Booking-1. SuccessfulBookingAddition.txt
# Add Booking-2. BookingWithoutLogin.txt
# Add Booking-5. CalculateTotalAmount.txt
# Add Booking-8. AddBookingWithoutFillingFields.txt
# Add Booking-13. CalculateAmountWithoutFillingFields.txt
# Add Booking-14. AddBookingWithoutCalculatingTotalAmount.txt
# Add Booking-18. AddBookingWithPartialFieldsFilled.txt
# Add Booking-19. LogoutAndTryToAddBooking.txt
# Add Employee-1. Test Scenario: Successful Employee Addition.txt
# Add Employee-2. Test Scenario: Manager Not Logged In.txt
# Add Employee-3. Test Scenario: Mandatory Fields Left Blank.txt
# Add Employee-4. Test Scenario: Invalid Field Entry.txt
# Add Employee-7. Test Scenario: Refresh Page During Employee Addition.txt
# Add Room-1. AddRoom_SuccessfulAddition.txt
# Add Room-2. AddRoom_InvalidFieldInput.txt
# Add Room-3. AddRoom_RoomAlreadyExists.txt
# Add Room-4. AddRoom_MissingMandatoryFields.txt
# Add Room-11. AddRoom_AccessControl_ManagerOnly.txt
# Check in-1. Test Scenario: Verify successful check-in with valid booking ID.txt
# Check in-2. Test Scenario: Verify system behavior with invalid booking ID.txt
# Check in-3. Test Scenario: Verify system response when no booking ID is entered.txt
# Check in-9. Test Scenario: Verify system behavior with already checked-in booking ID.txt
# Check out-1. Test Scenario: Valid Checkout Process.txt
# Check out-2. Test Scenario: Invalid Booking ID Entry.txt
# Check out-3. Test Scenario: Booking ID Without Linked Room.txt
# Hotel Owner - Generate Reports-- Access Reports Page with Non-Hotel Owner Role.txt
# Hotel Owner - Generate Reports-- Access Reports Page without Authentication.txt
# Hotel Owner - Generate Reports-- Display Error for Invalid Report Parameters.txt
# Hotel Owner - Generate Reports-- Generate Report without Selecting Parameters.txt
# Hotel Owner - Generate Reports-- Reset Report Parameters after Error.txt
# Hotel Owner - Generate Reports-- Successful Report Generation.txt
# Hotel Owner - Update Hotel Information-1. UpdateHotelInformation_SuccessfulUpdate.txt
# Hotel Owner - Update Hotel Information-2. UpdateHotelInformation_InvalidFieldInput.txt
# Hotel Owner - Update Hotel Information-3. UpdateHotelInformation_EmptyRequiredFields.txt
# Hotel Owner - Update Hotel Information-4. UpdateHotelInformation_UnauthorizedAccess.txt
# Hotel Owner - Update Hotel Information-15. UpdateHotelInformation_AccessByNonOwnerUser.txt
# Request Service-1. ValidRoomID_ServiceRequestSuccess.txt
# Request Service-2. InvalidRoomID_ShowErrorMessage.txt
# Request Service-4. ChooseMultipleServices_CalculateTotalCharges.txt
# Request Service-5. ChooseUnavailableService_ShowUnavailableMessage.txt
# Request Service-6. SubmitWithoutChoosingService_ShowChooseServiceMessage.txt
# Update Booking-1. UpdateBooking_SuccessfulUpdate.txt
# Update Booking-2. UpdateBooking_BookingNotFound.txt
# Update Booking-3. UpdateBooking_InvalidFieldInput.txt
# Update Booking-5. UpdateBooking_LoggedOutUser.txt
# Update Booking-7. UpdateBooking_NoFieldsUpdated.txt
# Update Booking-8. UpdateBooking_OnlyPartialFieldsUpdated.txt
# Update Booking-9. UpdateBooking_AddNewService_ComputePayment.txt
# Update Booking-10. UpdateBooking_ChangeRoomType_ComputePayment.txt
# Update Employee-1. UpdateEmployee_SuccessfulUpdate.txt
# Update Employee-3. UpdateEmployee_InvalidFieldInput.txt
# Update Employee-4. UpdateEmployee_ManagerNotLoggedIn.txt
# Update Employee-5. UpdateEmployee_EmployeeDoesNotExist.txt
# Update Employee-6. UpdateEmployee_NoFieldsChanged.txt
# Update Employee-7. UpdateEmployee_UpdateWithAllFields.txt
# Update Employee-8. UpdateEmployee_UpdateWithMinimumFields.txt
# Update Room-1. UpdateRoom_SuccessfulUpdate.txt
# Update Room-2. UpdateRoom_RoomNotFound.txt
# Update Room-3. UpdateRoom_InvalidFieldInput.txt
# Update Room-5. UpdateRoom_PreconditionsNotMet_NotLoggedIn.txt
# Update Room-6. UpdateRoom_PreconditionsNotMet_RoomDoesNotExist.txt
# Update Room-8. UpdateRoom_PartialFieldsUpdate.txt
# Update Room-9. UpdateRoom_ValidationCheck_MissingRequiredFields.txt
# Update Room-10. UpdateRoom_ValidationCheck_InvalidDataType.txt
# login-1. ValidLogin_HotelOwner.txt
# login-2. ValidLogin_Manager.txt
# login-3. ValidLogin_Employee.txt
# login-7. LoginWithEmptyUsername.txt
# login-8. LoginWithEmptyPassword.txt
# login-9. LoginWithEmptyUsernameAndPassword.txt
# login-19. ErrorMessageDisplayForInvalidLogin.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Booking-1. SuccessfulBookingAddition.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Booking-2. BookingWithoutLogin.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Booking-5. CalculateTotalAmount.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Booking-8. AddBookingWithoutFillingFields.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Booking-13. CalculateAmountWithoutFillingFields.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Booking-14. AddBookingWithoutCalculatingTotalAmount.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Booking-18. AddBookingWithPartialFieldsFilled.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Booking-19. LogoutAndTryToAddBooking.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Employee-1. Test Scenario: Successful Employee Addition.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Employee-2. Test Scenario: Manager Not Logged In.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Employee-3. Test Scenario: Mandatory Fields Left Blank.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Employee-4. Test Scenario: Invalid Field Entry.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Employee-7. Test Scenario: Refresh Page During Employee Addition.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Room-1. AddRoom_SuccessfulAddition.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Room-2. AddRoom_InvalidFieldInput.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Room-3. AddRoom_RoomAlreadyExists.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Room-4. AddRoom_MissingMandatoryFields.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Add Room-11. AddRoom_AccessControl_ManagerOnly.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Check in-1. Test Scenario: Verify successful check-in with valid booking ID.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Check in-2. Test Scenario: Verify system behavior with invalid booking ID.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Check in-3. Test Scenario: Verify system response when no booking ID is entered.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Check in-9. Test Scenario: Verify system behavior with already checked-in booking ID.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Check out-1. Test Scenario: Valid Checkout Process.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Check out-2. Test Scenario: Invalid Booking ID Entry.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Check out-3. Test Scenario: Booking ID Without Linked Room.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Generate Reports-- Access Reports Page with Non-Hotel Owner Role.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Generate Reports-- Access Reports Page without Authentication.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Generate Reports-- Display Error for Invalid Report Parameters.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Generate Reports-- Generate Report without Selecting Parameters.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Generate Reports-- Reset Report Parameters after Error.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Generate Reports-- Successful Report Generation.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Update Hotel Information-1. UpdateHotelInformation_SuccessfulUpdate.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Update Hotel Information-2. UpdateHotelInformation_InvalidFieldInput.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Update Hotel Information-3. UpdateHotelInformation_EmptyRequiredFields.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Update Hotel Information-4. UpdateHotelInformation_UnauthorizedAccess.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Hotel Owner - Update Hotel Information-15. UpdateHotelInformation_AccessByNonOwnerUser.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Request Service-1. ValidRoomID_ServiceRequestSuccess.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Request Service-2. InvalidRoomID_ShowErrorMessage.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Request Service-4. ChooseMultipleServices_CalculateTotalCharges.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Request Service-5. ChooseUnavailableService_ShowUnavailableMessage.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Request Service-6. SubmitWithoutChoosingService_ShowChooseServiceMessage.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Booking-1. UpdateBooking_SuccessfulUpdate.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Booking-2. UpdateBooking_BookingNotFound.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Booking-3. UpdateBooking_InvalidFieldInput.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Booking-5. UpdateBooking_LoggedOutUser.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Booking-7. UpdateBooking_NoFieldsUpdated.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Booking-8. UpdateBooking_OnlyPartialFieldsUpdated.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Booking-9. UpdateBooking_AddNewService_ComputePayment.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Booking-10. UpdateBooking_ChangeRoomType_ComputePayment.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Employee-1. UpdateEmployee_SuccessfulUpdate.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Employee-3. UpdateEmployee_InvalidFieldInput.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Employee-4. UpdateEmployee_ManagerNotLoggedIn.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Employee-5. UpdateEmployee_EmployeeDoesNotExist.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Employee-6. UpdateEmployee_NoFieldsChanged.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Employee-7. UpdateEmployee_UpdateWithAllFields.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Employee-8. UpdateEmployee_UpdateWithMinimumFields.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Room-1. UpdateRoom_SuccessfulUpdate.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Room-2. UpdateRoom_RoomNotFound.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Room-3. UpdateRoom_InvalidFieldInput.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Room-5. UpdateRoom_PreconditionsNotMet_NotLoggedIn.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Room-6. UpdateRoom_PreconditionsNotMet_RoomDoesNotExist.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Room-8. UpdateRoom_PartialFieldsUpdate.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Room-9. UpdateRoom_ValidationCheck_MissingRequiredFields.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\Update Room-10. UpdateRoom_ValidationCheck_InvalidDataType.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\login-1. ValidLogin_HotelOwner.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\login-2. ValidLogin_Manager.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\login-3. ValidLogin_Employee.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\login-7. LoginWithEmptyUsername.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\login-8. LoginWithEmptyPassword.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\login-9. LoginWithEmptyUsernameAndPassword.txt
# D:\Dissertation-GPT\evaluate\baseline 2\hotel\tc\login-19. ErrorMessageDisplayForInvalidLogin.txt
# [{'Use Case Name': 'Add Booking', 'Test Scenario Name': '1. SuccessfulBookingAddition', 'Test Case Name': 'Successful Booking Addition', 'Objective': 'Verify that an employee can successfully add a booking and the system updates and displays the booking correctly.', 'Test Steps': '- Step 1: Log in to the system as an employee.   - Step 2: Select the Booking panel on the dashboard.   - Step 3: Fill all the booking fields with valid data.   - Step 4: Click the calculate amount button to get the total payable payment.   - Step 5: Press the add booking button after the total amount is displayed.   - Step 6: Verify the booking is added by checking the initial status displayed as checked in.', 'Expected Result': 'The system should validate the fields, generate a booking ID, add the booking to the database, and display a message indicating the booking has been added successfully with the initial status as checked in.'}, {'Use Case Name': 'Add Booking', 'Test Scenario Name': '1. SuccessfulBookingAddition', 'Test Case Name': 'Booking Addition with Unfilled Amount', 'Objective': 'Verify that the system prevents booking addition if the total amount is not calculated.', 'Test Steps': '- Step 1: Log in to the system as an employee.   - Step 2: Select the Booking panel on the dashboard.   - Step 3: Fill all the booking fields but do not click the calculate amount button.   - Step 4: Attempt to press the add booking button without calculating the total amount.', 'Expected Result': 'The system should prevent the booking from being added and display a message indicating that the total amount needs to be calculated before adding the booking.'}, {'Use Case Name': 'Add Booking', 'Test Scenario Name': '1. SuccessfulBookingAddition', 'Test Case Name': 'Booking Addition with Invalid Field Entry', 'Objective': 'Verify that the system shows an error message for each invalid field when attempting to add a booking.', 'Test Steps': '- Step 1: Log in to the system as an employee.   - Step 2: Select the Booking panel on the dashboard.   - Step 3: Fill the booking fields with at least one invalid entry.   - Step 4: Click the calculate amount button.   - Step 5: Press the add booking button.', 'Expected Result': 'The system should validate the fields and show an error message indicating the specific invalid field entered.'}, {'Use Case Name': 'Add Booking', 'Test Scenario Name': '1. SuccessfulBookingAddition', 'Test Case Name': 'Booking Addition Failure Message Display', 'Objective': 'Verify that the system displays a failure message in case of any error during the booking addition process.', 'Test Steps': '- Step 1: Log in to the system as an employee.   - Step 2: Select the Booking panel on the dashboard and fill the booking fields with data that is expected to cause an error (e.g., invalid data format).   - Step 3: Click the calculate amount button.   - Step 4: Press the add booking button.', 'Expected Result': 'The system should attempt to validate the fields and add the booking to the database but ultimately show a failure message due to the error.'}, {'Use Case Name': 'Add Booking', 'Test Scenario Name': '2. BookingWithoutLogin', 'Test Case Name': 'Successful Booking Creation Without Login', 'Objective': 'Verify that the system prevents booking creation without login and prompts for login', 'Test Steps': '- Step 1: Navigate to the application dashboard without logging in.   - Step 2: Attempt to select the Booking panel on the dashboard.', 'Expected Result': 'The system should prompt the user to log in before accessing the Booking panel.'}, {'Use Case Name': 'Add Booking', 'Test Scenario Name': '2. BookingWithoutLogin', 'Test Case Name': 'Successful Booking Creation With Login', 'Objective': 'Verify that an employee can successfully create a booking after logging in', 'Test Steps': '- Step 1: Log in as an employee.   - Step 2: Select the Booking panel on the dashboard.   - Step 3: Fill all the booking fields with valid data.   - Step 4: Click the calcul ...
