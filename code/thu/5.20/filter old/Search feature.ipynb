# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
    )

    return response.choices[0].message.content

def askJSON(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
def write_string_to_file(filename, content):
    try:
        with open(filename, 'w') as file:
            file.write(content)
        print(f"String has been written to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# %%
#Prompt
MAIN_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow of a use case.
Then you predict all scenarios that can happen in this flow.

Rules to predict scenarios:
- Stay close to the details described in the flow.
- Choose important cases to generate, important scenario is the scenario that users are more likely to encounter it.
- Limit the appearance of scenarios that are hard to happen. 
- A scenario encompasses a whole function, not just verifying individual steps.
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

SUB_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow and one alternative or exception flow of a use case.
Then you predict all scenarios that can lead user from the main flow to change to the alternative or exception flow mentioned for creating test cases.

Rules to predict scenarios:
- A scenario encompasses a whole function, not just verifying individual steps.
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- Do not generate scenarios with user analysis. (Example: User accidentally do A and user intentionally do A is the same scenario, so do not consider about "accidentally" or "intentionally" in scenario)
- Do not choose another option that is not chosen by the flow, eventhough it is mentioned (Example: A pop up with OK and Cancel, the flow only has step choose OK. Do not generate scenario that press Cancel)
- Do not generate scenario to test only the main flow.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

EXTRACT_CONDITION_SYSTEM_PROMPT="""
Given use case flows of a feature.
Your task is to identify all the interactive elements within the feature. 
For each interactive element:
Identify what type of that element (button,buttons, icon,scroll, text field,text area, tab, radio buttons, menu, combobox, sliders, switches, dialog, link, form,rating, filter).
Identify all the conditions mentioned in the use case of that element that would make the element valid and the conditions that would make the element invalid based on the description of the use case flow.
Do not arbitrarily create additional conditions that not mention in the use case flow.
Return the element extracted in json format.
The JSON format should follow the following structure:
{"Name of interactive element": {"condition": {valid:"conditions that make element valid", invalid: "conditions that make element invalid"}, "type": "element type"}}
Examples of output json format template: 
{"Username": {"condition": {"valid": "must be over 8 characters and below 30 characters, must be entered", racter, empty"}, "type": "text field"}}
{"Search button": {"condition": {"valid": "", "invalid": ""}, "type": "text field"}}
"""

GEN_SCENARIO_FOR_CONDITION_PROMPT="""
Given a list of interaction element for input value, their extracted conditions and corresponding use case.
For each given invalid condition:
- Generate a test scenario that test that condition.
Do not generate test scenario to test element/condition that not mention in the given element list.
Do not generate test scenario to test valid conditions.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""


FILTER_SYSTEM_PROMPT="""
Your task is to read all of this scenarios generation from many sources.
Then you remove all the same copies because there are many duplicate scenarios in meanings inside the input.
Make sure every scenarios in the response is unique.
Return scenario name only.
"""

# %%
usecase_name = "Search feature"
project_name = "ShopeeWeb"
main_flow_prompt = """
Main flow: 
Step 1: User types a product name in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
"""
prompt_all = """
Main flow: 
Step 1: User types a product name in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.

Alternative flow 1:
Step 1: User types a brand name in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows list of all the products from that brand from many shops. If that brand has it own official stores, system will shows that store

Alternative flow 2:
Step 1: User types a shop name in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows all the shop that has the same name and product that has the same word that user typed in.

Exception flow 1:
Step 1: User types an unavailable keyword that is not the same with any shop, brand or product available in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows a blank list and recommend user to try another keywords.

Exception flow 2:
Step 1: User types an unavailable keyword that is not the same with any brand or product available in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows all the shop that has the same name a blank product list and recommend user to try another keywords.

Exception flow 3:
Step 1: User types an unavailable keyword that is not the same with any shop available in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows a blank shop listm recommend user to try another keywords and shows list of all the related products from many shops.
"""
alt_prompt=[
"""Alternative flow 1:
Step 1: User types a brand name in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows list of all the products from that brand from many shops. If that brand has it own official stores, system will shows that store""",
"""Alternative flow 2:
Step 1: User types a shop name in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows all the shop that has the same name and product that has the same word that user typed in."""
]
exc_prompt = ["""Exception flow 1:
Step 1: User types an unavailable keyword that is not the same with any shop, brand or product available in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows a blank list and recommend user to try another keywords.
""",
"""Exception flow 2:
Step 1: User types an unavailable keyword that is not the same with any brand or product available in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows all the shop that has the same name a blank product list and recommend user to try another keywords.
""",
"""Exception flow 3:
Step 1: User types an unavailable keyword that is not the same with any shop available in the search bar.
Step 2: User clicks on the search icon or press enter.
Step 3: System shows a blank shop listm recommend user to try another keywords and shows list of all the related products from many shops.
"""]

# %%
for i in range(1,4):
    print(f"D:\\Dissertation-GPT\\evaluate\\ResultSet\\5.20\\old filter\\{project_name}\\{usecase_name}-{i}.txt")
# Out:
# D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Search feature-1.txt
# D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Search feature-2.txt
# D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Search feature-3.txt

# %%
for i in range(1,4):
  print("TIME "+str(i))
  promptMainScenario = [
      { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt}
    ]
  main_gpt_response = ask(promptMainScenario, client, model)
  filtercontent = main_gpt_response
  print(filtercontent)
  for alt in alt_prompt:
    promptSubScenario = [
        { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
        { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
      ]
    print(main_flow_prompt +"\n\n"+alt)
    sub_gpt_response = ask(promptSubScenario, client, model)
    filtercontent+=  "\n\n" + sub_gpt_response
    print(filtercontent)
  for exc in exc_prompt:
    promptSubScenario = [
        { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
        { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
      ]
    print(main_flow_prompt +"\n\n"+exc)
    sub_gpt_response = ask(promptSubScenario, client, model)
    filtercontent+=  "\n\n" + sub_gpt_response
    print(filtercontent)

  promptExtractCondition = [
      { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
      { "role": "user", "content": prompt_all}
    ]
  gpt_response = askJSON(promptExtractCondition, client, model)
  full_elements = json.loads(gpt_response)
  condition_element = {key: value for key, value in full_elements.items() 
                                if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
  print(condition_element)
  if(len(condition_element)!= 0):
    promptScenarioForCondition = [
        { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
        { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
      ]
    condition_scenario_response = ask(promptScenarioForCondition, client, model)
    print(condition_scenario_response)
    filtercontent += "\n" + condition_scenario_response

  print(filtercontent)

  promptFilter = [
      { "role": "system", "content": FILTER_SYSTEM_PROMPT},
      { "role": "user", "content": filtercontent}
    ]
  filter_gpt_response = ask(promptFilter, client, model)
  print("filter_gpt_response \n" +filter_gpt_response)
  write_string_to_file(f"D:\\Dissertation-GPT\\evaluate\\ResultSet\\5.20\\old filter\\{project_name}\\{usecase_name}-{i}.txt", filter_gpt_response)
# Out:
# TIME 1
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results
# 4. Search with Typographical Errors
# 5. Search with Product Brand Name
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Alternative flow 1:
# Step 1: User types a brand name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows list of all the products from that brand from many shops. If that brand has it own official stores, system will shows that store
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results
# 4. Search with Typographical Errors
# 5. Search with Product Brand Name
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Scenario
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Alternative flow 2:
# Step 1: User types a shop name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows all the shop that has the same name and product that has the same word that user typed in.
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results
# 4. Search with Typographical Errors
# 5. Search with Product Brand Name
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Scenario
#
# 1. Search by Shop Name Scenario
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 1:
# Step 1: User types an unavailable keyword that is not the same with any shop, brand or product available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a blank list and recommend user to try another keywords.
#
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results
# 4. Search with Typographical Errors
# 5. Search with Product Brand Name
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Scenario
#
# 1. Search by Shop Name Scenario
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Search for an Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not exist in the database or is not currently available in any shop listed on the platform, leading to the exception flow where the system shows a blank list and recommends trying another keyword.
#
# 2. **Typographical Error in Search**: The user makes a typographical error while typing the product name, which results in no matches found, thus triggering the exception flow.
#
# 3. **Using Too Specific or Narrow Search Terms**: The user enters very specific or narrow search terms that do not match any products or shops, resulting in the system showing a blank list with a recommendation to try another keyword.
#
# 4. **Searching with Outdated Product Names**: The user searches for a product using an outdated or old product name that is no longer used or recognized in the database, leading to the exception flow.
#
# 5. **Searching for a Discontinued Product**: The user searches for a product that has been discontinued and is no longer available in any shop, which triggers the exception flow.
#
# Each of these scenarios transitions from the main flow to the exception flow due to specific conditions or user actions that result in no search results being found.
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 2:
# Step 1: User types an unavailable keyword that is not the same with any brand or product available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows all the shop that has the same name a blank product list and recommend user to try another keywords.
#
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results
# 4. Search with Typographical Errors
# 5. Search with Product Brand Name
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Scenario
#
# 1. Search by Shop Name Scenario
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Search for an Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not exist in the database or is not currently available in any shop listed on the platform, leading to the exception flow where the system shows a blank list and recommends trying another keyword.
#
# 2. **Typographical Error in Search**: The user makes a typographical error while typing the product name, which results in no matches found, thus triggering the exception flow.
#
# 3. **Using Too Specific or Narrow Search Terms**: The user enters very specific or narrow search terms that do not match any products or shops, resulting in the system showing a blank list with a recommendation to try another keyword.
#
# 4. **Searching with Outdated Product Names**: The user searches for a product using an outdated or old product name that is no longer used or recognized in the database, leading to the exception flow.
#
# 5. **Searching for a Discontinued Product**: The user searches for a product that has been discontinued and is no longer available in any shop, which triggers the exception flow.
#
# Each of these scenarios transitions from the main flow to the exception flow due to specific conditions or user actions that result in no search results being found.
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for an Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not match any available products or brands in the system, leading to the exception flow where the system recommends trying other keywords.
#
# 2. **Search Using Non-Product Keywords**: In this scenario, the user enters keywords that are not related to any product or brand, such as a random string of characters or unrelated words, which triggers the system to display shops with matching names if any, a blank product list, and a suggestion to try other keywords.
#
# 3. **Search with Special Characters or Symbols**: The user attempts to search using special characters or symbols that do not correspond to any product or brand names, leading to the exception flow.
#
# These scenarios encapsulate the transition from the main flow to the exception flow based on the user's actions and the system's response to those actions.
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 3:
# Step 1: User types an unavailable keyword that is not the same with any shop available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a blank shop listm recommend user to try another keywords and shows list of all the related products from many shops.
#
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results
# 4. Search with Typographical Errors
# 5. Search with Product Brand Name
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Scenario
#
# 1. Search by Shop Name Scenario
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Search for an Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not exist in the database or is not currently available in any shop listed on the platform, leading to the exception flow where the system shows a blank list and recommends trying another keyword.
#
# 2. **Typographical Error in Search**: The user makes a typographical error while typing the product name, which results in no matches found, thus triggering the exception flow.
#
# 3. **Using Too Specific or Narrow Search Terms**: The user enters very specific or narrow search terms that do not match any products or shops, resulting in the system showing a blank list with a recommendation to try another keyword.
#
# 4. **Searching with Outdated Product Names**: The user searches for a product using an outdated or old product name that is no longer used or recognized in the database, leading to the exception flow.
#
# 5. **Searching for a Discontinued Product**: The user searches for a product that has been discontinued and is no longer available in any shop, which triggers the exception flow.
#
# Each of these scenarios transitions from the main flow to the exception flow due to specific conditions or user actions that result in no search results being found.
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for an Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not match any available products or brands in the system, leading to the exception flow where the system recommends trying other keywords.
#
# 2. **Search Using Non-Product Keywords**: In this scenario, the user enters keywords that are not related to any product or brand, such as a random string of characters or unrelated words, which triggers the system to display shops with matching names if any, a blank product list, and a suggestion to try other keywords.
#
# 3. **Search with Special Characters or Symbols**: The user attempts to search using special characters or symbols that do not correspond to any product or brand names, leading to the exception flow.
#
# These scenarios encapsulate the transition from the main flow to the exception flow based on the user's actions and the system's response to those actions.
#
# 1. Scenario: Search with Unavailable Product Keyword
# {'Search bar': {'condition': {'valid': 'user types a product name, brand name, or shop name', 'invalid': 'user types an unavailable keyword that is not the same with any shop, brand, or product available'}, 'type': 'text field'}}
# 1. Scenario: Search with a keyword not matching any shop, brand, or product available
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results
# 4. Search with Typographical Errors
# 5. Search with Product Brand Name
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Scenario
#
# 1. Search by Shop Name Scenario
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Search for an Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not exist in the database or is not currently available in any shop listed on the platform, leading to the exception flow where the system shows a blank list and recommends trying another keyword.
#
# 2. **Typographical Error in Search**: The user makes a typographical error while typing the product name, which results in no matches found, thus triggering the exception flow.
#
# 3. **Using Too Specific or Narrow Search Terms**: The user enters very specific or narrow search terms that do not match any products or shops, resulting in the system showing a blank list with a recommendation to try another keyword.
#
# 4. **Searching with Outdated Product Names**: The user searches for a product using an outdated or old product name that is no longer used or recognized in the database, leading to the exception flow.
#
# 5. **Searching for a Discontinued Product**: The user searches for a product that has been discontinued and is no longer available in any shop, which triggers the exception flow.
#
# Each of these scenarios transitions from the main flow to the exception flow due to specific conditions or user actions that result in no search results being found.
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for an Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not match any available products or brands in the system, leading to the exception flow where the system recommends trying other keywords.
#
# 2. **Search Using Non-Product Keywords**: In this scenario, the user enters keywords that are not related to any product or brand, such as a random string of characters or unrelated words, which triggers the system to display shops with matching names if any, a blank product list, and a suggestion to try other keywords.
#
# 3. **Search with Special Characters or Symbols**: The user attempts to search using special characters or symbols that do not correspond to any product or brand names, leading to the exception flow.
#
# These scenarios encapsulate the transition from the main flow to the exception flow based on the user's actions and the system's response to those actions.
#
# 1. Scenario: Search with Unavailable Product Keyword
# 1. Scenario: Search with a keyword not matching any shop, brand, or product available
# filter_gpt_response
# - Successful Product Search
# - No Results Found
# - Partial Match Results
# - Search with Typographical Errors
# - Search with Product Brand Name
# - Searching by Brand Name Scenario
# - Search by Shop Name Scenario
# - Search for an Unavailable Product
# - Using Too Specific or Narrow Search Terms
# - Searching with Outdated Product Names
# - Searching for a Discontinued Product
# - Search Using Non-Product Keywords
# - Search with Special Characters or Symbols
# String has been written to D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Search feature-1.txt
# TIME 2
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Product Search - User finds the product and related products from multiple shops.
# 2. No Results Found - User searches for a product that does not exist or is not available in any shop.
# 3. Partial Match Results - User types a product name that partially matches available products, leading to a broader range of related products.
# 4. Search by Product Category - User types a category name instead of a specific product name, resulting in a list of products within that category.
# 5. Typo in Search Query - User makes a typo in the product name, and the system either corrects it automatically or suggests the correct spelling.
# 6. Search with Filters Applied - User applies filters (e.g., price range, brand) after the initial search to narrow down the results.
# 7. Slow Network Response - The system takes longer than usual to display the results due to slow network conditions.
# 8. Search Suggestions - As the user types, the system provides suggestions based on popular searches and user history before the search is executed.
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Alternative flow 1:
# Step 1: User types a brand name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows list of all the products from that brand from many shops. If that brand has it own official stores, system will shows that store
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Product Search - User finds the product and related products from multiple shops.
# 2. No Results Found - User searches for a product that does not exist or is not available in any shop.
# 3. Partial Match Results - User types a product name that partially matches available products, leading to a broader range of related products.
# 4. Search by Product Category - User types a category name instead of a specific product name, resulting in a list of products within that category.
# 5. Typo in Search Query - User makes a typo in the product name, and the system either corrects it automatically or suggests the correct spelling.
# 6. Search with Filters Applied - User applies filters (e.g., price range, brand) after the initial search to narrow down the results.
# 7. Slow Network Response - The system takes longer than usual to display the results due to slow network conditions.
# 8. Search Suggestions - As the user types, the system provides suggestions based on popular searches and user history before the search is executed.
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Instead of Product Name
# 2. Searching for a Brand with an Official Store
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Alternative flow 2:
# Step 1: User types a shop name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows all the shop that has the same name and product that has the same word that user typed in.
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Product Search - User finds the product and related products from multiple shops.
# 2. No Results Found - User searches for a product that does not exist or is not available in any shop.
# 3. Partial Match Results - User types a product name that partially matches available products, leading to a broader range of related products.
# 4. Search by Product Category - User types a category name instead of a specific product name, resulting in a list of products within that category.
# 5. Typo in Search Query - User makes a typo in the product name, and the system either corrects it automatically or suggests the correct spelling.
# 6. Search with Filters Applied - User applies filters (e.g., price range, brand) after the initial search to narrow down the results.
# 7. Slow Network Response - The system takes longer than usual to display the results due to slow network conditions.
# 8. Search Suggestions - As the user types, the system provides suggestions based on popular searches and user history before the search is executed.
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Instead of Product Name
# 2. Searching for a Brand with an Official Store
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 1:
# Step 1: User types an unavailable keyword that is not the same with any shop, brand or product available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a blank list and recommend user to try another keywords.
#
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Product Search - User finds the product and related products from multiple shops.
# 2. No Results Found - User searches for a product that does not exist or is not available in any shop.
# 3. Partial Match Results - User types a product name that partially matches available products, leading to a broader range of related products.
# 4. Search by Product Category - User types a category name instead of a specific product name, resulting in a list of products within that category.
# 5. Typo in Search Query - User makes a typo in the product name, and the system either corrects it automatically or suggests the correct spelling.
# 6. Search with Filters Applied - User applies filters (e.g., price range, brand) after the initial search to narrow down the results.
# 7. Slow Network Response - The system takes longer than usual to display the results due to slow network conditions.
# 8. Search Suggestions - As the user types, the system provides suggestions based on popular searches and user history before the search is executed.
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Instead of Product Name
# 2. Searching for a Brand with an Official Store
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Searching for an Unavailable Product
# 2. Typing a Misspelled Product Name
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 2:
# Step 1: User types an unavailable keyword that is not the same with any brand or product available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows all the shop that has the same name a blank product list and recommend user to try another keywords.
#
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Product Search - User finds the product and related products from multiple shops.
# 2. No Results Found - User searches for a product that does not exist or is not available in any shop.
# 3. Partial Match Results - User types a product name that partially matches available products, leading to a broader range of related products.
# 4. Search by Product Category - User types a category name instead of a specific product name, resulting in a list of products within that category.
# 5. Typo in Search Query - User makes a typo in the product name, and the system either corrects it automatically or suggests the correct spelling.
# 6. Search with Filters Applied - User applies filters (e.g., price range, brand) after the initial search to narrow down the results.
# 7. Slow Network Response - The system takes longer than usual to display the results due to slow network conditions.
# 8. Search Suggestions - As the user types, the system provides suggestions based on popular searches and user history before the search is executed.
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Instead of Product Name
# 2. Searching for a Brand with an Official Store
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Searching for an Unavailable Product
# 2. Typing a Misspelled Product Name
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not exist or is not available in the database, leading to the exception flow where the system suggests trying other keywords.
#
# 2. **Search Using Misspelled Product Name**: The user enters a product name with a typo or misspelling, which is not recognized as a valid product or brand in the system, triggering the exception flow.
#
# 3. **Search with Special Characters or Symbols**: The user includes special characters or symbols in the search query that do not match any product or brand names, resulting in the system displaying the exception flow message.
#
# 4. **Search with Generic Terms Not Linked to Products**: The user searches using very generic or broad terms that do not directly match any specific product or brand names, leading to the exception flow.
#
# These scenarios cover different user actions that could change the application's response from the main flow to the exception flow, based on the rules for predicting scenarios.
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 3:
# Step 1: User types an unavailable keyword that is not the same with any shop available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a blank shop listm recommend user to try another keywords and shows list of all the related products from many shops.
#
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Product Search - User finds the product and related products from multiple shops.
# 2. No Results Found - User searches for a product that does not exist or is not available in any shop.
# 3. Partial Match Results - User types a product name that partially matches available products, leading to a broader range of related products.
# 4. Search by Product Category - User types a category name instead of a specific product name, resulting in a list of products within that category.
# 5. Typo in Search Query - User makes a typo in the product name, and the system either corrects it automatically or suggests the correct spelling.
# 6. Search with Filters Applied - User applies filters (e.g., price range, brand) after the initial search to narrow down the results.
# 7. Slow Network Response - The system takes longer than usual to display the results due to slow network conditions.
# 8. Search Suggestions - As the user types, the system provides suggestions based on popular searches and user history before the search is executed.
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Instead of Product Name
# 2. Searching for a Brand with an Official Store
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Searching for an Unavailable Product
# 2. Typing a Misspelled Product Name
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not exist or is not available in the database, leading to the exception flow where the system suggests trying other keywords.
#
# 2. **Search Using Misspelled Product Name**: The user enters a product name with a typo or misspelling, which is not recognized as a valid product or brand in the system, triggering the exception flow.
#
# 3. **Search with Special Characters or Symbols**: The user includes special characters or symbols in the search query that do not match any product or brand names, resulting in the system displaying the exception flow message.
#
# 4. **Search with Generic Terms Not Linked to Products**: The user searches using very generic or broad terms that do not directly match any specific product or brand names, leading to the exception flow.
#
# These scenarios cover different user actions that could change the application's response from the main flow to the exception flow, based on the rules for predicting scenarios.
#
# 1. Scenario: Search with Unavailable Product Keyword
# {'Search bar': {'condition': {'valid': 'user types a product name, a brand name, or a shop name', 'invalid': 'user types an unavailable keyword that is not the same with any shop, brand, or product available'}, 'type': 'text field'}}
# 1. SearchWithUnavailableKeyword_ShowBlankListAndRecommendation
# Based on the provided main flow, here are the scenarios that can happen:
#
# 1. Successful Product Search - User finds the product and related products from multiple shops.
# 2. No Results Found - User searches for a product that does not exist or is not available in any shop.
# 3. Partial Match Results - User types a product name that partially matches available products, leading to a broader range of related products.
# 4. Search by Product Category - User types a category name instead of a specific product name, resulting in a list of products within that category.
# 5. Typo in Search Query - User makes a typo in the product name, and the system either corrects it automatically or suggests the correct spelling.
# 6. Search with Filters Applied - User applies filters (e.g., price range, brand) after the initial search to narrow down the results.
# 7. Slow Network Response - The system takes longer than usual to display the results due to slow network conditions.
# 8. Search Suggestions - As the user types, the system provides suggestions based on popular searches and user history before the search is executed.
#
# Based on the provided main and alternative flows, here are the scenarios that can lead a user from the main flow to switch to the alternative flow:
#
# 1. Searching by Brand Name Instead of Product Name
# 2. Searching for a Brand with an Official Store
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Searching for an Unavailable Product
# 2. Typing a Misspelled Product Name
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not exist or is not available in the database, leading to the exception flow where the system suggests trying other keywords.
#
# 2. **Search Using Misspelled Product Name**: The user enters a product name with a typo or misspelling, which is not recognized as a valid product or brand in the system, triggering the exception flow.
#
# 3. **Search with Special Characters or Symbols**: The user includes special characters or symbols in the search query that do not match any product or brand names, resulting in the system displaying the exception flow message.
#
# 4. **Search with Generic Terms Not Linked to Products**: The user searches using very generic or broad terms that do not directly match any specific product or brand names, leading to the exception flow.
#
# These scenarios cover different user actions that could change the application's response from the main flow to the exception flow, based on the rules for predicting scenarios.
#
# 1. Scenario: Search with Unavailable Product Keyword
# 1. SearchWithUnavailableKeyword_ShowBlankListAndRecommendation
# filter_gpt_response
# - Successful Product Search
# - No Results Found
# - Partial Match Results
# - Search by Product Category
# - Typo in Search Query
# - Search with Filters Applied
# - Slow Network Response
# - Search Suggestions
# - Searching by Brand Name Instead of Product Name
# - Searching for a Brand with an Official Store
# - Searching for a Shop Name Instead of a Product Name
# - Searching for an Unavailable Product
# - Typing a Misspelled Product Name
# - Search for Unavailable Product
# - Search Using Misspelled Product Name
# - Search with Special Characters or Symbols
# - Search with Generic Terms Not Linked to Products
# - Search with Unavailable Product Keyword
# - SearchWithUnavailableKeyword_ShowBlankListAndRecommendation
# String has been written to D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Search feature-2.txt
# TIME 3
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results Found
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Alternative flow 1:
# Step 1: User types a brand name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows list of all the products from that brand from many shops. If that brand has it own official stores, system will shows that store
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results Found
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Search by Brand Name Instead of Product Name**: This scenario occurs when the user decides to type a brand name into the search bar instead of a specific product name, leading to the alternative flow where the system displays all products from that brand and its official stores if available.
#
# 2. **Misinterpretation of Product Name as Brand Name**: In this scenario, the user might type what they believe is a product name, but it is actually recognized by the system as a brand name, thus triggering the alternative flow.
#
# These scenarios encapsulate the full sequence of actions from initiating a search to the system's response based on the nature of the search query (product name vs. brand name).
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Alternative flow 2:
# Step 1: User types a shop name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows all the shop that has the same name and product that has the same word that user typed in.
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results Found
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Search by Brand Name Instead of Product Name**: This scenario occurs when the user decides to type a brand name into the search bar instead of a specific product name, leading to the alternative flow where the system displays all products from that brand and its official stores if available.
#
# 2. **Misinterpretation of Product Name as Brand Name**: In this scenario, the user might type what they believe is a product name, but it is actually recognized by the system as a brand name, thus triggering the alternative flow.
#
# These scenarios encapsulate the full sequence of actions from initiating a search to the system's response based on the nature of the search query (product name vs. brand name).
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 1:
# Step 1: User types an unavailable keyword that is not the same with any shop, brand or product available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a blank list and recommend user to try another keywords.
#
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results Found
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Search by Brand Name Instead of Product Name**: This scenario occurs when the user decides to type a brand name into the search bar instead of a specific product name, leading to the alternative flow where the system displays all products from that brand and its official stores if available.
#
# 2. **Misinterpretation of Product Name as Brand Name**: In this scenario, the user might type what they believe is a product name, but it is actually recognized by the system as a brand name, thus triggering the alternative flow.
#
# These scenarios encapsulate the full sequence of actions from initiating a search to the system's response based on the nature of the search query (product name vs. brand name).
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# 1. Scenario: User searches for a product using a misspelled keyword
# 2. Scenario: User searches for a product that is not available in any shop or does not exist
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 2:
# Step 1: User types an unavailable keyword that is not the same with any brand or product available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows all the shop that has the same name a blank product list and recommend user to try another keywords.
#
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results Found
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Search by Brand Name Instead of Product Name**: This scenario occurs when the user decides to type a brand name into the search bar instead of a specific product name, leading to the alternative flow where the system displays all products from that brand and its official stores if available.
#
# 2. **Misinterpretation of Product Name as Brand Name**: In this scenario, the user might type what they believe is a product name, but it is actually recognized by the system as a brand name, thus triggering the alternative flow.
#
# These scenarios encapsulate the full sequence of actions from initiating a search to the system's response based on the nature of the search query (product name vs. brand name).
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# 1. Scenario: User searches for a product using a misspelled keyword
# 2. Scenario: User searches for a product that is not available in any shop or does not exist
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not match any available products or brands in the system, leading to the exception flow where the system recommends trying other keywords.
#
# 2. **Search Using Non-Product Keywords**: In this scenario, the user enters keywords that are not related to any product or brand, such as generic terms or unrelated words, which triggers the system to display shops with matching names but no product results, suggesting the user to try different keywords.
#
# 3. **Search with Typographical Errors**: The user mistakenly types a product name with spelling errors, leading to the exception flow because the misspelled keyword does not match any product or brand in the system.
#
# 4. **Search with Discontinued or Out-of-Stock Products**: The user searches for a product that has been discontinued or is currently out of stock, which might not be immediately recognized as unavailable by the system but eventually leads to the exception flow due to the lack of available listings.
#
# These scenarios encapsulate different user actions or conditions that could shift the outcome from the expected list of shops and related products to the alternative outcome where the system fails to find relevant products and suggests trying other keywords.
#
# Main flow:
# Step 1: User types a product name in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a list of shops that sells the product and list of all the related products from many shops.
#
#
# Exception flow 3:
# Step 1: User types an unavailable keyword that is not the same with any shop available in the search bar.
# Step 2: User clicks on the search icon or press enter.
# Step 3: System shows a blank shop listm recommend user to try another keywords and shows list of all the related products from many shops.
#
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results Found
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Search by Brand Name Instead of Product Name**: This scenario occurs when the user decides to type a brand name into the search bar instead of a specific product name, leading to the alternative flow where the system displays all products from that brand and its official stores if available.
#
# 2. **Misinterpretation of Product Name as Brand Name**: In this scenario, the user might type what they believe is a product name, but it is actually recognized by the system as a brand name, thus triggering the alternative flow.
#
# These scenarios encapsulate the full sequence of actions from initiating a search to the system's response based on the nature of the search query (product name vs. brand name).
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# 1. Scenario: User searches for a product using a misspelled keyword
# 2. Scenario: User searches for a product that is not available in any shop or does not exist
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not match any available products or brands in the system, leading to the exception flow where the system recommends trying other keywords.
#
# 2. **Search Using Non-Product Keywords**: In this scenario, the user enters keywords that are not related to any product or brand, such as generic terms or unrelated words, which triggers the system to display shops with matching names but no product results, suggesting the user to try different keywords.
#
# 3. **Search with Typographical Errors**: The user mistakenly types a product name with spelling errors, leading to the exception flow because the misspelled keyword does not match any product or brand in the system.
#
# 4. **Search with Discontinued or Out-of-Stock Products**: The user searches for a product that has been discontinued or is currently out of stock, which might not be immediately recognized as unavailable by the system but eventually leads to the exception flow due to the lack of available listings.
#
# These scenarios encapsulate different user actions or conditions that could shift the outcome from the expected list of shops and related products to the alternative outcome where the system fails to find relevant products and suggests trying other keywords.
#
# 1. Search with Unavailable Product Keyword Scenario
# {'Search bar': {'condition': {'valid': 'user types a product name, brand name, or shop name', 'invalid': 'user types an unavailable keyword that is not the same with any shop, brand, or product available'}, 'type': 'text field'}}
# 1. SearchWithUnavailableKeywordNotMatchingAnyShopBrandOrProduct
# 1. Successful Product Search
# 2. No Results Found
# 3. Partial Match Results Found
#
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Search by Brand Name Instead of Product Name**: This scenario occurs when the user decides to type a brand name into the search bar instead of a specific product name, leading to the alternative flow where the system displays all products from that brand and its official stores if available.
#
# 2. **Misinterpretation of Product Name as Brand Name**: In this scenario, the user might type what they believe is a product name, but it is actually recognized by the system as a brand name, thus triggering the alternative flow.
#
# These scenarios encapsulate the full sequence of actions from initiating a search to the system's response based on the nature of the search query (product name vs. brand name).
#
# Based on the information provided, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. Searching for a Shop Name Instead of a Product Name
#
# 1. Scenario: User searches for a product using a misspelled keyword
# 2. Scenario: User searches for a product that is not available in any shop or does not exist
#
# Based on the provided main and exception flows, here are the scenarios that can lead a user from the main flow to the alternative or exception flow:
#
# 1. **Search for Unavailable Product**: This scenario starts with the user entering a keyword for a product that does not match any available products or brands in the system, leading to the exception flow where the system recommends trying other keywords.
#
# 2. **Search Using Non-Product Keywords**: In this scenario, the user enters keywords that are not related to any product or brand, such as generic terms or unrelated words, which triggers the system to display shops with matching names but no product results, suggesting the user to try different keywords.
#
# 3. **Search with Typographical Errors**: The user mistakenly types a product name with spelling errors, leading to the exception flow because the misspelled keyword does not match any product or brand in the system.
#
# 4. **Search with Discontinued or Out-of-Stock Products**: The user searches for a product that has been discontinued or is currently out of stock, which might not be immediately recognized as unavailable by the system but eventually leads to the exception flow due to the lack of available listings.
#
# These scenarios encapsulate different user actions or conditions that could shift the outcome from the expected list of shops and related products to the alternative outcome where the system fails to find relevant products and suggests trying other keywords.
#
# 1. Search with Unavailable Product Keyword Scenario
# 1. SearchWithUnavailableKeywordNotMatchingAnyShopBrandOrProduct
# filter_gpt_response
# - Successful Product Search
# - No Results Found
# - Partial Match Results Found
# - Search by Brand Name Instead of Product Name
# - Misinterpretation of Product Name as Brand Name
# - Searching for a Shop Name Instead of a Product Name
# - User searches for a product using a misspelled keyword
# - User searches for a product that is not available in any shop or does not exist
# - Search for Unavailable Product
# - Search Using Non-Product Keywords
# - Search with Typographical Errors
# - Search with Discontinued or Out-of-Stock Products
# String has been written to D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Search feature-3.txt
