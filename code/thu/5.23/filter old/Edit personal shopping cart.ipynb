# %%
from openai import OpenAI
import json
import os

GPT_MODEL_4 = "gpt-4-0125-preview"
OPEN_API_KEY = os.getenv("OPENAI_API_KEY")

client = OpenAI()
model = GPT_MODEL_4

def ask(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
    )

    return response.choices[0].message.content

def askJSON(prompt, client, model, temperature = 0):
    response = None
    
    response = client.chat.completions.create(
      model=model,
      messages=prompt,
      temperature=temperature,
      response_format={ "type": "json_object" },
    )

    return response.choices[0].message.content

# %%
def write_string_to_file(filename, content):
    try:
        with open(filename, 'w') as file:
            file.write(content)
        print(f"String has been written to {filename}")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# %%
#Prompt
MAIN_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow of a use case.
Then you predict all scenarios that can happen in this flow.

Rules to predict scenarios:
- Stay close to the details described in the flow.
- Focus on important and likely scenarios, important scenario is the scenario that users are more likely to encounter it. 
- Minimize the appearance of rare scenarios. 
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

SUB_FLOW_SYSTEM_PROMPT="""
I want you to act as software tester.
Your task is to read this information about one main flow and one alternative or exception flow of a use case.
Then you predict all scenarios that can lead user from the main flow to change to the alternative or exception flow mentioned for creating test cases.

Rules to predict scenarios:
- If there is no other action in the flow beside clicking or there is no condition to vary the user's actions, that flow has one scenario only.
- A scenario often refers to a specific sequence of events or user actions that could potentially lead to a change in how the application behaves or responds.
- Test scenarios should be derived from cohesive sequences of steps that represent meaningful user interactions, rather than isolated steps.
- A scenario should cover from the first step to the final step in the flow, the start or the result of the scenario could be different.
- You cannot separate parts of a flow to be a scenario (Example: predict multiple scenarios for a flow by dividing steps into parts) because each scenarios should be independent and require a complete flow to proceed.
- Do not generate scenarios with user analysis. (Example: User accidentally do A and user intentionally do A is the same scenario, so do not consider about "accidentally" or "intentionally" in scenario)
- Do not choose another option that is not chosen by the flow, eventhough it is mentioned (Example: A pop up with OK and Cancel, the flow only has step choose OK. Do not generate scenario that press Cancel)
- Do not generate scenario to test only the main flow.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""

EXTRACT_CONDITION_SYSTEM_PROMPT="""
Given use case flows of a feature.
Your task is to identify all the interactive elements within the feature. 
For each interactive element:
Identify what type of that element (button,buttons, icon,scroll, text field,text area, tab, radio buttons, menu, combobox, sliders, switches, dialog, link, form,rating, filter).
Identify all the conditions mentioned in the use case of that element that would make the element valid and the conditions that would make the element invalid based on the description of the use case flow.
Do not arbitrarily create additional conditions that not mention in the use case flow.
Return the element extracted in json format.
The JSON format should follow the following structure:
{"Name of interactive element": {"condition": {valid:"conditions that make element valid", invalid: "conditions that make element invalid"}, "type": "element type"}}
Examples of output json format template: 
{"Username": {"condition": {"valid": "must be over 8 characters and below 30 characters, must be entered", racter, empty"}, "type": "text field"}}
{"Search button": {"condition": {"valid": "", "invalid": ""}, "type": "text field"}}
"""

GEN_SCENARIO_FOR_CONDITION_PROMPT="""
Given a list of interaction element for input value, their extracted conditions and corresponding use case.
For each given invalid condition:
- Generate a test scenario that test that condition.
Do not generate test scenario to test element/condition that not mention in the given element list.
Do not generate test scenario to test valid conditions.
I only need scenarios's name for the output, I do not need the steps to go with it.
"""
FILTER_SYSTEM_PROMPT="""
You will be provide with a use case and a list of test scenario.
Based on information in the use case flow, define what test scenario is necessary to test the use case and remove duplicate test scenarios.
Remove test case test system load error that not be mentioned in use case such as: Load Failure, System Error,Network Error,Non-Existent ...(and use case not mentioned these flow)
Make sure test scenarios filted cover all the flow of use case and every scenarios in the response is unique.
Return scenario name only.
"""

# %%
usecase_name = "Edit personal shopping cart"
project_name = "ShopeeWeb"
main_flow_prompt = """
Main flow
Step 1: User clicks on the shopping cart icon at the top right of the screen.
Step 2: System navigates user to the cart's page. There should be all the products that user have added but haven't bought yet and their corresponding information about which shop sells that product, the product's price, promotions information, quantity of the product that user have added and which option of the product the user have chosen if that product has many options.
"""
prompt_all = """
Main flow
Step 1: User clicks on the shopping cart icon at the top right of the screen.
Step 2: System navigates user to the cart's page. There should be all the products that user have added but haven't bought yet and their corresponding information about which shop sells that product, the product's price, promotions information, quantity of the product that user have added and which option of the product the user have chosen if that product has many options.

Alternative flow 1: User remove a product from their shopping cart by erasing it
Step 3: User ticks the box choosing the product they want to remove.
Step 4: User clicks at the Erase button at the bottom of the screen.
Step 5: System shows a pop up to confirm the changes with two options Yes or No.
Step 6: User clicks Yes.
Step 7: System removes the product from user's shopping cart.

Alternative flow 2: User remove a product from their shopping cart by erasing it but change mind
Step 3: User ticks the box choosing the product they want to remove.
Step 4: User clicks at the Erase button at the bottom of the screen.
Step 5: System shows a pop up to confirm the changes with two options Yes or No.
Step 6: User clicks No.

Alternative flow 3: User remove a product from their shopping cart by decreasing the quantity to zero
Step 3: User decreases the quantity of the product until it reached one by clicking the minus button in the quantity section.
Step 4: User clicks the minus button when the quantity is one.
Step 5: System shows a pop up to confirm the changes with two options Yes or No.
Step 6: User clicks Yes.
Step 7: System removes the product from user's shopping cart.

Alternative flow 4: User remove a product from their shopping cart by decreasing the quantity to zero
Step 3: User decreases the quantity of the product until the number reached one by clicking the minus button in the quantity section.
Step 4: User clicks the minus button when the quantity is one.
Step 5: System shows a pop up to confirm the changes with two options Yes or No.
Step 6: User clicks No.

Alternative flow 5: User increase a product's quantity
Step 3: User increases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.

Alternative flow 6: User decrease a product's quantity
Step 3: User decreases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.

Alternative flow 7: User change options of a product
Step 3: User clicks on the option dropdown of a product in shopping cart's list
Step 4: User clicks on the option they want to change to.
Step 5: System changes the option of that product to what user has chosen. 
"""
alt_prompt=[
"""Alternative flow 1: User remove a product from their shopping cart by erasing it
Step 3: User ticks the box choosing the product they want to remove.
Step 4: User clicks at the Erase button at the bottom of the screen.
Step 5: System shows a pop up to confirm the changes with two options Yes or No.
Step 6: User clicks Yes.
Step 7: System removes the product from user's shopping cart.""",
"""Alternative flow 2: User remove a product from their shopping cart by erasing it but change mind
Step 3: User ticks the box choosing the product they want to remove.
Step 4: User clicks at the Erase button at the bottom of the screen.
Step 5: System shows a pop up to confirm the changes with two options Yes or No.
Step 6: User clicks No.""",
"""Alternative flow 3: User remove a product from their shopping cart by decreasing the quantity to zero
Step 3: User decreases the quantity of the product until it reached one by clicking the minus button in the quantity section.
Step 4: User clicks the minus button when the quantity is one.
Step 5: System shows a pop up to confirm the changes with two options Yes or No.
Step 6: User clicks Yes.
Step 7: System removes the product from user's shopping cart.
""",
"""Alternative flow 4: User remove a product from their shopping cart by decreasing the quantity to zero
Step 3: User decreases the quantity of the product until the number reached one by clicking the minus button in the quantity section.
Step 4: User clicks the minus button when the quantity is one.
Step 5: System shows a pop up to confirm the changes with two options Yes or No.
Step 6: User clicks No.""",
"""Alternative flow 5: User increase a product's quantity
Step 3: User increases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.
""",
"""Alternative flow 6: User decrease a product's quantity
Step 3: User decreases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.
""",
"""Alternative flow 7: User change options of a product
Step 3: User clicks on the option dropdown of a product in shopping cart's list
Step 4: User clicks on the option they want to change to.
Step 5: System changes the option of that product to what user has chosen. """]
exc_prompt = []

# %%
for i in range(1,4):
    print(f"D:\\Dissertation-GPT\\evaluate\\ResultSet\\5.20\\old filter\\{project_name}\\{usecase_name}-{i}.txt")
# Out:
# D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Edit personal shopping cart-1.txt
# D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Edit personal shopping cart-2.txt
# D:\Dissertation-GPT\evaluate\ResultSet\5.20\old filter\ShopeeWeb\Edit personal shopping cart-3.txt

# %%
for i in range(1,4):
  print("TIME "+str(i))
  filtercontent1 = "Use case: " + prompt_all +"\n Test scenarios: \n"
  promptMainScenario = [
      { "role": "system", "content": MAIN_FLOW_SYSTEM_PROMPT},
      { "role": "user", "content": main_flow_prompt}
    ]
  main_gpt_response = ask(promptMainScenario, client, model)
  filtercontent = main_gpt_response
  print(main_flow_prompt)
  print("\nmain_gpt_response:             "+main_gpt_response+"\n")
  for alt in alt_prompt:
    promptSubScenario = [
        { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
        { "role": "user", "content": main_flow_prompt +"\n\n"+alt}
      ]
    sub_gpt_response = ask(promptSubScenario, client, model)
    print(alt)
    print("\n               sub_gpt_response:"+sub_gpt_response +"\n")
    filtercontent+=  "\n" + sub_gpt_response
  for exc in exc_prompt:
    promptSubScenario = [
        { "role": "system", "content": SUB_FLOW_SYSTEM_PROMPT},
        { "role": "user", "content": main_flow_prompt +"\n\n"+exc}
      ]
    sub_gpt_response = ask(promptSubScenario, client, model)
    print(exc)
    print("\n               sub_gpt_response:"+sub_gpt_response +"\n")
    filtercontent+=  "\n" + sub_gpt_response
    sub_gpt_response = ask(promptSubScenario, client, model)

  promptExtractCondition = [
      { "role": "system", "content": EXTRACT_CONDITION_SYSTEM_PROMPT},
      { "role": "user", "content": prompt_all}
    ]
  gpt_response = askJSON(promptExtractCondition, client, model)
  full_elements = json.loads(gpt_response)
  condition_element = {key: value for key, value in full_elements.items() 
                                if (value['type'] in ['text field','text area'] and (value['condition']['valid'] or value['condition']['invalid'] ))}
  print(condition_element)
  if(len(condition_element)!= 0):
    promptScenarioForCondition = [
        { "role": "system", "content": GEN_SCENARIO_FOR_CONDITION_PROMPT},
        { "role": "user", "content": prompt_all + '\n Element:' + str(condition_element)}
      ]
    condition_scenario_response = ask(promptScenarioForCondition, client, model)
    filtercontent += "\n" + condition_scenario_response

  print(filtercontent)
  filtercontent1 += filtercontent
  promptFilter = [
      { "role": "system", "content": FILTER_SYSTEM_PROMPT},
      { "role": "user", "content": filtercontent1}
    ]
  filter_gpt_response = ask(promptFilter, client, model)
  print("filter_gpt_response \n" +filter_gpt_response)
  write_string_to_file(f"D:\\Dissertation-GPT\\evaluate\\ResultSet\\5.23\\run propose\\{project_name}\\{usecase_name}-{i}.txt", filter_gpt_response)
# Out:
# TIME 1
#
# Main flow
# Step 1: User clicks on the shopping cart icon at the top right of the screen.
# Step 2: System navigates user to the cart's page. There should be all the products that user have added but haven't bought yet and their corresponding information about which shop sells that product, the product's price, promotions information, quantity of the product that user have added and which option of the product the user have chosen if that product has many options.
#
#
# main_gpt_response:             Given the details of the main flow, it appears there is only one primary scenario based on the rules provided:
#
# 1. Successful Navigation to Cart Page with Product Details Displayed
#
# Alternative flow 1: User remove a product from their shopping cart by erasing it
# Step 3: User ticks the box choosing the product they want to remove.
# Step 4: User clicks at the Erase button at the bottom of the screen.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks Yes.
# Step 7: System removes the product from user's shopping cart.
#
#                sub_gpt_response:1. User removes a product from their shopping cart by erasing it
#
# Alternative flow 2: User remove a product from their shopping cart by erasing it but change mind
# Step 3: User ticks the box choosing the product they want to remove.
# Step 4: User clicks at the Erase button at the bottom of the screen.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks No.
#
#                sub_gpt_response:Based on the provided main flow and the alternative flow, here are the predicted scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Scenario: User decides not to remove a product after initiating the removal process.
#
# Alternative flow 3: User remove a product from their shopping cart by decreasing the quantity to zero
# Step 3: User decreases the quantity of the product until it reached one by clicking the minus button in the quantity section.
# Step 4: User clicks the minus button when the quantity is one.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks Yes.
# Step 7: System removes the product from user's shopping cart.
#
#
#                sub_gpt_response:Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. **Removing a Product by Decreasing Quantity to Zero**: This scenario starts with the user viewing their shopping cart (main flow) and decides to remove a product by decreasing its quantity to zero, following through the steps outlined in the alternative flow.
#
# Alternative flow 4: User remove a product from their shopping cart by decreasing the quantity to zero
# Step 3: User decreases the quantity of the product until the number reached one by clicking the minus button in the quantity section.
# Step 4: User clicks the minus button when the quantity is one.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks No.
#
#                sub_gpt_response:Based on the provided main flow and the alternative flow, here are the predicted scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **User Decides Not to Remove a Product After Decreasing Quantity to Zero**: This scenario starts with the user following the main flow by accessing the shopping cart. Then, during the process of adjusting the quantity of a product (intending to remove it by decreasing its quantity to zero), the user changes their mind after seeing the confirmation pop-up and decides not to remove the product by selecting "No".
#
# Alternative flow 5: User increase a product's quantity
# Step 3: User increases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.
#
#
#                sub_gpt_response:Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Product Quantity Increase**: This scenario starts with the user following the main flow steps and then deciding to increase the quantity of a specific product in their cart by using the plus button in the quantity section.
#
# Alternative flow 6: User decrease a product's quantity
# Step 3: User decreases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.
#
#
#                sub_gpt_response:Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Decrease Product Quantity to Desired Number** - This scenario starts with the user following the main flow steps and then deciding to decrease the quantity of a specific product in their cart by using the plus button until they reach the desired quantity.
#
# Alternative flow 7: User change options of a product
# Step 3: User clicks on the option dropdown of a product in shopping cart's list
# Step 4: User clicks on the option they want to change to.
# Step 5: System changes the option of that product to what user has chosen.
#
#                sub_gpt_response:1. Product Option Change Scenario
#
# {}
# Given the details of the main flow, it appears there is only one primary scenario based on the rules provided:
#
# 1. Successful Navigation to Cart Page with Product Details Displayed
# 1. User removes a product from their shopping cart by erasing it
# Based on the provided main flow and the alternative flow, here are the predicted scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. Scenario: User decides not to remove a product after initiating the removal process.
# Based on the provided information, here are the scenarios that can lead a user from the main flow to the alternative flow:
#
# 1. **Removing a Product by Decreasing Quantity to Zero**: This scenario starts with the user viewing their shopping cart (main flow) and decides to remove a product by decreasing its quantity to zero, following through the steps outlined in the alternative flow.
# Based on the provided main flow and the alternative flow, here are the predicted scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **User Decides Not to Remove a Product After Decreasing Quantity to Zero**: This scenario starts with the user following the main flow by accessing the shopping cart. Then, during the process of adjusting the quantity of a product (intending to remove it by decreasing its quantity to zero), the user changes their mind after seeing the confirmation pop-up and decides not to remove the product by selecting "No".
# Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Product Quantity Increase**: This scenario starts with the user following the main flow steps and then deciding to increase the quantity of a specific product in their cart by using the plus button in the quantity section.
# Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Decrease Product Quantity to Desired Number** - This scenario starts with the user following the main flow steps and then deciding to decrease the quantity of a specific product in their cart by using the plus button until they reach the desired quantity.
# 1. Product Option Change Scenario
# filter_gpt_response
# 1. Successful Navigation to Cart Page with Product Details Displayed
# 2. User removes a product from their shopping cart by erasing it
# 3. Scenario: User decides not to remove a product after initiating the removal process.
# 4. Removing a Product by Decreasing Quantity to Zero
# 5. User Decides Not to Remove a Product After Decreasing Quantity to Zero
# 6. Product Quantity Increase
# 7. Decrease Product Quantity to Desired Number
# 8. Product Option Change Scenario
# String has been written to D:\Dissertation-GPT\evaluate\ResultSet\5.23\run propose\ShopeeWeb\Edit personal shopping cart-1.txt
# TIME 2
#
# Main flow
# Step 1: User clicks on the shopping cart icon at the top right of the screen.
# Step 2: System navigates user to the cart's page. There should be all the products that user have added but haven't bought yet and their corresponding information about which shop sells that product, the product's price, promotions information, quantity of the product that user have added and which option of the product the user have chosen if that product has many options.
#
#
# main_gpt_response:             Given the details of the main flow, it appears that there is only one primary scenario based on the rules provided:
#
# 1. Successful Navigation to Cart Page with Product Details Displayed
#
# Alternative flow 1: User remove a product from their shopping cart by erasing it
# Step 3: User ticks the box choosing the product they want to remove.
# Step 4: User clicks at the Erase button at the bottom of the screen.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks Yes.
# Step 7: System removes the product from user's shopping cart.
#
#                sub_gpt_response:1. Removing a Product from the Shopping Cart
#
# Alternative flow 2: User remove a product from their shopping cart by erasing it but change mind
# Step 3: User ticks the box choosing the product they want to remove.
# Step 4: User clicks at the Erase button at the bottom of the screen.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks No.
#
#                sub_gpt_response:1. User decides not to remove a product after initiating the removal process
#
# Alternative flow 3: User remove a product from their shopping cart by decreasing the quantity to zero
# Step 3: User decreases the quantity of the product until it reached one by clicking the minus button in the quantity section.
# Step 4: User clicks the minus button when the quantity is one.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks Yes.
# Step 7: System removes the product from user's shopping cart.
#
#
#                sub_gpt_response:Based on the provided main flow and alternative flow, here are the predicted scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Removing a Product by Decreasing Quantity to Zero**: This scenario starts with the user viewing their shopping cart, deciding to remove a product by decreasing its quantity to zero, and confirming the removal when prompted.
#
# Alternative flow 4: User remove a product from their shopping cart by decreasing the quantity to zero
# Step 3: User decreases the quantity of the product until the number reached one by clicking the minus button in the quantity section.
# Step 4: User clicks the minus button when the quantity is one.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks No.
#
#                sub_gpt_response:Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# **Scenario Name: User Attempts to Remove a Product but Decides Against It**
#
# Alternative flow 5: User increase a product's quantity
# Step 3: User increases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.
#
#
#                sub_gpt_response:Based on the provided main flow and the alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Product Quantity Increase Due to Stock Availability**: The user attempts to increase the quantity of a product, but the system limits the increase due to stock availability.
# 2. **Product Quantity Increase for Bulk Purchase**: The user increases the quantity of a product for a bulk purchase, aiming to take advantage of a bulk purchase discount or promotion.
# 3. **Product Quantity Adjustment After Reviewing Cart**: The user reviews their cart and decides to adjust the quantity of a product based on the total cost or to meet a free shipping threshold.
# 4. **Product Quantity Increase After Price Check**: The user increases the quantity of a product after checking and comparing the product's price with other shops or platforms to ensure they are getting the best deal.
#
# Alternative flow 6: User decrease a product's quantity
# Step 3: User decreases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.
#
#
#                sub_gpt_response:Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Decreasing Product Quantity to Desired Number** - This scenario starts with the user following the main flow steps and then deciding to decrease the quantity of a specific product in their cart by using the plus button until they reach the desired quantity.
#
# Alternative flow 7: User change options of a product
# Step 3: User clicks on the option dropdown of a product in shopping cart's list
# Step 4: User clicks on the option they want to change to.
# Step 5: System changes the option of that product to what user has chosen.
#
#                sub_gpt_response:1. Scenario: User changes the option of a product in the shopping cart
#
# {}
# Given the details of the main flow, it appears that there is only one primary scenario based on the rules provided:
#
# 1. Successful Navigation to Cart Page with Product Details Displayed
# 1. Removing a Product from the Shopping Cart
# 1. User decides not to remove a product after initiating the removal process
# Based on the provided main flow and alternative flow, here are the predicted scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Removing a Product by Decreasing Quantity to Zero**: This scenario starts with the user viewing their shopping cart, deciding to remove a product by decreasing its quantity to zero, and confirming the removal when prompted.
# Based on the provided information, here is the scenario that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# **Scenario Name: User Attempts to Remove a Product but Decides Against It**
# Based on the provided main flow and the alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Product Quantity Increase Due to Stock Availability**: The user attempts to increase the quantity of a product, but the system limits the increase due to stock availability.
# 2. **Product Quantity Increase for Bulk Purchase**: The user increases the quantity of a product for a bulk purchase, aiming to take advantage of a bulk purchase discount or promotion.
# 3. **Product Quantity Adjustment After Reviewing Cart**: The user reviews their cart and decides to adjust the quantity of a product based on the total cost or to meet a free shipping threshold.
# 4. **Product Quantity Increase After Price Check**: The user increases the quantity of a product after checking and comparing the product's price with other shops or platforms to ensure they are getting the best deal.
# Based on the provided information, here are the scenarios that can lead a user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Decreasing Product Quantity to Desired Number** - This scenario starts with the user following the main flow steps and then deciding to decrease the quantity of a specific product in their cart by using the plus button until they reach the desired quantity.
# 1. Scenario: User changes the option of a product in the shopping cart
# filter_gpt_response
# 1. Successful Navigation to Cart Page with Product Details Displayed
# 2. Removing a Product from the Shopping Cart
# 3. User decides not to remove a product after initiating the removal process
# 4. Removing a Product by Decreasing Quantity to Zero
# 5. User Attempts to Remove a Product but Decides Against It
# 6. Product Quantity Increase for Bulk Purchase
# 7. Product Quantity Adjustment After Reviewing Cart
# 8. Decreasing Product Quantity to Desired Number
# 9. User changes the option of a product in the shopping cart
# String has been written to D:\Dissertation-GPT\evaluate\ResultSet\5.23\run propose\ShopeeWeb\Edit personal shopping cart-2.txt
# TIME 3
#
# Main flow
# Step 1: User clicks on the shopping cart icon at the top right of the screen.
# Step 2: System navigates user to the cart's page. There should be all the products that user have added but haven't bought yet and their corresponding information about which shop sells that product, the product's price, promotions information, quantity of the product that user have added and which option of the product the user have chosen if that product has many options.
#
#
# main_gpt_response:             1. Successful Navigation to Cart Page with All Product Details Displayed
# 2. Cart Page Displays with Some Products Missing
# 3. Cart Page Displays Incorrect Product Information
# 4. Cart Page Displays Outdated Promotion Information
# 5. Cart Page Shows Incorrect Product Quantity
# 6. Cart Page Displays Incorrect Product Options Selected
#
# Alternative flow 1: User remove a product from their shopping cart by erasing it
# Step 3: User ticks the box choosing the product they want to remove.
# Step 4: User clicks at the Erase button at the bottom of the screen.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks Yes.
# Step 7: System removes the product from user's shopping cart.
#
#                sub_gpt_response:Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. Scenario: Removing a product from the shopping cart
#
# Alternative flow 2: User remove a product from their shopping cart by erasing it but change mind
# Step 3: User ticks the box choosing the product they want to remove.
# Step 4: User clicks at the Erase button at the bottom of the screen.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks No.
#
#                sub_gpt_response:1. User Removes Product but Decides to Keep It
#
# Alternative flow 3: User remove a product from their shopping cart by decreasing the quantity to zero
# Step 3: User decreases the quantity of the product until it reached one by clicking the minus button in the quantity section.
# Step 4: User clicks the minus button when the quantity is one.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks Yes.
# Step 7: System removes the product from user's shopping cart.
#
#
#                sub_gpt_response:Based on the provided main flow and the alternative flow, here are the predicted scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Removing a Product by Decreasing Quantity to Zero** - This scenario starts with the user viewing their shopping cart, deciding to remove an item by decreasing its quantity to zero, and confirming the removal when prompted.
#
# Alternative flow 4: User remove a product from their shopping cart by decreasing the quantity to zero
# Step 3: User decreases the quantity of the product until the number reached one by clicking the minus button in the quantity section.
# Step 4: User clicks the minus button when the quantity is one.
# Step 5: System shows a pop up to confirm the changes with two options Yes or No.
# Step 6: User clicks No.
#
#                sub_gpt_response:Based on the provided main flow and the alternative flow 4, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **User Decides Not to Remove a Product After Decreasing Quantity to Zero**: This scenario starts with the user following the main flow and then deciding to remove a product by decreasing its quantity to zero, but ultimately decides against it by selecting "No" on the confirmation pop-up.
#
# Alternative flow 5: User increase a product's quantity
# Step 3: User increases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.
#
#
#                sub_gpt_response:Based on the provided main flow and the alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Product Quantity Update Due to Stock Availability**: The user attempts to increase the quantity of a product, but the system limits the increase due to stock availability, leading the user to adjust the quantity within available limits.
#
# 2. **Product Quantity Update for Bulk Purchase Discount**: The user increases the quantity of a product to reach a threshold for a bulk purchase discount, as indicated in the promotions information.
#
# 3. **Product Quantity Adjustment After Promotion Information Review**: After reviewing the promotions information for a product, the user decides to adjust the quantity of the product to take advantage of a promotion.
#
# 4. **Product Option Selection Leading to Quantity Adjustment**: The user selects a specific option for a product (e.g., size, color) that has limited availability, prompting an adjustment in the quantity to match what is available for the selected option.
#
# Alternative flow 6: User decrease a product's quantity
# Step 3: User decreases the quantity of the product until the number reachs what user want by clicking the plus button in the quantity section.
#
#
#                sub_gpt_response:Based on the provided information, here are the predicted scenarios that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Decrease Product Quantity to Desired Number**: This scenario starts with the user following the main flow steps and then deciding to decrease the quantity of a product in their cart by using the plus button until they reach the desired number. This scenario transitions from the main flow to the alternative flow when the user interacts with the quantity controls of a product in their cart.
#
# Alternative flow 7: User change options of a product
# Step 3: User clicks on the option dropdown of a product in shopping cart's list
# Step 4: User clicks on the option they want to change to.
# Step 5: System changes the option of that product to what user has chosen.
#
#                sub_gpt_response:1. Product Option Change Scenario
#
# {}
# 1. Successful Navigation to Cart Page with All Product Details Displayed
# 2. Cart Page Displays with Some Products Missing
# 3. Cart Page Displays Incorrect Product Information
# 4. Cart Page Displays Outdated Promotion Information
# 5. Cart Page Shows Incorrect Product Quantity
# 6. Cart Page Displays Incorrect Product Options Selected
# Based on the provided main flow and alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. Scenario: Removing a product from the shopping cart
# 1. User Removes Product but Decides to Keep It
# Based on the provided main flow and the alternative flow, here are the predicted scenarios that can lead a user from the main flow to change to the alternative or exception flow:
#
# 1. **Removing a Product by Decreasing Quantity to Zero** - This scenario starts with the user viewing their shopping cart, deciding to remove an item by decreasing its quantity to zero, and confirming the removal when prompted.
# Based on the provided main flow and the alternative flow 4, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **User Decides Not to Remove a Product After Decreasing Quantity to Zero**: This scenario starts with the user following the main flow and then deciding to remove a product by decreasing its quantity to zero, but ultimately decides against it by selecting "No" on the confirmation pop-up.
# Based on the provided main flow and the alternative flow, here are the scenarios that can lead a user from the main flow to change to the alternative flow:
#
# 1. **Product Quantity Update Due to Stock Availability**: The user attempts to increase the quantity of a product, but the system limits the increase due to stock availability, leading the user to adjust the quantity within available limits.
#
# 2. **Product Quantity Update for Bulk Purchase Discount**: The user increases the quantity of a product to reach a threshold for a bulk purchase discount, as indicated in the promotions information.
#
# 3. **Product Quantity Adjustment After Promotion Information Review**: After reviewing the promotions information for a product, the user decides to adjust the quantity of the product to take advantage of a promotion.
#
# 4. **Product Option Selection Leading to Quantity Adjustment**: The user selects a specific option for a product (e.g., size, color) that has limited availability, prompting an adjustment in the quantity to match what is available for the selected option.
# Based on the provided information, here are the predicted scenarios that can lead the user from the main flow to change to the alternative or exception flow mentioned:
#
# 1. **Decrease Product Quantity to Desired Number**: This scenario starts with the user following the main flow steps and then deciding to decrease the quantity of a product in their cart by using the plus button until they reach the desired number. This scenario transitions from the main flow to the alternative flow when the user interacts with the quantity controls of a product in their cart.
# 1. Product Option Change Scenario
# filter_gpt_response
# 1. Successful Navigation to Cart Page with All Product Details Displayed
# 2. Cart Page Displays Incorrect Product Information
# 3. Cart Page Displays Outdated Promotion Information
# 4. Cart Page Shows Incorrect Product Quantity
# 5. Cart Page Displays Incorrect Product Options Selected
# 6. Removing a Product by Decreasing Quantity to Zero
# 7. User Decides Not to Remove a Product After Decreasing Quantity to Zero
# 8. Product Quantity Update Due to Stock Availability
# 9. Product Quantity Update for Bulk Purchase Discount
# 10. Product Quantity Adjustment After Promotion Information Review
# 11. Product Option Selection Leading to Quantity Adjustment
# 12. Decrease Product Quantity to Desired Number
# 13. Product Option Change Scenario
# String has been written to D:\Dissertation-GPT\evaluate\ResultSet\5.23\run propose\ShopeeWeb\Edit personal shopping cart-3.txt
