# %%
import pandas as pd

# Load the Excel file
file_path = r"D:\Matcha.xlsx"  # Update this with your actual file path
# df = pd.read_excel(file_path, sheet_name='Trang tinh1')
df = pd.read_excel(file_path,header=None)

# Iterate through the DataFrame to keep only the valid scenarios
def filter_scenarios(df):
    valid_scenarios = []
    use_case = None
    
    for index, row in df.iterrows():
        if pd.isna(row[0]):
            use_case = None
        elif row[0].endswith('.txt'):
            use_case = row[0]
        elif row[1] == 'x' and pd.isna(row[3]):
            valid_scenarios.append([use_case, row[0]])
    
    return valid_scenarios

filtered_scenarios = filter_scenarios(df)

# Create a new DataFrame with the filtered scenarios
filtered_df = pd.DataFrame(filtered_scenarios, columns=['Use Case', 'Scenario'])

# Save the filtered DataFrame to a new Excel file
filtered_file_path = 'Matcha.xlsx'
filtered_df.to_excel(filtered_file_path, index=False)

print(f"Filtered scenarios saved to {filtered_file_path}")
# Out:
# Filtered scenarios saved to Matcha.xlsx

# %%
import pandas as pd

# Load the Excel file
file_path = r"D:\Matcha.xlsx"  # Update this with your actual file path
df = pd.read_excel(file_path,header=None)

# Create a new DataFrame to store the filtered results
filtered_df = pd.DataFrame(columns=df.columns)

use_case = None
for index, row in df.iterrows():
    if pd.isna(row[0]):
        # Add a blank row to separate use cases
        filtered_df = filtered_df.append(row)
    elif row[0].endswith('.txt'):
        use_case = row[0]
        filtered_df = filtered_df.append(row)
    elif row[1] == 'x' and pd.isna(row[3]):
        filtered_df = filtered_df.append(row)

# Save the filtered DataFrame to a new Excel file
filtered_file_path = 'Matcha.xlsx'
filtered_df.to_excel(filtered_file_path, index=False)

print(f"Filtered scenarios saved to {filtered_file_path}")
# Out:
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# Filtered scenarios saved to Matcha.xlsx
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)
# C:\Users\phamn\AppData\Local\Temp\ipykernel_1180\2483096311.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = filtered_df.append(row)

# %%
import pandas as pd

# Load the Excel file
file_path = r"D:\Matcha.xlsx"  # Update this with your actual file path
df = pd.read_excel(file_path,header=None)

# Create a new DataFrame to store the filtered results
# filtered_df = pd.DataFrame(columns=df.columns)

use_case_scenarios = {}
current_use_case = None
# current_scenarios = []

# Iterate through the DataFrame
for index, row in df.iterrows():
    test_scenario = row[0]
    valid = row[1]
    dup = row[3]
    
    if pd.isna(test_scenario):
        continue
    elif test_scenario.endswith('.txt'):
        current_use_case = test_scenario.replace('.txt','')
        use_case_scenarios[current_use_case] = []
    elif valid == 'x' and pd.isna(dup):
        use_case_scenarios[current_use_case].append(test_scenario)

file_list = []
print(use_case_scenarios)
for key, value in use_case_scenarios.items():
    for scenario in value:

        file_list.append(key+'-'+scenario+'.txt')

for i in file_list: 
    print(i)
# Out:
# {'Add new topic': ['1. Successful Topic Addition', '2. Adding Topic with Duplicate Name', '3. Cancel Topic Addition', '4. Adding Topic without Name', '5. Adding Topic without Description', '6. Adding Topic with Special Characters in Name', '7. Adding Topic with Long Name', '8. Adding Topic with Long Description'], 'AddLesson': ['1. Successful Lesson Addition', '2. Adding Lesson with Already Used Name', '3. Cancel Adding New Lesson', '4. Navigate to Add New Lesson Page via Navbar Option', '5. Adding Lesson Without Name', '6. Adding Lesson Without Description', '7. Adding Lesson with Special Characters in Name', '8. Adding Lesson with Long Name and Description', '9. Adding Lesson with HTML Tags in Name or Description', '10. Adding Lesson with Script Injection in Name or Description'], 'AddQuestion - Copy': ['1. Successful Question Creation', '2. Access Lesson Management from Homepage', '3. Skip Compulsory Field "Sentence"', '4. Skip Compulsory Field "Correct Answer"', '5. Skip Compulsory Field "Other Option 1"', '6. Skip Compulsory Field "Other Option 2"', '7. Skip Compulsory Field "Other Option 3"', '8. Cancel Question Creation and Choose to Stay', '9. Enter Invalid Field Input', '10. Leave Page Without Saving Question', '11. Cancel Question Creation and Confirm Cancelation'], 'AddQuestion ': ['1. Successful question creation for selection test', '2. Access Lesson Management from Homepage', '3. Skip compulsory field "sentence" and handle error', '4. Skip compulsory field "correct answer" and handle error', '5. Skip compulsory field "other option 1" and handle error', '6. Skip compulsory field "other option 2" and handle error', '7. Skip compulsory field "other option 3" and handle error', '8. Cancel question creation and choose to stay', '9. Enter invalid sentence and handle error', '10. Leave page without saving question', '11. Cancel question creation and confirm cancellation'], 'EditTest': ['1. Successful Test Edit', '2. Cancel Edit and Exit Without Saving', '5. Save Edited Test With Mandatory Fields Missing', '7. Edit Test With Special Characters in Vocabulary', '8. Edit Test With Maximum Length of Vocabulary', '9. Edit Test With Minimum Length of Vocabulary'], 'Flashcard': ['1. Successful Navigation and Learning Flow', '2. Navigation with Back Button and Stay Decision', '3. Continue Studying After Completion', '4. Direct Access to Incomplete Topic from Home Page', '5. Attempt to Navigate to Previous Flashcard on First Card', '6. Exit During Flashcard Study and Mark Topic as Incomplete'], 'Handbook': ['1. View Vocabulary List', '2. Scroll Vocabulary List', '3. Search Vocabulary Successfully', '4. Search Meaningless Vocabulary', '5. Exclude Vocabulary from Review Test', '6. Include Vocabulary in Review Test'], 'Learning days history': ['1. **View Continuous Learning Days Scenario** - This scenario covers the basic flow where a learner checks their continuous learning days without any interruptions in their learning streak.', '2. **View Learning Days After Break Scenario** - This scenario tests the functionality when a learner has recently broken their learning streak and checks their learning days, which should reset to one.'], 'ListenToPronunciation': ['1. Successful Pronunciation Test Completion', '2. Incorrect Answer Selection', '6. Attempting Test Without Being Logged In', '8. Refreshing Page During Test', '9. Closing Application During Test', '11. Skipping Pronunciation Test Question'], 'Login': ['1. Successful Login with Username', '2. Successful Login with Email', '3. Login with Wrong Password', '4. Login with Unregistered Username', '5. Login with Blank Username Field', '6. Login with Blank Password Field'], 'Registry': ['1. Successful Registration with Valid Username and Password', '2. Successful Registration with Email', '4. Registration with Invalid Password', '5. Registration with Existed Username', '7. Registration with Password Same as Username', '8. Registration with Username Below Minimum Length', '9. Registr ...
# Add new topic-1. Successful Topic Addition.txt
# Add new topic-2. Adding Topic with Duplicate Name.txt
# Add new topic-3. Cancel Topic Addition.txt
# Add new topic-4. Adding Topic without Name.txt
# Add new topic-5. Adding Topic without Description.txt
# Add new topic-6. Adding Topic with Special Characters in Name.txt
# Add new topic-7. Adding Topic with Long Name.txt
# Add new topic-8. Adding Topic with Long Description.txt
# AddLesson-1. Successful Lesson Addition.txt
# AddLesson-2. Adding Lesson with Already Used Name.txt
# AddLesson-3. Cancel Adding New Lesson.txt
# AddLesson-4. Navigate to Add New Lesson Page via Navbar Option.txt
# AddLesson-5. Adding Lesson Without Name.txt
# AddLesson-6. Adding Lesson Without Description.txt
# AddLesson-7. Adding Lesson with Special Characters in Name.txt
# AddLesson-8. Adding Lesson with Long Name and Description.txt
# AddLesson-9. Adding Lesson with HTML Tags in Name or Description.txt
# AddLesson-10. Adding Lesson with Script Injection in Name or Description.txt
# AddQuestion - Copy-1. Successful Question Creation.txt
# AddQuestion - Copy-2. Access Lesson Management from Homepage.txt
# AddQuestion - Copy-3. Skip Compulsory Field "Sentence".txt
# AddQuestion - Copy-4. Skip Compulsory Field "Correct Answer".txt
# AddQuestion - Copy-5. Skip Compulsory Field "Other Option 1".txt
# AddQuestion - Copy-6. Skip Compulsory Field "Other Option 2".txt
# AddQuestion - Copy-7. Skip Compulsory Field "Other Option 3".txt
# AddQuestion - Copy-8. Cancel Question Creation and Choose to Stay.txt
# AddQuestion - Copy-9. Enter Invalid Field Input.txt
# AddQuestion - Copy-10. Leave Page Without Saving Question.txt
# AddQuestion - Copy-11. Cancel Question Creation and Confirm Cancelation.txt
# AddQuestion -1. Successful question creation for selection test.txt
# AddQuestion -2. Access Lesson Management from Homepage.txt
# AddQuestion -3. Skip compulsory field "sentence" and handle error.txt
# AddQuestion -4. Skip compulsory field "correct answer" and handle error.txt
# AddQuestion -5. Skip compulsory field "other option 1" and handle error.txt
# AddQuestion -6. Skip compulsory field "other option 2" and handle error.txt
# AddQuestion -7. Skip compulsory field "other option 3" and handle error.txt
# AddQuestion -8. Cancel question creation and choose to stay.txt
# AddQuestion -9. Enter invalid sentence and handle error.txt
# AddQuestion -10. Leave page without saving question.txt
# AddQuestion -11. Cancel question creation and confirm cancellation.txt
# EditTest-1. Successful Test Edit.txt
# EditTest-2. Cancel Edit and Exit Without Saving.txt
# EditTest-5. Save Edited Test With Mandatory Fields Missing.txt
# EditTest-7. Edit Test With Special Characters in Vocabulary.txt
# EditTest-8. Edit Test With Maximum Length of Vocabulary.txt
# EditTest-9. Edit Test With Minimum Length of Vocabulary.txt
# Flashcard-1. Successful Navigation and Learning Flow.txt
# Flashcard-2. Navigation with Back Button and Stay Decision.txt
# Flashcard-3. Continue Studying After Completion.txt
# Flashcard-4. Direct Access to Incomplete Topic from Home Page.txt
# Flashcard-5. Attempt to Navigate to Previous Flashcard on First Card.txt
# Flashcard-6. Exit During Flashcard Study and Mark Topic as Incomplete.txt
# Handbook-1. View Vocabulary List.txt
# Handbook-2. Scroll Vocabulary List.txt
# Handbook-3. Search Vocabulary Successfully.txt
# Handbook-4. Search Meaningless Vocabulary.txt
# Handbook-5. Exclude Vocabulary from Review Test.txt
# Handbook-6. Include Vocabulary in Review Test.txt
# Learning days history-1. **View Continuous Learning Days Scenario** - This scenario covers the basic flow where a learner checks their continuous learning days without any interruptions in their learning streak..txt
# Learning days history-2. **View Learning Days After Break Scenario** - This scenario tests the functionality when a learner has recently broken their learning streak and checks their learning days, which should reset to one..txt
# ListenToPronunciation-1. Successful Pronunciation Test Completion.txt
# ListenToPronunciation-2. Incorrect Answer Selection.txt
# ListenToPronunciation-6. Attempting Test Without Being Logged In.txt
# ListenToPronunciation-8. Refreshing Page During Test.txt
# ListenToPronunciation-9. Closing Application During Test.txt
# ListenToPronunciation-11. Skipping Pronunciation Test Question.txt
# Login-1. Successful Login with Username.txt
# Login-2. Successful Login with Email.txt
# Login-3. Login with Wrong Password.txt
# Login-4. Login with Unregistered Username.txt
# Login-5. Login with Blank Username Field.txt
# Login-6. Login with Blank Password Field.txt
# Registry-1. Successful Registration with Valid Username and Password.txt
# Registry-2. Successful Registration with Email.txt
# Registry-4. Registration with Invalid Password.txt
# Registry-5. Registration with Existed Username.txt
# Registry-7. Registration with Password Same as Username.txt
# Registry-8. Registration with Username Below Minimum Length.txt
# Registry-9. Registration with Username Above Maximum Length.txt
# Registry-10. Registration with Password Below Minimum Length.txt
# Registry-11. Registration with Password Above Maximum Length.txt
# Registry-12. Registration with Email in Incorrect Format.txt
# Registry-13. Registration with Non-Existent Email Address.txt
# Review test-1. Successful Review Completion with Correct Answers.txt
# Review test-2. Review Completion with Incorrect Answers.txt
# Review test-3. Review Process with Mixed Correct and Incorrect Answers.txt
# Review test-4. Exiting Review and Returning to Continue.txt
# Review test-5. Exiting Review and Confirming Exit.txt
# Review test-6. Review with Questions Method.txt
# Review test-7. Review with Sound Method.txt
# Review test-8. Review with Image Method.txt
# Review test-9. Review with Meanings Method.txt
# Review test-10. Last Word Review and Return to Home Page.txt
# Review test-11. Review with No Words in Review List.txt
# WordSortingTest-1. Successful Word Sorting with Vocabulary Definition.txt
# WordSortingTest-2. Successful Word Sorting with Image Clue.txt
# WordSortingTest-3. Incorrect Word Sorting with Vocabulary Definition.txt
# WordSortingTest-4. Incorrect Word Sorting with Image Clue.txt
# WordSortingTest-8. Word Sorting with Fewer Letters than Required.txt
