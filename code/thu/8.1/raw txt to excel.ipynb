# %%
import os
import pandas as pd

def read_files_in_folder(folder_path):
    all_content = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                # Add file name
                all_content.append(filename)
                # Add file contents line by line
                lines = file.readlines()
                all_content.extend(lines)
                # Add a blank line to separate files
                all_content.append('')
    return all_content

def write_content_to_excel(content, excel_file_path):
    df = pd.DataFrame(content, columns=["Test Scenario"])
    df.to_excel(excel_file_path, index=False, engine='openpyxl')

def main():
    folder_path = r'D:\Dissertation-GPT\evaluate\baseline 2\matcha\ts'  # Change this to your folder path
    excel_file_path = 'output.xlsx'

    content = read_files_in_folder(folder_path)
    write_content_to_excel(content, excel_file_path)
    print(f"All file contents have been written to {excel_file_path}")

if __name__ == "__main__":
    main()
# Out:
# All file contents have been written to output.xlsx

# %%
import re
import pandas as pd
import os
import chardet

def read_file_content(file_path):
    # Detect the encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        return content
    except FileNotFoundError:
        return f"Error: The file at path {file_path} was not found."
    except UnicodeDecodeError:
        return f"Error: The file at path {file_path} cannot be decoded with the {encoding} encoding."
    except IOError:
        return f"Error: An I/O error occurred while reading the file at path {file_path}."

def split_before_and_after_hyphen(file_name):
    parts = file_name.split('-', 1)
    if len(parts) == 2:
        before_hyphen, after_hyphen = parts
    else:
        before_hyphen, after_hyphen = file_name, ""
    return before_hyphen.strip(), after_hyphen.strip()

# Function to parse the test cases from the text file
def parse_test_cases(file_name):
    # with open(file_name, 'r') as file:
    #     content = file.read()
    content = read_file_content(file_name)
    base_name = os.path.basename(file_name)

    base_nam = os.path.splitext(base_name)[0]

    # Extract use case and test scenario names from the file name
    use_case_name, test_scenario_name = split_before_and_after_hyphen(base_nam)
    
    # Regular expression to extract test cases
    test_case_pattern = re.compile(
        r"Test Case: (.*?)\ntestCaseName: (.*?)\nobjective: (.*?)\ntestSteps:\n(.*?)\nexpectedResult: (.*?)\n",
        re.DOTALL
    )
    
    matches = test_case_pattern.findall(content)
    
    test_cases = []
    for match in matches:
        test_case_name = match[1].strip()
        objective = match[2].strip()
        test_steps = match[3].strip().replace('\n', ' ')
        expected_result = match[4].strip()
        
        test_cases.append({
            'Use Case Name': use_case_name,
            'Test Scenario Name': test_scenario_name,
            'Test Case Name': test_case_name,
            'Objective': objective,
            'Test Steps': test_steps,
            'Expected Result': expected_result
        })
    
    return test_cases

# Function to write the parsed test cases to an Excel file
def write_to_excel(test_cases, output_file):
    df = pd.DataFrame(test_cases)
    df.to_excel(output_file, index=False)
all_test_cases = []

# File names
# input_file = 'use_case-test_scenario.txt'
output_file = 'test_cases.xlsx'
folder_path = r'D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping'
# Parse the test cases and write to Excel
file_list = os.listdir(folder_path)

def extract_number(filename):
    match = re.search(r'(\d+)', filename)
    return int(match.group(1)) if match else float('inf')

# Function to sort filenames naturally by the extracted number
def natural_sort_key(filename):
    # Split the filename into parts: prefix and number
    parts = re.split(r'(\d+)', filename)
    # Convert numerical parts to integers for proper numeric sorting
    parts[1::2] = map(int, parts[1::2])
    return parts

# Sort filenames using the natural sort key
sorted_files = sorted(file_list, key=natural_sort_key)

for i in sorted_files: 
    print(i)
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    print(file_path)
    if os.path.isfile(file_path):
        test_cases = parse_test_cases(file_path)
        print(test_cases)
        test_cases = parse_test_cases(file_path)
        all_test_cases.extend(test_cases)
write_to_excel(all_test_cases, output_file)
# Out:
# add to cart-1. Add Single Item Without Options to Cart.txt
# add to cart-2. Add Single Item With Options to Cart - Option Selected.txt
# add to cart-3. Add Multiple Quantities of an Item to Cart.txt
# add to cart-4. Add Item to Cart Without Selecting Available Options.txt
# add to cart-5. Add Item to Cart With Quantity Exceeding Stock.txt
# add to cart-6. Decrease Quantity to Less Than One.txt
# add to cart-7. Add Out of Stock Item to Cart.txt
# add to cart-8. Add Item With Out of Stock Option to Cart.txt
# add to cart-10. Add Multiple Different Items to Cart.txt
# checkout-1. Successful Checkout with Default Options.txt
# checkout-2. Checkout with Changed Shipping Address.txt
# checkout-3. Checkout with New Shipping Address.txt
# checkout-4. Checkout with Application Voucher Applied.txt
# checkout-5. Checkout with Shop Voucher Applied.txt
# checkout-6. Checkout with Changed Payment Method.txt
# checkout-7. Checkout with Changed Shipping Option.txt
# checkout-8. Checkout with Note for Shop Added.txt
# checkout-9. Checkout with No Default Shipping Address.txt
# checkout-10. Checkout with Incorrect Voucher Code.txt
# checkout-11. Checkout with Disabled Voucher.txt
# checkout-12. Checkout with Invalid Shipping Address Input.txt
# product information display-1. Display Product Information with All Details Present.txt
# product information display-3. Display Product Information with Out of Stock Status.txt
# product information display-4. Display Product Information with Special Discount Pricing.txt
# product information display-5. Expand Customer Reviews and Ratings Section.txt
# product information display-6. Expand Customer Questions Section.txt
# product information display-7. Scroll Through Related Product Cards.txt
# product information display-8. Contact Seller via Seller Contact Option.txt
# product information display-9. Visit Seller's Store via Store Link.txt
# product information display-10. Display Product Information with No Customer Reviews.txt
# product information display-11. Display Product Information with High Volume of Customer Reviews.txt
# product information display-12. Display Product Information with Negative Customer Reviews.txt
# product information display-13. Display Product Information with Varied Shipping Options.txt
# product information display-14. Display Product Information with Free Shipping Option.txt
# purchase-1. Successful Purchase from Shopping Cart with Multiple Items from Different Stores.txt
# purchase-2. Successful Purchase from Shopping Cart with Items from a Single Store.txt
# purchase-3. Successful Direct Purchase from Product Detail Page with Default Options.txt
# purchase-4. Successful Direct Purchase from Product Detail Page with Selected Options and Adjusted Quantity.txt
# purchase-5. Attempt to Purchase Out-of-Stock Item from Shopping Cart.txt
# purchase-6. Attempt to Purchase without Selecting Options in Product Detail Page.txt
# purchase-7. Attempt to Purchase with Quantity Exceeding Stock in Product Detail Page.txt
# purchase-8. Attempt to Purchase with Quantity Less Than One in Product Detail Page.txt
# purchase-9. Attempt to Purchase Out-of-Stock Product Directly from Product Detail Page.txt
# purchase-10. Attempt to Checkout with Invalid Selected Product in Shopping Cart.txt
# search-1. Successful Search with Product Name Keyword.txt
# search-2. Successful Search with Partial Product Name Keyword.txt
# search-3. Successful Search with Product Description Keyword.txt
# search-4. Successful Search with Shop Name Keyword.txt
# search-5. Successful Search with Brand Name Keyword.txt
# search-6. Search with Non-Matching Keyword.txt
# search-7. Search Result Pagination Navigation.txt
# search-8. Search and Filter by Most Related.txt
# search-9. Search and Filter by Newest Products.txt
# search-10. Search and Filter by Best Sellers.txt
# search-11. Search and Sort by Price Ascending.txt
# search-12. Search and Sort by Price Descending.txt
# search-13. No Search Results Found Scenario.txt
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-1. Add Single Item Without Options to Cart.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '1. Add Single Item Without Options to Cart', 'Test Case Name': 'Add Single Item Without Options to Cart', 'Objective': 'Verify that a user can add a single item without options to their shopping cart successfully.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item without options.   - Step 3: Click the 'Add to Cart' button.", 'Expected Result': 'The item is added to the shopping cart successfully, and the cart icon updates to reflect the new number of items in the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '1. Add Single Item Without Options to Cart', 'Test Case Name': 'Add Single Item Without Options to Cart with Quantity Adjustment', 'Objective': 'Verify that a user can adjust the quantity of a single item without options before adding it to their shopping cart.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item without options.   - Step 3: Adjust the quantity of the item using the plus button.   - Step 4: Click the 'Add to Cart' button.", 'Expected Result': 'The item, with the adjusted quantity, is added to the shopping cart successfully, and the cart icon updates to reflect the new number of items in the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '1. Add Single Item Without Options to Cart', 'Test Case Name': 'Prevent Adding Item Without Options Over Maximum Stock', 'Objective': 'Verify that the system prevents adding an item without options to the cart if the selected quantity exceeds the available stock.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item without options but with limited stock.   - Step 3: Attempt to increase the quantity beyond the available stock using the plus button.', 'Expected Result': "The plus button is disabled, and a message 'You have reached the maximum of the stock.' is displayed, preventing the addition of the item to the cart."}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '1. Add Single Item Without Options to Cart', 'Test Case Name': 'Prevent Adding Out of Stock Item Without Options to Cart', 'Objective': 'Verify that the system prevents adding an out-of-stock item without options to the shopping cart.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item without options that is out of stock.', 'Expected Result': "The 'Add to Cart' button is disabled or not visible, preventing the item from being added to the cart."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-2. Add Single Item With Options to Cart - Option Selected.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '2. Add Single Item With Options to Cart - Option Selected', 'Test Case Name': 'Add Single Item With Selected Option to Cart', 'Objective': 'Verify that a user can successfully add a single item with a selected option to their shopping cart', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item that has multiple options.   - Step 3: Select one available option for the product.   - Step 4: Click the "Add to Cart" button.', 'Expected Result': 'The system confirms that the item with the selected option has been added to the cart, and the cart icon updates to reflect the new number of items in the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '2. Add Single Item With Options to Cart - Option Selected', 'Test Case Name': 'Add Single Item With Selected Option and Adjusted Quantity to Cart', 'Objective': 'Verify that a user can adjust the quantity of a single item with a selected option before adding it to their shopping cart', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item that has multiple options and is available in stock.   - Step 3: Select one available option for the product.   - Step 4: Adjust the quantity of the product by clicking the plus button.   - Step 5: Click the "Add to Cart" button.', 'Expected Result': 'The system confirms that the item with the selected option and adjusted quantity has been added to the cart, and the cart icon updates to reflect the new number of items in the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '2. Add Single Item With Options to Cart - Option Selected', 'Test Case Name': 'Attempt to Add Item With Unselected Option to Cart', 'Objective': 'Verify that the system prevents the user from adding an item to the cart if an option has not been selected', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item that has multiple options.   - Step 3: Without selecting an option, click the "Add to Cart" button.', 'Expected Result': 'The system prevents the item from being added to the cart and prompts the user to select an option before proceeding.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '2. Add Single Item With Options to Cart - Option Selected', 'Test Case Name': 'Attempt to Add Item With Quantity Exceeding Stock to Cart', 'Objective': 'Verify that the system prevents the user from adding an item to the cart if the selected quantity exceeds the available stock', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item that has limited stock.   - Step 3: Select an available option for the product.   - Step 4: Attempt to increase the quantity beyond the available stock by clicking the plus button.', 'Expected Result': 'The plus button is disabled, and a message is displayed below the quantity field indicating "You have reached the maximum of the stock."'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-3. Add Multiple Quantities of an Item to Cart.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '3. Add Multiple Quantities of an Item to Cart', 'Test Case Name': 'Add Single Quantity of an Item to Cart', 'Objective': 'Verify that a user can add a single quantity of an item to their shopping cart', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform feature 'View a product detail'.   - Step 3: Click the 'Add to Cart' button.", 'Expected Result': "The item is successfully added to the user's shopping cart with a quantity of one, and the cart icon updates to reflect the new number of items."}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '3. Add Multiple Quantities of an Item to Cart', 'Test Case Name': 'Add Multiple Quantities of an Item to Cart', 'Objective': 'Verify that a user can add multiple quantities of an item to their shopping cart', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform feature 'View a product detail'.   - Step 3: Adjust the quantity of the product by clicking the plus button next to the quantity.   - Step 4: Click the 'Add to Cart' button.", 'Expected Result': "The item is successfully added to the user's shopping cart with the specified quantity, and the cart icon updates to reflect the new number of items."}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '3. Add Multiple Quantities of an Item to Cart', 'Test Case Name': 'Prevent Adding Item with Quantity Exceeding Stock', 'Objective': 'Verify that the system prevents adding an item to the cart with a quantity that exceeds the current stock', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform feature 'View a product detail' for a product with limited stock.   - Step 3: Attempt to adjust the quantity of the product beyond the available stock by clicking the plus button.   - Step 4: Click the 'Add to Cart' button.", 'Expected Result': "The plus button is disabled when the maximum stock is reached, a message 'You have reached the maximum of the stock' is displayed, and the item is not added to the cart."}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '3. Add Multiple Quantities of an Item to Cart', 'Test Case Name': 'Prevent Adding Out of Stock Item to Cart', 'Objective': 'Verify that the system prevents adding an out-of-stock item to the shopping cart', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform feature 'View a product detail' for an out-of-stock product.   - Step 3: Attempt to click the 'Add to Cart' button.", 'Expected Result': "The 'Add to Cart' button is disabled or not present, preventing the user from adding the out-of-stock item to the cart."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-4. Add Item to Cart Without Selecting Available Options.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '4. Add Item to Cart Without Selecting Available Options', 'Test Case Name': 'Add Item to Cart Without Selecting Available Options', 'Objective': 'Verify that the system prevents adding an item to the cart without selecting available options if the product has multiple options.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to a product detail page for an item with multiple options.   - Step 3: Without selecting any available options, click the "Add to Cart" button.', 'Expected Result': 'The system should display a message indicating that selecting an option is required before adding the item to the cart. The item should not be added to the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '4. Add Item to Cart Without Selecting Available Options', 'Test Case Name': 'Add Item to Cart With Options But Without Selecting One', 'Objective': 'Verify that the system prevents adding an item to the cart if the product has options but none is selected.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to a product detail page for an item that has options.   - Step 3: Attempt to add the item to the cart without selecting any of the available options.', 'Expected Result': 'The system should prevent the item from being added to the cart and display an error message prompting the user to select an option.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '4. Add Item to Cart Without Selecting Available Options', 'Test Case Name': 'Attempt to Add Out of Stock Item to Cart', 'Objective': 'Verify that the system prevents adding an out-of-stock item to the shopping cart.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to a product detail page for an item that is out of stock.   - Step 3: Attempt to add the out-of-stock item to the cart by clicking the "Add to Cart" button.', 'Expected Result': 'The system should display a message indicating the item is out of stock and prevent the item from being added to the cart.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-5. Add Item to Cart With Quantity Exceeding Stock.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '5. Add Item to Cart With Quantity Exceeding Stock', 'Test Case Name': 'Add Item to Cart With Quantity Exceeding Stock', 'Objective': 'Verify that the system prevents adding an item to the cart with a quantity exceeding the available stock and displays an appropriate message.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item with limited stock.   - Step 3: Attempt to increase the product quantity beyond the available stock by clicking the plus button next to the quantity.   - Step 4: Observe the behavior of the plus button and the message displayed.', 'Expected Result': "The plus button is disabled when the quantity reaches the maximum stock available, and a message 'You has reach maximum of the stock.' is displayed below the quantity field."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-6. Decrease Quantity to Less Than One.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '6. Decrease Quantity to Less Than One', 'Test Case Name': 'Decrease Quantity to Less Than One for a Single Option Product', 'Objective': 'Verify that the system prevents decreasing the product quantity to less than one for a product without options.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Navigate to a product detail page for a product without options.   - Step 3: Click the 'Add to Cart' button to add the product to the cart.   - Step 4: Access the shopping cart.   - Step 5: Attempt to decrease the product quantity to less than one by clicking the minus button next to the product quantity.", 'Expected Result': 'The minus button is disabled, and the product quantity remains at one, ensuring the quantity cannot be decreased to less than one.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '6. Decrease Quantity to Less Than One', 'Test Case Name': 'Decrease Quantity to Less Than One for a Product with Multiple Options', 'Objective': 'Verify that the system prevents decreasing the product quantity to less than one for a product with multiple options.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Navigate to a product detail page for a product with multiple options.   - Step 3: Select one available option.   - Step 4: Click the 'Add to Cart' button to add the product to the cart.   - Step 5: Access the shopping cart.   - Step 6: Attempt to decrease the product quantity to less than one by clicking the minus button next to the product quantity.", 'Expected Result': 'The minus button is disabled, and the product quantity remains at one, ensuring the quantity cannot be decreased to less than one for products with multiple options.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-7. Add Out of Stock Item to Cart.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '7. Add Out of Stock Item to Cart', 'Test Case Name': 'Add Out of Stock Single Option Item to Cart', 'Objective': 'Verify that users cannot add a single option item that is out of stock to their shopping cart.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item that is out of stock.   - Step 3: Attempt to click the "Add to Cart" button.', 'Expected Result': 'The "Add to Cart" button should be disabled or an error message should be displayed indicating that the item is out of stock and cannot be added to the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '7. Add Out of Stock Item to Cart', 'Test Case Name': 'Add Out of Stock Option of a Multi-Option Product to Cart', 'Objective': 'Verify that users cannot add an out of stock option of a product with multiple options to their shopping cart.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item with multiple options, where at least one option is out of stock.   - Step 3: Select the out of stock option.   - Step 4: Attempt to click the "Add to Cart" button.', 'Expected Result': 'The "Add to Cart" button should be disabled for the out of stock option, or an error message should be displayed indicating that the selected option is out of stock and cannot be added to the cart.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-8. Add Item With Out of Stock Option to Cart.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '8. Add Item With Out of Stock Option to Cart', 'Test Case Name': 'Add Item With Out of Stock Option to Cart', 'Objective': 'Verify that the system prevents adding an item with an out of stock option to the shopping cart', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item with multiple options, where at least one option is out of stock.   - Step 3: Attempt to select the out of stock option for the item.   - Step 4: Click the "Add to Cart" button.', 'Expected Result': 'The system should prevent the item from being added to the cart, possibly displaying a message indicating that the option is out of stock.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '8. Add Item With Out of Stock Option to Cart', 'Test Case Name': 'Add Item With In-Stock Option to Cart When Another Option is Out of Stock', 'Objective': 'Verify that the system allows adding an item to the shopping cart when selecting an in-stock option, even if another option for the same item is out of stock', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item with multiple options, where at least one option is in stock and another is out of stock.   - Step 3: Select an in-stock option for the item.   - Step 4: Click the "Add to Cart" button.', 'Expected Result': 'The system adds the item with the selected in-stock option to the shopping cart and updates the cart icon to reflect the new number of items.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '8. Add Item With Out of Stock Option to Cart', 'Test Case Name': 'Attempt to Add Item to Cart Without Selecting Any Option When Multiple Options Exist', 'Objective': 'Verify that the system prevents adding an item to the shopping cart without selecting any available option when the item has multiple options', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item that has multiple options.   - Step 3: Without selecting any option, click the "Add to Cart" button.', 'Expected Result': 'The system should prevent the item from being added to the cart and prompt the user to select an option.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\add to cart-10. Add Multiple Different Items to Cart.txt
# [{'Use Case Name': 'add to cart', 'Test Scenario Name': '10. Add Multiple Different Items to Cart', 'Test Case Name': 'Add Single Item with Default Quantity to Cart', 'Objective': 'Verify that a user can add a single item with default quantity to their shopping cart successfully.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of the item to be added.   - Step 3: Click the 'Add to Cart' button without adjusting the quantity.   - Step 4: Confirm the addition if any confirmation dialog appears.", 'Expected Result': 'The item is added to the shopping cart successfully, and the cart icon updates to reflect the new number of items in the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '10. Add Multiple Different Items to Cart', 'Test Case Name': 'Add Multiple Different Items to Cart', 'Objective': 'Verify that a user can add multiple different items to their shopping cart successfully.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of the first item to be added.   - Step 3: Click the 'Add to Cart' button for the first item.   - Step 4: Navigate to the product detail page of the second item to be added.   - Step 5: Click the 'Add to Cart' button for the second item.   - Step 6: Repeat steps 2-5 for any additional items to be added.", 'Expected Result': 'All selected items are added to the shopping cart successfully, and the cart icon updates to reflect the total number of items in the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '10. Add Multiple Different Items to Cart', 'Test Case Name': 'Add Item with Selected Options to Cart', 'Objective': 'Verify that a user can add an item with selected options (e.g., size, color) to their shopping cart successfully.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of an item that has multiple options.   - Step 3: Select one available option for the item.   - Step 4: Click the 'Add to Cart' button.   - Step 5: Confirm the addition if any confirmation dialog appears.", 'Expected Result': 'The item, with the selected option, is added to the shopping cart successfully, and the cart icon updates to reflect the new number of items in the cart.'}, {'Use Case Name': 'add to cart', 'Test Scenario Name': '10. Add Multiple Different Items to Cart', 'Test Case Name': 'Add Item with Adjusted Quantity to Cart', 'Objective': 'Verify that a user can adjust the quantity of an item before adding it to their shopping cart successfully.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Navigate to the product detail page of the item to be added.   - Step 3: Adjust the quantity of the item using the plus or minus button.   - Step 4: Click the 'Add to Cart' button after adjusting the quantity.   - Step 5: Confirm the addition if any confirmation dialog appears.", 'Expected Result': 'The item, with the adjusted quantity, is added to the shopping cart successfully, and the cart icon updates to reflect the new number of items in the cart.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-1. Successful Checkout with Default Options.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '1. Successful Checkout with Default Options', 'Test Case Name': 'Successful Checkout with Default Options', 'Objective': 'Verify that a user can successfully checkout using the default shipping address, payment method, and shipping option without applying any vouchers.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate the checkout process.   - Step 3: Verify that the order summary is displayed, including items, quantities, prices, and total cost.   - Step 4: Confirm that the shipping address is set to the default address.   - Step 5: Confirm that the default payment method is set to COD (Cash on Delivery).   - Step 6: Do not apply any application or shop vouchers.   - Step 7: Confirm that the default shipping option is set to Standard Express.   - Step 8: Do not add any note for the shop.   - Step 9: Review the order details to ensure all information is correct and reflects the default options.   - Step 10: Click on the 'Place Order' button.   - Step 11: Confirm that the payment is processed and the order is confirmed.   - Step 12: Verify that the order confirmation and details are displayed.", 'Expected Result': 'The user successfully completes the checkout process with default options, and receives an order confirmation with all the details correctly displayed.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-2. Checkout with Changed Shipping Address.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '2. Checkout with Changed Shipping Address', 'Test Case Name': 'Checkout with Changed Shipping Address - Using Saved Address', 'Objective': 'Verify that the user can change the shipping address to a saved address during checkout.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: On the order summary page, click the 'Change Shipping Address' button.   - Step 4: From the list of saved addresses, select a different address than the default one.   - Step 5: Review the updated order summary to ensure the shipping address has been updated.   - Step 6: Complete the checkout process by clicking on the 'Place Order' button.", 'Expected Result': 'The order is successfully placed with the newly selected shipping address, and the user receives an order confirmation with the updated address details.'}, {'Use Case Name': 'checkout', 'Test Scenario Name': '2. Checkout with Changed Shipping Address', 'Test Case Name': 'Checkout with Changed Shipping Address - Adding a New Address', 'Objective': 'Verify that the user can add and select a new shipping address during checkout.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: On the order summary page, click the 'Change Shipping Address' button.   - Step 4: Click on the option to add a new address.   - Step 5: Fill in the new address form with valid details, including full name, phone number, city, district, ward, location's address, and address type (optional).   - Step 6: Click the 'Finish' button to save the new address.   - Step 7: Ensure the new address is selected as the shipping address.   - Step 8: Review the updated order summary to ensure the shipping address has been updated to the new address.   - Step 9: Complete the checkout process by clicking on the 'Place Order' button.", 'Expected Result': 'The order is successfully placed with the new shipping address, and the user receives an order confirmation with the new address details.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-3. Checkout with New Shipping Address.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '3. Checkout with New Shipping Address', 'Test Case Name': 'Checkout with New Shipping Address', 'Objective': 'Verify that the user can add a new shipping address during the checkout process and successfully place an order with it.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate the checkout process.   - Step 3: On the order summary page, click the button to change the shipping address.   - Step 4: Click on 'Add new address'.   - Step 5: Fill in the form with a new shipping address, ensuring all fields meet the specified requirements (Full name, phone number in the correct format, select city, district, ward from the dropdown, enter a valid location's address, and optionally select an address type).   - Step 6: Click the 'Finish' button to add the new shipping address.   - Step 7: Continue with the checkout process by selecting a payment method.   - Step 8: Optionally apply a valid voucher code.   - Step 9: Select a shipping option.   - Step 10: Add a note for the shop if necessary.   - Step 11: Review the updated total cost and order details.   - Step 12: Click on the 'Place Order' button.", 'Expected Result': 'The system should process the payment, confirm the order with the new shipping address, and display the order confirmation and details.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-4. Checkout with Application Voucher Applied.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '4. Checkout with Application Voucher Applied', 'Test Case Name': 'Checkout with Application Voucher Applied Successfully', 'Objective': 'Verify that a user can successfully apply an application voucher during checkout and the total cost is updated accordingly.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: Review the order summary displayed by the system, including items, quantities, prices, and total cost.   - Step 4: Confirm the shipping address is set as the default address or change/add a new shipping address if necessary.   - Step 5: Confirm the payment method is set to COD or select a new payment method if desired.   - Step 6: Apply an application voucher by selecting an available voucher or entering a valid voucher code.   - Step 7: Confirm the shipping option is set to Standard Express or change the shipping option if desired.   - Step 8: Optionally, add a note for the shop.   - Step 9: Review the updated total cost reflecting the application voucher discount.   - Step 10: Click on the "Place Order" button.   - Step 11: Confirm the order is processed and an order confirmation is displayed.', 'Expected Result': 'The order is successfully placed with the application voucher applied, and the total cost is updated to reflect the discount. An order confirmation is displayed.'}, {'Use Case Name': 'checkout', 'Test Scenario Name': '4. Checkout with Application Voucher Applied', 'Test Case Name': 'Checkout with Invalid Application Voucher Code', 'Objective': 'Verify that the system prevents the user from applying an invalid application voucher code and displays an appropriate error message.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: Attempt to apply an application voucher by entering an invalid voucher code.   - Step 4: Click on the 'apply' button after entering the invalid voucher code.", 'Expected Result': 'The system displays an error message indicating the voucher code is invalid and does not apply any discount to the total cost.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-5. Checkout with Shop Voucher Applied.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '5. Checkout with Shop Voucher Applied', 'Test Case Name': 'Checkout with Shop Voucher Applied Successfully', 'Objective': 'Verify that a user can successfully apply a shop voucher during checkout and the total cost is updated accordingly.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: On the order summary page, select an available shop voucher or enter a valid shop voucher code.   - Step 4: Click the 'apply' button to apply the shop voucher.   - Step 5: Review the updated total cost to ensure the shop voucher discount has been applied.   - Step 6: Click on the 'Place Order' button to complete the purchase.", 'Expected Result': 'The shop voucher is successfully applied, the total cost is updated to reflect the discount, and the order is placed successfully with an order confirmation displayed.'}, {'Use Case Name': 'checkout', 'Test Scenario Name': '5. Checkout with Shop Voucher Applied', 'Test Case Name': 'Checkout with Invalid Shop Voucher Code', 'Objective': 'Verify that the system prevents the user from applying an invalid shop voucher code and displays an appropriate error message.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: On the order summary page, enter an invalid shop voucher code.   - Step 4: Click the 'apply' button to attempt to apply the invalid shop voucher.", 'Expected Result': 'The system displays an error message indicating the shop voucher code is invalid and does not apply any discount to the total cost.'}, {'Use Case Name': 'checkout', 'Test Scenario Name': '5. Checkout with Shop Voucher Applied', 'Test Case Name': 'Checkout with Disabled Shop Voucher', 'Objective': 'Verify that the system prevents the user from applying a disabled shop voucher and displays an appropriate error message.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: On the order summary page, select or enter a code for a disabled shop voucher.   - Step 4: Click the 'apply' button to attempt to apply the disabled shop voucher.", 'Expected Result': 'The system displays an error message indicating the shop voucher is disabled and does not apply any discount to the total cost.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-6. Checkout with Changed Payment Method.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '6. Checkout with Changed Payment Method', 'Test Case Name': 'Checkout with Changed Payment Method from Default', 'Objective': 'Verify that the user can change the payment method from the default (COD) to another option (e.g., Shopee Pay, Google Pay, credit) during the checkout process and successfully place an order.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate the checkout process.   - Step 3: On the order summary page, observe the default payment method set to COD.   - Step 4: Change the payment method by selecting an alternative option (e.g., Shopee Pay).   - Step 5: Review the updated order details with the new payment method.   - Step 6: Click on the 'Place Order' button.   - Step 7: Observe the system processing the payment with the selected payment method.   - Step 8: Verify the order confirmation and details are displayed.", 'Expected Result': 'The system should successfully process the payment with the new selected payment method, and the user should receive an order confirmation with the details reflecting the chosen payment method.'}, {'Use Case Name': 'checkout', 'Test Scenario Name': '6. Checkout with Changed Payment Method', 'Test Case Name': 'Checkout with Changed Payment Method and Apply Voucher', 'Objective': 'Verify that the user can change the payment method and apply a voucher code successfully during the checkout process.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate the checkout process.   - Step 3: On the order summary page, change the payment method from the default COD to another option (e.g., credit).   - Step 4: Apply a valid shop or application voucher by entering the voucher code and clicking 'apply'.   - Step 5: Review the updated order details with the new payment method and applied voucher discount.   - Step 6: Click on the 'Place Order' button.   - Step 7: Observe the system processing the payment with the selected payment method and applied discount.   - Step 8: Verify the order confirmation and details are displayed, including the discount from the voucher.", 'Expected Result': 'The system should successfully process the payment with the new selected payment method and apply the voucher discount. The user should receive an order confirmation with the details reflecting the chosen payment method and the discount applied.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-7. Checkout with Changed Shipping Option.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '7. Checkout with Changed Shipping Option', 'Test Case Name': 'Checkout with Changed Shipping Option', 'Objective': 'Verify that the user can change the shipping option during checkout and complete the purchase successfully.', 'Test Steps': '- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: On the order summary page, observe the default shipping option set as Standard Express.   - Step 4: Click on the shipping option change button to view available shipping options.   - Step 5: Select a different shipping option from the list of available options.   - Step 6: Review the updated total cost reflecting the change in shipping option.   - Step 7: Click on the "Place Order" button to complete the purchase.', 'Expected Result': "The system should update the order's total cost based on the new shipping option, process the payment, and display an order confirmation with the details including the updated shipping option."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-8. Checkout with Note for Shop Added.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '8. Checkout with Note for Shop Added', 'Test Case Name': 'Checkout with Note for Shop Added', 'Objective': 'Verify that the user can add a note for the shop during the checkout process and successfully place an order with the note included.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate the checkout process.   - Step 3: Review the order summary displayed by the system, including items, quantities, prices, and total cost.   - Step 4: Confirm the shipping address is set as default or change/add a new shipping address if necessary.   - Step 5: Confirm the payment method is set to COD or select a new payment method (e.g., Shopee Pay, Google Pay, credit).   - Step 6: Optionally add an application voucher or shop voucher to the order.   - Step 7: Confirm the shipping option is set to Standard Express or change the shipping option if desired.   - Step 8: Add a note for the shop in the provided field.   - Step 9: Review the updated total cost and order details.   - Step 10: Click on the 'Place Order' button.   - Step 11: Wait for the system to process the payment and confirm the order.   - Step 12: Review the order confirmation and details displayed by the system.", 'Expected Result': 'The order is successfully placed with the note for the shop included, and the user receives an order confirmation with the note details.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-9. Checkout with No Default Shipping Address.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '9. Checkout with No Default Shipping Address', 'Test Case Name': 'Checkout with No Default Shipping Address - Adding New Address', 'Objective': 'Verify that the system forces the user to add a new shipping address when there is no default shipping address during checkout.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: Observe if the system prompts for adding a new shipping address due to the absence of a default shipping address.   - Step 4: Click on the button to add a new shipping address.   - Step 5: Fill in the form with valid details: Full name, phone number, city, district, ward, location's address, and address type (optional).   - Step 6: Click the 'Finish' button to add the new shipping address.", 'Expected Result': 'The system successfully adds the new shipping address and allows the user to proceed with the checkout process.'}, {'Use Case Name': 'checkout', 'Test Scenario Name': '9. Checkout with No Default Shipping Address', 'Test Case Name': 'Checkout with No Default Shipping Address - Invalid Address Input', 'Objective': 'Verify that the system prevents the user from adding a new shipping address with invalid inputs.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Add items to the shopping cart and proceed to checkout.   - Step 3: Attempt to add a new shipping address by clicking the appropriate button.   - Step 4: Fill in the shipping address form with invalid details (e.g., less than 2 letters for the full name, incorrect phone number format).   - Step 5: Click the 'Finish' button to attempt adding the new shipping address.", 'Expected Result': 'The system displays a notification about the incorrect input and prevents the user from adding the new shipping address.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-10. Checkout with Incorrect Voucher Code.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '10. Checkout with Incorrect Voucher Code', 'Test Case Name': 'Checkout with Incorrect Voucher Code', 'Objective': 'Verify that the system prevents the user from applying an incorrect voucher code during the checkout process and displays an appropriate error message.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate the checkout process.   - Step 3: On the order summary page, select or confirm the shipping address.   - Step 4: Choose the default payment method or select a new payment method.   - Step 5: Attempt to add a voucher by entering an incorrect voucher code into the voucher code field.   - Step 6: Click the 'apply' button after entering the incorrect voucher code.", 'Expected Result': 'The system should display an error message indicating that the voucher code is incorrect and prevent the application of the discount to the order.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-11. Checkout with Disabled Voucher.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '11. Checkout with Disabled Voucher', 'Test Case Name': 'Checkout with Disabled Voucher', 'Objective': 'Verify that the system prevents the user from adding a disabled voucher during the checkout process and displays an appropriate message.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate the checkout process.   - Step 3: Proceed through the checkout process until the step to add a voucher.   - Step 4: Attempt to add a disabled voucher by entering the voucher code.   - Step 5: Click on the 'apply' button after entering the disabled voucher code.", 'Expected Result': 'The system should prevent the addition of the disabled voucher and display a message indicating that the voucher cannot be added.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\checkout-12. Checkout with Invalid Shipping Address Input.txt
# [{'Use Case Name': 'checkout', 'Test Scenario Name': '12. Checkout with Invalid Shipping Address Input', 'Test Case Name': 'Checkout with Invalid Shipping Address - Invalid Full Name', 'Objective': 'Verify that the system prevents the user from adding a new shipping address with an invalid full name during checkout.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate checkout.   - Step 3: Click on the button to change the shipping address.   - Step 4: Select the option to add a new shipping address.   - Step 5: Fill in the full name field with a single letter (invalid input).   - Step 6: Fill in the rest of the form with valid information.   - Step 7: Click the 'Finish' button to add the new shipping address.", 'Expected Result': 'The system displays a notification indicating the full name is invalid and prevents the user from adding the new shipping address.'}, {'Use Case Name': 'checkout', 'Test Scenario Name': '12. Checkout with Invalid Shipping Address Input', 'Test Case Name': 'Checkout with Invalid Shipping Address - Invalid Phone Number', 'Objective': 'Verify that the system prevents the user from adding a new shipping address with an invalid phone number during checkout.', 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate checkout.   - Step 3: Click on the button to change the shipping address.   - Step 4: Select the option to add a new shipping address.   - Step 5: Fill in the phone number field with an incorrect format (e.g., missing country code or incorrect number of digits).   - Step 6: Fill in the rest of the form with valid information.   - Step 7: Click the 'Finish' button to add the new shipping address.", 'Expected Result': 'The system displays a notification indicating the phone number is invalid and prevents the user from adding the new shipping address.'}, {'Use Case Name': 'checkout', 'Test Scenario Name': '12. Checkout with Invalid Shipping Address Input', 'Test Case Name': 'Checkout with Invalid Shipping Address - Unidentifiable Location', 'Objective': "Verify that the system prevents the user from adding a new shipping address with a location's address that cannot be identified on the map during checkout.", 'Test Steps': "- Step 1: Log into the Shopee account.   - Step 2: Perform the 'Purchase' feature to initiate checkout.   - Step 3: Click on the button to change the shipping address.   - Step 4: Select the option to add a new shipping address.   - Step 5: Fill in the location's address field with an address that cannot be identified on the map.   - Step 6: Fill in the rest of the form with valid information.   - Step 7: Click the 'Finish' button to add the new shipping address.", 'Expected Result': "The system displays a notification indicating the location's address cannot be identified and prevents the user from adding the new shipping address."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\product information display-1. Display Product Information with All Details Present.txt
# ...
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-3. Successful Search with Product Description Keyword.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '3. Successful Search with Product Description Keyword', 'Test Case Name': 'Successful Search with Product Description Keyword', 'Objective': 'Verify that the system displays relevant product cards when a user searches using a keyword related to product descriptions', 'Test Steps': "- Step 1: Navigate to the search bar on the platform.   - Step 2: Type a keyword that is known to be part of a product's description but not necessarily in the product's name.   - Step 3: Press enter or click the search icon to initiate the search.", 'Expected Result': "The system displays a list of product cards where each product's name or description includes or is related to the keyword. The results should prioritize exact matches by name, followed by partial matches by name, and then matches by description. A maximum of 60 product cards are shown per page with a pagination bar at the bottom."}, {'Use Case Name': 'search', 'Test Scenario Name': '3. Successful Search with Product Description Keyword', 'Test Case Name': 'Successful Search with Product Description Keyword and Pagination Interaction', 'Objective': 'Verify that users can navigate through pages of search results using the pagination bar when they search using a keyword related to product descriptions', 'Test Steps': "- Step 1: Navigate to the search bar on the platform.   - Step 2: Type a keyword that is known to be part of a product's description but not necessarily in the product's name.   - Step 3: Press enter or click the search icon to initiate the search.   - Step 4: Once the search results are displayed, scroll down to the pagination bar at the bottom of the page.   - Step 5: Click on the right arrow button to move to the next page of search results.", 'Expected Result': "The system displays the next page of product cards relevant to the search keyword. Each product's name or description includes or is related to the keyword, ensuring continuity in the relevance of search results across pages."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-4. Successful Search with Shop Name Keyword.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '4. Successful Search with Shop Name Keyword', 'Test Case Name': 'Successful Search with Shop Name Keyword', 'Objective': "Verify that the system displays the shop's information, shop product cards, and related product cards when a user searches using a shop name keyword.", 'Test Steps': '- Step 1: Navigate to the search bar on the platform.   - Step 2: Type a keyword that is known to be a shop name into the search bar.   - Step 3: Press enter or click the search icon to initiate the search.', 'Expected Result': "The system should display the shop's information at the top of the search result including shop name, number of items, ratings, and response rate, average response time. Below the shop's information, shop product cards followed by related product cards (products with names matching the search keyword) should be displayed."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-5. Successful Search with Brand Name Keyword.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '5. Successful Search with Brand Name Keyword', 'Test Case Name': 'Successful Search with Brand Name Keyword', 'Objective': "Verify that the system displays the most related/best sold shop's information and related product cards when a brand name keyword is entered in the search bar.", 'Test Steps': '- Step 1: Navigate to the search bar on the application.   - Step 2: Type a brand name keyword into the search bar.   - Step 3: Press enter or click the search icon to initiate the search.', 'Expected Result': "The system should display the most related/best sold shop's information that sells the brand at the top of the search result, including shop name, number of items, ratings, and response rate, average response time. Below the shop's information, related product cards (products with names matching the search keyword) should be displayed."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-6. Search with Non-Matching Keyword.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '6. Search with Non-Matching Keyword', 'Test Case Name': 'Search with Non-Matching Keyword and Verify Result', 'Objective': 'Verify that the system displays random product cards when a non-matching keyword is entered in the search bar.', 'Test Steps': '- Step 1: Navigate to the search bar on the platform.   - Step 2: Enter a keyword that does not match any product, shop, or brand name in the search bar.   - Step 3: Press enter or click the search icon.', 'Expected Result': 'The system should display random product cards as no search results are found matching the keyword.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-7. Search Result Pagination Navigation.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '7. Search Result Pagination Navigation', 'Test Case Name': 'Search Result Pagination Navigation - Basic Navigation', 'Objective': 'Verify that users can navigate through search result pages using the pagination bar.', 'Test Steps': '- Step 1: Click on the search bar.   - Step 2: Type a keyword in the search bar that will yield more than 60 results.   - Step 3: Press enter or click the search icon.   - Step 4: Scroll down to the bottom of the search results page to locate the pagination bar.   - Step 5: Click on the right arrow button in the pagination bar to move to the next page.   - Step 6: Once on the new page, click on a specific page number in the pagination bar.   - Step 7: Finally, click on the left arrow button in the pagination bar to return to the previous page.', 'Expected Result': 'The user should be able to navigate to the next page, a specific page, and back to the previous page using the pagination bar, with each page displaying up to 60 product cards.'}, {'Use Case Name': 'search', 'Test Scenario Name': '7. Search Result Pagination Navigation', 'Test Case Name': 'Search Result Pagination Navigation - Navigation with No Results', 'Objective': 'Verify the pagination behavior when the search results are empty.', 'Test Steps': '- Step 1: Click on the search bar.   - Step 2: Type a keyword in the search bar that is unlikely to yield any results.   - Step 3: Press enter or click the search icon.', 'Expected Result': 'The system should display random product cards due to the absence of search results, and the pagination bar should either be hidden or disabled since there are no additional pages to navigate.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-8. Search and Filter by Most Related.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '8. Search and Filter by Most Related', 'Test Case Name': 'Search and Filter by Most Related', 'Objective': 'Verify that the system prioritizes search results based on the most related to the keyword entered by the user, focusing on exact name matches, partial name matches, and then matches by description.', 'Test Steps': "- Step 1: Click on the search bar.   - Step 2: Type a specific keyword related to a product name in the search bar.   - Step 3: Press enter or click the search icon.   - Step 4: Observe the list of search results.   - Step 5: Ensure the 'result most related with the keyword' radio button is selected by default.", 'Expected Result': 'The search results should be displayed prioritizing products that exactly match the keyword by name, followed by products that partially match the keyword by name, and finally products that match by description.'}, {'Use Case Name': 'search', 'Test Scenario Name': '8. Search and Filter by Most Related', 'Test Case Name': 'Search with Keyword Related to Shop Name', 'Objective': "Verify that the system displays shop information at the top of the search results when the keyword is related to a shop name, followed by the shop's product cards and related product cards.", 'Test Steps': '- Step 1: Click on the search bar.   - Step 2: Type a keyword that is known to be related to a shop name in the search bar.   - Step 3: Press enter or click the search icon.   - Step 4: Observe the search results.', 'Expected Result': "The search results should display the shop's information at the top, including shop name, number of items, ratings, and response rate, average response time, followed by the shop's product cards and related product cards."}, {'Use Case Name': 'search', 'Test Scenario Name': '8. Search and Filter by Most Related', 'Test Case Name': 'Search with Keyword Not Matching Any Shop or Brand', 'Objective': 'Verify that the system displays related product cards when the search keyword does not match any shop or brand name.', 'Test Steps': '- Step 1: Click on the search bar.   - Step 2: Type a keyword that does not match any shop or brand name in the search bar.   - Step 3: Press enter or click the search icon.   - Step 4: Observe the search results.', 'Expected Result': "The search results should only display related product cards based on the keyword's match with product names or descriptions."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-9. Search and Filter by Newest Products.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '9. Search and Filter by Newest Products', 'Test Case Name': 'Search and Filter by Newest Products', 'Objective': 'Verify that the user can search for products and filter the results by the newest products.', 'Test Steps': "- Step 1: Navigate to the main page of the application.   - Step 2: Click on the search bar.   - Step 3: Type a keyword related to products in the search bar.   - Step 4: Press enter or click the search icon to initiate the search.   - Step 5: Once the search results are displayed, locate the filter options.   - Step 6: Select the radio button for 'newest product result' to filter the search results.", 'Expected Result': 'The search results should be filtered to display products sorted by their release date, starting with the newest products.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-10. Search and Filter by Best Sellers.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '10. Search and Filter by Best Sellers', 'Test Case Name': 'Search and Filter by Best Sellers', 'Objective': 'Verify that the user can search for products and filter the results by best sellers', 'Test Steps': "- Step 1: Navigate to the search bar on the homepage.   - Step 2: Type a keyword related to products in the search bar.   - Step 3: Press enter or click the search icon to initiate the search.   - Step 4: Once the search results are displayed, locate the filter options.   - Step 5: Select the 'best seller result' radio button to filter the search results.", 'Expected Result': 'The search results should be filtered to display products sorted by best sellers, prioritizing products with higher sales.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-11. Search and Sort by Price Ascending.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '11. Search and Sort by Price Ascending', 'Test Case Name': 'Search and Verify Sort by Price Ascending', 'Objective': 'Verify that the user can search for products and sort the results by price in ascending order.', 'Test Steps': '- Step 1: Navigate to the search bar on the homepage.   - Step 2: Type a keyword related to the products you wish to find in the search bar.   - Step 3: Press enter or click the search icon to initiate the search.   - Step 4: After the search results are displayed, locate the sort option dropdown.   - Step 5: Select the option to sort products by price from lowest to highest.', 'Expected Result': 'The products in the search results should be sorted by price in ascending order, starting with the lowest priced item.'}, {'Use Case Name': 'search', 'Test Scenario Name': '11. Search and Sort by Price Ascending', 'Test Case Name': 'Search with Keyword Related to Shop Name and Sort by Price Ascending', 'Objective': "Verify that searching with a keyword related to a shop name displays the shop's information and products, and allows sorting by price in ascending order.", 'Test Steps': "- Step 1: Navigate to the search bar on the homepage.   - Step 2: Type a keyword that is known to be related to a shop name in the search bar.   - Step 3: Press enter or click the search icon to initiate the search.   - Step 4: Observe the shop's information displayed at the top of the search results.   - Step 5: Locate the sort option dropdown below the search bar or near the top of the search results.   - Step 6: Select the option to sort products by price from lowest to highest.", 'Expected Result': "The shop's information is displayed at the top, followed by the shop's product cards and related product cards, all sorted by price in ascending order."}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-12. Search and Sort by Price Descending.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '12. Search and Sort by Price Descending', 'Test Case Name': 'Search and Sort Products by Price Descending', 'Objective': 'Verify that the user can search for products and sort the results by price in descending order.', 'Test Steps': '- Step 1: Navigate to the search bar on the homepage.   - Step 2: Type a keyword related to the products you want to search for in the search bar.   - Step 3: Press enter or click the search icon to initiate the search.   - Step 4: After the search results are displayed, locate the sort option dropdown.   - Step 5: Select the option to sort products by price from highest to lowest.', 'Expected Result': 'The search results should be displayed with products sorted by price in descending order, starting with the highest priced item.'}]
# D:\Dissertation-GPT\evaluate\baseline 3 1.8\shopping\search-13. No Search Results Found Scenario.txt
# [{'Use Case Name': 'search', 'Test Scenario Name': '13. No Search Results Found Scenario', 'Test Case Name': 'Verify No Search Results Found displays random products', 'Objective': 'Ensure that when no search results are found, the system displays random product cards as per the exception flow.', 'Test Steps': '- Step 1: Navigate to the search bar on the application.   - Step 2: Enter a keyword that does not match any products, shops, or brands in the search bar.   - Step 3: Press enter or click the search icon.', 'Expected Result': 'The system should display random product cards indicating no direct search results were found for the entered keyword.'}]

# %%
import pandas as pd

# Load the Excel file
file_path = 'output_file.xlsx'  # Replace with your file path
df = pd.read_excel(file_path)

# Define the condition for keeping rows
condition = (df['Valid'].notna()) | (df['Test Scenario'].str.contains('txt', na=False))

# Apply the condition to filter the DataFrame
df_cleaned = df[condition]

# Save the cleaned data to a new Excel file
df_cleaned.to_excel('cleaned_file.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 # Load the Excel file
#       4 file_path = 'output_file.xlsx'  # Replace with your file path
# ----> 5 df = pd.read_excel(file_path)
#       7 # Define the condition for keeping rows
#       8 condition = (df['Valid'].notna()) | (df['Test Scenario'].str.contains('txt', na=False))
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1695, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1692 self.engine = engine
#    1693 self.storage_options = storage_options
# -> 1695 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:557, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     547 """
#     548 Reader using openpyxl engine.
#     549
#    (...)
#     554 {storage_options}
#     555 """
#     556 import_optional_dependency("openpyxl")
# --> 557 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:545, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     543 self.handles.handle.seek(0)
#     544 try:
# --> 545     self.book = self.load_workbook(self.handles.handle)
#     546 except Exception:
#     547     self.close()
#
# File e:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_openpyxl.py:568, in OpenpyxlReader.load_workbook(self, filepath_or_buffer)
#     565 def load_workbook(self, filepath_or_buffer: FilePath | ReadBuffer[bytes]):
#     566     from openpyxl import load_workbook
# --> 568     return load_workbook(
#     569         filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     570     )
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:317, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     290 """Open the given filename and return the workbook
#     291
#     292 :param filename: the path to open or a file-like object
#    (...)
#     313
#     314 """
#     315 reader = ExcelReader(filename, read_only, keep_vba,
#     316                     data_only, keep_links)
# --> 317 reader.read()
#     318 return reader.wb
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:279, in ExcelReader.read(self)
#     277 self.read_strings()
#     278 self.read_workbook()
# --> 279 self.read_properties()
#     280 self.read_theme()
#     281 apply_stylesheet(self.archive, self.wb)
#
# File e:\ProgramData\anaconda3\lib\site-packages\openpyxl\reader\excel.py:172, in ExcelReader.read_properties(self)
#     170 def read_properties(self):
#     171     if ARC_CORE in self.valid_files:
# --> 172         src = fromstring(self.archive.read(ARC_CORE))
#     173         self.wb.properties = DocumentProperties.from_tree(src)
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:1475, in ZipFile.read(self, name, pwd)
#    1473 def read(self, name, pwd=None):
#    1474     """Return file bytes for name."""
# -> 1475     with self.open(name, "r", pwd) as fp:
#    1476         return fp.read()
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:1530, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1526 zef_file = _SharedFile(self.fp, zinfo.header_offset,
#    1527                        self._fpclose, self._lock, lambda: self._writing)
#    1528 try:
#    1529     # Skip the file header:
# -> 1530     fheader = zef_file.read(sizeFileHeader)
#    1531     if len(fheader) != sizeFileHeader:
#    1532         raise BadZipFile("Truncated file header")
#
# File e:\ProgramData\anaconda3\lib\zipfile.py:745, in _SharedFile.read(self, n)
#     741     raise ValueError("Can't read from the ZIP file while there "
#     742             "is an open writing handle on it. "
#     743             "Close the writing handle before trying to read.")
#     744 self._file.seek(self._pos)
# --> 745 data = self._file.read(n)
#     746 self._pos = self._file.tell()
#     747 return data
#
# KeyboardInterrupt:

# %%
import pandas as pd
import json

# Load the Excel file
file_path = 'cleaned_file.xlsx'
df = pd.read_excel(file_path, usecols=['Test Scenario'])

# Initialize variables
use_case_name = ''
scenarios = []
result = []

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    test_scenario = row['Test Scenario']
    if test_scenario.endswith('.txt'):
        # If we already have a use case name, save the previous use case and its scenarios
        if use_case_name:
            result.append({
                'use_case_name': use_case_name,
                'scenarios': scenarios
            })
        # Set the new use case name and reset the scenarios list
        use_case_name = test_scenario
        scenarios = []
    else:
        # Add the scenario to the current use case's scenarios list
        scenarios.append(test_scenario)

# Add the last use case and its scenarios
if use_case_name:
    result.append({
        'use_case_name': use_case_name,
        'scenarios': scenarios
    })

# Convert the result to a JSON string
result_json = json.dumps(result, indent=4)

# Print the result
print(result_json)

# # Optionally, save the result to a JSON file
# with open('result.json', 'w') as json_file:
#     json_file.write(result_json)
# Out:
# [
#     {
#         "use_case_name": "Add a new author.txt",
#         "scenarios": [
#             "3. VerifySubmitWithValidData",
#             "4. VerifyErrorMessageForInvalidData",
#             "6. VerifyErrorMessageOnDatabaseError",
#             "8. VerifyCancelOperationBeforeDataSubmission",
#             "10. VerifyNavigationAwayDoesNotSaveData",
#             "12. VerifyMaxLengthValidationForNameField",
#             "13. VerifyMaxLengthValidationForBioField",
#             "16. VerifyUniqueNameConstraint"
#         ]
#     },
#     {
#         "use_case_name": "Add a new book.txt",
#         "scenarios": [
#             "3. VerifySubmitWithValidData",
#             "4. VerifyErrorMessageForInvalidData",
#             "6. VerifyErrorMessageOnDatabaseError",
#             "9. VerifyDataNotSavedOnCancel",
#             "10. VerifyNavigationAwayDoesNotSaveData",
#             "16. VerifyFieldValidationsWithEmptyInputs",
#             "17. VerifyFieldValidationsWithBoundaryValues",
#             "18. VerifyFieldValidationsWithSpecialCharacters",
#             "22. VerifyUniqueConstraintForBookTitle"
#         ]
#     },
#     {
#         "use_case_name": "Add a new genre.txt",
#         "scenarios": [
#             "1. SuccessfulGenreCreation",
#             "3. IncorrectDataEntry",
#             "5. DisplaySuccessMessageOnSuccessfulAddition",
#             "6. CancelOperationWithDataEntered",
#             "7. CancelOperationWithoutDataEntered",
#             "11. ValidateInputFieldsForEmptyData",
#             "12. ValidateInputFieldsForInvalidData",
#             "13. ValidateMaxLengthForNameField",
#             "14. ValidateMaxLengthForDescriptionField",
#             "16. CheckDuplicateGenreNameHandling",
#             "19. CheckErrorResponseHandlingOnDatabaseError",
#             "20. ValidateGenreCreationWithSpecialCharactersInName",
#             "21. ValidateGenreCreationWithHTMLTagsInDescription",
#             "22. CheckLoadingIndicatorDuringDataSubmission",
#             "23. ValidateNavigationToBooksMenuWithoutSaving",
#             "24. ValidateNavigationToGenresMenuWithoutSaving",
#             "25. ValidateNavigationToAuthorsMenuWithoutSaving",
#             "26. ValidateNavigationToHomeMenuWithoutSaving",
#             "27. ValidateNavigationToAPIMenuWithoutSaving"
#         ]
#     },
#     {
#         "use_case_name": "Display author details.txt",
#         "scenarios": [
#             "10. Test Scenario: Verify Navigation from Author List to Author Details"
#         ]
#     },
#     {
#         "use_case_name": "Display book details.txt",
#         "scenarios": [
#             "1. Test Display of Book Details on Click"
#         ]
#     },
#     {
#         "use_case_name": "Display genre details.txt",
#         "scenarios": [
#             "1. Test_DisplayValidGenreDetails"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of authors.txt",
#         "scenarios": [
#             "1. DisplayInitialAuthorsList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation",
#             "11. LastPageAuthorsListDisplay",
#             "12. FirstPageNavigationFromMiddlePage",
#             "13. LastPageNavigationFromMiddlePage"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of books.txt",
#         "scenarios": [
#             "1. DisplayInitialBooksList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation",
#             "4. FilterBooksByDateRange",
#             "5. DisplayBooksListWithEmptyDateRange",
#             "6. DisplayBooksListWithInvalidDateRange",
#             "7. DisplayBooksListWithSingleDate",
#             "8. DisplayBooksListWithFutureDateRange",
#             "9. DisplayBooksListWithPastDateRange",
#             "10. DisplayBooksListWithNonexistentDates",
#             "11. DisplayBooksListWithBoundaryDateRange",
#             "19. DisplayBooksListWithSpecialCharactersInDateRange"
#         ]
#     },
#     {
#         "use_case_name": "Display the list of genres.txt",
#         "scenarios": [
#             "1. DisplayInitialGenresList",
#             "2. PaginationNextButtonFunctionality",
#             "3. PaginationNumberedPageNavigation"
#         ]
#     },
#     {
#         "use_case_name": "Edit the author.txt",
#         "scenarios": [
#             "1. UpdateAuthor_SuccessfulUpdate",
#             "3. UpdateAuthor_DatabaseError",
#             "4. UpdateAuthor_CancelOperation",
#             "5. UpdateAuthor_NavigationAwayWithoutSaving",
#             "6. UpdateAuthor_EmptyNameField",
#             "7. UpdateAuthor_InvalidBioCharacters",
#             "8. UpdateAuthor_MaximumLengthExceeded_Name",
#             "9. UpdateAuthor_MaximumLengthExceeded_Bio",
#             "10. UpdateAuthor_MinimumLengthNotMet_Name",
#             "11. UpdateAuthor_MinimumLengthNotMet_Bio",
#             "12. UpdateAuthor_SpecialCharactersInName",
#             "13. UpdateAuthor_HTMLTagsInBio",
#             "14. UpdateAuthor_SQLInjection_NameField",
#             "15. UpdateAuthor_SQLInjection_BioField",
#             "16. UpdateAuthor_XSSAttack_NameField",
#             "17. UpdateAuthor_XSSAttack_BioField",
#             "18. UpdateAuthor_UpdateWithExistingAuthorName",
#             "19. UpdateAuthor_UpdateWithWhitespaceOnlyName",
#             "20. UpdateAuthor_UpdateWithWhitespaceOnlyBio"
#         ]
#     },
#     {
#         "use_case_name": "Edit the book.txt",
#         "scenarios": [
#             "1. UpdateBook_WithValidData",
#             "2. UpdateBook_WithInvalidTitle",
#             "3. UpdateBook_WithInvalidAuthor",
#             "4. UpdateBook_WithInvalidGenre",
#             "5. UpdateBook_WithInvalidDescription",
#             "6. UpdateBook_WithInvalidPublicationDate",
#             "7. UpdateBook_WithEmptyTitle",
#             "8. UpdateBook_WithEmptyAuthor",
#             "9. UpdateBook_WithEmptyGenre",
#             "10. UpdateBook_WithEmptyDescription",
#             "11. UpdateBook_WithEmptyPublicationDate",
#             "12. UpdateBook_DisplayErrorMessage_OnDatabaseError",
#             "15. CancelUpdateBook_BeforeSubmitting",
#             "16. CancelUpdateBook_AfterModifyingData",
#             "17. NavigateAwayFromUpdatePage_UsingMenuBeforeSubmitting",
#             "18. NavigateAwayFromUpdatePage_UsingMenuAfterModifyingData",
#             "19. UpdateBook_WithSpecialCharactersInTitle",
#             "20. UpdateBook_WithFuturePublicationDate",
#             "21. UpdateBook_WithPastPublicationDate",
#             "22. UpdateBook_WithNonexistentAuthor",
#             "23. UpdateBook_WithNonexistentGenre"
#         ]
#     },
#     {
#         "use_case_name": "Edit the genre.txt",
#         "scenarios": [
#             "1. UpdateGenre_SuccessfulUpdate",
#             "4. UpdateGenre_CancelOperationBeforeSubmit",
#             "5. UpdateGenre_NavigateAwayBeforeSubmit",
#             "6. UpdateGenre_RequiredFieldsMissing",
#             "7. UpdateGenre_InvalidCharactersInName",
#             "8. UpdateGenre_InvalidFormatInDescription",
#             "9. UpdateGenre_UniqueNameConstraint",
#             "11. UpdateGenre_CheckMaxLengthName",
#             "12. UpdateGenre_CheckMaxLengthDescription",
#             "13. UpdateGenre_SpecialCharactersInName",
#             "14. UpdateGenre_SpecialCharactersInDescription",
#             "15. UpdateGenre_WhitespaceInName",
#             "16. UpdateGenre_WhitespaceInDescription",
#             "17. UpdateGenre_UpdateWithSameData"
#         ]
#     },
#     {
#         "use_case_name": "Remove the author.txt",
#         "scenarios": [
#             "1. DeleteAuthor_SuccessfulDeletion",
#             "2. DeleteAuthor_CancelDeletion",
#             "6. DeleteAuthor_NavigateAwayUsingMenuBeforeDeletion",
#             "7. DeleteAuthor_NavigateAwayUsingBrowserBackBeforeDeletion",
#             "8. DeleteAuthor_MultipleDeletionsSequential"
#         ]
#     },
#     {
#         "use_case_name": "Remove the book.txt",
#         "scenarios": [
#             "1. DeleteBook_SuccessfulDeletion",
#             "2. DeleteBook_CancelDeletion"
#         ]
#     },
#     {
#         "use_case_name": "Remove the genre.txt",
#         "scenarios": [
#             "1. DeleteGenre_SuccessfulDeletion",
#             "2. DeleteGenre_CancelDeletion",
#             "4. DeleteGenre_NavigationAfterCancellation"
#         ]
#     }
# ]

# %%
import os
import csv

# Function to convert txt file content to csv
def convert_txt_to_csv(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            txt_file_path = os.path.join(folder_path, filename)
            csv_file_path = os.path.join(folder_path, f"{os.path.splitext(filename)[0]}.csv")
            
            # Read the content of the txt file
            with open(txt_file_path, 'r') as txt_file:
                content = txt_file.readlines()
            
            # Write the content to a csv file
            with open(csv_file_path, 'w', newline='') as csv_file:
                csv_writer = csv.writer(csv_file)
                
                # Write the name of the txt file in the first cell of column A
                csv_writer.writerow([filename])
                
                # Write an empty cell
                csv_writer.writerow([""])
                
                # Write the content of the txt file, each line in a new row
                for line in content:
                    csv_writer.writerow([line.strip()])

# Example usage:
folder_path =  r'D:\Dissertation-GPT\evaluate\ResultSet\5.23\0\MatchaEnglishWebsite' # Replace with your folder path
convert_txt_to_csv(folder_path)

# %%
import os
import pandas as pd
from openpyxl import Workbook

# Directory containing the txt files
directory = r'D:\Dissertation-GPT\code\thu\6.23'

# Initialize an empty dictionary to hold data for the main sheet
valid_invalid_data = []

# Initialize a dictionary to hold data for individual sheets
individual_sheets_data = {}

# Initialize a list for the Coverage sheet
coverage_data = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
        # Extract the function name
        function_name = filename.replace("-1", "").replace("-2", "").replace("-3", "").replace(".txt", "").strip()
        
        # Read the file content
        with open(os.path.join(directory, filename), 'r') as file:
            lines = file.readlines()
        
        # Prepare data for the "Valid/Invalid" sheet
        valid_invalid_data.append([function_name])
        valid_invalid_data.extend([[line.strip()] for line in lines])
        valid_invalid_data.append([''])  # Add a blank line after each file's content
        
        # Prepare data for the individual function sheet
        individual_sheets_data[function_name] = [[function_name], ['']]
        individual_sheets_data[function_name].extend([[line.strip()] for line in lines])
        
        # Prepare data for the Coverage sheet
        coverage_data.append([function_name, '', ''])

# Create a new workbook and add sheets
wb = Workbook()

# Create "Valid/Invalid" sheet
ws_valid_invalid = wb.active
ws_valid_invalid.title = "Valid Invalid"

# Write data to the "Valid/Invalid" sheet
ws_valid_invalid.append(['Test scenario'])
for row in valid_invalid_data:
    ws_valid_invalid.append(row)

# Write data to the individual function sheets
for function_name, content in individual_sheets_data.items():
    ws = wb.create_sheet(title=function_name)
    for row in content:
        ws.append(row)

# Create "Coverage" sheet
ws_coverage = wb.create_sheet(title="Coverage")
ws_coverage.append(['Use case', 'flow coverage', 'condition coverage'])
for row in coverage_data:
    ws_coverage.append(row)

# Save the workbook to an Excel file
wb.save('output_file.xlsx')
# Out:
# e:\ProgramData\anaconda3\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
import os

def print_file_names(folder_path):
    try:
        # List all files in the given directory
        for filename in os.listdir(folder_path):
            # Check if it is a file
            if os.path.isfile(os.path.join(folder_path, filename)):
                # Split the filename to remove the extension
                name, _ = os.path.splitext(filename)
                print(name)
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
folder_path = r"D:\Dissertation-GPT\dataset\SpecificationData\Hotel Management System"
print_file_names(folder_path)
# Out:
# Add Booking
# Add Employee
# Add Room
# Check in
# Check out
# Hotel Owner - Generate Reports
# Hotel Owner - Update Hotel Information
# login
# Request Service
# Update Booking
# Update Employee
# Update Room

# %%
import os

def create_summary_files(directory, path):
    # Define the names of the summary files
    directory_name = os.path.basename(directory)
    summary_file_raw = os.path.join(path, f"{directory_name}-Raw.txt")
    summary_file = os.path.join(path, f"{directory_name}.txt")

    # Initialize strings to store file contents
    raw_content = ""
    non_raw_content = ""

    # Iterate through the files in the directory
    for file_name in os.listdir(directory):
        file_path = os.path.join(directory, file_name)
        # Check if the current item is a file and not one of the summary files
        if os.path.isfile(file_path) and file_name not in [os.path.basename(summary_file_raw), os.path.basename(summary_file)]:
            # Read the file content
            with open(file_path, 'r') as file:
                content = file.read()
                # Categorize the files based on the presence of "-Raw" in the file name
                if "-Raw" in file_name:
                    raw_content += "Scenario: "+ file_name +"\n"
                    raw_content += content + "\n"
                else:
                    non_raw_content +="Scenario: "+ file_name +"\n"
                    non_raw_content += content + "\n"

    # Write the collected raw file contents to "Summary File Raw.txt"
    with open(summary_file_raw, 'w') as file:
        file.write(raw_content)

    # Write the collected non-raw file contents to "Summary File.txt"
    with open(summary_file, 'w') as file:
        file.write(non_raw_content)

# Example usage
directory_path =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"
create_summary_files(directory_path, path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 40
#      38 directory_path =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
#      39 path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"
# ---> 40 create_summary_files(directory_path, path)
#
# Cell In[15], line 30, in create_summary_files(directory, path)
#      27                 non_raw_content += content + "\n"
#      29 # Write the collected raw file contents to "Summary File Raw.txt"
# ---> 30 with open(summary_file_raw, 'w') as file:
#      31     file.write(raw_content)
#      33 # Write the collected non-raw file contents to "Summary File.txt"
#
# File e:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Dissertation-GPT\\5.25-NhuY\\Matcha\\summary test case\\AddLesson-Raw.txt'

# %%
def get_test_steps_and_expected_result(scenario, file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
        
        # Split content into individual scenarios
        scenarios = content.split("Scenario:")
        scenarios = content.strip().split('Scenario: ')
        scenarios = [s for s in scenarios if s.strip()]  # Remove empty strings if any
        for scenario_block in scenarios:
            if scenario in scenario_block:
                lines = scenario_block.strip().split("\n")
                test_steps = ""
                expected_result = ""
                for line in lines:
                    if line.startswith("testSteps:"):
                        test_steps = line.split("testSteps:")[1].strip()
                    elif line.startswith("expectedResult:"):
                        expected_result = line.split("expectedResult:")[1].strip()
                return test_steps, expected_result

        return None, None  # Scenario not found
    except FileNotFoundError:
        print("File not found.")
        return None, None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None, None

# Example usage:
scenario = "Cancel Adding New Lesson After Entering Name1"  # Replace with the actual scenario you are looking for
file_path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt"  # Replace with the actual file path
test_steps, expected_result = get_test_steps_and_expected_result(scenario, file_path)

if test_steps and expected_result:
    print("Test Steps:", test_steps)
    print("Expected Result:", expected_result)
else:
    print("Scenario not found or an error occurred.")
# Out:
# ['', " Cancel Adding New Lesson After Entering Description-Raw1.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's description.\ntestSteps:\n  - Step 1: Log in to the application as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The system should cancel the process of adding a new lesson and redirect the administrator to the previous page without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information into the description field, without the system saving any entered data. It directly tests the exception flow mentioned in the use case specification.\n\n\n", " Cancel Adding New Lesson After Entering Description-Raw2.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the lesson's description.\ntestSteps:\n  - Step 1: Log in to the application as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The process of adding a new lesson is cancelled, and the administrator is redirected away from the 'Add new Lesson' page without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information into the description field, which aligns with the exception flow of the use case specification.\n\n\n", " Cancel Adding New Lesson After Entering Description-Raw3.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Description\nobjective: Verify that the administrator can cancel the process of adding a new lesson after entering the description but before saving.\ntestSteps:\n  - Step 1: Log in as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from the dropdown menu.\n  - Step 4: Redirected to the 'Add new Lesson' page, enter a unique name for the lesson in the name field.\n  - Step 5: Enter a description for the lesson in the description field.\n  - Step 6: Select 'Cancel' to stop adding the new lesson.\nexpectedResult: The system should cancel the process of adding a new lesson and redirect the administrator back to the previous page or a main/admin dashboard without creating a new lesson.\nexplanation: This test case ensures that administrators have the ability to cancel the process of adding a new lesson after they have entered information but decided not to proceed with saving it. It directly relates to the exception flow where the administrator can select 'Cancel' to stop adding a new lesson at any time.\n\n\n", " Cancel Adding New Lesson After Entering Name-Raw1.txt\nTest Case: Test Case 1\ntestCaseName: Cancel Adding New Lesson After Entering Name\nobjective: Verify that the administrator can cancel adding a new lesson after entering the lesson name but before saving.\ntestSteps:\n  - Step 1: Log in as an administrator.\n  - Step 2: Press the tab 'Lesson Management' on the navbar.\n  - Step 3: Select 'Add new Lesson' from  ...
# Scenario not found or an error occurred.

# %%
directory =r"D:\Dissertation-GPT\5.25-NhuY\Matcha\AddLesson"  # Replace with your folder path
file_path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt"  # Replace with the actual file path
directory_name = os.path.basename(directory)
path = r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case"

# %%
import json

content = ""
with open(r"D:\Dissertation-GPT\5.25-NhuY\Matcha\summary test case\AddLesson-Raw.txt", 'r') as file:
    content = file.read()
scenarios = content.strip().split('Scenario: ')
scenarios = [s for s in scenarios if s.strip()]  # Remove empty strings if any

# Function to parse each scenario into a dictionary
def parse_scenario(scenario_text):
    lines = scenario_text.strip().split('\n')
    scenario_name = lines[0].strip()
    test_case = {}
    for line in lines[1:]:
        if line.startswith('testSteps:'):
            test_case['testSteps'] = []
            continue
        if line.startswith('  - Step '):
            test_case['testSteps'].append(line.strip())
            continue
        if ':' in line:
            key, value = line.split(':', 1)
            test_case[key.strip()] = value.strip()
    return scenario_name, test_case

# Parse all scenarios
parsed_scenarios = {}
for scenario in scenarios:
    name, details = parse_scenario(scenario)
    parsed_scenarios[name] = details


filename = os.path.join(path,directory_name) + '.json'
with open(filename, 'w') as f:
    json.dump(parsed_scenarios, f, indent=4)

# print(parsed_scenarios)
print(parsed_scenarios["Lesson Creation with Duplicate Name-Raw1.txt"]["testSteps"])
# # Write each scenario to a separate JSON file
# for scenario_name, scenario_details in parsed_scenarios.items():
#     filename = scenario_name + '.json'
#     with open(filename, 'w') as f:
#         json.dump(scenario_details, f, indent=4)

# print("JSON files created successfully.")
# Out:
# ['- Step 1: Log in as an administrator.', "- Step 2: Press the tab 'Lesson Management' on the navbar.", "- Step 3: Select 'Add new Lesson' from the dropdown menu.", "- Step 4: Enter a name that is already used by an existing lesson in the name field on the 'Add new Lesson' page.", '- Step 5: Enter a description for the lesson in the description field.', "- Step 6: Select 'Save' to attempt to create the new lesson."]
